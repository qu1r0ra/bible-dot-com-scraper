# %% [markdown]
# # Data Cleaner

# %% [markdown]
# ### Download the raw files and place them into your folder.
#
# From the scraper that CJ did, you have the raw text files. Put them in `/cleaning/yourname/raw` folder, organized per language. See `/cleaning/yna/raw` folder.

# %% [markdown]
# ### Installations

# %%
# %pip install bs4
# %pip install lxml

# %% [markdown]
# ### Imports

# %%
import re
from collections import OrderedDict
from bs4 import BeautifulSoup
import lxml 
import os
import pandas as pd
import io

# %% [markdown]
# ### Convert txt files to html files

# %%
source_parent = "cj/raw"          # IMPORTANT: your original parent folder with .txt files
output_parent = "cj/html"         # IMPORTANT: change parent folder name to your name

os.makedirs(output_parent, exist_ok=True)

for root, dirs, files in os.walk(source_parent):
    for file in files:
        if file.endswith(".txt"):
            txt_path = os.path.join(root, file)

            relative_path = os.path.relpath(root, source_parent)
            target_dir = os.path.join(output_parent, relative_path)
            os.makedirs(target_dir, exist_ok=True)

            html_filename = os.path.splitext(file)[0] + ".html"
            html_path = os.path.join(target_dir, html_filename)

            with open(txt_path, "r", encoding="utf-8") as f:
                content = f.read()

            wrapped = f"<html>\n{content}\n</html>"

            soup = BeautifulSoup(wrapped, "html.parser")
            pretty_html = soup.prettify()

            with open(html_path, "w", encoding="utf-8") as f:
                f.write(pretty_html)

            print(f"Converted {txt_path} → {html_path}")
# Out:
# Converted cj/raw/Yami/SNT_MRK_raw.txt → cj/html/Yami/SNT_MRK_raw.html
# Converted cj/raw/Yami/SNT_MAT_raw.txt → cj/html/Yami/SNT_MAT_raw.html
# Converted cj/raw/Yami/SNT_1TI_raw.txt → cj/html/Yami/SNT_1TI_raw.html
# Converted cj/raw/Yami/SNT_EPH_raw.txt → cj/html/Yami/SNT_EPH_raw.html
# Converted cj/raw/Yami/SNT_LUK_raw.txt → cj/html/Yami/SNT_LUK_raw.html
# Converted cj/raw/Yami/SNT_3JN_raw.txt → cj/html/Yami/SNT_3JN_raw.html
# Converted cj/raw/Yami/SNT_1PE_raw.txt → cj/html/Yami/SNT_1PE_raw.html
# Converted cj/raw/Yami/SNT_1TH_raw.txt → cj/html/Yami/SNT_1TH_raw.html
# Converted cj/raw/Yami/SNT_1CO_raw.txt → cj/html/Yami/SNT_1CO_raw.html
# Converted cj/raw/Yami/SNT_ROM_raw.txt → cj/html/Yami/SNT_ROM_raw.html
# Converted cj/raw/Yami/SNT_2JN_raw.txt → cj/html/Yami/SNT_2JN_raw.html
# Converted cj/raw/Yami/SNT_HEB_raw.txt → cj/html/Yami/SNT_HEB_raw.html
# Converted cj/raw/Yami/SNT_JHN_raw.txt → cj/html/Yami/SNT_JHN_raw.html
# Converted cj/raw/Yami/SNT_PHP_raw.txt → cj/html/Yami/SNT_PHP_raw.html
# Converted cj/raw/Yami/SNT_GAL_raw.txt → cj/html/Yami/SNT_GAL_raw.html
# Converted cj/raw/Yami/SNT_1JN_raw.txt → cj/html/Yami/SNT_1JN_raw.html
# Converted cj/raw/Yami/SNT_JUD_raw.txt → cj/html/Yami/SNT_JUD_raw.html
# Converted cj/raw/Yami/SNT_PHM_raw.txt → cj/html/Yami/SNT_PHM_raw.html
# Converted cj/raw/Tagalog/MBB05_TIT_raw.txt → cj/html/Tagalog/MBB05_TIT_raw.html
# Converted cj/raw/Tagalog/MBB05_JOB_raw.txt → cj/html/Tagalog/MBB05_JOB_raw.html
# Converted cj/raw/Tagalog/MBB05_2TH_raw.txt → cj/html/Tagalog/MBB05_2TH_raw.html
# Converted cj/raw/Tagalog/MBB05_2CO_raw.txt → cj/html/Tagalog/MBB05_2CO_raw.html
# Converted cj/raw/Pangasinense/PNPV_HOS_raw.txt → cj/html/Pangasinense/PNPV_HOS_raw.html
# Converted cj/raw/Pangasinense/PNPV_JUD_raw.txt → cj/html/Pangasinense/PNPV_JUD_raw.html
# Converted cj/raw/Pangasinense/PNPV_JDT_raw.txt → cj/html/Pangasinense/PNPV_JDT_raw.html
# Converted cj/raw/Pangasinense/PNPV_EST_raw.txt → cj/html/Pangasinense/PNPV_EST_raw.html
# Converted cj/raw/Pangasinense/PNPV_HAB_raw.txt → cj/html/Pangasinense/PNPV_HAB_raw.html
# Converted cj/raw/Pangasinense/PNPV_PSA_raw.txt → cj/html/Pangasinense/PNPV_PSA_raw.html
# Converted cj/raw/Pangasinense/PNPV_PHM_raw.txt → cj/html/Pangasinense/PNPV_PHM_raw.html
# Converted cj/raw/Pangasinense/PNPV_2MA_raw.txt → cj/html/Pangasinense/PNPV_2MA_raw.html
# Converted cj/raw/Pangasinense/PNPV_EZR_raw.txt → cj/html/Pangasinense/PNPV_EZR_raw.html
# Converted cj/raw/Pangasinense/PNPV_1CH_raw.txt → cj/html/Pangasinense/PNPV_1CH_raw.html
# Converted cj/raw/Pangasinense/PNPV_LAM_raw.txt → cj/html/Pangasinense/PNPV_LAM_raw.html
# Converted cj/raw/Pangasinense/PNPV_AMO_raw.txt → cj/html/Pangasinense/PNPV_AMO_raw.html
# Converted cj/raw/Pangasinense/PNPV_WIS_raw.txt → cj/html/Pangasinense/PNPV_WIS_raw.html
# Converted cj/raw/Pangasinense/PNPV_1JN_raw.txt → cj/html/Pangasinense/PNPV_1JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_GAL_raw.txt → cj/html/Pangasinense/PNPV_GAL_raw.html
# Converted cj/raw/Pangasinense/PNPV_LJE_raw.txt → cj/html/Pangasinense/PNPV_LJE_raw.html
# Converted cj/raw/Pangasinense/PNPV_ZEP_raw.txt → cj/html/Pangasinense/PNPV_ZEP_raw.html
# Converted cj/raw/Pangasinense/PNPV_BEL_raw.txt → cj/html/Pangasinense/PNPV_BEL_raw.html
# Converted cj/raw/Pangasinense/PNPV_PHP_raw.txt → cj/html/Pangasinense/PNPV_PHP_raw.html
# Converted cj/raw/Pangasinense/PNPV_2SA_raw.txt → cj/html/Pangasinense/PNPV_2SA_raw.html
# Converted cj/raw/Pangasinense/PNPV_S3Y_raw.txt → cj/html/Pangasinense/PNPV_S3Y_raw.html
# Converted cj/raw/Pangasinense/PNPV_SUS_raw.txt → cj/html/Pangasinense/PNPV_SUS_raw.html
# Converted cj/raw/Pangasinense/PNPV_2CO_raw.txt → cj/html/Pangasinense/PNPV_2CO_raw.html
# Converted cj/raw/Pangasinense/PNPV_2TH_raw.txt → cj/html/Pangasinense/PNPV_2TH_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOB_raw.txt → cj/html/Pangasinense/PNPV_JOB_raw.html
# Converted cj/raw/Pangasinense/PNPV_TIT_raw.txt → cj/html/Pangasinense/PNPV_TIT_raw.html
# Converted cj/raw/Pangasinense/PNPV_2KI_raw.txt → cj/html/Pangasinense/PNPV_2KI_raw.html
# Converted cj/raw/Pangasinense/PNPV_JAS_raw.txt → cj/html/Pangasinense/PNPV_JAS_raw.html
# Converted cj/raw/Pangasinense/PNPV_LEV_raw.txt → cj/html/Pangasinense/PNPV_LEV_raw.html
# Converted cj/raw/Pangasinense/PNPV_2PE_raw.txt → cj/html/Pangasinense/PNPV_2PE_raw.html
# Converted cj/raw/Pangasinense/PNPV_ISA_raw.txt → cj/html/Pangasinense/PNPV_ISA_raw.html
# Converted cj/raw/Pangasinense/PNPV_ACT_raw.txt → cj/html/Pangasinense/PNPV_ACT_raw.html
# Converted cj/raw/Pangasinense/PNPV_MAL_raw.txt → cj/html/Pangasinense/PNPV_MAL_raw.html
# Converted cj/raw/Pangasinense/PNPV_2TI_raw.txt → cj/html/Pangasinense/PNPV_2TI_raw.html
# Converted cj/raw/Pangasinense/PNPV_TOB_raw.txt → cj/html/Pangasinense/PNPV_TOB_raw.html
# Converted cj/raw/Pangasinense/PNPV_MIC_raw.txt → cj/html/Pangasinense/PNPV_MIC_raw.html
# Converted cj/raw/Pangasinense/PNPV_COL_raw.txt → cj/html/Pangasinense/PNPV_COL_raw.html
# Converted cj/raw/Pangasinense/PNPV_REV_raw.txt → cj/html/Pangasinense/PNPV_REV_raw.html
# Converted cj/raw/Pangasinense/PNPV_1PE_raw.txt → cj/html/Pangasinense/PNPV_1PE_raw.html
# Converted cj/raw/Pangasinense/PNPV_OBA_raw.txt → cj/html/Pangasinense/PNPV_OBA_raw.html
# Converted cj/raw/Pangasinense/PNPV_PRO_raw.txt → cj/html/Pangasinense/PNPV_PRO_raw.html
# Converted cj/raw/Pangasinense/PNPV_1KI_raw.txt → cj/html/Pangasinense/PNPV_1KI_raw.html
# Converted cj/raw/Pangasinense/PNPV_SIR_raw.txt → cj/html/Pangasinense/PNPV_SIR_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOS_raw.txt → cj/html/Pangasinense/PNPV_JOS_raw.html
# Converted cj/raw/Pangasinense/PNPV_BAR_raw.txt → cj/html/Pangasinense/PNPV_BAR_raw.html
# Converted cj/raw/Pangasinense/PNPV_1CO_raw.txt → cj/html/Pangasinense/PNPV_1CO_raw.html
# Converted cj/raw/Pangasinense/PNPV_ZEC_raw.txt → cj/html/Pangasinense/PNPV_ZEC_raw.html
# Converted cj/raw/Pangasinense/PNPV_1TH_raw.txt → cj/html/Pangasinense/PNPV_1TH_raw.html
# Converted cj/raw/Pangasinense/PNPV_3JN_raw.txt → cj/html/Pangasinense/PNPV_3JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_LUK_raw.txt → cj/html/Pangasinense/PNPV_LUK_raw.html
# Converted cj/raw/Pangasinense/PNPV_ECC_raw.txt → cj/html/Pangasinense/PNPV_ECC_raw.html
# Converted cj/raw/Pangasinense/PNPV_NAM_raw.txt → cj/html/Pangasinense/PNPV_NAM_raw.html
# Converted cj/raw/Pangasinense/PNPV_EXO_raw.txt → cj/html/Pangasinense/PNPV_EXO_raw.html
# Converted cj/raw/Pangasinense/PNPV_EPH_raw.txt → cj/html/Pangasinense/PNPV_EPH_raw.html
# Converted cj/raw/Pangasinense/PNPV_JDG_raw.txt → cj/html/Pangasinense/PNPV_JDG_raw.html
# Converted cj/raw/Pangasinense/PNPV_JON_raw.txt → cj/html/Pangasinense/PNPV_JON_raw.html
# Converted cj/raw/Pangasinense/PNPV_JER_raw.txt → cj/html/Pangasinense/PNPV_JER_raw.html
# Converted cj/raw/Pangasinense/PNPV_GEN_raw.txt → cj/html/Pangasinense/PNPV_GEN_raw.html
# Converted cj/raw/Pangasinense/PNPV_NEH_raw.txt → cj/html/Pangasinense/PNPV_NEH_raw.html
# Converted cj/raw/Pangasinense/PNPV_DAN_raw.txt → cj/html/Pangasinense/PNPV_DAN_raw.html
# Converted cj/raw/Pangasinense/PNPV_MRK_raw.txt → cj/html/Pangasinense/PNPV_MRK_raw.html
# Converted cj/raw/Pangasinense/PNPV_NUM_raw.txt → cj/html/Pangasinense/PNPV_NUM_raw.html
# Converted cj/raw/Pangasinense/PNPV_1TI_raw.txt → cj/html/Pangasinense/PNPV_1TI_raw.html
# Converted cj/raw/Pangasinense/PNPV_MAT_raw.txt → cj/html/Pangasinense/PNPV_MAT_raw.html
# Converted cj/raw/Pangasinense/PNPV_1MA_raw.txt → cj/html/Pangasinense/PNPV_1MA_raw.html
# Converted cj/raw/Pangasinense/PNPV_JHN_raw.txt → cj/html/Pangasinense/PNPV_JHN_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOL_raw.txt → cj/html/Pangasinense/PNPV_JOL_raw.html
# Converted cj/raw/Pangasinense/PNPV_2JN_raw.txt → cj/html/Pangasinense/PNPV_2JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_HEB_raw.txt → cj/html/Pangasinense/PNPV_HEB_raw.html
# Converted cj/raw/Pangasinense/PNPV_2CH_raw.txt → cj/html/Pangasinense/PNPV_2CH_raw.html
# Converted cj/raw/Pangasinense/PNPV_SNG_raw.txt → cj/html/Pangasinense/PNPV_SNG_raw.html
# Converted cj/raw/Pangasinense/PNPV_EZK_raw.txt → cj/html/Pangasinense/PNPV_EZK_raw.html
# Converted cj/raw/Pangasinense/PNPV_RUT_raw.txt → cj/html/Pangasinense/PNPV_RUT_raw.html
# Converted cj/raw/Pangasinense/PNPV_ROM_raw.txt → cj/html/Pangasinense/PNPV_ROM_raw.html
# Converted cj/raw/Pangasinense/PNPV_DEU_raw.txt → cj/html/Pangasinense/PNPV_DEU_raw.html
# Converted cj/raw/Pangasinense/PNPV_HAG_raw.txt → cj/html/Pangasinense/PNPV_HAG_raw.html
# Converted cj/raw/Pangasinense/PNPV_1SA_raw.txt → cj/html/Pangasinense/PNPV_1SA_raw.html

# %% [markdown]
# ### HTML Parser

# %%
source_parent = "cj/html"         # IMPORTANT to change
output_parent = "cj/parsed"      # IMPORTANT to change

os.makedirs(output_parent, exist_ok=True)

# %%
try:
    import lxml  # noqa: F401
    _PARSER = "lxml"
except Exception:
    _PARSER = "html.parser"

def _norm_space(s: str) -> str:
    s = re.sub(r"\s+", " ", s).strip()
    s = re.sub(r"\s+([,.;:?!])", r"\1", s)
    s = re.sub(r"\s+([”\)\]])", r"\1", s)
    return s

def parse_usfm_html(raw_html: str):
    soup = BeautifulSoup(raw_html, _PARSER)
    parts_by_usfm = OrderedDict()

    for vtag in soup.select('span.verse[data-usfm]'):
        usfm = vtag.get("data-usfm")
        if not usfm:
            continue

        for t in vtag.select("span.label, span.note"):
            t.decompose()

        frag = " ".join(s.strip() for s in vtag.stripped_strings)
        frag = _norm_space(frag)
        if frag:
            parts_by_usfm.setdefault(usfm, []).append(frag)

    rows = []
    for usfm, frags in parts_by_usfm.items():
        text = _norm_space(" ".join(frags))
        book = ch = ver = None
        try:
            book, ch, ver = usfm.split(".")
            ch = int(ch); ver = int(ver)
        except Exception:
            pass

        vmeta = soup.select_one(f'span.verse[data-usfm="{usfm}"]')
        iso = vid = None
        if vmeta:
            ver_div = vmeta.find_parent("div", class_="version")
            if ver_div:
                iso = ver_div.get("data-iso6393")
                vid = ver_div.get("data-vid")

        rows.append({
            "usfm": usfm,
            "book": book,
            "chapter": ch,
            "verse": ver,
            "text": text,
            "iso6393": iso,
            "vid": vid,
        })
    return rows

def expand_multi_usfm_rows(rows):
    """
    If a row has usfm like '1CO.5.12+1CO.5.13', split into two rows
    with identical text/metadata but separate usfm/book/chapter/verse.
    """
    out = []
    for r in rows:
        usfm = (r.get("usfm") or "").strip()
        if "+" not in usfm:
            out.append(r)
            continue

        tokens = [t.strip() for t in usfm.split("+") if t.strip()]

        def split_parts(tok, fb=None):
            parts = tok.split(".")
            if len(parts) == 3:
                b, c, v = parts[0], int(parts[1]), int(parts[2])
                return b, c, v
            if len(parts) == 1 and parts[0].isdigit() and fb:
                b, c = fb
                return b, c, int(parts[0])
            return None, None, None

        fb_b, fb_c, _ = split_parts(tokens[0], None)

        for tok in tokens:
            b, c, v = split_parts(tok, (fb_b, fb_c))
            new = r.copy()
            new["usfm"] = f"{b}.{c}.{v}" if b and c is not None and v is not None else tok
            new["book"] = b
            new["chapter"] = c
            new["verse"] = v
            out.append(new)
    return out

def rows_to_df(rows):
    df = pd.DataFrame(rows)
    if df.empty:
        for c in ["usfm","book","chapter","verse","text","iso6393","vid"]:
            if c not in df.columns:
                df[c] = pd.Series(dtype="object")
        return df

    if df[["book","chapter","verse"]].isnull().any().any():
        def split_usfm(u):
            try:
                b, c, v = u.split(".")
                return pd.Series([b, int(c), int(v)])
            except Exception:
                return pd.Series([None, None, None])
        df[["book","chapter","verse"]] = df["usfm"].apply(split_usfm)

    df = df.sort_values(["book","chapter","verse"], kind="stable").reset_index(drop=True)
    return df

# %%
if not os.path.isdir(source_parent):
    raise FileNotFoundError(f"source_parent not found: {os.path.abspath(source_parent)}")

processed = 0
empties = 0
errors = []

for root, dirs, files in os.walk(source_parent):
    for fname in files:
        if not fname.lower().endswith(".html"):
            continue
        processed += 1

        in_path = os.path.join(root, fname)
        rel = os.path.relpath(in_path, start=source_parent)

        try:
            with io.open(in_path, "r", encoding="utf-8") as f:
                raw_html = f.read()

            rows = parse_usfm_html(raw_html)
            rows = expand_multi_usfm_rows(rows)   # Split 1CO.5.12+1CO.5.13 → two rows
            df = rows_to_df(rows)

            out_base = os.path.splitext(os.path.join(output_parent, rel))[0]
            out_dir = os.path.dirname(out_base)
            os.makedirs(out_dir, exist_ok=True)

            out_csv = out_base + ".csv"
            out_txt = out_base + ".txt"

            df.to_csv(out_csv, index=False, encoding="utf-8")

            with io.open(out_txt, "w", encoding="utf-8") as f:
                for _, r in df.iterrows():
                    f.write(f"{r['usfm']} {r['text']}\n")

            if df.empty:
                empties += 1
                print(f"Empty {rel}")
            else:
                print(f"Parsed {rel} -> {os.path.basename(out_csv)}, {os.path.basename(out_txt)}")

        except Exception as e:
            errors.append((rel, str(e)))
            print(f"Error {rel}: {e}")

print("\n--- Summary ---")
print(f"Processed: {processed}")
print(f"Empty     : {empties}")
print(f"Errors    : {len(errors)}")
if errors:
    for pth, msg in errors[:5]:
        print(f" - {pth}: {msg}")
# Out:
# Parsed Yami/SNT_LUK_raw.html -> SNT_LUK_raw.csv, SNT_LUK_raw.txt
# Parsed Yami/SNT_3JN_raw.html -> SNT_3JN_raw.csv, SNT_3JN_raw.txt
# Parsed Yami/SNT_JUD_raw.html -> SNT_JUD_raw.csv, SNT_JUD_raw.txt
# Parsed Yami/SNT_1TI_raw.html -> SNT_1TI_raw.csv, SNT_1TI_raw.txt
# Parsed Yami/SNT_1TH_raw.html -> SNT_1TH_raw.csv, SNT_1TH_raw.txt
# Parsed Yami/SNT_2CO_raw.html -> SNT_2CO_raw.csv, SNT_2CO_raw.txt
# Parsed Yami/SNT_2PE_raw.html -> SNT_2PE_raw.csv, SNT_2PE_raw.txt
# Parsed Yami/SNT_1JN_raw.html -> SNT_1JN_raw.csv, SNT_1JN_raw.txt
# Parsed Yami/SNT_PHP_raw.html -> SNT_PHP_raw.csv, SNT_PHP_raw.txt
# Parsed Yami/SNT_TIT_raw.html -> SNT_TIT_raw.csv, SNT_TIT_raw.txt
# Parsed Yami/SNT_REV_raw.html -> SNT_REV_raw.csv, SNT_REV_raw.txt
# Parsed Yami/SNT_COL_raw.html -> SNT_COL_raw.csv, SNT_COL_raw.txt
# Parsed Yami/SNT_2JN_raw.html -> SNT_2JN_raw.csv, SNT_2JN_raw.txt
# Parsed Yami/SNT_MRK_raw.html -> SNT_MRK_raw.csv, SNT_MRK_raw.txt
# Parsed Yami/SNT_1PE_raw.html -> SNT_1PE_raw.csv, SNT_1PE_raw.txt
# Parsed Yami/SNT_JAS_raw.html -> SNT_JAS_raw.csv, SNT_JAS_raw.txt
# Parsed Yami/SNT_HEB_raw.html -> SNT_HEB_raw.csv, SNT_HEB_raw.txt
# Parsed Yami/SNT_PHM_raw.html -> SNT_PHM_raw.csv, SNT_PHM_raw.txt
# Parsed Yami/SNT_EPH_raw.html -> SNT_EPH_raw.csv, SNT_EPH_raw.txt
# Parsed Yami/SNT_MAT_raw.html -> SNT_MAT_raw.csv, SNT_MAT_raw.txt
# Parsed Yami/SNT_ACT_raw.html -> SNT_ACT_raw.csv, SNT_ACT_raw.txt
# Parsed Yami/SNT_GAL_raw.html -> SNT_GAL_raw.csv, SNT_GAL_raw.txt
# Parsed Yami/SNT_ROM_raw.html -> SNT_ROM_raw.csv, SNT_ROM_raw.txt
# Parsed Yami/SNT_1CO_raw.html -> SNT_1CO_raw.csv, SNT_1CO_raw.txt
# Parsed Yami/SNT_2TI_raw.html -> SNT_2TI_raw.csv, SNT_2TI_raw.txt
# Parsed Yami/SNT_2TH_raw.html -> SNT_2TH_raw.csv, SNT_2TH_raw.txt
# Parsed Yami/SNT_JHN_raw.html -> SNT_JHN_raw.csv, SNT_JHN_raw.txt
# Parsed Ivatan/VTSP_COL_raw.html -> VTSP_COL_raw.csv, VTSP_COL_raw.txt
# Parsed Ivatan/VTSP_2JN_raw.html -> VTSP_2JN_raw.csv, VTSP_2JN_raw.txt
# Parsed Ivatan/VTSP_ACT_raw.html -> VTSP_ACT_raw.csv, VTSP_ACT_raw.txt
# Parsed Ivatan/VTSP_GAL_raw.html -> VTSP_GAL_raw.csv, VTSP_GAL_raw.txt
# Parsed Ivatan/VTSP_ROM_raw.html -> VTSP_ROM_raw.csv, VTSP_ROM_raw.txt
# Parsed Ivatan/VTSP_1CO_raw.html -> VTSP_1CO_raw.csv, VTSP_1CO_raw.txt
# Parsed Ivatan/VTSP_PRO_raw.html -> VTSP_PRO_raw.csv, VTSP_PRO_raw.txt
# Parsed Ivatan/VTSP_JHN_raw.html -> VTSP_JHN_raw.csv, VTSP_JHN_raw.txt
# Parsed Ivatan/VTSP_2TI_raw.html -> VTSP_2TI_raw.csv, VTSP_2TI_raw.txt
# Parsed Ivatan/VTSP_2TH_raw.html -> VTSP_2TH_raw.csv, VTSP_2TH_raw.txt
# Parsed Ivatan/VTSP_JAS_raw.html -> VTSP_JAS_raw.csv, VTSP_JAS_raw.txt
# Parsed Ivatan/VTSP_MRK_raw.html -> VTSP_MRK_raw.csv, VTSP_MRK_raw.txt
# Parsed Ivatan/VTSP_1PE_raw.html -> VTSP_1PE_raw.csv, VTSP_1PE_raw.txt
# Parsed Ivatan/VTSP_HEB_raw.html -> VTSP_HEB_raw.csv, VTSP_HEB_raw.txt
# Parsed Ivatan/VTSP_PHM_raw.html -> VTSP_PHM_raw.csv, VTSP_PHM_raw.txt
# Parsed Ivatan/VTSP_MAT_raw.html -> VTSP_MAT_raw.csv, VTSP_MAT_raw.txt
# Parsed Ivatan/VTSP_EPH_raw.html -> VTSP_EPH_raw.csv, VTSP_EPH_raw.txt
# Parsed Ivatan/VTSP_2PE_raw.html -> VTSP_2PE_raw.csv, VTSP_2PE_raw.txt
# Parsed Ivatan/VTSP_3JN_raw.html -> VTSP_3JN_raw.csv, VTSP_3JN_raw.txt
# Parsed Ivatan/VTSP_LUK_raw.html -> VTSP_LUK_raw.csv, VTSP_LUK_raw.txt
# Parsed Ivatan/VTSP_1TI_raw.html -> VTSP_1TI_raw.csv, VTSP_1TI_raw.txt
# Parsed Ivatan/VTSP_JUD_raw.html -> VTSP_JUD_raw.csv, VTSP_JUD_raw.txt
# Parsed Ivatan/VTSP_1TH_raw.html -> VTSP_1TH_raw.csv, VTSP_1TH_raw.txt
# Parsed Ivatan/VTSP_2CO_raw.html -> VTSP_2CO_raw.csv, VTSP_2CO_raw.txt
# Parsed Ivatan/VTSP_REV_raw.html -> VTSP_REV_raw.csv, VTSP_REV_raw.txt
# Parsed Ivatan/VTSP_PSA_raw.html -> VTSP_PSA_raw.csv, VTSP_PSA_raw.txt
# Parsed Ivatan/VTSP_1JN_raw.html -> VTSP_1JN_raw.csv, VTSP_1JN_raw.txt
# Parsed Ivatan/VTSP_TIT_raw.html -> VTSP_TIT_raw.csv, VTSP_TIT_raw.txt
# Parsed Ivatan/VTSP_PHP_raw.html -> VTSP_PHP_raw.csv, VTSP_PHP_raw.txt
# Parsed Tagalog/MBB05_OBA_raw.html -> MBB05_OBA_raw.csv, MBB05_OBA_raw.txt
# Parsed Tagalog/MBB05_PSA_raw.html -> MBB05_PSA_raw.csv, MBB05_PSA_raw.txt
# Parsed Tagalog/MBB05_HAB_raw.html -> MBB05_HAB_raw.csv, MBB05_HAB_raw.txt
# Parsed Tagalog/MBB05_S3Y_raw.html -> MBB05_S3Y_raw.csv, MBB05_S3Y_raw.txt
# Parsed Tagalog/MBB05_BEL_raw.html -> MBB05_BEL_raw.csv, MBB05_BEL_raw.txt
# Parsed Tagalog/MBB05_2CH_raw.html -> MBB05_2CH_raw.csv, MBB05_2CH_raw.txt
# Parsed Tagalog/MBB05_JER_raw.html -> MBB05_JER_raw.csv, MBB05_JER_raw.txt
# Parsed Tagalog/MBB05_1KI_raw.html -> MBB05_1KI_raw.csv, MBB05_1KI_raw.txt
# Parsed Tagalog/MBB05_REV_raw.html -> MBB05_REV_raw.csv, MBB05_REV_raw.txt
# Parsed Tagalog/MBB05_ZEC_raw.html -> MBB05_ZEC_raw.csv, MBB05_ZEC_raw.txt
# Parsed Tagalog/MBB05_NAM_raw.html -> MBB05_NAM_raw.csv, MBB05_NAM_raw.txt
# Parsed Tagalog/MBB05_LEV_raw.html -> MBB05_LEV_raw.csv, MBB05_LEV_raw.txt
# Parsed Tagalog/MBB05_HOS_raw.html -> MBB05_HOS_raw.csv, MBB05_HOS_raw.txt
# Parsed Tagalog/MBB05_TIT_raw.html -> MBB05_TIT_raw.csv, MBB05_TIT_raw.txt
# Parsed Tagalog/MBB05_PHP_raw.html -> MBB05_PHP_raw.csv, MBB05_PHP_raw.txt
# Parsed Tagalog/MBB05_1JN_raw.html -> MBB05_1JN_raw.csv, MBB05_1JN_raw.txt
# Parsed Tagalog/MBB05_JDT_raw.html -> MBB05_JDT_raw.csv, MBB05_JDT_raw.txt
# Parsed Tagalog/MBB05_SIR_raw.html -> MBB05_SIR_raw.csv, MBB05_SIR_raw.txt
# Parsed Tagalog/MBB05_EZR_raw.html -> MBB05_EZR_raw.csv, MBB05_EZR_raw.txt
# Parsed Tagalog/MBB05_EXO_raw.html -> MBB05_EXO_raw.csv, MBB05_EXO_raw.txt
# Parsed Tagalog/MBB05_2SA_raw.html -> MBB05_2SA_raw.csv, MBB05_2SA_raw.txt
# Parsed Tagalog/MBB05_RUT_raw.html -> MBB05_RUT_raw.csv, MBB05_RUT_raw.txt
# Parsed Tagalog/MBB05_LAM_raw.html -> MBB05_LAM_raw.csv, MBB05_LAM_raw.txt
# Parsed Tagalog/MBB05_ZEP_raw.html -> MBB05_ZEP_raw.csv, MBB05_ZEP_raw.txt
# Parsed Tagalog/MBB05_JOL_raw.html -> MBB05_JOL_raw.csv, MBB05_JOL_raw.txt
# Parsed Tagalog/MBB05_NUM_raw.html -> MBB05_NUM_raw.csv, MBB05_NUM_raw.txt
# Parsed Tagalog/MBB05_2PE_raw.html -> MBB05_2PE_raw.csv, MBB05_2PE_raw.txt
# Parsed Tagalog/MBB05_1TH_raw.html -> MBB05_1TH_raw.csv, MBB05_1TH_raw.txt
# Parsed Tagalog/MBB05_JUD_raw.html -> MBB05_JUD_raw.csv, MBB05_JUD_raw.txt
# Parsed Tagalog/MBB05_1TI_raw.html -> MBB05_1TI_raw.csv, MBB05_1TI_raw.txt
# Parsed Tagalog/MBB05_EZK_raw.html -> MBB05_EZK_raw.csv, MBB05_EZK_raw.txt
# Parsed Tagalog/MBB05_NEH_raw.html -> MBB05_NEH_raw.csv, MBB05_NEH_raw.txt
# Parsed Tagalog/MBB05_2CO_raw.html -> MBB05_2CO_raw.csv, MBB05_2CO_raw.txt
# Parsed Tagalog/MBB05_JOS_raw.html -> MBB05_JOS_raw.csv, MBB05_JOS_raw.txt
# Parsed Tagalog/MBB05_ISA_raw.html -> MBB05_ISA_raw.csv, MBB05_ISA_raw.txt
# Parsed Tagalog/MBB05_2MA_raw.html -> MBB05_2MA_raw.csv, MBB05_2MA_raw.txt
# Parsed Tagalog/MBB05_SNG_raw.html -> MBB05_SNG_raw.csv, MBB05_SNG_raw.txt
# Parsed Tagalog/MBB05_JDG_raw.html -> MBB05_JDG_raw.csv, MBB05_JDG_raw.txt
# Parsed Tagalog/MBB05_3JN_raw.html -> MBB05_3JN_raw.csv, MBB05_3JN_raw.txt
# Parsed Tagalog/MBB05_LUK_raw.html -> MBB05_LUK_raw.csv, MBB05_LUK_raw.txt
# Parsed Tagalog/MBB05_ROM_raw.html -> MBB05_ROM_raw.csv, MBB05_ROM_raw.txt
# Parsed Tagalog/MBB05_1CO_raw.html -> MBB05_1CO_raw.csv, MBB05_1CO_raw.txt
# Parsed Tagalog/MBB05_PRO_raw.html -> MBB05_PRO_raw.csv, MBB05_PRO_raw.txt
# Parsed Tagalog/MBB05_JHN_raw.html -> MBB05_JHN_raw.csv, MBB05_JHN_raw.txt
# Parsed Tagalog/MBB05_DEU_raw.html -> MBB05_DEU_raw.csv, MBB05_DEU_raw.txt
# Parsed Tagalog/MBB05_GEN_raw.html -> MBB05_GEN_raw.csv, MBB05_GEN_raw.txt
# Parsed Tagalog/MBB05_2TH_raw.html -> MBB05_2TH_raw.csv, MBB05_2TH_raw.txt
# Parsed Tagalog/MBB05_2TI_raw.html -> MBB05_2TI_raw.csv, MBB05_2TI_raw.txt
# Parsed Tagalog/MBB05_SUS_raw.html -> MBB05_SUS_raw.csv, MBB05_SUS_raw.txt
# Parsed Tagalog/MBB05_JOB_raw.html -> MBB05_JOB_raw.csv, MBB05_JOB_raw.txt
# Parsed Tagalog/MBB05_BAR_raw.html -> MBB05_BAR_raw.csv, MBB05_BAR_raw.txt
# Parsed Tagalog/MBB05_ACT_raw.html -> MBB05_ACT_raw.csv, MBB05_ACT_raw.txt
# Parsed Tagalog/MBB05_1MA_raw.html -> MBB05_1MA_raw.csv, MBB05_1MA_raw.txt
# Parsed Tagalog/MBB05_ECC_raw.html -> MBB05_ECC_raw.csv, MBB05_ECC_raw.txt
# Parsed Tagalog/MBB05_TOB_raw.html -> MBB05_TOB_raw.csv, MBB05_TOB_raw.txt
# Parsed Tagalog/MBB05_GAL_raw.html -> MBB05_GAL_raw.csv, MBB05_GAL_raw.txt
# Parsed Tagalog/MBB05_AMO_raw.html -> MBB05_AMO_raw.csv, MBB05_AMO_raw.txt
# Parsed Tagalog/MBB05_HEB_raw.html -> MBB05_HEB_raw.csv, MBB05_HEB_raw.txt
# Parsed Tagalog/MBB05_WIS_raw.html -> MBB05_WIS_raw.csv, MBB05_WIS_raw.txt
# Parsed Tagalog/MBB05_PHM_raw.html -> MBB05_PHM_raw.csv, MBB05_PHM_raw.txt
# Parsed Tagalog/MBB05_1SA_raw.html -> MBB05_1SA_raw.csv, MBB05_1SA_raw.txt
# Parsed Tagalog/MBB05_EPH_raw.html -> MBB05_EPH_raw.csv, MBB05_EPH_raw.txt
# Parsed Tagalog/MBB05_MAT_raw.html -> MBB05_MAT_raw.csv, MBB05_MAT_raw.txt
# Parsed Tagalog/MBB05_JAS_raw.html -> MBB05_JAS_raw.csv, MBB05_JAS_raw.txt
# Parsed Tagalog/MBB05_MRK_raw.html -> MBB05_MRK_raw.csv, MBB05_MRK_raw.txt
# Parsed Tagalog/MBB05_1PE_raw.html -> MBB05_1PE_raw.csv, MBB05_1PE_raw.txt
# Parsed Tagalog/MBB05_DAN_raw.html -> MBB05_DAN_raw.csv, MBB05_DAN_raw.txt
# Parsed Tagalog/MBB05_MIC_raw.html -> MBB05_MIC_raw.csv, MBB05_MIC_raw.txt
# Parsed Tagalog/MBB05_LJE_raw.html -> MBB05_LJE_raw.csv, MBB05_LJE_raw.txt
# Parsed Tagalog/MBB05_COL_raw.html -> MBB05_COL_raw.csv, MBB05_COL_raw.txt
# Parsed Tagalog/MBB05_HAG_raw.html -> MBB05_HAG_raw.csv, MBB05_HAG_raw.txt
# Parsed Tagalog/MBB05_2JN_raw.html -> MBB05_2JN_raw.csv, MBB05_2JN_raw.txt
# Parsed Tagalog/MBB05_1CH_raw.html -> MBB05_1CH_raw.csv, MBB05_1CH_raw.txt
# Parsed Tagalog/MBB05_JON_raw.html -> MBB05_JON_raw.csv, MBB05_JON_raw.txt
# Parsed Tagalog/MBB05_EST_raw.html -> MBB05_EST_raw.csv, MBB05_EST_raw.txt
# Parsed Tagalog/MBB05_MAL_raw.html -> MBB05_MAL_raw.csv, MBB05_MAL_raw.txt
# Parsed Tagalog/MBB05_2KI_raw.html -> MBB05_2KI_raw.csv, MBB05_2KI_raw.txt
# Parsed Pangasinense/PNPV_2SA_raw.html -> PNPV_2SA_raw.csv, PNPV_2SA_raw.txt
# Parsed Pangasinense/PNPV_RUT_raw.html -> PNPV_RUT_raw.csv, PNPV_RUT_raw.txt
# Parsed Pangasinense/PNPV_JOL_raw.html -> PNPV_JOL_raw.csv, PNPV_JOL_raw.txt
# Parsed Pangasinense/PNPV_ZEP_raw.html -> PNPV_ZEP_raw.csv, PNPV_ZEP_raw.txt
# Parsed Pangasinense/PNPV_NUM_raw.html -> PNPV_NUM_raw.csv, PNPV_NUM_raw.txt
# Parsed Pangasinense/PNPV_LAM_raw.html -> PNPV_LAM_raw.csv, PNPV_LAM_raw.txt
# Parsed Pangasinense/PNPV_2PE_raw.html -> PNPV_2PE_raw.csv, PNPV_2PE_raw.txt
# Parsed Pangasinense/PNPV_JUD_raw.html -> PNPV_JUD_raw.csv, PNPV_JUD_raw.txt
# Parsed Pangasinense/PNPV_1TI_raw.html -> PNPV_1TI_raw.csv, PNPV_1TI_raw.txt
# Parsed Pangasinense/PNPV_1TH_raw.html -> PNPV_1TH_raw.csv, PNPV_1TH_raw.txt
# Parsed Pangasinense/PNPV_EZK_raw.html -> PNPV_EZK_raw.csv, PNPV_EZK_raw.txt
# Parsed Pangasinense/PNPV_2CO_raw.html -> PNPV_2CO_raw.csv, PNPV_2CO_raw.txt
# Parsed Pangasinense/PNPV_JOS_raw.html -> PNPV_JOS_raw.csv, PNPV_JOS_raw.txt
# Parsed Pangasinense/PNPV_NEH_raw.html -> PNPV_NEH_raw.csv, PNPV_NEH_raw.txt
# Parsed Pangasinense/PNPV_ISA_raw.html -> PNPV_ISA_raw.csv, PNPV_ISA_raw.txt
# Parsed Pangasinense/PNPV_2MA_raw.html -> PNPV_2MA_raw.csv, PNPV_2MA_raw.txt
# Parsed Pangasinense/PNPV_SNG_raw.html -> PNPV_SNG_raw.csv, PNPV_SNG_raw.txt
# Parsed Pangasinense/PNPV_LUK_raw.html -> PNPV_LUK_raw.csv, PNPV_LUK_raw.txt
# Parsed Pangasinense/PNPV_JDG_raw.html -> PNPV_JDG_raw.csv, PNPV_JDG_raw.txt
# Parsed Pangasinense/PNPV_3JN_raw.html -> PNPV_3JN_raw.csv, PNPV_3JN_raw.txt
# Parsed Pangasinense/PNPV_S3Y_raw.html -> PNPV_S3Y_raw.csv, PNPV_S3Y_raw.txt
# Parsed Pangasinense/PNPV_HAB_raw.html -> PNPV_HAB_raw.csv, PNPV_HAB_raw.txt
# Parsed Pangasinense/PNPV_PSA_raw.html -> PNPV_PSA_raw.csv, PNPV_PSA_raw.txt
# Parsed Pangasinense/PNPV_OBA_raw.html -> PNPV_OBA_raw.csv, PNPV_OBA_raw.txt
# Parsed Pangasinense/PNPV_2CH_raw.html -> PNPV_2CH_raw.csv, PNPV_2CH_raw.txt
# Parsed Pangasinense/PNPV_BEL_raw.html -> PNPV_BEL_raw.csv, PNPV_BEL_raw.txt
# Parsed Pangasinense/PNPV_REV_raw.html -> PNPV_REV_raw.csv, PNPV_REV_raw.txt
# Parsed Pangasinense/PNPV_1KI_raw.html -> PNPV_1KI_raw.csv, PNPV_1KI_raw.txt
# Parsed Pangasinense/PNPV_JER_raw.html -> PNPV_JER_raw.csv, PNPV_JER_raw.txt
# Parsed Pangasinense/PNPV_LEV_raw.html -> PNPV_LEV_raw.csv, PNPV_LEV_raw.txt
# Parsed Pangasinense/PNPV_NAM_raw.html -> PNPV_NAM_raw.csv, PNPV_NAM_raw.txt
# Parsed Pangasinense/PNPV_ZEC_raw.html -> PNPV_ZEC_raw.csv, PNPV_ZEC_raw.txt
# Parsed Pangasinense/PNPV_HOS_raw.html -> PNPV_HOS_raw.csv, PNPV_HOS_raw.txt
# Parsed Pangasinense/PNPV_PHP_raw.html -> PNPV_PHP_raw.csv, PNPV_PHP_raw.txt
# Parsed Pangasinense/PNPV_TIT_raw.html -> PNPV_TIT_raw.csv, PNPV_TIT_raw.txt
# Parsed Pangasinense/PNPV_JDT_raw.html -> PNPV_JDT_raw.csv, PNPV_JDT_raw.txt
# Parsed Pangasinense/PNPV_SIR_raw.html -> PNPV_SIR_raw.csv, PNPV_SIR_raw.txt
# Parsed Pangasinense/PNPV_1JN_raw.html -> PNPV_1JN_raw.csv, PNPV_1JN_raw.txt
# Parsed Pangasinense/PNPV_EXO_raw.html -> PNPV_EXO_raw.csv, PNPV_EXO_raw.txt
# Parsed Pangasinense/PNPV_EZR_raw.html -> PNPV_EZR_raw.csv, PNPV_EZR_raw.txt
# Parsed Pangasinense/PNPV_MIC_raw.html -> PNPV_MIC_raw.csv, PNPV_MIC_raw.txt
# Parsed Pangasinense/PNPV_DAN_raw.html -> PNPV_DAN_raw.csv, PNPV_DAN_raw.txt
# Parsed Pangasinense/PNPV_LJE_raw.html -> PNPV_LJE_raw.csv, PNPV_LJE_raw.txt
# Parsed Pangasinense/PNPV_HAG_raw.html -> PNPV_HAG_raw.csv, PNPV_HAG_raw.txt
# Parsed Pangasinense/PNPV_COL_raw.html -> PNPV_COL_raw.csv, PNPV_COL_raw.txt
# Parsed Pangasinense/PNPV_2JN_raw.html -> PNPV_2JN_raw.csv, PNPV_2JN_raw.txt
# Parsed Pangasinense/PNPV_JON_raw.html -> PNPV_JON_raw.csv, PNPV_JON_raw.txt
# Parsed Pangasinense/PNPV_1CH_raw.html -> PNPV_1CH_raw.csv, PNPV_1CH_raw.txt
# Parsed Pangasinense/PNPV_EST_raw.html -> PNPV_EST_raw.csv, PNPV_EST_raw.txt
# Parsed Pangasinense/PNPV_MAL_raw.html -> PNPV_MAL_raw.csv, PNPV_MAL_raw.txt
# Parsed Pangasinense/PNPV_2KI_raw.html -> PNPV_2KI_raw.csv, PNPV_2KI_raw.txt
# Parsed Pangasinense/PNPV_PRO_raw.html -> PNPV_PRO_raw.csv, PNPV_PRO_raw.txt
# Parsed Pangasinense/PNPV_1CO_raw.html -> PNPV_1CO_raw.csv, PNPV_1CO_raw.txt
# Parsed Pangasinense/PNPV_ROM_raw.html -> PNPV_ROM_raw.csv, PNPV_ROM_raw.txt
# Parsed Pangasinense/PNPV_2TI_raw.html -> PNPV_2TI_raw.csv, PNPV_2TI_raw.txt
# Parsed Pangasinense/PNPV_GEN_raw.html -> PNPV_GEN_raw.csv, PNPV_GEN_raw.txt
# Parsed Pangasinense/PNPV_2TH_raw.html -> PNPV_2TH_raw.csv, PNPV_2TH_raw.txt
# Parsed Pangasinense/PNPV_SUS_raw.html -> PNPV_SUS_raw.csv, PNPV_SUS_raw.txt
# Parsed Pangasinense/PNPV_DEU_raw.html -> PNPV_DEU_raw.csv, PNPV_DEU_raw.txt
# Parsed Pangasinense/PNPV_JHN_raw.html -> PNPV_JHN_raw.csv, PNPV_JHN_raw.txt
# Parsed Pangasinense/PNPV_ACT_raw.html -> PNPV_ACT_raw.csv, PNPV_ACT_raw.txt
# Parsed Pangasinense/PNPV_JOB_raw.html -> PNPV_JOB_raw.csv, PNPV_JOB_raw.txt
# Parsed Pangasinense/PNPV_BAR_raw.html -> PNPV_BAR_raw.csv, PNPV_BAR_raw.txt
# Parsed Pangasinense/PNPV_TOB_raw.html -> PNPV_TOB_raw.csv, PNPV_TOB_raw.txt
# Parsed Pangasinense/PNPV_GAL_raw.html -> PNPV_GAL_raw.csv, PNPV_GAL_raw.txt
# Parsed Pangasinense/PNPV_1MA_raw.html -> PNPV_1MA_raw.csv, PNPV_1MA_raw.txt
# Parsed Pangasinense/PNPV_ECC_raw.html -> PNPV_ECC_raw.csv, PNPV_ECC_raw.txt
# Parsed Pangasinense/PNPV_PHM_raw.html -> PNPV_PHM_raw.csv, PNPV_PHM_raw.txt
# Parsed Pangasinense/PNPV_WIS_raw.html -> PNPV_WIS_raw.csv, PNPV_WIS_raw.txt
# Parsed Pangasinense/PNPV_HEB_raw.html -> PNPV_HEB_raw.csv, PNPV_HEB_raw.txt
# Parsed Pangasinense/PNPV_AMO_raw.html -> PNPV_AMO_raw.csv, PNPV_AMO_raw.txt
# Parsed Pangasinense/PNPV_EPH_raw.html -> PNPV_EPH_raw.csv, PNPV_EPH_raw.txt
# Parsed Pangasinense/PNPV_MAT_raw.html -> PNPV_MAT_raw.csv, PNPV_MAT_raw.txt
# Parsed Pangasinense/PNPV_1SA_raw.html -> PNPV_1SA_raw.csv, PNPV_1SA_raw.txt
# Parsed Pangasinense/PNPV_1PE_raw.html -> PNPV_1PE_raw.csv, PNPV_1PE_raw.txt
# Parsed Pangasinense/PNPV_MRK_raw.html -> PNPV_MRK_raw.csv, PNPV_MRK_raw.txt
# Parsed Pangasinense/PNPV_JAS_raw.html -> PNPV_JAS_raw.csv, PNPV_JAS_raw.txt
#
# --- Summary ---
# Processed: 210
# Empty     : 0
# Errors    : 0
