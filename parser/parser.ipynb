# %% [markdown]
# # Data Parser

# %% [markdown]
# ### Installations

# %%
# %pip install bs4
# %pip install lxml

# %% [markdown]
# ### Imports

# %%
import re
from collections import OrderedDict
from bs4 import BeautifulSoup
import lxml 
import os
import glob
import pandas as pd
import io
import csv
from typing import List

# %% [markdown]
# ## By verse

# %% [markdown]
# ### Step 1: Download the raw files and place them into your folder
#
# From the data scraper, the output are raw data in .txt files. Put them in `/parser/yourname/raw` folder. See `/parser/yna/raw` folder. So, the folder structure is as follows.
# ```
# /parser
# -- /yourname
# ---- /language1
# -------- text files here
# ---- /language2
# ---- /language3
# ---- /language4
# ```

# %% [markdown]
# ### Step 2: Convert Raw TXT Files into Clean HTML
# After scraping, the resulting files were saved as `.txt` documents, but their contents still contained raw HTML fragments such as `<div>`, `<span>`, and other tags. To standardize and clean these files, we implemented a conversion pipeline that transforms the raw text into properly structured `.html` files. This pipeline automates the cleanup of scraped `.txt` files across multiple language datasets, standardizing them into well-formed HTML files while preserving the original folder hierarchy.
#
# **Source Language Directories**
#    The script is configured to process multiple languages at once. Each entry in `LANG_DIRS` corresponds to a folder containing raw `.txt` files (e.g., `yna/raw/Cebuano`, `yna/raw/Spanish`, etc.). Commented-out entries can be enabled later when needed.
#
# **Folder Mapping (Raw → HTML)**
#    - The variable `SRC = "raw"` defines the source segment of the path.
#    - The variable `DST = "html"` defines the target segment.
#    - The helper function `swap_segment` replaces `"raw"` with `"html"` in a given path so that outputs mirror the original folder structure.
#
# **Conversion Process**
# - The `convert_tree` function traverses each source folder recursively.
# - For every `.txt` file found, it creates a corresponding `.html` file in the mirrored output directory.
# - Files are wrapped with a minimal `<html> ... </html>` block, parsed with BeautifulSoup, and then prettified to ensure clean and valid HTML formatting.
# - If a file cannot be decoded with UTF-8, the script falls back to `latin-1` encoding to prevent crashes.
#
# **Execution Flow**
# - The main loop iterates through all `LANG_DIRS`.
# - For each language folder, the script ensures that the destination directory exists.
# - The conversion runs and counts how many files were successfully transformed.
# - A log message prints the mapping for every file processed.
#
# **Completion Summary**
# After processing all directories, the script prints the total number of `.txt` files converted into `.html`. This ensures visibility into the batch operation and confirms that all language folders were handled consistently.

# %%
# CHANGE: List all source folders that contain .txt files
LANG_DIRS = [
    "yna/raw/Cebuano",
    "yna/raw/Spanish",
    "yna/raw/Chavacano",
    "yna/raw/Tausug",
    "cj/raw/Ivatan",
    "cj/raw/Pangasinense",
    "cj/raw/Tagalog",
    "cj/raw/Yami",
    "trish/raw/Bikolano",
    "trish/raw/Ilokano",
    "trish/raw/Kalinga",
    "trish/raw/Kapampangan",
    "enz/raw/Isnag",
    "enz/raw/Kankanaey",
    "enz/raw/Sambal",
    "enz/raw/Yakan",
]

SRC_SEGMENT = "raw"   
DST_SEGMENT = "html"

# %%
# helper functions
def swap_segment(path: str, old: str, new: str) -> str:
    parts = path.split(os.sep)
    for i, p in enumerate(parts):
        if p == old:
            parts[i] = new
            return os.sep.join(parts)
    parent, leaf = os.path.split(path)
    return os.path.join(os.path.dirname(parent), new, leaf)

def convert_tree(src_root: str, dst_root: str) -> int:
    files_converted = 0
    for root, _, files in os.walk(src_root):
        rel = os.path.relpath(root, src_root)
        target_dir = dst_root if rel == "." else os.path.join(dst_root, rel)
        os.makedirs(target_dir, exist_ok=True)

        for name in files:
            if not name.lower().endswith(".txt"):
                continue

            txt_path = os.path.join(root, name)
            html_name = os.path.splitext(name)[0] + ".html"
            html_path = os.path.join(target_dir, html_name)

            try:
                with open(txt_path, "r", encoding="utf-8") as f:
                    content = f.read()
            except UnicodeDecodeError:
                with open(txt_path, "r", encoding="latin-1") as f:
                    content = f.read()

            wrapped = f"<html>\n{content}\n</html>"
            soup = BeautifulSoup(wrapped, "html.parser")
            pretty_html = soup.prettify()

            with open(html_path, "w", encoding="utf-8") as f:
                f.write(pretty_html)

            files_converted += 1
            print(f"Converted {txt_path} → {html_path}")
    return files_converted

# %%
# main
total = 0
for src in LANG_DIRS:
    dst = swap_segment(src, SRC_SEGMENT, DST_SEGMENT)
    os.makedirs(dst, exist_ok=True)
    print(f"\nFolder {src} → {dst}")
    total += convert_tree(src, dst)

print(f"\nDone. Converted {total} file(s).")
# Out:
# Folder yna/raw/Cebuano → yna/html/Cebuano
# Converted yna/raw/Cebuano/ABCEB_PHP_raw.txt → yna/html/Cebuano/ABCEB_PHP_raw.html
# Converted yna/raw/Cebuano/ABCEB_ZEP_raw.txt → yna/html/Cebuano/ABCEB_ZEP_raw.html
# Converted yna/raw/Cebuano/ABCEB_2SA_raw.txt → yna/html/Cebuano/ABCEB_2SA_raw.html
# Converted yna/raw/Cebuano/ABCEB_PSA_raw.txt → yna/html/Cebuano/ABCEB_PSA_raw.html
# Converted yna/raw/Cebuano/ABCEB_HAB_raw.txt → yna/html/Cebuano/ABCEB_HAB_raw.html
# Converted yna/raw/Cebuano/ABCEB_EZR_raw.txt → yna/html/Cebuano/ABCEB_EZR_raw.html
# Converted yna/raw/Cebuano/ABCEB_PHM_raw.txt → yna/html/Cebuano/ABCEB_PHM_raw.html
# Converted yna/raw/Cebuano/ABCEB_HOS_raw.txt → yna/html/Cebuano/ABCEB_HOS_raw.html
# Converted yna/raw/Cebuano/ABCEB_JUD_raw.txt → yna/html/Cebuano/ABCEB_JUD_raw.html
# Converted yna/raw/Cebuano/ABCEB_EST_raw.txt → yna/html/Cebuano/ABCEB_EST_raw.html
# Converted yna/raw/Cebuano/ABCEB_1JN_raw.txt → yna/html/Cebuano/ABCEB_1JN_raw.html
# Converted yna/raw/Cebuano/ABCEB_GAL_raw.txt → yna/html/Cebuano/ABCEB_GAL_raw.html
# Converted yna/raw/Cebuano/ABCEB_1CH_raw.txt → yna/html/Cebuano/ABCEB_1CH_raw.html
# Converted yna/raw/Cebuano/ABCEB_LAM_raw.txt → yna/html/Cebuano/ABCEB_LAM_raw.html
# Converted yna/raw/Cebuano/ABCEB_AMO_raw.txt → yna/html/Cebuano/ABCEB_AMO_raw.html
# Converted yna/raw/Cebuano/ABCEB_MAL_raw.txt → yna/html/Cebuano/ABCEB_MAL_raw.html
# Converted yna/raw/Cebuano/ABCEB_MIC_raw.txt → yna/html/Cebuano/ABCEB_MIC_raw.html
# Converted yna/raw/Cebuano/ABCEB_COL_raw.txt → yna/html/Cebuano/ABCEB_COL_raw.html
# Converted yna/raw/Cebuano/ABCEB_REV_raw.txt → yna/html/Cebuano/ABCEB_REV_raw.html
# Converted yna/raw/Cebuano/ABCEB_2TI_raw.txt → yna/html/Cebuano/ABCEB_2TI_raw.html
# Converted yna/raw/Cebuano/ABCEB_2KI_raw.txt → yna/html/Cebuano/ABCEB_2KI_raw.html
# Converted yna/raw/Cebuano/ABCEB_LEV_raw.txt → yna/html/Cebuano/ABCEB_LEV_raw.html
# Converted yna/raw/Cebuano/ABCEB_JAS_raw.txt → yna/html/Cebuano/ABCEB_JAS_raw.html
# Converted yna/raw/Cebuano/ABCEB_2PE_raw.txt → yna/html/Cebuano/ABCEB_2PE_raw.html
# Converted yna/raw/Cebuano/ABCEB_2CO_raw.txt → yna/html/Cebuano/ABCEB_2CO_raw.html
# Converted yna/raw/Cebuano/ABCEB_2TH_raw.txt → yna/html/Cebuano/ABCEB_2TH_raw.html
# Converted yna/raw/Cebuano/ABCEB_JOB_raw.txt → yna/html/Cebuano/ABCEB_JOB_raw.html
# Converted yna/raw/Cebuano/ABCEB_TIT_raw.txt → yna/html/Cebuano/ABCEB_TIT_raw.html
# Converted yna/raw/Cebuano/ABCEB_ACT_raw.txt → yna/html/Cebuano/ABCEB_ACT_raw.html
# Converted yna/raw/Cebuano/ABCEB_ISA_raw.txt → yna/html/Cebuano/ABCEB_ISA_raw.html
# Converted yna/raw/Cebuano/ABCEB_JDG_raw.txt → yna/html/Cebuano/ABCEB_JDG_raw.html
# Converted yna/raw/Cebuano/ABCEB_JON_raw.txt → yna/html/Cebuano/ABCEB_JON_raw.html
# Converted yna/raw/Cebuano/ABCEB_GEN_raw.txt → yna/html/Cebuano/ABCEB_GEN_raw.html
# Converted yna/raw/Cebuano/ABCEB_JER_raw.txt → yna/html/Cebuano/ABCEB_JER_raw.html
# Converted yna/raw/Cebuano/ABCEB_EPH_raw.txt → yna/html/Cebuano/ABCEB_EPH_raw.html
# Converted yna/raw/Cebuano/ABCEB_1TI_raw.txt → yna/html/Cebuano/ABCEB_1TI_raw.html
# Converted yna/raw/Cebuano/ABCEB_MAT_raw.txt → yna/html/Cebuano/ABCEB_MAT_raw.html
# Converted yna/raw/Cebuano/ABCEB_NEH_raw.txt → yna/html/Cebuano/ABCEB_NEH_raw.html
# Converted yna/raw/Cebuano/ABCEB_DAN_raw.txt → yna/html/Cebuano/ABCEB_DAN_raw.html
# Converted yna/raw/Cebuano/ABCEB_MRK_raw.txt → yna/html/Cebuano/ABCEB_MRK_raw.html
# Converted yna/raw/Cebuano/ABCEB_NUM_raw.txt → yna/html/Cebuano/ABCEB_NUM_raw.html
# Converted yna/raw/Cebuano/ABCEB_JOS_raw.txt → yna/html/Cebuano/ABCEB_JOS_raw.html
# Converted yna/raw/Cebuano/ABCEB_1CO_raw.txt → yna/html/Cebuano/ABCEB_1CO_raw.html
# Converted yna/raw/Cebuano/ABCEB_1TH_raw.txt → yna/html/Cebuano/ABCEB_1TH_raw.html
# Converted yna/raw/Cebuano/ABCEB_ZEC_raw.txt → yna/html/Cebuano/ABCEB_ZEC_raw.html
# Converted yna/raw/Cebuano/ABCEB_1PE_raw.txt → yna/html/Cebuano/ABCEB_1PE_raw.html
# Converted yna/raw/Cebuano/ABCEB_PRO_raw.txt → yna/html/Cebuano/ABCEB_PRO_raw.html
# Converted yna/raw/Cebuano/ABCEB_OBA_raw.txt → yna/html/Cebuano/ABCEB_OBA_raw.html
# Converted yna/raw/Cebuano/ABCEB_1KI_raw.txt → yna/html/Cebuano/ABCEB_1KI_raw.html
# Converted yna/raw/Cebuano/ABCEB_ECC_raw.txt → yna/html/Cebuano/ABCEB_ECC_raw.html
# Converted yna/raw/Cebuano/ABCEB_NAM_raw.txt → yna/html/Cebuano/ABCEB_NAM_raw.html
# Converted yna/raw/Cebuano/ABCEB_EXO_raw.txt → yna/html/Cebuano/ABCEB_EXO_raw.html
# Converted yna/raw/Cebuano/ABCEB_3JN_raw.txt → yna/html/Cebuano/ABCEB_3JN_raw.html
# Converted yna/raw/Cebuano/ABCEB_LUK_raw.txt → yna/html/Cebuano/ABCEB_LUK_raw.html
# Converted yna/raw/Cebuano/ABCEB_DEU_raw.txt → yna/html/Cebuano/ABCEB_DEU_raw.html
# Converted yna/raw/Cebuano/ABCEB_SNG_raw.txt → yna/html/Cebuano/ABCEB_SNG_raw.html
# Converted yna/raw/Cebuano/ABCEB_EZK_raw.txt → yna/html/Cebuano/ABCEB_EZK_raw.html
# Converted yna/raw/Cebuano/ABCEB_RUT_raw.txt → yna/html/Cebuano/ABCEB_RUT_raw.html
# Converted yna/raw/Cebuano/ABCEB_ROM_raw.txt → yna/html/Cebuano/ABCEB_ROM_raw.html
# Converted yna/raw/Cebuano/ABCEB_1SA_raw.txt → yna/html/Cebuano/ABCEB_1SA_raw.html
# Converted yna/raw/Cebuano/ABCEB_HAG_raw.txt → yna/html/Cebuano/ABCEB_HAG_raw.html
# Converted yna/raw/Cebuano/ABCEB_JHN_raw.txt → yna/html/Cebuano/ABCEB_JHN_raw.html
# Converted yna/raw/Cebuano/ABCEB_JOL_raw.txt → yna/html/Cebuano/ABCEB_JOL_raw.html
# Converted yna/raw/Cebuano/ABCEB_HEB_raw.txt → yna/html/Cebuano/ABCEB_HEB_raw.html
# Converted yna/raw/Cebuano/ABCEB_2CH_raw.txt → yna/html/Cebuano/ABCEB_2CH_raw.html
# Converted yna/raw/Cebuano/ABCEB_2JN_raw.txt → yna/html/Cebuano/ABCEB_2JN_raw.html
#
# Folder yna/raw/Spanish → yna/html/Spanish
# Converted yna/raw/Spanish/RVR95_ROM_raw.txt → yna/html/Spanish/RVR95_ROM_raw.html
# Converted yna/raw/Spanish/RVR95_EZK_raw.txt → yna/html/Spanish/RVR95_EZK_raw.html
# Converted yna/raw/Spanish/RVR95_RUT_raw.txt → yna/html/Spanish/RVR95_RUT_raw.html
# Converted yna/raw/Spanish/RVR95_SNG_raw.txt → yna/html/Spanish/RVR95_SNG_raw.html
# Converted yna/raw/Spanish/RVR95_DEU_raw.txt → yna/html/Spanish/RVR95_DEU_raw.html
# Converted yna/raw/Spanish/RVR95_HAG_raw.txt → yna/html/Spanish/RVR95_HAG_raw.html
# Converted yna/raw/Spanish/RVR95_1SA_raw.txt → yna/html/Spanish/RVR95_1SA_raw.html
# Converted yna/raw/Spanish/RVR95_JOL_raw.txt → yna/html/Spanish/RVR95_JOL_raw.html
# Converted yna/raw/Spanish/RVR95_JHN_raw.txt → yna/html/Spanish/RVR95_JHN_raw.html
# Converted yna/raw/Spanish/RVR95_2JN_raw.txt → yna/html/Spanish/RVR95_2JN_raw.html
# Converted yna/raw/Spanish/RVR95_2CH_raw.txt → yna/html/Spanish/RVR95_2CH_raw.html
# Converted yna/raw/Spanish/RVR95_HEB_raw.txt → yna/html/Spanish/RVR95_HEB_raw.html
# Converted yna/raw/Spanish/RVR95_EPH_raw.txt → yna/html/Spanish/RVR95_EPH_raw.html
# Converted yna/raw/Spanish/RVR95_GEN_raw.txt → yna/html/Spanish/RVR95_GEN_raw.html
# Converted yna/raw/Spanish/RVR95_JER_raw.txt → yna/html/Spanish/RVR95_JER_raw.html
# Converted yna/raw/Spanish/RVR95_JON_raw.txt → yna/html/Spanish/RVR95_JON_raw.html
# Converted yna/raw/Spanish/RVR95_JDG_raw.txt → yna/html/Spanish/RVR95_JDG_raw.html
# Converted yna/raw/Spanish/RVR95_MRK_raw.txt → yna/html/Spanish/RVR95_MRK_raw.html
# Converted yna/raw/Spanish/RVR95_NUM_raw.txt → yna/html/Spanish/RVR95_NUM_raw.html
# Converted yna/raw/Spanish/RVR95_DAN_raw.txt → yna/html/Spanish/RVR95_DAN_raw.html
# Converted yna/raw/Spanish/RVR95_NEH_raw.txt → yna/html/Spanish/RVR95_NEH_raw.html
# Converted yna/raw/Spanish/RVR95_MAT_raw.txt → yna/html/Spanish/RVR95_MAT_raw.html
# Converted yna/raw/Spanish/RVR95_1TI_raw.txt → yna/html/Spanish/RVR95_1TI_raw.html
# Converted yna/raw/Spanish/RVR95_1KI_raw.txt → yna/html/Spanish/RVR95_1KI_raw.html
# Converted yna/raw/Spanish/RVR95_1PE_raw.txt → yna/html/Spanish/RVR95_1PE_raw.html
# Converted yna/raw/Spanish/RVR95_OBA_raw.txt → yna/html/Spanish/RVR95_OBA_raw.html
# Converted yna/raw/Spanish/RVR95_PRO_raw.txt → yna/html/Spanish/RVR95_PRO_raw.html
# Converted yna/raw/Spanish/RVR95_ZEC_raw.txt → yna/html/Spanish/RVR95_ZEC_raw.html
# Converted yna/raw/Spanish/RVR95_1TH_raw.txt → yna/html/Spanish/RVR95_1TH_raw.html
# Converted yna/raw/Spanish/RVR95_1CO_raw.txt → yna/html/Spanish/RVR95_1CO_raw.html
# Converted yna/raw/Spanish/RVR95_JOS_raw.txt → yna/html/Spanish/RVR95_JOS_raw.html
# Converted yna/raw/Spanish/RVR95_LUK_raw.txt → yna/html/Spanish/RVR95_LUK_raw.html
# Converted yna/raw/Spanish/RVR95_3JN_raw.txt → yna/html/Spanish/RVR95_3JN_raw.html
# Converted yna/raw/Spanish/RVR95_EXO_raw.txt → yna/html/Spanish/RVR95_EXO_raw.html
# Converted yna/raw/Spanish/RVR95_NAM_raw.txt → yna/html/Spanish/RVR95_NAM_raw.html
# Converted yna/raw/Spanish/RVR95_ECC_raw.txt → yna/html/Spanish/RVR95_ECC_raw.html
# Converted yna/raw/Spanish/RVR95_MAL_raw.txt → yna/html/Spanish/RVR95_MAL_raw.html
# Converted yna/raw/Spanish/RVR95_2TI_raw.txt → yna/html/Spanish/RVR95_2TI_raw.html
# Converted yna/raw/Spanish/RVR95_COL_raw.txt → yna/html/Spanish/RVR95_COL_raw.html
# Converted yna/raw/Spanish/RVR95_REV_raw.txt → yna/html/Spanish/RVR95_REV_raw.html
# Converted yna/raw/Spanish/RVR95_MIC_raw.txt → yna/html/Spanish/RVR95_MIC_raw.html
# Converted yna/raw/Spanish/RVR95_JOB_raw.txt → yna/html/Spanish/RVR95_JOB_raw.html
# Converted yna/raw/Spanish/RVR95_TIT_raw.txt → yna/html/Spanish/RVR95_TIT_raw.html
# Converted yna/raw/Spanish/RVR95_2TH_raw.txt → yna/html/Spanish/RVR95_2TH_raw.html
# Converted yna/raw/Spanish/RVR95_2CO_raw.txt → yna/html/Spanish/RVR95_2CO_raw.html
# Converted yna/raw/Spanish/RVR95_2PE_raw.txt → yna/html/Spanish/RVR95_2PE_raw.html
# Converted yna/raw/Spanish/RVR95_JAS_raw.txt → yna/html/Spanish/RVR95_JAS_raw.html
# Converted yna/raw/Spanish/RVR95_LEV_raw.txt → yna/html/Spanish/RVR95_LEV_raw.html
# Converted yna/raw/Spanish/RVR95_2KI_raw.txt → yna/html/Spanish/RVR95_2KI_raw.html
# Converted yna/raw/Spanish/RVR95_ISA_raw.txt → yna/html/Spanish/RVR95_ISA_raw.html
# Converted yna/raw/Spanish/RVR95_ACT_raw.txt → yna/html/Spanish/RVR95_ACT_raw.html
# Converted yna/raw/Spanish/RVR95_ZEP_raw.txt → yna/html/Spanish/RVR95_ZEP_raw.html
# Converted yna/raw/Spanish/RVR95_PHP_raw.txt → yna/html/Spanish/RVR95_PHP_raw.html
# Converted yna/raw/Spanish/RVR95_2SA_raw.txt → yna/html/Spanish/RVR95_2SA_raw.html
# Converted yna/raw/Spanish/RVR95_EST_raw.txt → yna/html/Spanish/RVR95_EST_raw.html
# Converted yna/raw/Spanish/RVR95_JUD_raw.txt → yna/html/Spanish/RVR95_JUD_raw.html
# Converted yna/raw/Spanish/RVR95_HOS_raw.txt → yna/html/Spanish/RVR95_HOS_raw.html
# Converted yna/raw/Spanish/RVR95_EZR_raw.txt → yna/html/Spanish/RVR95_EZR_raw.html
# Converted yna/raw/Spanish/RVR95_PHM_raw.txt → yna/html/Spanish/RVR95_PHM_raw.html
# Converted yna/raw/Spanish/RVR95_PSA_raw.txt → yna/html/Spanish/RVR95_PSA_raw.html
# Converted yna/raw/Spanish/RVR95_HAB_raw.txt → yna/html/Spanish/RVR95_HAB_raw.html
# Converted yna/raw/Spanish/RVR95_LAM_raw.txt → yna/html/Spanish/RVR95_LAM_raw.html
# Converted yna/raw/Spanish/RVR95_AMO_raw.txt → yna/html/Spanish/RVR95_AMO_raw.html
# Converted yna/raw/Spanish/RVR95_1CH_raw.txt → yna/html/Spanish/RVR95_1CH_raw.html
# Converted yna/raw/Spanish/RVR95_GAL_raw.txt → yna/html/Spanish/RVR95_GAL_raw.html
# Converted yna/raw/Spanish/RVR95_1JN_raw.txt → yna/html/Spanish/RVR95_1JN_raw.html
#
# Folder yna/raw/Chavacano → yna/html/Chavacano
# Converted yna/raw/Chavacano/CBKNT_PHM_raw.txt → yna/html/Chavacano/CBKNT_PHM_raw.html
# Converted yna/raw/Chavacano/CBKNT_JUD_raw.txt → yna/html/Chavacano/CBKNT_JUD_raw.html
# Converted yna/raw/Chavacano/CBKNT_1JN_raw.txt → yna/html/Chavacano/CBKNT_1JN_raw.html
# Converted yna/raw/Chavacano/CBKNT_GAL_raw.txt → yna/html/Chavacano/CBKNT_GAL_raw.html
# Converted yna/raw/Chavacano/CBKNT_PHP_raw.txt → yna/html/Chavacano/CBKNT_PHP_raw.html
# Converted yna/raw/Chavacano/CBKNT_JAS_raw.txt → yna/html/Chavacano/CBKNT_JAS_raw.html
# Converted yna/raw/Chavacano/CBKNT_2PE_raw.txt → yna/html/Chavacano/CBKNT_2PE_raw.html
# Converted yna/raw/Chavacano/CBKNT_TIT_raw.txt → yna/html/Chavacano/CBKNT_TIT_raw.html
# Converted yna/raw/Chavacano/CBKNT_2CO_raw.txt → yna/html/Chavacano/CBKNT_2CO_raw.html
# Converted yna/raw/Chavacano/CBKNT_2TH_raw.txt → yna/html/Chavacano/CBKNT_2TH_raw.html
# Converted yna/raw/Chavacano/CBKNT_ACT_raw.txt → yna/html/Chavacano/CBKNT_ACT_raw.html
# Converted yna/raw/Chavacano/CBKNT_REV_raw.txt → yna/html/Chavacano/CBKNT_REV_raw.html
# Converted yna/raw/Chavacano/CBKNT_COL_raw.txt → yna/html/Chavacano/CBKNT_COL_raw.html
# Converted yna/raw/Chavacano/CBKNT_2TI_raw.txt → yna/html/Chavacano/CBKNT_2TI_raw.html
# Converted yna/raw/Chavacano/CBKNT_1CO_raw.txt → yna/html/Chavacano/CBKNT_1CO_raw.html
# Converted yna/raw/Chavacano/CBKNT_1TH_raw.txt → yna/html/Chavacano/CBKNT_1TH_raw.html
# Converted yna/raw/Chavacano/CBKNT_1PE_raw.txt → yna/html/Chavacano/CBKNT_1PE_raw.html
# Converted yna/raw/Chavacano/CBKNT_3JN_raw.txt → yna/html/Chavacano/CBKNT_3JN_raw.html
# Converted yna/raw/Chavacano/CBKNT_LUK_raw.txt → yna/html/Chavacano/CBKNT_LUK_raw.html
# Converted yna/raw/Chavacano/CBKNT_EPH_raw.txt → yna/html/Chavacano/CBKNT_EPH_raw.html
# Converted yna/raw/Chavacano/CBKNT_1TI_raw.txt → yna/html/Chavacano/CBKNT_1TI_raw.html
# Converted yna/raw/Chavacano/CBKNT_MAT_raw.txt → yna/html/Chavacano/CBKNT_MAT_raw.html
# Converted yna/raw/Chavacano/CBKNT_MRK_raw.txt → yna/html/Chavacano/CBKNT_MRK_raw.html
# Converted yna/raw/Chavacano/CBKNT_JHN_raw.txt → yna/html/Chavacano/CBKNT_JHN_raw.html
# Converted yna/raw/Chavacano/CBKNT_HEB_raw.txt → yna/html/Chavacano/CBKNT_HEB_raw.html
# Converted yna/raw/Chavacano/CBKNT_2JN_raw.txt → yna/html/Chavacano/CBKNT_2JN_raw.html
# Converted yna/raw/Chavacano/CBKNT_ROM_raw.txt → yna/html/Chavacano/CBKNT_ROM_raw.html
#
# Folder yna/raw/Tausug → yna/html/Tausug
# Converted yna/raw/Tausug/TSG_ACT_raw.txt → yna/html/Tausug/TSG_ACT_raw.html
# Converted yna/raw/Tausug/TSG_TIT_raw.txt → yna/html/Tausug/TSG_TIT_raw.html
# Converted yna/raw/Tausug/TSG_2TH_raw.txt → yna/html/Tausug/TSG_2TH_raw.html
# Converted yna/raw/Tausug/TSG_2CO_raw.txt → yna/html/Tausug/TSG_2CO_raw.html
# Converted yna/raw/Tausug/TSG_2PE_raw.txt → yna/html/Tausug/TSG_2PE_raw.html
# Converted yna/raw/Tausug/TSG_JAS_raw.txt → yna/html/Tausug/TSG_JAS_raw.html
# Converted yna/raw/Tausug/TSG_2TI_raw.txt → yna/html/Tausug/TSG_2TI_raw.html
# Converted yna/raw/Tausug/TSG_COL_raw.txt → yna/html/Tausug/TSG_COL_raw.html
# Converted yna/raw/Tausug/TSG_REV_raw.txt → yna/html/Tausug/TSG_REV_raw.html
# Converted yna/raw/Tausug/TSG_GAL_raw.txt → yna/html/Tausug/TSG_GAL_raw.html
# Converted yna/raw/Tausug/TSG_1JN_raw.txt → yna/html/Tausug/TSG_1JN_raw.html
# Converted yna/raw/Tausug/TSG_JUD_raw.txt → yna/html/Tausug/TSG_JUD_raw.html
# Converted yna/raw/Tausug/TSG_PHM_raw.txt → yna/html/Tausug/TSG_PHM_raw.html
# Converted yna/raw/Tausug/TSG_PHP_raw.txt → yna/html/Tausug/TSG_PHP_raw.html
# Converted yna/raw/Tausug/TSG_2JN_raw.txt → yna/html/Tausug/TSG_2JN_raw.html
# Converted yna/raw/Tausug/TSG_HEB_raw.txt → yna/html/Tausug/TSG_HEB_raw.html
# Converted yna/raw/Tausug/TSG_JHN_raw.txt → yna/html/Tausug/TSG_JHN_raw.html
# Converted yna/raw/Tausug/TSG_ROM_raw.txt → yna/html/Tausug/TSG_ROM_raw.html
# Converted yna/raw/Tausug/TSG_LUK_raw.txt → yna/html/Tausug/TSG_LUK_raw.html
# Converted yna/raw/Tausug/TSG_3JN_raw.txt → yna/html/Tausug/TSG_3JN_raw.html
# Converted yna/raw/Tausug/TSG_1PE_raw.txt → yna/html/Tausug/TSG_1PE_raw.html
# Converted yna/raw/Tausug/TSG_1TH_raw.txt → yna/html/Tausug/TSG_1TH_raw.html
# Converted yna/raw/Tausug/TSG_1CO_raw.txt → yna/html/Tausug/TSG_1CO_raw.html
# Converted yna/raw/Tausug/TSG_MRK_raw.txt → yna/html/Tausug/TSG_MRK_raw.html
# Converted yna/raw/Tausug/TSG_MAT_raw.txt → yna/html/Tausug/TSG_MAT_raw.html
# Converted yna/raw/Tausug/TSG_1TI_raw.txt → yna/html/Tausug/TSG_1TI_raw.html
# Converted yna/raw/Tausug/TSG_EPH_raw.txt → yna/html/Tausug/TSG_EPH_raw.html
#
# Folder cj/raw/Ivatan → cj/html/Ivatan
# Converted cj/raw/Ivatan/VTSP_PHP_raw.txt → cj/html/Ivatan/VTSP_PHP_raw.html
# Converted cj/raw/Ivatan/VTSP_PSA_raw.txt → cj/html/Ivatan/VTSP_PSA_raw.html
# Converted cj/raw/Ivatan/VTSP_PHM_raw.txt → cj/html/Ivatan/VTSP_PHM_raw.html
# Converted cj/raw/Ivatan/VTSP_JUD_raw.txt → cj/html/Ivatan/VTSP_JUD_raw.html
# Converted cj/raw/Ivatan/VTSP_1JN_raw.txt → cj/html/Ivatan/VTSP_1JN_raw.html
# Converted cj/raw/Ivatan/VTSP_GAL_raw.txt → cj/html/Ivatan/VTSP_GAL_raw.html
# Converted cj/raw/Ivatan/VTSP_REV_raw.txt → cj/html/Ivatan/VTSP_REV_raw.html
# Converted cj/raw/Ivatan/VTSP_COL_raw.txt → cj/html/Ivatan/VTSP_COL_raw.html
# Converted cj/raw/Ivatan/VTSP_2TI_raw.txt → cj/html/Ivatan/VTSP_2TI_raw.html
# Converted cj/raw/Ivatan/VTSP_JAS_raw.txt → cj/html/Ivatan/VTSP_JAS_raw.html
# Converted cj/raw/Ivatan/VTSP_2PE_raw.txt → cj/html/Ivatan/VTSP_2PE_raw.html
# Converted cj/raw/Ivatan/VTSP_2CO_raw.txt → cj/html/Ivatan/VTSP_2CO_raw.html
# Converted cj/raw/Ivatan/VTSP_2TH_raw.txt → cj/html/Ivatan/VTSP_2TH_raw.html
# Converted cj/raw/Ivatan/VTSP_TIT_raw.txt → cj/html/Ivatan/VTSP_TIT_raw.html
# Converted cj/raw/Ivatan/VTSP_ACT_raw.txt → cj/html/Ivatan/VTSP_ACT_raw.html
# Converted cj/raw/Ivatan/VTSP_EPH_raw.txt → cj/html/Ivatan/VTSP_EPH_raw.html
# Converted cj/raw/Ivatan/VTSP_1TI_raw.txt → cj/html/Ivatan/VTSP_1TI_raw.html
# Converted cj/raw/Ivatan/VTSP_MAT_raw.txt → cj/html/Ivatan/VTSP_MAT_raw.html
# Converted cj/raw/Ivatan/VTSP_MRK_raw.txt → cj/html/Ivatan/VTSP_MRK_raw.html
# Converted cj/raw/Ivatan/VTSP_1CO_raw.txt → cj/html/Ivatan/VTSP_1CO_raw.html
# Converted cj/raw/Ivatan/VTSP_1TH_raw.txt → cj/html/Ivatan/VTSP_1TH_raw.html
# Converted cj/raw/Ivatan/VTSP_PRO_raw.txt → cj/html/Ivatan/VTSP_PRO_raw.html
# Converted cj/raw/Ivatan/VTSP_1PE_raw.txt → cj/html/Ivatan/VTSP_1PE_raw.html
# Converted cj/raw/Ivatan/VTSP_3JN_raw.txt → cj/html/Ivatan/VTSP_3JN_raw.html
# Converted cj/raw/Ivatan/VTSP_LUK_raw.txt → cj/html/Ivatan/VTSP_LUK_raw.html
# Converted cj/raw/Ivatan/VTSP_ROM_raw.txt → cj/html/Ivatan/VTSP_ROM_raw.html
# Converted cj/raw/Ivatan/VTSP_JHN_raw.txt → cj/html/Ivatan/VTSP_JHN_raw.html
# Converted cj/raw/Ivatan/VTSP_HEB_raw.txt → cj/html/Ivatan/VTSP_HEB_raw.html
# Converted cj/raw/Ivatan/VTSP_2JN_raw.txt → cj/html/Ivatan/VTSP_2JN_raw.html
#
# Folder cj/raw/Pangasinense → cj/html/Pangasinense
# Converted cj/raw/Pangasinense/PNPV_HOS_raw.txt → cj/html/Pangasinense/PNPV_HOS_raw.html
# Converted cj/raw/Pangasinense/PNPV_JUD_raw.txt → cj/html/Pangasinense/PNPV_JUD_raw.html
# Converted cj/raw/Pangasinense/PNPV_JDT_raw.txt → cj/html/Pangasinense/PNPV_JDT_raw.html
# Converted cj/raw/Pangasinense/PNPV_EST_raw.txt → cj/html/Pangasinense/PNPV_EST_raw.html
# Converted cj/raw/Pangasinense/PNPV_HAB_raw.txt → cj/html/Pangasinense/PNPV_HAB_raw.html
# Converted cj/raw/Pangasinense/PNPV_PSA_raw.txt → cj/html/Pangasinense/PNPV_PSA_raw.html
# Converted cj/raw/Pangasinense/PNPV_PHM_raw.txt → cj/html/Pangasinense/PNPV_PHM_raw.html
# Converted cj/raw/Pangasinense/PNPV_2MA_raw.txt → cj/html/Pangasinense/PNPV_2MA_raw.html
# Converted cj/raw/Pangasinense/PNPV_EZR_raw.txt → cj/html/Pangasinense/PNPV_EZR_raw.html
# Converted cj/raw/Pangasinense/PNPV_1CH_raw.txt → cj/html/Pangasinense/PNPV_1CH_raw.html
# Converted cj/raw/Pangasinense/PNPV_LAM_raw.txt → cj/html/Pangasinense/PNPV_LAM_raw.html
# Converted cj/raw/Pangasinense/PNPV_AMO_raw.txt → cj/html/Pangasinense/PNPV_AMO_raw.html
# Converted cj/raw/Pangasinense/PNPV_WIS_raw.txt → cj/html/Pangasinense/PNPV_WIS_raw.html
# Converted cj/raw/Pangasinense/PNPV_1JN_raw.txt → cj/html/Pangasinense/PNPV_1JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_GAL_raw.txt → cj/html/Pangasinense/PNPV_GAL_raw.html
# Converted cj/raw/Pangasinense/PNPV_LJE_raw.txt → cj/html/Pangasinense/PNPV_LJE_raw.html
# Converted cj/raw/Pangasinense/PNPV_ZEP_raw.txt → cj/html/Pangasinense/PNPV_ZEP_raw.html
# Converted cj/raw/Pangasinense/PNPV_BEL_raw.txt → cj/html/Pangasinense/PNPV_BEL_raw.html
# Converted cj/raw/Pangasinense/PNPV_PHP_raw.txt → cj/html/Pangasinense/PNPV_PHP_raw.html
# Converted cj/raw/Pangasinense/PNPV_2SA_raw.txt → cj/html/Pangasinense/PNPV_2SA_raw.html
# Converted cj/raw/Pangasinense/PNPV_S3Y_raw.txt → cj/html/Pangasinense/PNPV_S3Y_raw.html
# Converted cj/raw/Pangasinense/PNPV_SUS_raw.txt → cj/html/Pangasinense/PNPV_SUS_raw.html
# Converted cj/raw/Pangasinense/PNPV_2CO_raw.txt → cj/html/Pangasinense/PNPV_2CO_raw.html
# Converted cj/raw/Pangasinense/PNPV_2TH_raw.txt → cj/html/Pangasinense/PNPV_2TH_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOB_raw.txt → cj/html/Pangasinense/PNPV_JOB_raw.html
# Converted cj/raw/Pangasinense/PNPV_TIT_raw.txt → cj/html/Pangasinense/PNPV_TIT_raw.html
# Converted cj/raw/Pangasinense/PNPV_2KI_raw.txt → cj/html/Pangasinense/PNPV_2KI_raw.html
# Converted cj/raw/Pangasinense/PNPV_JAS_raw.txt → cj/html/Pangasinense/PNPV_JAS_raw.html
# Converted cj/raw/Pangasinense/PNPV_LEV_raw.txt → cj/html/Pangasinense/PNPV_LEV_raw.html
# Converted cj/raw/Pangasinense/PNPV_2PE_raw.txt → cj/html/Pangasinense/PNPV_2PE_raw.html
# Converted cj/raw/Pangasinense/PNPV_ISA_raw.txt → cj/html/Pangasinense/PNPV_ISA_raw.html
# Converted cj/raw/Pangasinense/PNPV_ACT_raw.txt → cj/html/Pangasinense/PNPV_ACT_raw.html
# Converted cj/raw/Pangasinense/PNPV_MAL_raw.txt → cj/html/Pangasinense/PNPV_MAL_raw.html
# Converted cj/raw/Pangasinense/PNPV_2TI_raw.txt → cj/html/Pangasinense/PNPV_2TI_raw.html
# Converted cj/raw/Pangasinense/PNPV_TOB_raw.txt → cj/html/Pangasinense/PNPV_TOB_raw.html
# Converted cj/raw/Pangasinense/PNPV_MIC_raw.txt → cj/html/Pangasinense/PNPV_MIC_raw.html
# Converted cj/raw/Pangasinense/PNPV_COL_raw.txt → cj/html/Pangasinense/PNPV_COL_raw.html
# Converted cj/raw/Pangasinense/PNPV_REV_raw.txt → cj/html/Pangasinense/PNPV_REV_raw.html
# Converted cj/raw/Pangasinense/PNPV_1PE_raw.txt → cj/html/Pangasinense/PNPV_1PE_raw.html
# Converted cj/raw/Pangasinense/PNPV_OBA_raw.txt → cj/html/Pangasinense/PNPV_OBA_raw.html
# Converted cj/raw/Pangasinense/PNPV_PRO_raw.txt → cj/html/Pangasinense/PNPV_PRO_raw.html
# Converted cj/raw/Pangasinense/PNPV_1KI_raw.txt → cj/html/Pangasinense/PNPV_1KI_raw.html
# Converted cj/raw/Pangasinense/PNPV_SIR_raw.txt → cj/html/Pangasinense/PNPV_SIR_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOS_raw.txt → cj/html/Pangasinense/PNPV_JOS_raw.html
# Converted cj/raw/Pangasinense/PNPV_BAR_raw.txt → cj/html/Pangasinense/PNPV_BAR_raw.html
# Converted cj/raw/Pangasinense/PNPV_1CO_raw.txt → cj/html/Pangasinense/PNPV_1CO_raw.html
# Converted cj/raw/Pangasinense/PNPV_ZEC_raw.txt → cj/html/Pangasinense/PNPV_ZEC_raw.html
# Converted cj/raw/Pangasinense/PNPV_1TH_raw.txt → cj/html/Pangasinense/PNPV_1TH_raw.html
# Converted cj/raw/Pangasinense/PNPV_3JN_raw.txt → cj/html/Pangasinense/PNPV_3JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_LUK_raw.txt → cj/html/Pangasinense/PNPV_LUK_raw.html
# Converted cj/raw/Pangasinense/PNPV_ECC_raw.txt → cj/html/Pangasinense/PNPV_ECC_raw.html
# Converted cj/raw/Pangasinense/PNPV_NAM_raw.txt → cj/html/Pangasinense/PNPV_NAM_raw.html
# Converted cj/raw/Pangasinense/PNPV_EXO_raw.txt → cj/html/Pangasinense/PNPV_EXO_raw.html
# Converted cj/raw/Pangasinense/PNPV_EPH_raw.txt → cj/html/Pangasinense/PNPV_EPH_raw.html
# Converted cj/raw/Pangasinense/PNPV_JDG_raw.txt → cj/html/Pangasinense/PNPV_JDG_raw.html
# Converted cj/raw/Pangasinense/PNPV_JON_raw.txt → cj/html/Pangasinense/PNPV_JON_raw.html
# Converted cj/raw/Pangasinense/PNPV_JER_raw.txt → cj/html/Pangasinense/PNPV_JER_raw.html
# Converted cj/raw/Pangasinense/PNPV_GEN_raw.txt → cj/html/Pangasinense/PNPV_GEN_raw.html
# Converted cj/raw/Pangasinense/PNPV_NEH_raw.txt → cj/html/Pangasinense/PNPV_NEH_raw.html
# Converted cj/raw/Pangasinense/PNPV_DAN_raw.txt → cj/html/Pangasinense/PNPV_DAN_raw.html
# Converted cj/raw/Pangasinense/PNPV_MRK_raw.txt → cj/html/Pangasinense/PNPV_MRK_raw.html
# Converted cj/raw/Pangasinense/PNPV_NUM_raw.txt → cj/html/Pangasinense/PNPV_NUM_raw.html
# Converted cj/raw/Pangasinense/PNPV_1TI_raw.txt → cj/html/Pangasinense/PNPV_1TI_raw.html
# Converted cj/raw/Pangasinense/PNPV_MAT_raw.txt → cj/html/Pangasinense/PNPV_MAT_raw.html
# Converted cj/raw/Pangasinense/PNPV_1MA_raw.txt → cj/html/Pangasinense/PNPV_1MA_raw.html
# Converted cj/raw/Pangasinense/PNPV_JHN_raw.txt → cj/html/Pangasinense/PNPV_JHN_raw.html
# Converted cj/raw/Pangasinense/PNPV_JOL_raw.txt → cj/html/Pangasinense/PNPV_JOL_raw.html
# Converted cj/raw/Pangasinense/PNPV_2JN_raw.txt → cj/html/Pangasinense/PNPV_2JN_raw.html
# Converted cj/raw/Pangasinense/PNPV_HEB_raw.txt → cj/html/Pangasinense/PNPV_HEB_raw.html
# Converted cj/raw/Pangasinense/PNPV_2CH_raw.txt → cj/html/Pangasinense/PNPV_2CH_raw.html
# Converted cj/raw/Pangasinense/PNPV_SNG_raw.txt → cj/html/Pangasinense/PNPV_SNG_raw.html
# Converted cj/raw/Pangasinense/PNPV_EZK_raw.txt → cj/html/Pangasinense/PNPV_EZK_raw.html
# Converted cj/raw/Pangasinense/PNPV_RUT_raw.txt → cj/html/Pangasinense/PNPV_RUT_raw.html
# Converted cj/raw/Pangasinense/PNPV_ROM_raw.txt → cj/html/Pangasinense/PNPV_ROM_raw.html
# Converted cj/raw/Pangasinense/PNPV_DEU_raw.txt → cj/html/Pangasinense/PNPV_DEU_raw.html
# Converted cj/raw/Pangasinense/PNPV_HAG_raw.txt → cj/html/Pangasinense/PNPV_HAG_raw.html
# Converted cj/raw/Pangasinense/PNPV_1SA_raw.txt → cj/html/Pangasinense/PNPV_1SA_raw.html
#
# Folder cj/raw/Tagalog → cj/html/Tagalog
# Converted cj/raw/Tagalog/MBB05_MAT_raw.txt → cj/html/Tagalog/MBB05_MAT_raw.html
# Converted cj/raw/Tagalog/MBB05_1TI_raw.txt → cj/html/Tagalog/MBB05_1TI_raw.html
# Converted cj/raw/Tagalog/MBB05_NUM_raw.txt → cj/html/Tagalog/MBB05_NUM_raw.html
# Converted cj/raw/Tagalog/MBB05_MRK_raw.txt → cj/html/Tagalog/MBB05_MRK_raw.html
# Converted cj/raw/Tagalog/MBB05_DAN_raw.txt → cj/html/Tagalog/MBB05_DAN_raw.html
# Converted cj/raw/Tagalog/MBB05_NEH_raw.txt → cj/html/Tagalog/MBB05_NEH_raw.html
# Converted cj/raw/Tagalog/MBB05_JER_raw.txt → cj/html/Tagalog/MBB05_JER_raw.html
# Converted cj/raw/Tagalog/MBB05_GEN_raw.txt → cj/html/Tagalog/MBB05_GEN_raw.html
# Converted cj/raw/Tagalog/MBB05_JON_raw.txt → cj/html/Tagalog/MBB05_JON_raw.html
# Converted cj/raw/Tagalog/MBB05_JDG_raw.txt → cj/html/Tagalog/MBB05_JDG_raw.html
# Converted cj/raw/Tagalog/MBB05_EPH_raw.txt → cj/html/Tagalog/MBB05_EPH_raw.html
# Converted cj/raw/Tagalog/MBB05_EXO_raw.txt → cj/html/Tagalog/MBB05_EXO_raw.html
# Converted cj/raw/Tagalog/MBB05_NAM_raw.txt → cj/html/Tagalog/MBB05_NAM_raw.html
# Converted cj/raw/Tagalog/MBB05_ECC_raw.txt → cj/html/Tagalog/MBB05_ECC_raw.html
# Converted cj/raw/Tagalog/MBB05_LUK_raw.txt → cj/html/Tagalog/MBB05_LUK_raw.html
# Converted cj/raw/Tagalog/MBB05_3JN_raw.txt → cj/html/Tagalog/MBB05_3JN_raw.html
# Converted cj/raw/Tagalog/MBB05_1TH_raw.txt → cj/html/Tagalog/MBB05_1TH_raw.html
# Converted cj/raw/Tagalog/MBB05_ZEC_raw.txt → cj/html/Tagalog/MBB05_ZEC_raw.html
# Converted cj/raw/Tagalog/MBB05_1CO_raw.txt → cj/html/Tagalog/MBB05_1CO_raw.html
# Converted cj/raw/Tagalog/MBB05_JOS_raw.txt → cj/html/Tagalog/MBB05_JOS_raw.html
# Converted cj/raw/Tagalog/MBB05_BAR_raw.txt → cj/html/Tagalog/MBB05_BAR_raw.html
# Converted cj/raw/Tagalog/MBB05_SIR_raw.txt → cj/html/Tagalog/MBB05_SIR_raw.html
# Converted cj/raw/Tagalog/MBB05_1KI_raw.txt → cj/html/Tagalog/MBB05_1KI_raw.html
# Converted cj/raw/Tagalog/MBB05_PRO_raw.txt → cj/html/Tagalog/MBB05_PRO_raw.html
# Converted cj/raw/Tagalog/MBB05_OBA_raw.txt → cj/html/Tagalog/MBB05_OBA_raw.html
# Converted cj/raw/Tagalog/MBB05_1PE_raw.txt → cj/html/Tagalog/MBB05_1PE_raw.html
# Converted cj/raw/Tagalog/MBB05_1SA_raw.txt → cj/html/Tagalog/MBB05_1SA_raw.html
# Converted cj/raw/Tagalog/MBB05_HAG_raw.txt → cj/html/Tagalog/MBB05_HAG_raw.html
# Converted cj/raw/Tagalog/MBB05_DEU_raw.txt → cj/html/Tagalog/MBB05_DEU_raw.html
# Converted cj/raw/Tagalog/MBB05_ROM_raw.txt → cj/html/Tagalog/MBB05_ROM_raw.html
# Converted cj/raw/Tagalog/MBB05_RUT_raw.txt → cj/html/Tagalog/MBB05_RUT_raw.html
# Converted cj/raw/Tagalog/MBB05_EZK_raw.txt → cj/html/Tagalog/MBB05_EZK_raw.html
# Converted cj/raw/Tagalog/MBB05_SNG_raw.txt → cj/html/Tagalog/MBB05_SNG_raw.html
# Converted cj/raw/Tagalog/MBB05_2CH_raw.txt → cj/html/Tagalog/MBB05_2CH_raw.html
# Converted cj/raw/Tagalog/MBB05_HEB_raw.txt → cj/html/Tagalog/MBB05_HEB_raw.html
# Converted cj/raw/Tagalog/MBB05_2JN_raw.txt → cj/html/Tagalog/MBB05_2JN_raw.html
# Converted cj/raw/Tagalog/MBB05_JOL_raw.txt → cj/html/Tagalog/MBB05_JOL_raw.html
# Converted cj/raw/Tagalog/MBB05_JHN_raw.txt → cj/html/Tagalog/MBB05_JHN_raw.html
# Converted cj/raw/Tagalog/MBB05_1MA_raw.txt → cj/html/Tagalog/MBB05_1MA_raw.html
# Converted cj/raw/Tagalog/MBB05_SUS_raw.txt → cj/html/Tagalog/MBB05_SUS_raw.html
# Converted cj/raw/Tagalog/MBB05_S3Y_raw.txt → cj/html/Tagalog/MBB05_S3Y_raw.html
# Converted cj/raw/Tagalog/MBB05_2SA_raw.txt → cj/html/Tagalog/MBB05_2SA_raw.html
# Converted cj/raw/Tagalog/MBB05_BEL_raw.txt → cj/html/Tagalog/MBB05_BEL_raw.html
# Converted cj/raw/Tagalog/MBB05_PHP_raw.txt → cj/html/Tagalog/MBB05_PHP_raw.html
# Converted cj/raw/Tagalog/MBB05_ZEP_raw.txt → cj/html/Tagalog/MBB05_ZEP_raw.html
# Converted cj/raw/Tagalog/MBB05_LJE_raw.txt → cj/html/Tagalog/MBB05_LJE_raw.html
# Converted cj/raw/Tagalog/MBB05_GAL_raw.txt → cj/html/Tagalog/MBB05_GAL_raw.html
# Converted cj/raw/Tagalog/MBB05_1JN_raw.txt → cj/html/Tagalog/MBB05_1JN_raw.html
# Converted cj/raw/Tagalog/MBB05_WIS_raw.txt → cj/html/Tagalog/MBB05_WIS_raw.html
# Converted cj/raw/Tagalog/MBB05_AMO_raw.txt → cj/html/Tagalog/MBB05_AMO_raw.html
# Converted cj/raw/Tagalog/MBB05_LAM_raw.txt → cj/html/Tagalog/MBB05_LAM_raw.html
# Converted cj/raw/Tagalog/MBB05_1CH_raw.txt → cj/html/Tagalog/MBB05_1CH_raw.html
# Converted cj/raw/Tagalog/MBB05_2MA_raw.txt → cj/html/Tagalog/MBB05_2MA_raw.html
# Converted cj/raw/Tagalog/MBB05_PHM_raw.txt → cj/html/Tagalog/MBB05_PHM_raw.html
# Converted cj/raw/Tagalog/MBB05_EZR_raw.txt → cj/html/Tagalog/MBB05_EZR_raw.html
# Converted cj/raw/Tagalog/MBB05_HAB_raw.txt → cj/html/Tagalog/MBB05_HAB_raw.html
# Converted cj/raw/Tagalog/MBB05_PSA_raw.txt → cj/html/Tagalog/MBB05_PSA_raw.html
# Converted cj/raw/Tagalog/MBB05_EST_raw.txt → cj/html/Tagalog/MBB05_EST_raw.html
# Converted cj/raw/Tagalog/MBB05_JDT_raw.txt → cj/html/Tagalog/MBB05_JDT_raw.html
# Converted cj/raw/Tagalog/MBB05_JUD_raw.txt → cj/html/Tagalog/MBB05_JUD_raw.html
# Converted cj/raw/Tagalog/MBB05_HOS_raw.txt → cj/html/Tagalog/MBB05_HOS_raw.html
# Converted cj/raw/Tagalog/MBB05_REV_raw.txt → cj/html/Tagalog/MBB05_REV_raw.html
# Converted cj/raw/Tagalog/MBB05_COL_raw.txt → cj/html/Tagalog/MBB05_COL_raw.html
# Converted cj/raw/Tagalog/MBB05_MIC_raw.txt → cj/html/Tagalog/MBB05_MIC_raw.html
# Converted cj/raw/Tagalog/MBB05_TOB_raw.txt → cj/html/Tagalog/MBB05_TOB_raw.html
# Converted cj/raw/Tagalog/MBB05_2TI_raw.txt → cj/html/Tagalog/MBB05_2TI_raw.html
# Converted cj/raw/Tagalog/MBB05_MAL_raw.txt → cj/html/Tagalog/MBB05_MAL_raw.html
# Converted cj/raw/Tagalog/MBB05_ACT_raw.txt → cj/html/Tagalog/MBB05_ACT_raw.html
# Converted cj/raw/Tagalog/MBB05_ISA_raw.txt → cj/html/Tagalog/MBB05_ISA_raw.html
# Converted cj/raw/Tagalog/MBB05_2PE_raw.txt → cj/html/Tagalog/MBB05_2PE_raw.html
# Converted cj/raw/Tagalog/MBB05_LEV_raw.txt → cj/html/Tagalog/MBB05_LEV_raw.html
# Converted cj/raw/Tagalog/MBB05_JAS_raw.txt → cj/html/Tagalog/MBB05_JAS_raw.html
# Converted cj/raw/Tagalog/MBB05_2KI_raw.txt → cj/html/Tagalog/MBB05_2KI_raw.html
# Converted cj/raw/Tagalog/MBB05_TIT_raw.txt → cj/html/Tagalog/MBB05_TIT_raw.html
# Converted cj/raw/Tagalog/MBB05_JOB_raw.txt → cj/html/Tagalog/MBB05_JOB_raw.html
# Converted cj/raw/Tagalog/MBB05_2TH_raw.txt → cj/html/Tagalog/MBB05_2TH_raw.html
# Converted cj/raw/Tagalog/MBB05_2CO_raw.txt → cj/html/Tagalog/MBB05_2CO_raw.html
#
# Folder cj/raw/Yami → cj/html/Yami
# Converted cj/raw/Yami/SNT_MRK_raw.txt → cj/html/Yami/SNT_MRK_raw.html
# Converted cj/raw/Yami/SNT_MAT_raw.txt → cj/html/Yami/SNT_MAT_raw.html
# Converted cj/raw/Yami/SNT_1TI_raw.txt → cj/html/Yami/SNT_1TI_raw.html
# Converted cj/raw/Yami/SNT_EPH_raw.txt → cj/html/Yami/SNT_EPH_raw.html
# Converted cj/raw/Yami/SNT_LUK_raw.txt → cj/html/Yami/SNT_LUK_raw.html
# Converted cj/raw/Yami/SNT_3JN_raw.txt → cj/html/Yami/SNT_3JN_raw.html
# Converted cj/raw/Yami/SNT_1PE_raw.txt → cj/html/Yami/SNT_1PE_raw.html
# Converted cj/raw/Yami/SNT_1TH_raw.txt → cj/html/Yami/SNT_1TH_raw.html
# Converted cj/raw/Yami/SNT_1CO_raw.txt → cj/html/Yami/SNT_1CO_raw.html
# Converted cj/raw/Yami/SNT_ROM_raw.txt → cj/html/Yami/SNT_ROM_raw.html
# Converted cj/raw/Yami/SNT_2JN_raw.txt → cj/html/Yami/SNT_2JN_raw.html
# Converted cj/raw/Yami/SNT_HEB_raw.txt → cj/html/Yami/SNT_HEB_raw.html
# Converted cj/raw/Yami/SNT_JHN_raw.txt → cj/html/Yami/SNT_JHN_raw.html
# Converted cj/raw/Yami/SNT_PHP_raw.txt → cj/html/Yami/SNT_PHP_raw.html
# Converted cj/raw/Yami/SNT_GAL_raw.txt → cj/html/Yami/SNT_GAL_raw.html
# Converted cj/raw/Yami/SNT_1JN_raw.txt → cj/html/Yami/SNT_1JN_raw.html
# Converted cj/raw/Yami/SNT_JUD_raw.txt → cj/html/Yami/SNT_JUD_raw.html
# Converted cj/raw/Yami/SNT_PHM_raw.txt → cj/html/Yami/SNT_PHM_raw.html
# Converted cj/raw/Yami/SNT_2TI_raw.txt → cj/html/Yami/SNT_2TI_raw.html
# Converted cj/raw/Yami/SNT_COL_raw.txt → cj/html/Yami/SNT_COL_raw.html
# Converted cj/raw/Yami/SNT_REV_raw.txt → cj/html/Yami/SNT_REV_raw.html
# Converted cj/raw/Yami/SNT_ACT_raw.txt → cj/html/Yami/SNT_ACT_raw.html
# Converted cj/raw/Yami/SNT_2TH_raw.txt → cj/html/Yami/SNT_2TH_raw.html
# Converted cj/raw/Yami/SNT_2CO_raw.txt → cj/html/Yami/SNT_2CO_raw.html
# Converted cj/raw/Yami/SNT_TIT_raw.txt → cj/html/Yami/SNT_TIT_raw.html
# Converted cj/raw/Yami/SNT_2PE_raw.txt → cj/html/Yami/SNT_2PE_raw.html
# Converted cj/raw/Yami/SNT_JAS_raw.txt → cj/html/Yami/SNT_JAS_raw.html
#
# Folder trish/raw/Bikolano → trish/html/Bikolano
# Converted trish/raw/Bikolano/MBBBIK92_LUK_raw.txt → trish/html/Bikolano/MBBBIK92_LUK_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_3JN_raw.txt → trish/html/Bikolano/MBBBIK92_3JN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_NAM_raw.txt → trish/html/Bikolano/MBBBIK92_NAM_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ECC_raw.txt → trish/html/Bikolano/MBBBIK92_ECC_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_EXO_raw.txt → trish/html/Bikolano/MBBBIK92_EXO_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1PE_raw.txt → trish/html/Bikolano/MBBBIK92_1PE_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_OBA_raw.txt → trish/html/Bikolano/MBBBIK92_OBA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_PRO_raw.txt → trish/html/Bikolano/MBBBIK92_PRO_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_SIR_raw.txt → trish/html/Bikolano/MBBBIK92_SIR_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1KI_raw.txt → trish/html/Bikolano/MBBBIK92_1KI_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_BAR_raw.txt → trish/html/Bikolano/MBBBIK92_BAR_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JOS_raw.txt → trish/html/Bikolano/MBBBIK92_JOS_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ZEC_raw.txt → trish/html/Bikolano/MBBBIK92_ZEC_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1TH_raw.txt → trish/html/Bikolano/MBBBIK92_1TH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1CO_raw.txt → trish/html/Bikolano/MBBBIK92_1CO_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_DAN_raw.txt → trish/html/Bikolano/MBBBIK92_DAN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_NEH_raw.txt → trish/html/Bikolano/MBBBIK92_NEH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_MRK_raw.txt → trish/html/Bikolano/MBBBIK92_MRK_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_NUM_raw.txt → trish/html/Bikolano/MBBBIK92_NUM_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_MAT_raw.txt → trish/html/Bikolano/MBBBIK92_MAT_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1TI_raw.txt → trish/html/Bikolano/MBBBIK92_1TI_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_EPH_raw.txt → trish/html/Bikolano/MBBBIK92_EPH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JON_raw.txt → trish/html/Bikolano/MBBBIK92_JON_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JDG_raw.txt → trish/html/Bikolano/MBBBIK92_JDG_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JER_raw.txt → trish/html/Bikolano/MBBBIK92_JER_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_GEN_raw.txt → trish/html/Bikolano/MBBBIK92_GEN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2JN_raw.txt → trish/html/Bikolano/MBBBIK92_2JN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_HEB_raw.txt → trish/html/Bikolano/MBBBIK92_HEB_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2CH_raw.txt → trish/html/Bikolano/MBBBIK92_2CH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1MA_raw.txt → trish/html/Bikolano/MBBBIK92_1MA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JHN_raw.txt → trish/html/Bikolano/MBBBIK92_JHN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JOL_raw.txt → trish/html/Bikolano/MBBBIK92_JOL_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_HAG_raw.txt → trish/html/Bikolano/MBBBIK92_HAG_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1SA_raw.txt → trish/html/Bikolano/MBBBIK92_1SA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_SNG_raw.txt → trish/html/Bikolano/MBBBIK92_SNG_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ROM_raw.txt → trish/html/Bikolano/MBBBIK92_ROM_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_EZK_raw.txt → trish/html/Bikolano/MBBBIK92_EZK_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_RUT_raw.txt → trish/html/Bikolano/MBBBIK92_RUT_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_DEU_raw.txt → trish/html/Bikolano/MBBBIK92_DEU_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_LAM_raw.txt → trish/html/Bikolano/MBBBIK92_LAM_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_AMO_raw.txt → trish/html/Bikolano/MBBBIK92_AMO_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1CH_raw.txt → trish/html/Bikolano/MBBBIK92_1CH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_WIS_raw.txt → trish/html/Bikolano/MBBBIK92_WIS_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_GAL_raw.txt → trish/html/Bikolano/MBBBIK92_GAL_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_1JN_raw.txt → trish/html/Bikolano/MBBBIK92_1JN_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JUD_raw.txt → trish/html/Bikolano/MBBBIK92_JUD_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JDT_raw.txt → trish/html/Bikolano/MBBBIK92_JDT_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_HOS_raw.txt → trish/html/Bikolano/MBBBIK92_HOS_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_EST_raw.txt → trish/html/Bikolano/MBBBIK92_EST_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_HAB_raw.txt → trish/html/Bikolano/MBBBIK92_HAB_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_PSA_raw.txt → trish/html/Bikolano/MBBBIK92_PSA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_EZR_raw.txt → trish/html/Bikolano/MBBBIK92_EZR_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_PHM_raw.txt → trish/html/Bikolano/MBBBIK92_PHM_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2MA_raw.txt → trish/html/Bikolano/MBBBIK92_2MA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2SA_raw.txt → trish/html/Bikolano/MBBBIK92_2SA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_S3Y_raw.txt → trish/html/Bikolano/MBBBIK92_S3Y_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_SUS_raw.txt → trish/html/Bikolano/MBBBIK92_SUS_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_LJE_raw.txt → trish/html/Bikolano/MBBBIK92_LJE_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ZEP_raw.txt → trish/html/Bikolano/MBBBIK92_ZEP_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_BEL_raw.txt → trish/html/Bikolano/MBBBIK92_BEL_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_PHP_raw.txt → trish/html/Bikolano/MBBBIK92_PHP_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ISA_raw.txt → trish/html/Bikolano/MBBBIK92_ISA_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_ACT_raw.txt → trish/html/Bikolano/MBBBIK92_ACT_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2TH_raw.txt → trish/html/Bikolano/MBBBIK92_2TH_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2CO_raw.txt → trish/html/Bikolano/MBBBIK92_2CO_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JOB_raw.txt → trish/html/Bikolano/MBBBIK92_JOB_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_TIT_raw.txt → trish/html/Bikolano/MBBBIK92_TIT_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2KI_raw.txt → trish/html/Bikolano/MBBBIK92_2KI_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2PE_raw.txt → trish/html/Bikolano/MBBBIK92_2PE_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_JAS_raw.txt → trish/html/Bikolano/MBBBIK92_JAS_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_LEV_raw.txt → trish/html/Bikolano/MBBBIK92_LEV_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_2TI_raw.txt → trish/html/Bikolano/MBBBIK92_2TI_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_TOB_raw.txt → trish/html/Bikolano/MBBBIK92_TOB_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_MIC_raw.txt → trish/html/Bikolano/MBBBIK92_MIC_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_COL_raw.txt → trish/html/Bikolano/MBBBIK92_COL_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_REV_raw.txt → trish/html/Bikolano/MBBBIK92_REV_raw.html
# Converted trish/raw/Bikolano/MBBBIK92_MAL_raw.txt → trish/html/Bikolano/MBBBIK92_MAL_raw.html
#
# Folder trish/raw/Ilokano → trish/html/Ilokano
# Converted trish/raw/Ilokano/RIPV_2PE_raw.txt → trish/html/Ilokano/RIPV_2PE_raw.html
# Converted trish/raw/Ilokano/RIPV_JAS_raw.txt → trish/html/Ilokano/RIPV_JAS_raw.html
# Converted trish/raw/Ilokano/RIPV_LEV_raw.txt → trish/html/Ilokano/RIPV_LEV_raw.html
# Converted trish/raw/Ilokano/RIPV_2KI_raw.txt → trish/html/Ilokano/RIPV_2KI_raw.html
# Converted trish/raw/Ilokano/RIPV_TIT_raw.txt → trish/html/Ilokano/RIPV_TIT_raw.html
# Converted trish/raw/Ilokano/RIPV_JOB_raw.txt → trish/html/Ilokano/RIPV_JOB_raw.html
# Converted trish/raw/Ilokano/RIPV_2TH_raw.txt → trish/html/Ilokano/RIPV_2TH_raw.html
# Converted trish/raw/Ilokano/RIPV_2CO_raw.txt → trish/html/Ilokano/RIPV_2CO_raw.html
# Converted trish/raw/Ilokano/RIPV_ACT_raw.txt → trish/html/Ilokano/RIPV_ACT_raw.html
# Converted trish/raw/Ilokano/RIPV_ISA_raw.txt → trish/html/Ilokano/RIPV_ISA_raw.html
# Converted trish/raw/Ilokano/RIPV_MAL_raw.txt → trish/html/Ilokano/RIPV_MAL_raw.html
# Converted trish/raw/Ilokano/RIPV_REV_raw.txt → trish/html/Ilokano/RIPV_REV_raw.html
# Converted trish/raw/Ilokano/RIPV_COL_raw.txt → trish/html/Ilokano/RIPV_COL_raw.html
# Converted trish/raw/Ilokano/RIPV_MIC_raw.txt → trish/html/Ilokano/RIPV_MIC_raw.html
# Converted trish/raw/Ilokano/RIPV_2TI_raw.txt → trish/html/Ilokano/RIPV_2TI_raw.html
# Converted trish/raw/Ilokano/RIPV_PHM_raw.txt → trish/html/Ilokano/RIPV_PHM_raw.html
# Converted trish/raw/Ilokano/RIPV_EZR_raw.txt → trish/html/Ilokano/RIPV_EZR_raw.html
# Converted trish/raw/Ilokano/RIPV_PSA_raw.txt → trish/html/Ilokano/RIPV_PSA_raw.html
# Converted trish/raw/Ilokano/RIPV_HAB_raw.txt → trish/html/Ilokano/RIPV_HAB_raw.html
# Converted trish/raw/Ilokano/RIPV_EST_raw.txt → trish/html/Ilokano/RIPV_EST_raw.html
# Converted trish/raw/Ilokano/RIPV_JUD_raw.txt → trish/html/Ilokano/RIPV_JUD_raw.html
# Converted trish/raw/Ilokano/RIPV_HOS_raw.txt → trish/html/Ilokano/RIPV_HOS_raw.html
# Converted trish/raw/Ilokano/RIPV_GAL_raw.txt → trish/html/Ilokano/RIPV_GAL_raw.html
# Converted trish/raw/Ilokano/RIPV_1JN_raw.txt → trish/html/Ilokano/RIPV_1JN_raw.html
# Converted trish/raw/Ilokano/RIPV_AMO_raw.txt → trish/html/Ilokano/RIPV_AMO_raw.html
# Converted trish/raw/Ilokano/RIPV_LAM_raw.txt → trish/html/Ilokano/RIPV_LAM_raw.html
# Converted trish/raw/Ilokano/RIPV_1CH_raw.txt → trish/html/Ilokano/RIPV_1CH_raw.html
# Converted trish/raw/Ilokano/RIPV_PHP_raw.txt → trish/html/Ilokano/RIPV_PHP_raw.html
# Converted trish/raw/Ilokano/RIPV_ZEP_raw.txt → trish/html/Ilokano/RIPV_ZEP_raw.html
# Converted trish/raw/Ilokano/RIPV_2SA_raw.txt → trish/html/Ilokano/RIPV_2SA_raw.html
# Converted trish/raw/Ilokano/RIPV_JOL_raw.txt → trish/html/Ilokano/RIPV_JOL_raw.html
# Converted trish/raw/Ilokano/RIPV_JHN_raw.txt → trish/html/Ilokano/RIPV_JHN_raw.html
# Converted trish/raw/Ilokano/RIPV_2CH_raw.txt → trish/html/Ilokano/RIPV_2CH_raw.html
# Converted trish/raw/Ilokano/RIPV_HEB_raw.txt → trish/html/Ilokano/RIPV_HEB_raw.html
# Converted trish/raw/Ilokano/RIPV_2JN_raw.txt → trish/html/Ilokano/RIPV_2JN_raw.html
# Converted trish/raw/Ilokano/RIPV_DEU_raw.txt → trish/html/Ilokano/RIPV_DEU_raw.html
# Converted trish/raw/Ilokano/RIPV_ROM_raw.txt → trish/html/Ilokano/RIPV_ROM_raw.html
# Converted trish/raw/Ilokano/RIPV_RUT_raw.txt → trish/html/Ilokano/RIPV_RUT_raw.html
# Converted trish/raw/Ilokano/RIPV_EZK_raw.txt → trish/html/Ilokano/RIPV_EZK_raw.html
# Converted trish/raw/Ilokano/RIPV_SNG_raw.txt → trish/html/Ilokano/RIPV_SNG_raw.html
# Converted trish/raw/Ilokano/RIPV_1SA_raw.txt → trish/html/Ilokano/RIPV_1SA_raw.html
# Converted trish/raw/Ilokano/RIPV_HAG_raw.txt → trish/html/Ilokano/RIPV_HAG_raw.html
# Converted trish/raw/Ilokano/RIPV_ZEC_raw.txt → trish/html/Ilokano/RIPV_ZEC_raw.html
# Converted trish/raw/Ilokano/RIPV_1TH_raw.txt → trish/html/Ilokano/RIPV_1TH_raw.html
# Converted trish/raw/Ilokano/RIPV_1CO_raw.txt → trish/html/Ilokano/RIPV_1CO_raw.html
# Converted trish/raw/Ilokano/RIPV_JOS_raw.txt → trish/html/Ilokano/RIPV_JOS_raw.html
# Converted trish/raw/Ilokano/RIPV_1KI_raw.txt → trish/html/Ilokano/RIPV_1KI_raw.html
# Converted trish/raw/Ilokano/RIPV_OBA_raw.txt → trish/html/Ilokano/RIPV_OBA_raw.html
# Converted trish/raw/Ilokano/RIPV_PRO_raw.txt → trish/html/Ilokano/RIPV_PRO_raw.html
# Converted trish/raw/Ilokano/RIPV_1PE_raw.txt → trish/html/Ilokano/RIPV_1PE_raw.html
# Converted trish/raw/Ilokano/RIPV_EXO_raw.txt → trish/html/Ilokano/RIPV_EXO_raw.html
# Converted trish/raw/Ilokano/RIPV_NAM_raw.txt → trish/html/Ilokano/RIPV_NAM_raw.html
# Converted trish/raw/Ilokano/RIPV_ECC_raw.txt → trish/html/Ilokano/RIPV_ECC_raw.html
# Converted trish/raw/Ilokano/RIPV_LUK_raw.txt → trish/html/Ilokano/RIPV_LUK_raw.html
# Converted trish/raw/Ilokano/RIPV_3JN_raw.txt → trish/html/Ilokano/RIPV_3JN_raw.html
# Converted trish/raw/Ilokano/RIPV_GEN_raw.txt → trish/html/Ilokano/RIPV_GEN_raw.html
# Converted trish/raw/Ilokano/RIPV_JER_raw.txt → trish/html/Ilokano/RIPV_JER_raw.html
# Converted trish/raw/Ilokano/RIPV_JON_raw.txt → trish/html/Ilokano/RIPV_JON_raw.html
# Converted trish/raw/Ilokano/RIPV_JDG_raw.txt → trish/html/Ilokano/RIPV_JDG_raw.html
# Converted trish/raw/Ilokano/RIPV_EPH_raw.txt → trish/html/Ilokano/RIPV_EPH_raw.html
# Converted trish/raw/Ilokano/RIPV_MAT_raw.txt → trish/html/Ilokano/RIPV_MAT_raw.html
# Converted trish/raw/Ilokano/RIPV_1TI_raw.txt → trish/html/Ilokano/RIPV_1TI_raw.html
# Converted trish/raw/Ilokano/RIPV_NUM_raw.txt → trish/html/Ilokano/RIPV_NUM_raw.html
# Converted trish/raw/Ilokano/RIPV_MRK_raw.txt → trish/html/Ilokano/RIPV_MRK_raw.html
# Converted trish/raw/Ilokano/RIPV_DAN_raw.txt → trish/html/Ilokano/RIPV_DAN_raw.html
# Converted trish/raw/Ilokano/RIPV_NEH_raw.txt → trish/html/Ilokano/RIPV_NEH_raw.html
#
# Folder trish/raw/Kalinga → trish/html/Kalinga
# Converted trish/raw/Kalinga/kmk_PHP_raw.txt → trish/html/Kalinga/kmk_PHP_raw.html
# Converted trish/raw/Kalinga/kmk_PHM_raw.txt → trish/html/Kalinga/kmk_PHM_raw.html
# Converted trish/raw/Kalinga/kmk_JUD_raw.txt → trish/html/Kalinga/kmk_JUD_raw.html
# Converted trish/raw/Kalinga/kmk_1JN_raw.txt → trish/html/Kalinga/kmk_1JN_raw.html
# Converted trish/raw/Kalinga/kmk_GAL_raw.txt → trish/html/Kalinga/kmk_GAL_raw.html
# Converted trish/raw/Kalinga/kmk_REV_raw.txt → trish/html/Kalinga/kmk_REV_raw.html
# Converted trish/raw/Kalinga/kmk_COL_raw.txt → trish/html/Kalinga/kmk_COL_raw.html
# Converted trish/raw/Kalinga/kmk_2TI_raw.txt → trish/html/Kalinga/kmk_2TI_raw.html
# Converted trish/raw/Kalinga/kmk_JAS_raw.txt → trish/html/Kalinga/kmk_JAS_raw.html
# Converted trish/raw/Kalinga/kmk_2PE_raw.txt → trish/html/Kalinga/kmk_2PE_raw.html
# Converted trish/raw/Kalinga/kmk_TIT_raw.txt → trish/html/Kalinga/kmk_TIT_raw.html
# Converted trish/raw/Kalinga/kmk_2CO_raw.txt → trish/html/Kalinga/kmk_2CO_raw.html
# Converted trish/raw/Kalinga/kmk_2TH_raw.txt → trish/html/Kalinga/kmk_2TH_raw.html
# Converted trish/raw/Kalinga/kmk_ACT_raw.txt → trish/html/Kalinga/kmk_ACT_raw.html
# Converted trish/raw/Kalinga/kmk_EPH_raw.txt → trish/html/Kalinga/kmk_EPH_raw.html
# Converted trish/raw/Kalinga/kmk_1TI_raw.txt → trish/html/Kalinga/kmk_1TI_raw.html
# Converted trish/raw/Kalinga/kmk_MAT_raw.txt → trish/html/Kalinga/kmk_MAT_raw.html
# Converted trish/raw/Kalinga/kmk_MRK_raw.txt → trish/html/Kalinga/kmk_MRK_raw.html
# Converted trish/raw/Kalinga/kmk_1CO_raw.txt → trish/html/Kalinga/kmk_1CO_raw.html
# Converted trish/raw/Kalinga/kmk_1TH_raw.txt → trish/html/Kalinga/kmk_1TH_raw.html
# Converted trish/raw/Kalinga/kmk_1PE_raw.txt → trish/html/Kalinga/kmk_1PE_raw.html
# Converted trish/raw/Kalinga/kmk_3JN_raw.txt → trish/html/Kalinga/kmk_3JN_raw.html
# Converted trish/raw/Kalinga/kmk_LUK_raw.txt → trish/html/Kalinga/kmk_LUK_raw.html
# Converted trish/raw/Kalinga/kmk_ROM_raw.txt → trish/html/Kalinga/kmk_ROM_raw.html
# Converted trish/raw/Kalinga/kmk_JHN_raw.txt → trish/html/Kalinga/kmk_JHN_raw.html
# Converted trish/raw/Kalinga/kmk_HEB_raw.txt → trish/html/Kalinga/kmk_HEB_raw.html
# Converted trish/raw/Kalinga/kmk_2JN_raw.txt → trish/html/Kalinga/kmk_2JN_raw.html
#
# Folder trish/raw/Kapampangan → trish/html/Kapampangan
# Converted trish/raw/Kapampangan/PmPV_2SA_raw.txt → trish/html/Kapampangan/PmPV_2SA_raw.html
# Converted trish/raw/Kapampangan/PmPV_S3Y_raw.txt → trish/html/Kapampangan/PmPV_S3Y_raw.html
# ...
# Converted trish/raw/Kapampangan/PmPV_JOB_raw.txt → trish/html/Kapampangan/PmPV_JOB_raw.html
# Converted trish/raw/Kapampangan/PmPV_2KI_raw.txt → trish/html/Kapampangan/PmPV_2KI_raw.html
# Converted trish/raw/Kapampangan/PmPV_2PE_raw.txt → trish/html/Kapampangan/PmPV_2PE_raw.html
# Converted trish/raw/Kapampangan/PmPV_LEV_raw.txt → trish/html/Kapampangan/PmPV_LEV_raw.html
# Converted trish/raw/Kapampangan/PmPV_JAS_raw.txt → trish/html/Kapampangan/PmPV_JAS_raw.html
# Converted trish/raw/Kapampangan/PmPV_DAN_raw.txt → trish/html/Kapampangan/PmPV_DAN_raw.html
# Converted trish/raw/Kapampangan/PmPV_NEH_raw.txt → trish/html/Kapampangan/PmPV_NEH_raw.html
# Converted trish/raw/Kapampangan/PmPV_NUM_raw.txt → trish/html/Kapampangan/PmPV_NUM_raw.html
# Converted trish/raw/Kapampangan/PmPV_MRK_raw.txt → trish/html/Kapampangan/PmPV_MRK_raw.html
# Converted trish/raw/Kapampangan/PmPV_MAT_raw.txt → trish/html/Kapampangan/PmPV_MAT_raw.html
# Converted trish/raw/Kapampangan/PmPV_1TI_raw.txt → trish/html/Kapampangan/PmPV_1TI_raw.html
# Converted trish/raw/Kapampangan/PmPV_EPH_raw.txt → trish/html/Kapampangan/PmPV_EPH_raw.html
# Converted trish/raw/Kapampangan/PmPV_JON_raw.txt → trish/html/Kapampangan/PmPV_JON_raw.html
# Converted trish/raw/Kapampangan/PmPV_JDG_raw.txt → trish/html/Kapampangan/PmPV_JDG_raw.html
# Converted trish/raw/Kapampangan/PmPV_JER_raw.txt → trish/html/Kapampangan/PmPV_JER_raw.html
# Converted trish/raw/Kapampangan/PmPV_GEN_raw.txt → trish/html/Kapampangan/PmPV_GEN_raw.html
# Converted trish/raw/Kapampangan/PmPV_LUK_raw.txt → trish/html/Kapampangan/PmPV_LUK_raw.html
# Converted trish/raw/Kapampangan/PmPV_3JN_raw.txt → trish/html/Kapampangan/PmPV_3JN_raw.html
# Converted trish/raw/Kapampangan/PmPV_NAM_raw.txt → trish/html/Kapampangan/PmPV_NAM_raw.html
# Converted trish/raw/Kapampangan/PmPV_ECC_raw.txt → trish/html/Kapampangan/PmPV_ECC_raw.html
# Converted trish/raw/Kapampangan/PmPV_EXO_raw.txt → trish/html/Kapampangan/PmPV_EXO_raw.html
# Converted trish/raw/Kapampangan/PmPV_PRO_raw.txt → trish/html/Kapampangan/PmPV_PRO_raw.html
# Converted trish/raw/Kapampangan/PmPV_OBA_raw.txt → trish/html/Kapampangan/PmPV_OBA_raw.html
# Converted trish/raw/Kapampangan/PmPV_1PE_raw.txt → trish/html/Kapampangan/PmPV_1PE_raw.html
# Converted trish/raw/Kapampangan/PmPV_SIR_raw.txt → trish/html/Kapampangan/PmPV_SIR_raw.html
# Converted trish/raw/Kapampangan/PmPV_1KI_raw.txt → trish/html/Kapampangan/PmPV_1KI_raw.html
# Converted trish/raw/Kapampangan/PmPV_BAR_raw.txt → trish/html/Kapampangan/PmPV_BAR_raw.html
# Converted trish/raw/Kapampangan/PmPV_JOS_raw.txt → trish/html/Kapampangan/PmPV_JOS_raw.html
# Converted trish/raw/Kapampangan/PmPV_1TH_raw.txt → trish/html/Kapampangan/PmPV_1TH_raw.html
# Converted trish/raw/Kapampangan/PmPV_ZEC_raw.txt → trish/html/Kapampangan/PmPV_ZEC_raw.html
# Converted trish/raw/Kapampangan/PmPV_1CO_raw.txt → trish/html/Kapampangan/PmPV_1CO_raw.html
# Converted trish/raw/Kapampangan/PmPV_HAG_raw.txt → trish/html/Kapampangan/PmPV_HAG_raw.html
# Converted trish/raw/Kapampangan/PmPV_1SA_raw.txt → trish/html/Kapampangan/PmPV_1SA_raw.html
# Converted trish/raw/Kapampangan/PmPV_SNG_raw.txt → trish/html/Kapampangan/PmPV_SNG_raw.html
# Converted trish/raw/Kapampangan/PmPV_ROM_raw.txt → trish/html/Kapampangan/PmPV_ROM_raw.html
# Converted trish/raw/Kapampangan/PmPV_RUT_raw.txt → trish/html/Kapampangan/PmPV_RUT_raw.html
# Converted trish/raw/Kapampangan/PmPV_EZK_raw.txt → trish/html/Kapampangan/PmPV_EZK_raw.html
# Converted trish/raw/Kapampangan/PmPV_DEU_raw.txt → trish/html/Kapampangan/PmPV_DEU_raw.html
# Converted trish/raw/Kapampangan/PmPV_2JN_raw.txt → trish/html/Kapampangan/PmPV_2JN_raw.html
# Converted trish/raw/Kapampangan/PmPV_HEB_raw.txt → trish/html/Kapampangan/PmPV_HEB_raw.html
# Converted trish/raw/Kapampangan/PmPV_2CH_raw.txt → trish/html/Kapampangan/PmPV_2CH_raw.html
# Converted trish/raw/Kapampangan/PmPV_1MA_raw.txt → trish/html/Kapampangan/PmPV_1MA_raw.html
# Converted trish/raw/Kapampangan/PmPV_JHN_raw.txt → trish/html/Kapampangan/PmPV_JHN_raw.html
# Converted trish/raw/Kapampangan/PmPV_JOL_raw.txt → trish/html/Kapampangan/PmPV_JOL_raw.html
#
# Folder enz/raw/Isnag → enz/html/Isnag
# Converted enz/raw/Isnag/ISDNT_ROM_raw.txt → enz/html/Isnag/ISDNT_ROM_raw.html
# Converted enz/raw/Isnag/ISDNT_JHN_raw.txt → enz/html/Isnag/ISDNT_JHN_raw.html
# Converted enz/raw/Isnag/ISDNT_HEB_raw.txt → enz/html/Isnag/ISDNT_HEB_raw.html
# Converted enz/raw/Isnag/ISDNT_2JN_raw.txt → enz/html/Isnag/ISDNT_2JN_raw.html
# Converted enz/raw/Isnag/ISDNT_GEN_raw.txt → enz/html/Isnag/ISDNT_GEN_raw.html
# Converted enz/raw/Isnag/ISDNT_EPH_raw.txt → enz/html/Isnag/ISDNT_EPH_raw.html
# Converted enz/raw/Isnag/ISDNT_MAT_raw.txt → enz/html/Isnag/ISDNT_MAT_raw.html
# Converted enz/raw/Isnag/ISDNT_1TI_raw.txt → enz/html/Isnag/ISDNT_1TI_raw.html
# Converted enz/raw/Isnag/ISDNT_MRK_raw.txt → enz/html/Isnag/ISDNT_MRK_raw.html
# Converted enz/raw/Isnag/ISDNT_1TH_raw.txt → enz/html/Isnag/ISDNT_1TH_raw.html
# Converted enz/raw/Isnag/ISDNT_1CO_raw.txt → enz/html/Isnag/ISDNT_1CO_raw.html
# Converted enz/raw/Isnag/ISDNT_1PE_raw.txt → enz/html/Isnag/ISDNT_1PE_raw.html
# Converted enz/raw/Isnag/ISDNT_EXO_raw.txt → enz/html/Isnag/ISDNT_EXO_raw.html
# Converted enz/raw/Isnag/ISDNT_LUK_raw.txt → enz/html/Isnag/ISDNT_LUK_raw.html
# Converted enz/raw/Isnag/ISDNT_3JN_raw.txt → enz/html/Isnag/ISDNT_3JN_raw.html
# Converted enz/raw/Isnag/ISDNT_REV_raw.txt → enz/html/Isnag/ISDNT_REV_raw.html
# Converted enz/raw/Isnag/ISDNT_COL_raw.txt → enz/html/Isnag/ISDNT_COL_raw.html
# Converted enz/raw/Isnag/ISDNT_2TI_raw.txt → enz/html/Isnag/ISDNT_2TI_raw.html
# Converted enz/raw/Isnag/ISDNT_2PE_raw.txt → enz/html/Isnag/ISDNT_2PE_raw.html
# Converted enz/raw/Isnag/ISDNT_JAS_raw.txt → enz/html/Isnag/ISDNT_JAS_raw.html
# Converted enz/raw/Isnag/ISDNT_2TH_raw.txt → enz/html/Isnag/ISDNT_2TH_raw.html
# Converted enz/raw/Isnag/ISDNT_2CO_raw.txt → enz/html/Isnag/ISDNT_2CO_raw.html
# Converted enz/raw/Isnag/ISDNT_TIT_raw.txt → enz/html/Isnag/ISDNT_TIT_raw.html
# Converted enz/raw/Isnag/ISDNT_ACT_raw.txt → enz/html/Isnag/ISDNT_ACT_raw.html
# Converted enz/raw/Isnag/ISDNT_PHP_raw.txt → enz/html/Isnag/ISDNT_PHP_raw.html
# Converted enz/raw/Isnag/ISDNT_PHM_raw.txt → enz/html/Isnag/ISDNT_PHM_raw.html
# Converted enz/raw/Isnag/ISDNT_JUD_raw.txt → enz/html/Isnag/ISDNT_JUD_raw.html
# Converted enz/raw/Isnag/ISDNT_GAL_raw.txt → enz/html/Isnag/ISDNT_GAL_raw.html
# Converted enz/raw/Isnag/ISDNT_1JN_raw.txt → enz/html/Isnag/ISDNT_1JN_raw.html
#
# Folder enz/raw/Kankanaey → enz/html/Kankanaey
# Converted enz/raw/Kankanaey/XNN_1JN_raw.txt → enz/html/Kankanaey/XNN_1JN_raw.html
# Converted enz/raw/Kankanaey/XNN_GAL_raw.txt → enz/html/Kankanaey/XNN_GAL_raw.html
# Converted enz/raw/Kankanaey/XNN_AMO_raw.txt → enz/html/Kankanaey/XNN_AMO_raw.html
# Converted enz/raw/Kankanaey/XNN_WIS_raw.txt → enz/html/Kankanaey/XNN_WIS_raw.html
# Converted enz/raw/Kankanaey/XNN_HAB_raw.txt → enz/html/Kankanaey/XNN_HAB_raw.html
# Converted enz/raw/Kankanaey/XNN_PSA_raw.txt → enz/html/Kankanaey/XNN_PSA_raw.html
# Converted enz/raw/Kankanaey/XNN_PHM_raw.txt → enz/html/Kankanaey/XNN_PHM_raw.html
# Converted enz/raw/Kankanaey/XNN_HOS_raw.txt → enz/html/Kankanaey/XNN_HOS_raw.html
# Converted enz/raw/Kankanaey/XNN_JDT_raw.txt → enz/html/Kankanaey/XNN_JDT_raw.html
# Converted enz/raw/Kankanaey/XNN_JUD_raw.txt → enz/html/Kankanaey/XNN_JUD_raw.html
# Converted enz/raw/Kankanaey/XNN_2SA_raw.txt → enz/html/Kankanaey/XNN_2SA_raw.html
# Converted enz/raw/Kankanaey/XNN_PHP_raw.txt → enz/html/Kankanaey/XNN_PHP_raw.html
# Converted enz/raw/Kankanaey/XNN_ZEP_raw.txt → enz/html/Kankanaey/XNN_ZEP_raw.html
# Converted enz/raw/Kankanaey/XNN_ACT_raw.txt → enz/html/Kankanaey/XNN_ACT_raw.html
# Converted enz/raw/Kankanaey/XNN_ISA_raw.txt → enz/html/Kankanaey/XNN_ISA_raw.html
# Converted enz/raw/Kankanaey/XNN_2KI_raw.txt → enz/html/Kankanaey/XNN_2KI_raw.html
# Converted enz/raw/Kankanaey/XNN_JAS_raw.txt → enz/html/Kankanaey/XNN_JAS_raw.html
# Converted enz/raw/Kankanaey/XNN_LEV_raw.txt → enz/html/Kankanaey/XNN_LEV_raw.html
# Converted enz/raw/Kankanaey/XNN_2PE_raw.txt → enz/html/Kankanaey/XNN_2PE_raw.html
# Converted enz/raw/Kankanaey/XNN_2CO_raw.txt → enz/html/Kankanaey/XNN_2CO_raw.html
# Converted enz/raw/Kankanaey/XNN_2TH_raw.txt → enz/html/Kankanaey/XNN_2TH_raw.html
# Converted enz/raw/Kankanaey/XNN_TIT_raw.txt → enz/html/Kankanaey/XNN_TIT_raw.html
# Converted enz/raw/Kankanaey/XNN_JOB_raw.txt → enz/html/Kankanaey/XNN_JOB_raw.html
# Converted enz/raw/Kankanaey/XNN_MIC_raw.txt → enz/html/Kankanaey/XNN_MIC_raw.html
# Converted enz/raw/Kankanaey/XNN_REV_raw.txt → enz/html/Kankanaey/XNN_REV_raw.html
# Converted enz/raw/Kankanaey/XNN_COL_raw.txt → enz/html/Kankanaey/XNN_COL_raw.html
# Converted enz/raw/Kankanaey/XNN_2TI_raw.txt → enz/html/Kankanaey/XNN_2TI_raw.html
# Converted enz/raw/Kankanaey/XNN_MAL_raw.txt → enz/html/Kankanaey/XNN_MAL_raw.html
# Converted enz/raw/Kankanaey/XNN_ECC_raw.txt → enz/html/Kankanaey/XNN_ECC_raw.html
# Converted enz/raw/Kankanaey/XNN_EXO_raw.txt → enz/html/Kankanaey/XNN_EXO_raw.html
# Converted enz/raw/Kankanaey/XNN_3JN_raw.txt → enz/html/Kankanaey/XNN_3JN_raw.html
# Converted enz/raw/Kankanaey/XNN_LUK_raw.txt → enz/html/Kankanaey/XNN_LUK_raw.html
# Converted enz/raw/Kankanaey/XNN_JOS_raw.txt → enz/html/Kankanaey/XNN_JOS_raw.html
# Converted enz/raw/Kankanaey/XNN_BAR_raw.txt → enz/html/Kankanaey/XNN_BAR_raw.html
# Converted enz/raw/Kankanaey/XNN_1CO_raw.txt → enz/html/Kankanaey/XNN_1CO_raw.html
# Converted enz/raw/Kankanaey/XNN_ZEC_raw.txt → enz/html/Kankanaey/XNN_ZEC_raw.html
# Converted enz/raw/Kankanaey/XNN_1TH_raw.txt → enz/html/Kankanaey/XNN_1TH_raw.html
# Converted enz/raw/Kankanaey/XNN_PRO_raw.txt → enz/html/Kankanaey/XNN_PRO_raw.html
# Converted enz/raw/Kankanaey/XNN_1PE_raw.txt → enz/html/Kankanaey/XNN_1PE_raw.html
# Converted enz/raw/Kankanaey/XNN_1KI_raw.txt → enz/html/Kankanaey/XNN_1KI_raw.html
# Converted enz/raw/Kankanaey/XNN_SIR_raw.txt → enz/html/Kankanaey/XNN_SIR_raw.html
# Converted enz/raw/Kankanaey/XNN_1TI_raw.txt → enz/html/Kankanaey/XNN_1TI_raw.html
# Converted enz/raw/Kankanaey/XNN_MAT_raw.txt → enz/html/Kankanaey/XNN_MAT_raw.html
# Converted enz/raw/Kankanaey/XNN_NEH_raw.txt → enz/html/Kankanaey/XNN_NEH_raw.html
# Converted enz/raw/Kankanaey/XNN_DAN_raw.txt → enz/html/Kankanaey/XNN_DAN_raw.html
# Converted enz/raw/Kankanaey/XNN_NUM_raw.txt → enz/html/Kankanaey/XNN_NUM_raw.html
# Converted enz/raw/Kankanaey/XNN_MRK_raw.txt → enz/html/Kankanaey/XNN_MRK_raw.html
# Converted enz/raw/Kankanaey/XNN_JDG_raw.txt → enz/html/Kankanaey/XNN_JDG_raw.html
# Converted enz/raw/Kankanaey/XNN_JON_raw.txt → enz/html/Kankanaey/XNN_JON_raw.html
# Converted enz/raw/Kankanaey/XNN_JER_raw.txt → enz/html/Kankanaey/XNN_JER_raw.html
# Converted enz/raw/Kankanaey/XNN_GEN_raw.txt → enz/html/Kankanaey/XNN_GEN_raw.html
# Converted enz/raw/Kankanaey/XNN_EPH_raw.txt → enz/html/Kankanaey/XNN_EPH_raw.html
# Converted enz/raw/Kankanaey/XNN_HEB_raw.txt → enz/html/Kankanaey/XNN_HEB_raw.html
# Converted enz/raw/Kankanaey/XNN_2CH_raw.txt → enz/html/Kankanaey/XNN_2CH_raw.html
# Converted enz/raw/Kankanaey/XNN_2JN_raw.txt → enz/html/Kankanaey/XNN_2JN_raw.html
# Converted enz/raw/Kankanaey/XNN_JHN_raw.txt → enz/html/Kankanaey/XNN_JHN_raw.html
# Converted enz/raw/Kankanaey/XNN_JOL_raw.txt → enz/html/Kankanaey/XNN_JOL_raw.html
# Converted enz/raw/Kankanaey/XNN_1SA_raw.txt → enz/html/Kankanaey/XNN_1SA_raw.html
# Converted enz/raw/Kankanaey/XNN_DEU_raw.txt → enz/html/Kankanaey/XNN_DEU_raw.html
# Converted enz/raw/Kankanaey/XNN_RUT_raw.txt → enz/html/Kankanaey/XNN_RUT_raw.html
# Converted enz/raw/Kankanaey/XNN_EZK_raw.txt → enz/html/Kankanaey/XNN_EZK_raw.html
# Converted enz/raw/Kankanaey/XNN_ROM_raw.txt → enz/html/Kankanaey/XNN_ROM_raw.html
#
# Folder enz/raw/Sambal → enz/html/Sambal
# Converted enz/raw/Sambal/XSB_JHN_raw.txt → enz/html/Sambal/XSB_JHN_raw.html
# Converted enz/raw/Sambal/XSB_HEB_raw.txt → enz/html/Sambal/XSB_HEB_raw.html
# Converted enz/raw/Sambal/XSB_2JN_raw.txt → enz/html/Sambal/XSB_2JN_raw.html
# Converted enz/raw/Sambal/XSB_ROM_raw.txt → enz/html/Sambal/XSB_ROM_raw.html
# Converted enz/raw/Sambal/XSB_1CO_raw.txt → enz/html/Sambal/XSB_1CO_raw.html
# Converted enz/raw/Sambal/XSB_1TH_raw.txt → enz/html/Sambal/XSB_1TH_raw.html
# Converted enz/raw/Sambal/XSB_1PE_raw.txt → enz/html/Sambal/XSB_1PE_raw.html
# Converted enz/raw/Sambal/XSB_3JN_raw.txt → enz/html/Sambal/XSB_3JN_raw.html
# Converted enz/raw/Sambal/XSB_LUK_raw.txt → enz/html/Sambal/XSB_LUK_raw.html
# Converted enz/raw/Sambal/XSB_EPH_raw.txt → enz/html/Sambal/XSB_EPH_raw.html
# Converted enz/raw/Sambal/XSB_1TI_raw.txt → enz/html/Sambal/XSB_1TI_raw.html
# Converted enz/raw/Sambal/XSB_MAT_raw.txt → enz/html/Sambal/XSB_MAT_raw.html
# Converted enz/raw/Sambal/XSB_MRK_raw.txt → enz/html/Sambal/XSB_MRK_raw.html
# Converted enz/raw/Sambal/XSB_JAS_raw.txt → enz/html/Sambal/XSB_JAS_raw.html
# Converted enz/raw/Sambal/XSB_2PE_raw.txt → enz/html/Sambal/XSB_2PE_raw.html
# Converted enz/raw/Sambal/XSB_TIT_raw.txt → enz/html/Sambal/XSB_TIT_raw.html
# Converted enz/raw/Sambal/XSB_2CO_raw.txt → enz/html/Sambal/XSB_2CO_raw.html
# Converted enz/raw/Sambal/XSB_2TH_raw.txt → enz/html/Sambal/XSB_2TH_raw.html
# Converted enz/raw/Sambal/XSB_ACT_raw.txt → enz/html/Sambal/XSB_ACT_raw.html
# Converted enz/raw/Sambal/XSB_COL_raw.txt → enz/html/Sambal/XSB_COL_raw.html
# Converted enz/raw/Sambal/XSB_REV_raw.txt → enz/html/Sambal/XSB_REV_raw.html
# Converted enz/raw/Sambal/XSB_2TI_raw.txt → enz/html/Sambal/XSB_2TI_raw.html
# Converted enz/raw/Sambal/XSB_PHM_raw.txt → enz/html/Sambal/XSB_PHM_raw.html
# Converted enz/raw/Sambal/XSB_JUD_raw.txt → enz/html/Sambal/XSB_JUD_raw.html
# Converted enz/raw/Sambal/XSB_1JN_raw.txt → enz/html/Sambal/XSB_1JN_raw.html
# Converted enz/raw/Sambal/XSB_GAL_raw.txt → enz/html/Sambal/XSB_GAL_raw.html
# Converted enz/raw/Sambal/XSB_PHP_raw.txt → enz/html/Sambal/XSB_PHP_raw.html
#
# Folder enz/raw/Yakan → enz/html/Yakan
# Converted enz/raw/Yakan/YAKV_2TI_raw.txt → enz/html/Yakan/YAKV_2TI_raw.html
# Converted enz/raw/Yakan/YAKV_COL_raw.txt → enz/html/Yakan/YAKV_COL_raw.html
# Converted enz/raw/Yakan/YAKV_REV_raw.txt → enz/html/Yakan/YAKV_REV_raw.html
# Converted enz/raw/Yakan/YAKV_ACT_raw.txt → enz/html/Yakan/YAKV_ACT_raw.html
# Converted enz/raw/Yakan/YAKV_2TH_raw.txt → enz/html/Yakan/YAKV_2TH_raw.html
# Converted enz/raw/Yakan/YAKV_2CO_raw.txt → enz/html/Yakan/YAKV_2CO_raw.html
# Converted enz/raw/Yakan/YAKV_TIT_raw.txt → enz/html/Yakan/YAKV_TIT_raw.html
# Converted enz/raw/Yakan/YAKV_2PE_raw.txt → enz/html/Yakan/YAKV_2PE_raw.html
# Converted enz/raw/Yakan/YAKV_JAS_raw.txt → enz/html/Yakan/YAKV_JAS_raw.html
# Converted enz/raw/Yakan/YAKV_PHP_raw.txt → enz/html/Yakan/YAKV_PHP_raw.html
# Converted enz/raw/Yakan/YAKV_GAL_raw.txt → enz/html/Yakan/YAKV_GAL_raw.html
# Converted enz/raw/Yakan/YAKV_1JN_raw.txt → enz/html/Yakan/YAKV_1JN_raw.html
# Converted enz/raw/Yakan/YAKV_JUD_raw.txt → enz/html/Yakan/YAKV_JUD_raw.html
# Converted enz/raw/Yakan/YAKV_PHM_raw.txt → enz/html/Yakan/YAKV_PHM_raw.html
# Converted enz/raw/Yakan/YAKV_ROM_raw.txt → enz/html/Yakan/YAKV_ROM_raw.html
# Converted enz/raw/Yakan/YAKV_RUT_raw.txt → enz/html/Yakan/YAKV_RUT_raw.html
# Converted enz/raw/Yakan/YAKV_2JN_raw.txt → enz/html/Yakan/YAKV_2JN_raw.html
# Converted enz/raw/Yakan/YAKV_HEB_raw.txt → enz/html/Yakan/YAKV_HEB_raw.html
# Converted enz/raw/Yakan/YAKV_JHN_raw.txt → enz/html/Yakan/YAKV_JHN_raw.html
# Converted enz/raw/Yakan/YAKV_MRK_raw.txt → enz/html/Yakan/YAKV_MRK_raw.html
# Converted enz/raw/Yakan/YAKV_MAT_raw.txt → enz/html/Yakan/YAKV_MAT_raw.html
# Converted enz/raw/Yakan/YAKV_1TI_raw.txt → enz/html/Yakan/YAKV_1TI_raw.html
# Converted enz/raw/Yakan/YAKV_EPH_raw.txt → enz/html/Yakan/YAKV_EPH_raw.html
# Converted enz/raw/Yakan/YAKV_JON_raw.txt → enz/html/Yakan/YAKV_JON_raw.html
# Converted enz/raw/Yakan/YAKV_GEN_raw.txt → enz/html/Yakan/YAKV_GEN_raw.html
# Converted enz/raw/Yakan/YAKV_LUK_raw.txt → enz/html/Yakan/YAKV_LUK_raw.html
# Converted enz/raw/Yakan/YAKV_3JN_raw.txt → enz/html/Yakan/YAKV_3JN_raw.html
# Converted enz/raw/Yakan/YAKV_1PE_raw.txt → enz/html/Yakan/YAKV_1PE_raw.html
# Converted enz/raw/Yakan/YAKV_1TH_raw.txt → enz/html/Yakan/YAKV_1TH_raw.html
# Converted enz/raw/Yakan/YAKV_1CO_raw.txt → enz/html/Yakan/YAKV_1CO_raw.html
#
# Done. Converted 791 file(s).

# %% [markdown]
# ### Step 3: Parse HTML Files into Structured CSV and TXT Outputs
# Once the `.html` files have been generated, the next stage is to parse them into structured tabular data for analysis. The script below handles this by reading verse spans from HTML, extracting metadata, and producing parallel `.csv` and `.txt` files for each language dataset. This stage converts the cleaned HTML corpus into normalized, language-specific `.csv` and `.txt` files, providing a standardized dataset.
#
#
# **Configuration**
# - `LANG_DIRS` lists all the language folders to be processed (e.g., Cebuano, Spanish, Chavacano, etc.).
# - `SRC_SEGMENT = "html"` identifies the location of the input files.
# - `DST_SEGMENT = "parsed"` defines the destination where outputs will be written.
#
# Helper functions (`to_src_root`, `to_dst_root`, and `replace_segment`) ensure that the folder structure is preserved, with only the path segment swapped (`html → parsed`).
#
# **HTML Parsing**
# - Each `.html` file is read and parsed using **BeautifulSoup** (with `lxml` if available).
# - Verses are identified by the CSS selector `span.verse[data-usfm]`.
# - Inside each verse:
#   - Child spans such as labels or notes are removed.
#   - Remaining text fragments are normalized (whitespace collapsed, punctuation spacing fixed).
#   - Metadata (book, chapter, verse) is parsed from the `data-usfm` attribute.
#   - Additional fields such as language code (`iso6393`) and version ID (`vid`) are extracted from parent `<div class="version">`.
#
# **Handling Tables**
# - Any `<table>` elements encountered in the HTML are intentionally discarded during parsing. This ensures that only verse text and metadata are retained, preventing structural markup or formatting artifacts from polluting the output dataset.
#
# **DataFrame Assembly**
# - Extracted rows are assembled into a **Pandas DataFrame** using `rows_to_df`.
# - Missing book/chapter/verse fields are back-filled from the `usfm` string.
# - Data is sorted by canonical order (`book`, `chapter`, `verse`).
#
# **Output Generation**
# For each input `.html` file:
# - A corresponding `.csv` file is written with structured columns (`usfm`, `book`, `chapter`, `verse`, `text`, `iso6393`, `vid`).
# - A `.txt` file is also written, containing verse-level text prefixed by its `usfm` code.
#
# **Logging and Error Handling**
# - Empty outputs (no verses found) are tracked separately.
# - Errors during parsing are collected and summarized at the end.
# - A final summary prints:
#   - Total files processed
#   - Number of empty outputs
#   - Number of errors

# %%
# CHANGE: List all source folders that contain .html files

LANG_DIRS = [
    "yna/html/Cebuano",
    "yna/html/Spanish",
    "yna/html/Chavacano",
    "yna/html/Tausug",
    "cj/html/Ivatan",
    "cj/html/Pangasinense",
    "cj/html/Tagalog",
    "cj/html/Yami",
    "trish/html/Bikolano",
    "trish/html/Ilokano",
    "trish/html/Kalinga",
    "trish/html/Kapampangan",
    "enz/html/Isnag",
    "enz/html/Kankanaey",
    "enz/html/Sambal",
    "enz/html/Yakan",
]

SRC_SEGMENT = "html"    
DST_SEGMENT = "parsed"   

_PARSER = "lxml"

# %%
# helper functions

def replace_segment(path: str, old_seg: str, new_seg: str) -> str:
    parts = path.split(os.sep)
    for i, p in enumerate(parts):
        if p == old_seg:
            parts[i] = new_seg
            return os.sep.join(parts)
    parent, leaf = os.path.split(path)
    if parent:
        return os.path.join(os.path.dirname(parent), new_seg, leaf)
    return os.path.join(new_seg, leaf)

def to_src_root(lang_dir: str) -> str:
    """
    Given a LANG_DIR (which may contain 'sentence' or 'raw' or already 'html'),
    produce the source root where .html files are located.
    """
    parts = lang_dir.split(os.sep)
    if "sentence" in parts:
        return replace_segment(lang_dir, "sentence", SRC_SEGMENT)
    if "raw" in parts:
        return replace_segment(lang_dir, "raw", SRC_SEGMENT)
    return lang_dir

def to_dst_root(src_root: str) -> str:
    """
    Given a source root that contains the SRC_SEGMENT, swap that segment to DST_SEGMENT.
    """
    parts = src_root.split(os.sep)
    if SRC_SEGMENT in parts:
        return replace_segment(src_root, SRC_SEGMENT, DST_SEGMENT)
    parent, leaf = os.path.split(src_root)
    return os.path.join(os.path.dirname(parent), DST_SEGMENT, leaf)

def _norm_space(s: str) -> str:
    s = re.sub(r"\s+", " ", s).strip()
    s = re.sub(r"\s+([,.;:?!])", r"\1", s)
    s = re.sub(r"\s+([”\)\]])", r"\1", s)
    return s

def parse_usfm_html(raw_html: str):
    soup = BeautifulSoup(raw_html, _PARSER)

    for tbl in soup.find_all("table"):
        tbl.decompose()

    parts_by_usfm = OrderedDict()

    for vtag in soup.select('span.verse[data-usfm]'):
        usfm = vtag.get("data-usfm")
        if not usfm:
            continue

        for t in vtag.select("span.label, span.note"):
            t.decompose()

        frag = " ".join(s.strip() for s in vtag.stripped_strings)
        frag = _norm_space(frag)
        if frag:
            parts_by_usfm.setdefault(usfm, []).append(frag)

    rows = []
    for usfm, frags in parts_by_usfm.items():
        text = _norm_space(" ".join(frags))
        book = ch = ver = None
        try:
            book, ch, ver = usfm.split(".")
            ch = int(ch); ver = int(ver)
        except Exception:
            pass

        vmeta = soup.select_one(f'span.verse[data-usfm="{usfm}"]')
        iso = vid = None
        if vmeta:
            ver_div = vmeta.find_parent("div", class_="version")
            if ver_div:
                iso = ver_div.get("data-iso6393")
                vid = ver_div.get("data-vid")

        rows.append({
            "usfm": usfm,
            "book": book,
            "chapter": ch,
            "verse": ver,
            "text": text,
            "iso6393": iso,
            "vid": vid,
        })
    return rows

# def expand_multi_usfm_rows(rows):
#     """
#     If a row has usfm like '1CO.5.12+1CO.5.13', split into two rows
#     with identical text/metadata but separate usfm/book/chapter/verse.
#     """
#     out = []
#     for r in rows:
#         usfm = (r.get("usfm") or "").strip()
#         if "+" not in usfm:
#             out.append(r)
#             continue

#         tokens = [t.strip() for t in usfm.split("+") if t.strip()]

#         def split_parts(tok, fb=None):
#             parts = tok.split(".")
#             if len(parts) == 3:
#                 b, c, v = parts[0], int(parts[1]), int(parts[2])
#                 return b, c, v
#             if len(parts) == 1 and parts[0].isdigit() and fb:
#                 b, c = fb
#                 return b, c, int(parts[0])
#             return None, None, None

#         fb_b, fb_c, _ = split_parts(tokens[0], None)

#         for tok in tokens:
#             b, c, v = split_parts(tok, (fb_b, fb_c))
#             new = r.copy()
#             new["usfm"] = f"{b}.{c}.{v}" if b and c is not None and v is not None else tok
#             new["book"] = b
#             new["chapter"] = c
#             new["verse"] = v
#             out.append(new)
#     return out

def rows_to_df(rows):
    df = pd.DataFrame(rows)
    if df.empty:
        for c in ["usfm","book","chapter","verse","text","iso6393","vid"]:
            if c not in df.columns:
                df[c] = pd.Series(dtype="object")
        return df

    def parse_primary_bcv(usfm: str):
        """
        For sorting & columns: from '1CO.5.12+1CO.5.13' (or similar) extract
        (book, chapter, first_verse). Supports shorthand like '+13' using the
        first token's book/chapter as fallback.
        """
        if not isinstance(usfm, str):
            return (None, None, None)

        tokens = [t.strip() for t in usfm.split("+") if t.strip()]
        if not tokens:
            return (None, None, None)

        def split_tok(tok: str, fb=None):
            parts = tok.split(".")
            try:
                if len(parts) == 3:
                    b, c, v = parts[0], int(parts[1]), int(parts[2])
                    return b, c, v
                if len(parts) == 1 and parts[0].isdigit() and fb:
                    b, c = fb
                    return b, c, int(parts[0])
            except Exception:
                pass
            return None, None, None

        b0, c0, v0 = split_tok(tokens[0], None)

        if (b0 is None or c0 is None) and len(tokens) > 1:
            for t in tokens[1:]:
                bt, ct, vt = split_tok(t, (b0, c0))
                if b0 is None and bt is not None:
                    b0 = bt
                if c0 is None and ct is not None:
                    c0 = ct
                if v0 is None and vt is not None:
                    v0 = vt

        return (b0, c0, v0)

    df[["book","chapter","verse"]] = df["usfm"].apply(
        lambda u: pd.Series(parse_primary_bcv(u))
    )

    df = df.sort_values(["book","chapter","verse"], kind="stable").reset_index(drop=True)
    return df

def process_tree(src_root: str, dst_root: str):
    processed = 0
    empties = 0
    errors = []

    if not os.path.isdir(src_root):
        print(f"[Skip] Source not found: {os.path.abspath(src_root)}")
        return processed, empties, errors

    os.makedirs(dst_root, exist_ok=True)

    for root, dirs, files in os.walk(src_root):
        for fname in files:
            if not fname.lower().endswith(".html"):
                continue
            processed += 1

            in_path = os.path.join(root, fname)
            rel = os.path.relpath(in_path, start=src_root)

            try:
                with io.open(in_path, "r", encoding="utf-8") as f:
                    raw_html = f.read()

                rows = parse_usfm_html(raw_html)
                #rows = expand_multi_usfm_rows(rows)
                df = rows_to_df(rows)

                out_base = os.path.splitext(os.path.join(dst_root, rel))[0]
                out_dir = os.path.dirname(out_base)
                os.makedirs(out_dir, exist_ok=True)

                out_csv = out_base + ".csv"
                out_txt = out_base + ".txt"

                df.to_csv(out_csv, index=False, encoding="utf-8")

                with io.open(out_txt, "w", encoding="utf-8") as g:
                    for _, r in df.iterrows():
                        usfm = "" if pd.isna(r.get("usfm")) else str(r.get("usfm"))
                        text = "" if pd.isna(r.get("text")) else str(r.get("text"))
                        g.write(f"{usfm} {text}\n")

                if df.empty:
                    empties += 1
                    print(f"Empty {rel}")
                else:
                    print(f"Parsed {rel} → {os.path.basename(out_csv)}, {os.path.basename(out_txt)}")

            except Exception as e:
                errors.append((rel, str(e)))
                print(f"Error {rel}: {e}")

    return processed, empties, errors

# %%
#main

grand_total = 0
grand_empties = 0
grand_errors = []

for lang_dir in LANG_DIRS:
    src_root = to_src_root(lang_dir)  
    dst_root = to_dst_root(src_root)  
    p, e, errs = process_tree(src_root, dst_root)
    grand_total  += p
    grand_empties += e
    grand_errors += errs

print("\nSummary")
print(f"Processed (all folders): {grand_total}")
print(f"Empty filesets         : {grand_empties}")
print(f"Errors                 : {len(grand_errors)}")
if grand_errors:
    for pth, msg in grand_errors[:10]:
        print(f" - {pth}: {msg}")
# Out:
# Parsed ABCEB_JON_raw.html → ABCEB_JON_raw.csv, ABCEB_JON_raw.txt
# Parsed ABCEB_1CH_raw.html → ABCEB_1CH_raw.csv, ABCEB_1CH_raw.txt
# Parsed ABCEB_EST_raw.html → ABCEB_EST_raw.csv, ABCEB_EST_raw.txt
# Parsed ABCEB_MAL_raw.html → ABCEB_MAL_raw.csv, ABCEB_MAL_raw.txt
# Parsed ABCEB_2KI_raw.html → ABCEB_2KI_raw.csv, ABCEB_2KI_raw.txt
# Parsed ABCEB_MIC_raw.html → ABCEB_MIC_raw.csv, ABCEB_MIC_raw.txt
# Parsed ABCEB_DAN_raw.html → ABCEB_DAN_raw.csv, ABCEB_DAN_raw.txt
# Parsed ABCEB_HAG_raw.html → ABCEB_HAG_raw.csv, ABCEB_HAG_raw.txt
# Parsed ABCEB_COL_raw.html → ABCEB_COL_raw.csv, ABCEB_COL_raw.txt
# Parsed ABCEB_2JN_raw.html → ABCEB_2JN_raw.csv, ABCEB_2JN_raw.txt
# Parsed ABCEB_HEB_raw.html → ABCEB_HEB_raw.csv, ABCEB_HEB_raw.txt
# Parsed ABCEB_PHM_raw.html → ABCEB_PHM_raw.csv, ABCEB_PHM_raw.txt
# Parsed ABCEB_AMO_raw.html → ABCEB_AMO_raw.csv, ABCEB_AMO_raw.txt
# Parsed ABCEB_MAT_raw.html → ABCEB_MAT_raw.csv, ABCEB_MAT_raw.txt
# Parsed ABCEB_EPH_raw.html → ABCEB_EPH_raw.csv, ABCEB_EPH_raw.txt
# Parsed ABCEB_1SA_raw.html → ABCEB_1SA_raw.csv, ABCEB_1SA_raw.txt
# Parsed ABCEB_MRK_raw.html → ABCEB_MRK_raw.csv, ABCEB_MRK_raw.txt
# Parsed ABCEB_1PE_raw.html → ABCEB_1PE_raw.csv, ABCEB_1PE_raw.txt
# Parsed ABCEB_JAS_raw.html → ABCEB_JAS_raw.csv, ABCEB_JAS_raw.txt
# Parsed ABCEB_PRO_raw.html → ABCEB_PRO_raw.csv, ABCEB_PRO_raw.txt
# Parsed ABCEB_ROM_raw.html → ABCEB_ROM_raw.csv, ABCEB_ROM_raw.txt
# Parsed ABCEB_1CO_raw.html → ABCEB_1CO_raw.csv, ABCEB_1CO_raw.txt
# Parsed ABCEB_2TI_raw.html → ABCEB_2TI_raw.csv, ABCEB_2TI_raw.txt
# Parsed ABCEB_GEN_raw.html → ABCEB_GEN_raw.csv, ABCEB_GEN_raw.txt
# Parsed ABCEB_2TH_raw.html → ABCEB_2TH_raw.csv, ABCEB_2TH_raw.txt
# Parsed ABCEB_JHN_raw.html → ABCEB_JHN_raw.csv, ABCEB_JHN_raw.txt
# Parsed ABCEB_DEU_raw.html → ABCEB_DEU_raw.csv, ABCEB_DEU_raw.txt
# Parsed ABCEB_ACT_raw.html → ABCEB_ACT_raw.csv, ABCEB_ACT_raw.txt
# Parsed ABCEB_JOB_raw.html → ABCEB_JOB_raw.csv, ABCEB_JOB_raw.txt
# Parsed ABCEB_GAL_raw.html → ABCEB_GAL_raw.csv, ABCEB_GAL_raw.txt
# Parsed ABCEB_ECC_raw.html → ABCEB_ECC_raw.csv, ABCEB_ECC_raw.txt
# Parsed ABCEB_EZK_raw.html → ABCEB_EZK_raw.csv, ABCEB_EZK_raw.txt
# Parsed ABCEB_JUD_raw.html → ABCEB_JUD_raw.csv, ABCEB_JUD_raw.txt
# Parsed ABCEB_1TI_raw.html → ABCEB_1TI_raw.csv, ABCEB_1TI_raw.txt
# Parsed ABCEB_1TH_raw.html → ABCEB_1TH_raw.csv, ABCEB_1TH_raw.txt
# Parsed ABCEB_2CO_raw.html → ABCEB_2CO_raw.csv, ABCEB_2CO_raw.txt
# Parsed ABCEB_JOS_raw.html → ABCEB_JOS_raw.csv, ABCEB_JOS_raw.txt
# Parsed ABCEB_NEH_raw.html → ABCEB_NEH_raw.csv, ABCEB_NEH_raw.txt
# Parsed ABCEB_SNG_raw.html → ABCEB_SNG_raw.csv, ABCEB_SNG_raw.txt
# Parsed ABCEB_ISA_raw.html → ABCEB_ISA_raw.csv, ABCEB_ISA_raw.txt
# Parsed ABCEB_LUK_raw.html → ABCEB_LUK_raw.csv, ABCEB_LUK_raw.txt
# Parsed ABCEB_3JN_raw.html → ABCEB_3JN_raw.csv, ABCEB_3JN_raw.txt
# Parsed ABCEB_JDG_raw.html → ABCEB_JDG_raw.csv, ABCEB_JDG_raw.txt
# Parsed ABCEB_2SA_raw.html → ABCEB_2SA_raw.csv, ABCEB_2SA_raw.txt
# Parsed ABCEB_RUT_raw.html → ABCEB_RUT_raw.csv, ABCEB_RUT_raw.txt
# Parsed ABCEB_NUM_raw.html → ABCEB_NUM_raw.csv, ABCEB_NUM_raw.txt
# Parsed ABCEB_ZEP_raw.html → ABCEB_ZEP_raw.csv, ABCEB_ZEP_raw.txt
# Parsed ABCEB_JOL_raw.html → ABCEB_JOL_raw.csv, ABCEB_JOL_raw.txt
# Parsed ABCEB_LAM_raw.html → ABCEB_LAM_raw.csv, ABCEB_LAM_raw.txt
# Parsed ABCEB_2PE_raw.html → ABCEB_2PE_raw.csv, ABCEB_2PE_raw.txt
# Parsed ABCEB_HOS_raw.html → ABCEB_HOS_raw.csv, ABCEB_HOS_raw.txt
# Parsed ABCEB_PHP_raw.html → ABCEB_PHP_raw.csv, ABCEB_PHP_raw.txt
# Parsed ABCEB_TIT_raw.html → ABCEB_TIT_raw.csv, ABCEB_TIT_raw.txt
# Parsed ABCEB_1JN_raw.html → ABCEB_1JN_raw.csv, ABCEB_1JN_raw.txt
# Parsed ABCEB_EZR_raw.html → ABCEB_EZR_raw.csv, ABCEB_EZR_raw.txt
# Parsed ABCEB_EXO_raw.html → ABCEB_EXO_raw.csv, ABCEB_EXO_raw.txt
# Parsed ABCEB_OBA_raw.html → ABCEB_OBA_raw.csv, ABCEB_OBA_raw.txt
# Parsed ABCEB_PSA_raw.html → ABCEB_PSA_raw.csv, ABCEB_PSA_raw.txt
# Parsed ABCEB_HAB_raw.html → ABCEB_HAB_raw.csv, ABCEB_HAB_raw.txt
# Parsed ABCEB_2CH_raw.html → ABCEB_2CH_raw.csv, ABCEB_2CH_raw.txt
# Parsed ABCEB_1KI_raw.html → ABCEB_1KI_raw.csv, ABCEB_1KI_raw.txt
# Parsed ABCEB_REV_raw.html → ABCEB_REV_raw.csv, ABCEB_REV_raw.txt
# Parsed ABCEB_JER_raw.html → ABCEB_JER_raw.csv, ABCEB_JER_raw.txt
# Parsed ABCEB_ZEC_raw.html → ABCEB_ZEC_raw.csv, ABCEB_ZEC_raw.txt
# Parsed ABCEB_NAM_raw.html → ABCEB_NAM_raw.csv, ABCEB_NAM_raw.txt
# Parsed ABCEB_LEV_raw.html → ABCEB_LEV_raw.csv, ABCEB_LEV_raw.txt
# Parsed RVR95_GAL_raw.html → RVR95_GAL_raw.csv, RVR95_GAL_raw.txt
# Parsed RVR95_ECC_raw.html → RVR95_ECC_raw.csv, RVR95_ECC_raw.txt
# Parsed RVR95_ACT_raw.html → RVR95_ACT_raw.csv, RVR95_ACT_raw.txt
# Parsed RVR95_JOB_raw.html → RVR95_JOB_raw.csv, RVR95_JOB_raw.txt
# Parsed RVR95_GEN_raw.html → RVR95_GEN_raw.csv, RVR95_GEN_raw.txt
# Parsed RVR95_2TH_raw.html → RVR95_2TH_raw.csv, RVR95_2TH_raw.txt
# Parsed RVR95_2TI_raw.html → RVR95_2TI_raw.csv, RVR95_2TI_raw.txt
# Parsed RVR95_DEU_raw.html → RVR95_DEU_raw.csv, RVR95_DEU_raw.txt
# Parsed RVR95_JHN_raw.html → RVR95_JHN_raw.csv, RVR95_JHN_raw.txt
# Parsed RVR95_PRO_raw.html → RVR95_PRO_raw.csv, RVR95_PRO_raw.txt
# Parsed RVR95_ROM_raw.html → RVR95_ROM_raw.csv, RVR95_ROM_raw.txt
# Parsed RVR95_1CO_raw.html → RVR95_1CO_raw.csv, RVR95_1CO_raw.txt
# Parsed RVR95_1PE_raw.html → RVR95_1PE_raw.csv, RVR95_1PE_raw.txt
# Parsed RVR95_MRK_raw.html → RVR95_MRK_raw.csv, RVR95_MRK_raw.txt
# Parsed RVR95_JAS_raw.html → RVR95_JAS_raw.csv, RVR95_JAS_raw.txt
# Parsed RVR95_EPH_raw.html → RVR95_EPH_raw.csv, RVR95_EPH_raw.txt
# Parsed RVR95_MAT_raw.html → RVR95_MAT_raw.csv, RVR95_MAT_raw.txt
# Parsed RVR95_1SA_raw.html → RVR95_1SA_raw.csv, RVR95_1SA_raw.txt
# Parsed RVR95_HEB_raw.html → RVR95_HEB_raw.csv, RVR95_HEB_raw.txt
# Parsed RVR95_PHM_raw.html → RVR95_PHM_raw.csv, RVR95_PHM_raw.txt
# Parsed RVR95_AMO_raw.html → RVR95_AMO_raw.csv, RVR95_AMO_raw.txt
# Parsed RVR95_2JN_raw.html → RVR95_2JN_raw.csv, RVR95_2JN_raw.txt
# Parsed RVR95_HAG_raw.html → RVR95_HAG_raw.csv, RVR95_HAG_raw.txt
# Parsed RVR95_COL_raw.html → RVR95_COL_raw.csv, RVR95_COL_raw.txt
# Parsed RVR95_MIC_raw.html → RVR95_MIC_raw.csv, RVR95_MIC_raw.txt
# Parsed RVR95_DAN_raw.html → RVR95_DAN_raw.csv, RVR95_DAN_raw.txt
# Parsed RVR95_2KI_raw.html → RVR95_2KI_raw.csv, RVR95_2KI_raw.txt
# Parsed RVR95_MAL_raw.html → RVR95_MAL_raw.csv, RVR95_MAL_raw.txt
# Parsed RVR95_EST_raw.html → RVR95_EST_raw.csv, RVR95_EST_raw.txt
# Parsed RVR95_JON_raw.html → RVR95_JON_raw.csv, RVR95_JON_raw.txt
# Parsed RVR95_1CH_raw.html → RVR95_1CH_raw.csv, RVR95_1CH_raw.txt
# Parsed RVR95_LEV_raw.html → RVR95_LEV_raw.csv, RVR95_LEV_raw.txt
# Parsed RVR95_ZEC_raw.html → RVR95_ZEC_raw.csv, RVR95_ZEC_raw.txt
# Parsed RVR95_NAM_raw.html → RVR95_NAM_raw.csv, RVR95_NAM_raw.txt
# Parsed RVR95_REV_raw.html → RVR95_REV_raw.csv, RVR95_REV_raw.txt
# Parsed RVR95_1KI_raw.html → RVR95_1KI_raw.csv, RVR95_1KI_raw.txt
# Parsed RVR95_JER_raw.html → RVR95_JER_raw.csv, RVR95_JER_raw.txt
# Parsed RVR95_2CH_raw.html → RVR95_2CH_raw.csv, RVR95_2CH_raw.txt
# Parsed RVR95_PSA_raw.html → RVR95_PSA_raw.csv, RVR95_PSA_raw.txt
# Parsed RVR95_HAB_raw.html → RVR95_HAB_raw.csv, RVR95_HAB_raw.txt
# Parsed RVR95_OBA_raw.html → RVR95_OBA_raw.csv, RVR95_OBA_raw.txt
# Parsed RVR95_EXO_raw.html → RVR95_EXO_raw.csv, RVR95_EXO_raw.txt
# Parsed RVR95_EZR_raw.html → RVR95_EZR_raw.csv, RVR95_EZR_raw.txt
# Parsed RVR95_1JN_raw.html → RVR95_1JN_raw.csv, RVR95_1JN_raw.txt
# Parsed RVR95_PHP_raw.html → RVR95_PHP_raw.csv, RVR95_PHP_raw.txt
# Parsed RVR95_TIT_raw.html → RVR95_TIT_raw.csv, RVR95_TIT_raw.txt
# Parsed RVR95_HOS_raw.html → RVR95_HOS_raw.csv, RVR95_HOS_raw.txt
# Parsed RVR95_2PE_raw.html → RVR95_2PE_raw.csv, RVR95_2PE_raw.txt
# Parsed RVR95_JOL_raw.html → RVR95_JOL_raw.csv, RVR95_JOL_raw.txt
# Parsed RVR95_ZEP_raw.html → RVR95_ZEP_raw.csv, RVR95_ZEP_raw.txt
# Parsed RVR95_NUM_raw.html → RVR95_NUM_raw.csv, RVR95_NUM_raw.txt
# Parsed RVR95_LAM_raw.html → RVR95_LAM_raw.csv, RVR95_LAM_raw.txt
# Parsed RVR95_RUT_raw.html → RVR95_RUT_raw.csv, RVR95_RUT_raw.txt
# Parsed RVR95_2SA_raw.html → RVR95_2SA_raw.csv, RVR95_2SA_raw.txt
# Parsed RVR95_LUK_raw.html → RVR95_LUK_raw.csv, RVR95_LUK_raw.txt
# Parsed RVR95_JDG_raw.html → RVR95_JDG_raw.csv, RVR95_JDG_raw.txt
# Parsed RVR95_3JN_raw.html → RVR95_3JN_raw.csv, RVR95_3JN_raw.txt
# Parsed RVR95_ISA_raw.html → RVR95_ISA_raw.csv, RVR95_ISA_raw.txt
# Parsed RVR95_SNG_raw.html → RVR95_SNG_raw.csv, RVR95_SNG_raw.txt
# Parsed RVR95_2CO_raw.html → RVR95_2CO_raw.csv, RVR95_2CO_raw.txt
# Parsed RVR95_JOS_raw.html → RVR95_JOS_raw.csv, RVR95_JOS_raw.txt
# Parsed RVR95_NEH_raw.html → RVR95_NEH_raw.csv, RVR95_NEH_raw.txt
# Parsed RVR95_1TH_raw.html → RVR95_1TH_raw.csv, RVR95_1TH_raw.txt
# Parsed RVR95_JUD_raw.html → RVR95_JUD_raw.csv, RVR95_JUD_raw.txt
# Parsed RVR95_1TI_raw.html → RVR95_1TI_raw.csv, RVR95_1TI_raw.txt
# Parsed RVR95_EZK_raw.html → RVR95_EZK_raw.csv, RVR95_EZK_raw.txt
# Parsed CBKNT_2PE_raw.html → CBKNT_2PE_raw.csv, CBKNT_2PE_raw.txt
# Parsed CBKNT_1TH_raw.html → CBKNT_1TH_raw.csv, CBKNT_1TH_raw.txt
# Parsed CBKNT_1TI_raw.html → CBKNT_1TI_raw.csv, CBKNT_1TI_raw.txt
# Parsed CBKNT_JUD_raw.html → CBKNT_JUD_raw.csv, CBKNT_JUD_raw.txt
# Parsed CBKNT_2CO_raw.html → CBKNT_2CO_raw.csv, CBKNT_2CO_raw.txt
# Parsed CBKNT_3JN_raw.html → CBKNT_3JN_raw.csv, CBKNT_3JN_raw.txt
# Parsed CBKNT_LUK_raw.html → CBKNT_LUK_raw.csv, CBKNT_LUK_raw.txt
# Parsed CBKNT_REV_raw.html → CBKNT_REV_raw.csv, CBKNT_REV_raw.txt
# Parsed CBKNT_TIT_raw.html → CBKNT_TIT_raw.csv, CBKNT_TIT_raw.txt
# Parsed CBKNT_PHP_raw.html → CBKNT_PHP_raw.csv, CBKNT_PHP_raw.txt
# Parsed CBKNT_1JN_raw.html → CBKNT_1JN_raw.csv, CBKNT_1JN_raw.txt
# Parsed CBKNT_COL_raw.html → CBKNT_COL_raw.csv, CBKNT_COL_raw.txt
# Parsed CBKNT_2JN_raw.html → CBKNT_2JN_raw.csv, CBKNT_2JN_raw.txt
# Parsed CBKNT_ROM_raw.html → CBKNT_ROM_raw.csv, CBKNT_ROM_raw.txt
# Parsed CBKNT_1CO_raw.html → CBKNT_1CO_raw.csv, CBKNT_1CO_raw.txt
# Parsed CBKNT_JHN_raw.html → CBKNT_JHN_raw.csv, CBKNT_JHN_raw.txt
# Parsed CBKNT_2TH_raw.html → CBKNT_2TH_raw.csv, CBKNT_2TH_raw.txt
# Parsed CBKNT_2TI_raw.html → CBKNT_2TI_raw.csv, CBKNT_2TI_raw.txt
# Parsed CBKNT_ACT_raw.html → CBKNT_ACT_raw.csv, CBKNT_ACT_raw.txt
# Parsed CBKNT_GAL_raw.html → CBKNT_GAL_raw.csv, CBKNT_GAL_raw.txt
# Parsed CBKNT_HEB_raw.html → CBKNT_HEB_raw.csv, CBKNT_HEB_raw.txt
# Parsed CBKNT_PHM_raw.html → CBKNT_PHM_raw.csv, CBKNT_PHM_raw.txt
# Parsed CBKNT_EPH_raw.html → CBKNT_EPH_raw.csv, CBKNT_EPH_raw.txt
# Parsed CBKNT_MAT_raw.html → CBKNT_MAT_raw.csv, CBKNT_MAT_raw.txt
# Parsed CBKNT_JAS_raw.html → CBKNT_JAS_raw.csv, CBKNT_JAS_raw.txt
# Parsed CBKNT_MRK_raw.html → CBKNT_MRK_raw.csv, CBKNT_MRK_raw.txt
# Parsed CBKNT_1PE_raw.html → CBKNT_1PE_raw.csv, CBKNT_1PE_raw.txt
# Parsed TSG_GAL_raw.html → TSG_GAL_raw.csv, TSG_GAL_raw.txt
# Parsed TSG_ACT_raw.html → TSG_ACT_raw.csv, TSG_ACT_raw.txt
# Parsed TSG_2TI_raw.html → TSG_2TI_raw.csv, TSG_2TI_raw.txt
# Parsed TSG_2TH_raw.html → TSG_2TH_raw.csv, TSG_2TH_raw.txt
# Parsed TSG_JHN_raw.html → TSG_JHN_raw.csv, TSG_JHN_raw.txt
# Parsed TSG_ROM_raw.html → TSG_ROM_raw.csv, TSG_ROM_raw.txt
# Parsed TSG_1CO_raw.html → TSG_1CO_raw.csv, TSG_1CO_raw.txt
# Parsed TSG_MRK_raw.html → TSG_MRK_raw.csv, TSG_MRK_raw.txt
# Parsed TSG_1PE_raw.html → TSG_1PE_raw.csv, TSG_1PE_raw.txt
# Parsed TSG_JAS_raw.html → TSG_JAS_raw.csv, TSG_JAS_raw.txt
# Parsed TSG_EPH_raw.html → TSG_EPH_raw.csv, TSG_EPH_raw.txt
# Parsed TSG_MAT_raw.html → TSG_MAT_raw.csv, TSG_MAT_raw.txt
# Parsed TSG_HEB_raw.html → TSG_HEB_raw.csv, TSG_HEB_raw.txt
# Parsed TSG_PHM_raw.html → TSG_PHM_raw.csv, TSG_PHM_raw.txt
# Parsed TSG_2JN_raw.html → TSG_2JN_raw.csv, TSG_2JN_raw.txt
# Parsed TSG_COL_raw.html → TSG_COL_raw.csv, TSG_COL_raw.txt
# Parsed TSG_REV_raw.html → TSG_REV_raw.csv, TSG_REV_raw.txt
# Parsed TSG_1JN_raw.html → TSG_1JN_raw.csv, TSG_1JN_raw.txt
# Parsed TSG_PHP_raw.html → TSG_PHP_raw.csv, TSG_PHP_raw.txt
# Parsed TSG_TIT_raw.html → TSG_TIT_raw.csv, TSG_TIT_raw.txt
# Parsed TSG_2PE_raw.html → TSG_2PE_raw.csv, TSG_2PE_raw.txt
# Parsed TSG_LUK_raw.html → TSG_LUK_raw.csv, TSG_LUK_raw.txt
# Parsed TSG_3JN_raw.html → TSG_3JN_raw.csv, TSG_3JN_raw.txt
# Parsed TSG_2CO_raw.html → TSG_2CO_raw.csv, TSG_2CO_raw.txt
# Parsed TSG_1TI_raw.html → TSG_1TI_raw.csv, TSG_1TI_raw.txt
# Parsed TSG_JUD_raw.html → TSG_JUD_raw.csv, TSG_JUD_raw.txt
# Parsed TSG_1TH_raw.html → TSG_1TH_raw.csv, TSG_1TH_raw.txt
# Parsed VTSP_COL_raw.html → VTSP_COL_raw.csv, VTSP_COL_raw.txt
# Parsed VTSP_2JN_raw.html → VTSP_2JN_raw.csv, VTSP_2JN_raw.txt
# Parsed VTSP_ACT_raw.html → VTSP_ACT_raw.csv, VTSP_ACT_raw.txt
# Parsed VTSP_GAL_raw.html → VTSP_GAL_raw.csv, VTSP_GAL_raw.txt
# Parsed VTSP_ROM_raw.html → VTSP_ROM_raw.csv, VTSP_ROM_raw.txt
# Parsed VTSP_1CO_raw.html → VTSP_1CO_raw.csv, VTSP_1CO_raw.txt
# Parsed VTSP_PRO_raw.html → VTSP_PRO_raw.csv, VTSP_PRO_raw.txt
# Parsed VTSP_JHN_raw.html → VTSP_JHN_raw.csv, VTSP_JHN_raw.txt
# Parsed VTSP_2TI_raw.html → VTSP_2TI_raw.csv, VTSP_2TI_raw.txt
# Parsed VTSP_2TH_raw.html → VTSP_2TH_raw.csv, VTSP_2TH_raw.txt
# Parsed VTSP_JAS_raw.html → VTSP_JAS_raw.csv, VTSP_JAS_raw.txt
# Parsed VTSP_MRK_raw.html → VTSP_MRK_raw.csv, VTSP_MRK_raw.txt
# Parsed VTSP_1PE_raw.html → VTSP_1PE_raw.csv, VTSP_1PE_raw.txt
# Parsed VTSP_HEB_raw.html → VTSP_HEB_raw.csv, VTSP_HEB_raw.txt
# Parsed VTSP_PHM_raw.html → VTSP_PHM_raw.csv, VTSP_PHM_raw.txt
# Parsed VTSP_MAT_raw.html → VTSP_MAT_raw.csv, VTSP_MAT_raw.txt
# Parsed VTSP_EPH_raw.html → VTSP_EPH_raw.csv, VTSP_EPH_raw.txt
# Parsed VTSP_2PE_raw.html → VTSP_2PE_raw.csv, VTSP_2PE_raw.txt
# Parsed VTSP_3JN_raw.html → VTSP_3JN_raw.csv, VTSP_3JN_raw.txt
# Parsed VTSP_LUK_raw.html → VTSP_LUK_raw.csv, VTSP_LUK_raw.txt
# Parsed VTSP_1TI_raw.html → VTSP_1TI_raw.csv, VTSP_1TI_raw.txt
# Parsed VTSP_JUD_raw.html → VTSP_JUD_raw.csv, VTSP_JUD_raw.txt
# Parsed VTSP_1TH_raw.html → VTSP_1TH_raw.csv, VTSP_1TH_raw.txt
# Parsed VTSP_2CO_raw.html → VTSP_2CO_raw.csv, VTSP_2CO_raw.txt
# Parsed VTSP_REV_raw.html → VTSP_REV_raw.csv, VTSP_REV_raw.txt
# Parsed VTSP_PSA_raw.html → VTSP_PSA_raw.csv, VTSP_PSA_raw.txt
# Parsed VTSP_1JN_raw.html → VTSP_1JN_raw.csv, VTSP_1JN_raw.txt
# Parsed VTSP_TIT_raw.html → VTSP_TIT_raw.csv, VTSP_TIT_raw.txt
# Parsed VTSP_PHP_raw.html → VTSP_PHP_raw.csv, VTSP_PHP_raw.txt
# Parsed PNPV_2SA_raw.html → PNPV_2SA_raw.csv, PNPV_2SA_raw.txt
# Parsed PNPV_RUT_raw.html → PNPV_RUT_raw.csv, PNPV_RUT_raw.txt
# Parsed PNPV_JOL_raw.html → PNPV_JOL_raw.csv, PNPV_JOL_raw.txt
# Parsed PNPV_ZEP_raw.html → PNPV_ZEP_raw.csv, PNPV_ZEP_raw.txt
# Parsed PNPV_NUM_raw.html → PNPV_NUM_raw.csv, PNPV_NUM_raw.txt
# Parsed PNPV_LAM_raw.html → PNPV_LAM_raw.csv, PNPV_LAM_raw.txt
# Parsed PNPV_2PE_raw.html → PNPV_2PE_raw.csv, PNPV_2PE_raw.txt
# Parsed PNPV_JUD_raw.html → PNPV_JUD_raw.csv, PNPV_JUD_raw.txt
# Parsed PNPV_1TI_raw.html → PNPV_1TI_raw.csv, PNPV_1TI_raw.txt
# Parsed PNPV_1TH_raw.html → PNPV_1TH_raw.csv, PNPV_1TH_raw.txt
# Parsed PNPV_EZK_raw.html → PNPV_EZK_raw.csv, PNPV_EZK_raw.txt
# Parsed PNPV_2CO_raw.html → PNPV_2CO_raw.csv, PNPV_2CO_raw.txt
# Parsed PNPV_JOS_raw.html → PNPV_JOS_raw.csv, PNPV_JOS_raw.txt
# Parsed PNPV_NEH_raw.html → PNPV_NEH_raw.csv, PNPV_NEH_raw.txt
# Parsed PNPV_ISA_raw.html → PNPV_ISA_raw.csv, PNPV_ISA_raw.txt
# Parsed PNPV_2MA_raw.html → PNPV_2MA_raw.csv, PNPV_2MA_raw.txt
# Parsed PNPV_SNG_raw.html → PNPV_SNG_raw.csv, PNPV_SNG_raw.txt
# Parsed PNPV_LUK_raw.html → PNPV_LUK_raw.csv, PNPV_LUK_raw.txt
# Parsed PNPV_JDG_raw.html → PNPV_JDG_raw.csv, PNPV_JDG_raw.txt
# Parsed PNPV_3JN_raw.html → PNPV_3JN_raw.csv, PNPV_3JN_raw.txt
# Parsed PNPV_S3Y_raw.html → PNPV_S3Y_raw.csv, PNPV_S3Y_raw.txt
# Parsed PNPV_HAB_raw.html → PNPV_HAB_raw.csv, PNPV_HAB_raw.txt
# Parsed PNPV_PSA_raw.html → PNPV_PSA_raw.csv, PNPV_PSA_raw.txt
# Parsed PNPV_OBA_raw.html → PNPV_OBA_raw.csv, PNPV_OBA_raw.txt
# Parsed PNPV_2CH_raw.html → PNPV_2CH_raw.csv, PNPV_2CH_raw.txt
# Parsed PNPV_BEL_raw.html → PNPV_BEL_raw.csv, PNPV_BEL_raw.txt
# Parsed PNPV_REV_raw.html → PNPV_REV_raw.csv, PNPV_REV_raw.txt
# Parsed PNPV_1KI_raw.html → PNPV_1KI_raw.csv, PNPV_1KI_raw.txt
# Parsed PNPV_JER_raw.html → PNPV_JER_raw.csv, PNPV_JER_raw.txt
# Parsed PNPV_LEV_raw.html → PNPV_LEV_raw.csv, PNPV_LEV_raw.txt
# Parsed PNPV_NAM_raw.html → PNPV_NAM_raw.csv, PNPV_NAM_raw.txt
# Parsed PNPV_ZEC_raw.html → PNPV_ZEC_raw.csv, PNPV_ZEC_raw.txt
# Parsed PNPV_HOS_raw.html → PNPV_HOS_raw.csv, PNPV_HOS_raw.txt
# Parsed PNPV_PHP_raw.html → PNPV_PHP_raw.csv, PNPV_PHP_raw.txt
# Parsed PNPV_TIT_raw.html → PNPV_TIT_raw.csv, PNPV_TIT_raw.txt
# Parsed PNPV_JDT_raw.html → PNPV_JDT_raw.csv, PNPV_JDT_raw.txt
# Parsed PNPV_SIR_raw.html → PNPV_SIR_raw.csv, PNPV_SIR_raw.txt
# Parsed PNPV_1JN_raw.html → PNPV_1JN_raw.csv, PNPV_1JN_raw.txt
# Parsed PNPV_EXO_raw.html → PNPV_EXO_raw.csv, PNPV_EXO_raw.txt
# Parsed PNPV_EZR_raw.html → PNPV_EZR_raw.csv, PNPV_EZR_raw.txt
# Parsed PNPV_MIC_raw.html → PNPV_MIC_raw.csv, PNPV_MIC_raw.txt
# Parsed PNPV_DAN_raw.html → PNPV_DAN_raw.csv, PNPV_DAN_raw.txt
# Parsed PNPV_LJE_raw.html → PNPV_LJE_raw.csv, PNPV_LJE_raw.txt
# Parsed PNPV_HAG_raw.html → PNPV_HAG_raw.csv, PNPV_HAG_raw.txt
# Parsed PNPV_COL_raw.html → PNPV_COL_raw.csv, PNPV_COL_raw.txt
# Parsed PNPV_2JN_raw.html → PNPV_2JN_raw.csv, PNPV_2JN_raw.txt
# Parsed PNPV_JON_raw.html → PNPV_JON_raw.csv, PNPV_JON_raw.txt
# Parsed PNPV_1CH_raw.html → PNPV_1CH_raw.csv, PNPV_1CH_raw.txt
# Parsed PNPV_EST_raw.html → PNPV_EST_raw.csv, PNPV_EST_raw.txt
# Parsed PNPV_MAL_raw.html → PNPV_MAL_raw.csv, PNPV_MAL_raw.txt
# Parsed PNPV_2KI_raw.html → PNPV_2KI_raw.csv, PNPV_2KI_raw.txt
# Parsed PNPV_PRO_raw.html → PNPV_PRO_raw.csv, PNPV_PRO_raw.txt
# Parsed PNPV_1CO_raw.html → PNPV_1CO_raw.csv, PNPV_1CO_raw.txt
# Parsed PNPV_ROM_raw.html → PNPV_ROM_raw.csv, PNPV_ROM_raw.txt
# Parsed PNPV_2TI_raw.html → PNPV_2TI_raw.csv, PNPV_2TI_raw.txt
# Parsed PNPV_GEN_raw.html → PNPV_GEN_raw.csv, PNPV_GEN_raw.txt
# Parsed PNPV_2TH_raw.html → PNPV_2TH_raw.csv, PNPV_2TH_raw.txt
# Parsed PNPV_SUS_raw.html → PNPV_SUS_raw.csv, PNPV_SUS_raw.txt
# Parsed PNPV_DEU_raw.html → PNPV_DEU_raw.csv, PNPV_DEU_raw.txt
# Parsed PNPV_JHN_raw.html → PNPV_JHN_raw.csv, PNPV_JHN_raw.txt
# Parsed PNPV_ACT_raw.html → PNPV_ACT_raw.csv, PNPV_ACT_raw.txt
# Parsed PNPV_JOB_raw.html → PNPV_JOB_raw.csv, PNPV_JOB_raw.txt
# Parsed PNPV_BAR_raw.html → PNPV_BAR_raw.csv, PNPV_BAR_raw.txt
# Parsed PNPV_TOB_raw.html → PNPV_TOB_raw.csv, PNPV_TOB_raw.txt
# Parsed PNPV_GAL_raw.html → PNPV_GAL_raw.csv, PNPV_GAL_raw.txt
# Parsed PNPV_1MA_raw.html → PNPV_1MA_raw.csv, PNPV_1MA_raw.txt
# Parsed PNPV_ECC_raw.html → PNPV_ECC_raw.csv, PNPV_ECC_raw.txt
# Parsed PNPV_PHM_raw.html → PNPV_PHM_raw.csv, PNPV_PHM_raw.txt
# Parsed PNPV_WIS_raw.html → PNPV_WIS_raw.csv, PNPV_WIS_raw.txt
# Parsed PNPV_HEB_raw.html → PNPV_HEB_raw.csv, PNPV_HEB_raw.txt
# Parsed PNPV_AMO_raw.html → PNPV_AMO_raw.csv, PNPV_AMO_raw.txt
# Parsed PNPV_EPH_raw.html → PNPV_EPH_raw.csv, PNPV_EPH_raw.txt
# Parsed PNPV_MAT_raw.html → PNPV_MAT_raw.csv, PNPV_MAT_raw.txt
# Parsed PNPV_1SA_raw.html → PNPV_1SA_raw.csv, PNPV_1SA_raw.txt
# Parsed PNPV_1PE_raw.html → PNPV_1PE_raw.csv, PNPV_1PE_raw.txt
# Parsed PNPV_MRK_raw.html → PNPV_MRK_raw.csv, PNPV_MRK_raw.txt
# Parsed PNPV_JAS_raw.html → PNPV_JAS_raw.csv, PNPV_JAS_raw.txt
# Parsed MBB05_OBA_raw.html → MBB05_OBA_raw.csv, MBB05_OBA_raw.txt
# Parsed MBB05_PSA_raw.html → MBB05_PSA_raw.csv, MBB05_PSA_raw.txt
# Parsed MBB05_HAB_raw.html → MBB05_HAB_raw.csv, MBB05_HAB_raw.txt
# Parsed MBB05_S3Y_raw.html → MBB05_S3Y_raw.csv, MBB05_S3Y_raw.txt
# Parsed MBB05_BEL_raw.html → MBB05_BEL_raw.csv, MBB05_BEL_raw.txt
# Parsed MBB05_2CH_raw.html → MBB05_2CH_raw.csv, MBB05_2CH_raw.txt
# Parsed MBB05_JER_raw.html → MBB05_JER_raw.csv, MBB05_JER_raw.txt
# Parsed MBB05_1KI_raw.html → MBB05_1KI_raw.csv, MBB05_1KI_raw.txt
# Parsed MBB05_REV_raw.html → MBB05_REV_raw.csv, MBB05_REV_raw.txt
# Parsed MBB05_ZEC_raw.html → MBB05_ZEC_raw.csv, MBB05_ZEC_raw.txt
# Parsed MBB05_NAM_raw.html → MBB05_NAM_raw.csv, MBB05_NAM_raw.txt
# Parsed MBB05_LEV_raw.html → MBB05_LEV_raw.csv, MBB05_LEV_raw.txt
# Parsed MBB05_HOS_raw.html → MBB05_HOS_raw.csv, MBB05_HOS_raw.txt
# Parsed MBB05_TIT_raw.html → MBB05_TIT_raw.csv, MBB05_TIT_raw.txt
# Parsed MBB05_PHP_raw.html → MBB05_PHP_raw.csv, MBB05_PHP_raw.txt
# Parsed MBB05_1JN_raw.html → MBB05_1JN_raw.csv, MBB05_1JN_raw.txt
# Parsed MBB05_JDT_raw.html → MBB05_JDT_raw.csv, MBB05_JDT_raw.txt
# Parsed MBB05_SIR_raw.html → MBB05_SIR_raw.csv, MBB05_SIR_raw.txt
# Parsed MBB05_EZR_raw.html → MBB05_EZR_raw.csv, MBB05_EZR_raw.txt
# Parsed MBB05_EXO_raw.html → MBB05_EXO_raw.csv, MBB05_EXO_raw.txt
# Parsed MBB05_2SA_raw.html → MBB05_2SA_raw.csv, MBB05_2SA_raw.txt
# Parsed MBB05_RUT_raw.html → MBB05_RUT_raw.csv, MBB05_RUT_raw.txt
# Parsed MBB05_LAM_raw.html → MBB05_LAM_raw.csv, MBB05_LAM_raw.txt
# Parsed MBB05_ZEP_raw.html → MBB05_ZEP_raw.csv, MBB05_ZEP_raw.txt
# Parsed MBB05_JOL_raw.html → MBB05_JOL_raw.csv, MBB05_JOL_raw.txt
# Parsed MBB05_NUM_raw.html → MBB05_NUM_raw.csv, MBB05_NUM_raw.txt
# Parsed MBB05_2PE_raw.html → MBB05_2PE_raw.csv, MBB05_2PE_raw.txt
# Parsed MBB05_1TH_raw.html → MBB05_1TH_raw.csv, MBB05_1TH_raw.txt
# Parsed MBB05_JUD_raw.html → MBB05_JUD_raw.csv, MBB05_JUD_raw.txt
# Parsed MBB05_1TI_raw.html → MBB05_1TI_raw.csv, MBB05_1TI_raw.txt
# Parsed MBB05_EZK_raw.html → MBB05_EZK_raw.csv, MBB05_EZK_raw.txt
# Parsed MBB05_NEH_raw.html → MBB05_NEH_raw.csv, MBB05_NEH_raw.txt
# Parsed MBB05_2CO_raw.html → MBB05_2CO_raw.csv, MBB05_2CO_raw.txt
# Parsed MBB05_JOS_raw.html → MBB05_JOS_raw.csv, MBB05_JOS_raw.txt
# Parsed MBB05_ISA_raw.html → MBB05_ISA_raw.csv, MBB05_ISA_raw.txt
# Parsed MBB05_2MA_raw.html → MBB05_2MA_raw.csv, MBB05_2MA_raw.txt
# Parsed MBB05_SNG_raw.html → MBB05_SNG_raw.csv, MBB05_SNG_raw.txt
# Parsed MBB05_JDG_raw.html → MBB05_JDG_raw.csv, MBB05_JDG_raw.txt
# Parsed MBB05_3JN_raw.html → MBB05_3JN_raw.csv, MBB05_3JN_raw.txt
# Parsed MBB05_LUK_raw.html → MBB05_LUK_raw.csv, MBB05_LUK_raw.txt
# Parsed MBB05_ROM_raw.html → MBB05_ROM_raw.csv, MBB05_ROM_raw.txt
# Parsed MBB05_1CO_raw.html → MBB05_1CO_raw.csv, MBB05_1CO_raw.txt
# Parsed MBB05_PRO_raw.html → MBB05_PRO_raw.csv, MBB05_PRO_raw.txt
# Parsed MBB05_JHN_raw.html → MBB05_JHN_raw.csv, MBB05_JHN_raw.txt
# Parsed MBB05_DEU_raw.html → MBB05_DEU_raw.csv, MBB05_DEU_raw.txt
# Parsed MBB05_GEN_raw.html → MBB05_GEN_raw.csv, MBB05_GEN_raw.txt
# Parsed MBB05_2TH_raw.html → MBB05_2TH_raw.csv, MBB05_2TH_raw.txt
# Parsed MBB05_2TI_raw.html → MBB05_2TI_raw.csv, MBB05_2TI_raw.txt
# Parsed MBB05_SUS_raw.html → MBB05_SUS_raw.csv, MBB05_SUS_raw.txt
# Parsed MBB05_JOB_raw.html → MBB05_JOB_raw.csv, MBB05_JOB_raw.txt
# Parsed MBB05_BAR_raw.html → MBB05_BAR_raw.csv, MBB05_BAR_raw.txt
# Parsed MBB05_ACT_raw.html → MBB05_ACT_raw.csv, MBB05_ACT_raw.txt
# Parsed MBB05_1MA_raw.html → MBB05_1MA_raw.csv, MBB05_1MA_raw.txt
# Parsed MBB05_ECC_raw.html → MBB05_ECC_raw.csv, MBB05_ECC_raw.txt
# Parsed MBB05_TOB_raw.html → MBB05_TOB_raw.csv, MBB05_TOB_raw.txt
# Parsed MBB05_GAL_raw.html → MBB05_GAL_raw.csv, MBB05_GAL_raw.txt
# Parsed MBB05_AMO_raw.html → MBB05_AMO_raw.csv, MBB05_AMO_raw.txt
# Parsed MBB05_HEB_raw.html → MBB05_HEB_raw.csv, MBB05_HEB_raw.txt
# Parsed MBB05_WIS_raw.html → MBB05_WIS_raw.csv, MBB05_WIS_raw.txt
# Parsed MBB05_PHM_raw.html → MBB05_PHM_raw.csv, MBB05_PHM_raw.txt
# Parsed MBB05_1SA_raw.html → MBB05_1SA_raw.csv, MBB05_1SA_raw.txt
# Parsed MBB05_EPH_raw.html → MBB05_EPH_raw.csv, MBB05_EPH_raw.txt
# Parsed MBB05_MAT_raw.html → MBB05_MAT_raw.csv, MBB05_MAT_raw.txt
# Parsed MBB05_JAS_raw.html → MBB05_JAS_raw.csv, MBB05_JAS_raw.txt
# Parsed MBB05_MRK_raw.html → MBB05_MRK_raw.csv, MBB05_MRK_raw.txt
# Parsed MBB05_1PE_raw.html → MBB05_1PE_raw.csv, MBB05_1PE_raw.txt
# Parsed MBB05_DAN_raw.html → MBB05_DAN_raw.csv, MBB05_DAN_raw.txt
# Parsed MBB05_MIC_raw.html → MBB05_MIC_raw.csv, MBB05_MIC_raw.txt
# Parsed MBB05_LJE_raw.html → MBB05_LJE_raw.csv, MBB05_LJE_raw.txt
# Parsed MBB05_COL_raw.html → MBB05_COL_raw.csv, MBB05_COL_raw.txt
# Parsed MBB05_HAG_raw.html → MBB05_HAG_raw.csv, MBB05_HAG_raw.txt
# Parsed MBB05_2JN_raw.html → MBB05_2JN_raw.csv, MBB05_2JN_raw.txt
# Parsed MBB05_1CH_raw.html → MBB05_1CH_raw.csv, MBB05_1CH_raw.txt
# Parsed MBB05_JON_raw.html → MBB05_JON_raw.csv, MBB05_JON_raw.txt
# Parsed MBB05_EST_raw.html → MBB05_EST_raw.csv, MBB05_EST_raw.txt
# Parsed MBB05_MAL_raw.html → MBB05_MAL_raw.csv, MBB05_MAL_raw.txt
# Parsed MBB05_2KI_raw.html → MBB05_2KI_raw.csv, MBB05_2KI_raw.txt
# Parsed SNT_LUK_raw.html → SNT_LUK_raw.csv, SNT_LUK_raw.txt
# Parsed SNT_3JN_raw.html → SNT_3JN_raw.csv, SNT_3JN_raw.txt
# Parsed SNT_JUD_raw.html → SNT_JUD_raw.csv, SNT_JUD_raw.txt
# Parsed SNT_1TI_raw.html → SNT_1TI_raw.csv, SNT_1TI_raw.txt
# Parsed SNT_1TH_raw.html → SNT_1TH_raw.csv, SNT_1TH_raw.txt
# Parsed SNT_2CO_raw.html → SNT_2CO_raw.csv, SNT_2CO_raw.txt
# Parsed SNT_2PE_raw.html → SNT_2PE_raw.csv, SNT_2PE_raw.txt
# Parsed SNT_1JN_raw.html → SNT_1JN_raw.csv, SNT_1JN_raw.txt
# Parsed SNT_PHP_raw.html → SNT_PHP_raw.csv, SNT_PHP_raw.txt
# Parsed SNT_TIT_raw.html → SNT_TIT_raw.csv, SNT_TIT_raw.txt
# Parsed SNT_REV_raw.html → SNT_REV_raw.csv, SNT_REV_raw.txt
# Parsed SNT_COL_raw.html → SNT_COL_raw.csv, SNT_COL_raw.txt
# Parsed SNT_2JN_raw.html → SNT_2JN_raw.csv, SNT_2JN_raw.txt
# Parsed SNT_MRK_raw.html → SNT_MRK_raw.csv, SNT_MRK_raw.txt
# Parsed SNT_1PE_raw.html → SNT_1PE_raw.csv, SNT_1PE_raw.txt
# Parsed SNT_JAS_raw.html → SNT_JAS_raw.csv, SNT_JAS_raw.txt
# Parsed SNT_HEB_raw.html → SNT_HEB_raw.csv, SNT_HEB_raw.txt
# Parsed SNT_PHM_raw.html → SNT_PHM_raw.csv, SNT_PHM_raw.txt
# Parsed SNT_EPH_raw.html → SNT_EPH_raw.csv, SNT_EPH_raw.txt
# Parsed SNT_MAT_raw.html → SNT_MAT_raw.csv, SNT_MAT_raw.txt
# Parsed SNT_ACT_raw.html → SNT_ACT_raw.csv, SNT_ACT_raw.txt
# Parsed SNT_GAL_raw.html → SNT_GAL_raw.csv, SNT_GAL_raw.txt
# Parsed SNT_ROM_raw.html → SNT_ROM_raw.csv, SNT_ROM_raw.txt
# Parsed SNT_1CO_raw.html → SNT_1CO_raw.csv, SNT_1CO_raw.txt
# Parsed SNT_2TI_raw.html → SNT_2TI_raw.csv, SNT_2TI_raw.txt
# Parsed SNT_2TH_raw.html → SNT_2TH_raw.csv, SNT_2TH_raw.txt
# Parsed SNT_JHN_raw.html → SNT_JHN_raw.csv, SNT_JHN_raw.txt
# Parsed MBBBIK92_ROM_raw.html → MBBBIK92_ROM_raw.csv, MBBBIK92_ROM_raw.txt
# Parsed MBBBIK92_1CO_raw.html → MBBBIK92_1CO_raw.csv, MBBBIK92_1CO_raw.txt
# Parsed MBBBIK92_PRO_raw.html → MBBBIK92_PRO_raw.csv, MBBBIK92_PRO_raw.txt
# Parsed MBBBIK92_DEU_raw.html → MBBBIK92_DEU_raw.csv, MBBBIK92_DEU_raw.txt
# Parsed MBBBIK92_JHN_raw.html → MBBBIK92_JHN_raw.csv, MBBBIK92_JHN_raw.txt
# Parsed MBBBIK92_SUS_raw.html → MBBBIK92_SUS_raw.csv, MBBBIK92_SUS_raw.txt
# Parsed MBBBIK92_2TH_raw.html → MBBBIK92_2TH_raw.csv, MBBBIK92_2TH_raw.txt
# Parsed MBBBIK92_GEN_raw.html → MBBBIK92_GEN_raw.csv, MBBBIK92_GEN_raw.txt
# Parsed MBBBIK92_2TI_raw.html → MBBBIK92_2TI_raw.csv, MBBBIK92_2TI_raw.txt
# Parsed MBBBIK92_BAR_raw.html → MBBBIK92_BAR_raw.csv, MBBBIK92_BAR_raw.txt
# Parsed MBBBIK92_JOB_raw.html → MBBBIK92_JOB_raw.csv, MBBBIK92_JOB_raw.txt
# Parsed MBBBIK92_ACT_raw.html → MBBBIK92_ACT_raw.csv, MBBBIK92_ACT_raw.txt
# Parsed MBBBIK92_ECC_raw.html → MBBBIK92_ECC_raw.csv, MBBBIK92_ECC_raw.txt
# Parsed MBBBIK92_1MA_raw.html → MBBBIK92_1MA_raw.csv, MBBBIK92_1MA_raw.txt
# Parsed MBBBIK92_GAL_raw.html → MBBBIK92_GAL_raw.csv, MBBBIK92_GAL_raw.txt
# Parsed MBBBIK92_TOB_raw.html → MBBBIK92_TOB_raw.csv, MBBBIK92_TOB_raw.txt
# Parsed MBBBIK92_AMO_raw.html → MBBBIK92_AMO_raw.csv, MBBBIK92_AMO_raw.txt
# Parsed MBBBIK92_HEB_raw.html → MBBBIK92_HEB_raw.csv, MBBBIK92_HEB_raw.txt
# Parsed MBBBIK92_WIS_raw.html → MBBBIK92_WIS_raw.csv, MBBBIK92_WIS_raw.txt
# Parsed MBBBIK92_PHM_raw.html → MBBBIK92_PHM_raw.csv, MBBBIK92_PHM_raw.txt
# Parsed MBBBIK92_1SA_raw.html → MBBBIK92_1SA_raw.csv, MBBBIK92_1SA_raw.txt
# Parsed MBBBIK92_MAT_raw.html → MBBBIK92_MAT_raw.csv, MBBBIK92_MAT_raw.txt
# Parsed MBBBIK92_EPH_raw.html → MBBBIK92_EPH_raw.csv, MBBBIK92_EPH_raw.txt
# Parsed MBBBIK92_JAS_raw.html → MBBBIK92_JAS_raw.csv, MBBBIK92_JAS_raw.txt
# Parsed MBBBIK92_1PE_raw.html → MBBBIK92_1PE_raw.csv, MBBBIK92_1PE_raw.txt
# Parsed MBBBIK92_MRK_raw.html → MBBBIK92_MRK_raw.csv, MBBBIK92_MRK_raw.txt
# Parsed MBBBIK92_DAN_raw.html → MBBBIK92_DAN_raw.csv, MBBBIK92_DAN_raw.txt
# Parsed MBBBIK92_MIC_raw.html → MBBBIK92_MIC_raw.csv, MBBBIK92_MIC_raw.txt
# Parsed MBBBIK92_LJE_raw.html → MBBBIK92_LJE_raw.csv, MBBBIK92_LJE_raw.txt
# Parsed MBBBIK92_COL_raw.html → MBBBIK92_COL_raw.csv, MBBBIK92_COL_raw.txt
# Parsed MBBBIK92_HAG_raw.html → MBBBIK92_HAG_raw.csv, MBBBIK92_HAG_raw.txt
# Parsed MBBBIK92_2JN_raw.html → MBBBIK92_2JN_raw.csv, MBBBIK92_2JN_raw.txt
# Parsed MBBBIK92_1CH_raw.html → MBBBIK92_1CH_raw.csv, MBBBIK92_1CH_raw.txt
# Parsed MBBBIK92_JON_raw.html → MBBBIK92_JON_raw.csv, MBBBIK92_JON_raw.txt
# Parsed MBBBIK92_EST_raw.html → MBBBIK92_EST_raw.csv, MBBBIK92_EST_raw.txt
# Parsed MBBBIK92_MAL_raw.html → MBBBIK92_MAL_raw.csv, MBBBIK92_MAL_raw.txt
# Parsed MBBBIK92_2KI_raw.html → MBBBIK92_2KI_raw.csv, MBBBIK92_2KI_raw.txt
# Parsed MBBBIK92_PSA_raw.html → MBBBIK92_PSA_raw.csv, MBBBIK92_PSA_raw.txt
# Parsed MBBBIK92_HAB_raw.html → MBBBIK92_HAB_raw.csv, MBBBIK92_HAB_raw.txt
# Parsed MBBBIK92_S3Y_raw.html → MBBBIK92_S3Y_raw.csv, MBBBIK92_S3Y_raw.txt
# Parsed MBBBIK92_OBA_raw.html → MBBBIK92_OBA_raw.csv, MBBBIK92_OBA_raw.txt
# Parsed MBBBIK92_BEL_raw.html → MBBBIK92_BEL_raw.csv, MBBBIK92_BEL_raw.txt
# Parsed MBBBIK92_2CH_raw.html → MBBBIK92_2CH_raw.csv, MBBBIK92_2CH_raw.txt
# Parsed MBBBIK92_JER_raw.html → MBBBIK92_JER_raw.csv, MBBBIK92_JER_raw.txt
# Parsed MBBBIK92_REV_raw.html → MBBBIK92_REV_raw.csv, MBBBIK92_REV_raw.txt
# Parsed MBBBIK92_1KI_raw.html → MBBBIK92_1KI_raw.csv, MBBBIK92_1KI_raw.txt
# Parsed MBBBIK92_LEV_raw.html → MBBBIK92_LEV_raw.csv, MBBBIK92_LEV_raw.txt
# Parsed MBBBIK92_ZEC_raw.html → MBBBIK92_ZEC_raw.csv, MBBBIK92_ZEC_raw.txt
# Parsed MBBBIK92_NAM_raw.html → MBBBIK92_NAM_raw.csv, MBBBIK92_NAM_raw.txt
# Parsed MBBBIK92_HOS_raw.html → MBBBIK92_HOS_raw.csv, MBBBIK92_HOS_raw.txt
# Parsed MBBBIK92_TIT_raw.html → MBBBIK92_TIT_raw.csv, MBBBIK92_TIT_raw.txt
# Parsed MBBBIK92_PHP_raw.html → MBBBIK92_PHP_raw.csv, MBBBIK92_PHP_raw.txt
# Parsed MBBBIK92_1JN_raw.html → MBBBIK92_1JN_raw.csv, MBBBIK92_1JN_raw.txt
# Parsed MBBBIK92_SIR_raw.html → MBBBIK92_SIR_raw.csv, MBBBIK92_SIR_raw.txt
# Parsed MBBBIK92_JDT_raw.html → MBBBIK92_JDT_raw.csv, MBBBIK92_JDT_raw.txt
# Parsed MBBBIK92_EXO_raw.html → MBBBIK92_EXO_raw.csv, MBBBIK92_EXO_raw.txt
# Parsed MBBBIK92_EZR_raw.html → MBBBIK92_EZR_raw.csv, MBBBIK92_EZR_raw.txt
# Parsed MBBBIK92_2SA_raw.html → MBBBIK92_2SA_raw.csv, MBBBIK92_2SA_raw.txt
# Parsed MBBBIK92_RUT_raw.html → MBBBIK92_RUT_raw.csv, MBBBIK92_RUT_raw.txt
# Parsed MBBBIK92_LAM_raw.html → MBBBIK92_LAM_raw.csv, MBBBIK92_LAM_raw.txt
# Parsed MBBBIK92_NUM_raw.html → MBBBIK92_NUM_raw.csv, MBBBIK92_NUM_raw.txt
# Parsed MBBBIK92_JOL_raw.html → MBBBIK92_JOL_raw.csv, MBBBIK92_JOL_raw.txt
# Parsed MBBBIK92_ZEP_raw.html → MBBBIK92_ZEP_raw.csv, MBBBIK92_ZEP_raw.txt
# Parsed MBBBIK92_2PE_raw.html → MBBBIK92_2PE_raw.csv, MBBBIK92_2PE_raw.txt
# Parsed MBBBIK92_EZK_raw.html → MBBBIK92_EZK_raw.csv, MBBBIK92_EZK_raw.txt
# Parsed MBBBIK92_1TH_raw.html → MBBBIK92_1TH_raw.csv, MBBBIK92_1TH_raw.txt
# Parsed MBBBIK92_1TI_raw.html → MBBBIK92_1TI_raw.csv, MBBBIK92_1TI_raw.txt
# Parsed MBBBIK92_JUD_raw.html → MBBBIK92_JUD_raw.csv, MBBBIK92_JUD_raw.txt
# Parsed MBBBIK92_NEH_raw.html → MBBBIK92_NEH_raw.csv, MBBBIK92_NEH_raw.txt
# Parsed MBBBIK92_JOS_raw.html → MBBBIK92_JOS_raw.csv, MBBBIK92_JOS_raw.txt
# Parsed MBBBIK92_2CO_raw.html → MBBBIK92_2CO_raw.csv, MBBBIK92_2CO_raw.txt
# Parsed MBBBIK92_SNG_raw.html → MBBBIK92_SNG_raw.csv, MBBBIK92_SNG_raw.txt
# Parsed MBBBIK92_2MA_raw.html → MBBBIK92_2MA_raw.csv, MBBBIK92_2MA_raw.txt
# Parsed MBBBIK92_ISA_raw.html → MBBBIK92_ISA_raw.csv, MBBBIK92_ISA_raw.txt
# Parsed MBBBIK92_3JN_raw.html → MBBBIK92_3JN_raw.csv, MBBBIK92_3JN_raw.txt
# Parsed MBBBIK92_JDG_raw.html → MBBBIK92_JDG_raw.csv, MBBBIK92_JDG_raw.txt
# Parsed MBBBIK92_LUK_raw.html → MBBBIK92_LUK_raw.csv, MBBBIK92_LUK_raw.txt
# Parsed RIPV_GAL_raw.html → RIPV_GAL_raw.csv, RIPV_GAL_raw.txt
# Parsed RIPV_ECC_raw.html → RIPV_ECC_raw.csv, RIPV_ECC_raw.txt
# Parsed RIPV_ACT_raw.html → RIPV_ACT_raw.csv, RIPV_ACT_raw.txt
# Parsed RIPV_JOB_raw.html → RIPV_JOB_raw.csv, RIPV_JOB_raw.txt
# Parsed RIPV_GEN_raw.html → RIPV_GEN_raw.csv, RIPV_GEN_raw.txt
# Parsed RIPV_2TH_raw.html → RIPV_2TH_raw.csv, RIPV_2TH_raw.txt
# Parsed RIPV_2TI_raw.html → RIPV_2TI_raw.csv, RIPV_2TI_raw.txt
# Parsed RIPV_DEU_raw.html → RIPV_DEU_raw.csv, RIPV_DEU_raw.txt
# Parsed RIPV_JHN_raw.html → RIPV_JHN_raw.csv, RIPV_JHN_raw.txt
# Parsed RIPV_PRO_raw.html → RIPV_PRO_raw.csv, RIPV_PRO_raw.txt
# Parsed RIPV_ROM_raw.html → RIPV_ROM_raw.csv, RIPV_ROM_raw.txt
# Parsed RIPV_1CO_raw.html → RIPV_1CO_raw.csv, RIPV_1CO_raw.txt
# Parsed RIPV_1PE_raw.html → RIPV_1PE_raw.csv, RIPV_1PE_raw.txt
# Parsed RIPV_MRK_raw.html → RIPV_MRK_raw.csv, RIPV_MRK_raw.txt
# Parsed RIPV_JAS_raw.html → RIPV_JAS_raw.csv, RIPV_JAS_raw.txt
# Parsed RIPV_MAT_raw.html → RIPV_MAT_raw.csv, RIPV_MAT_raw.txt
# Parsed RIPV_EPH_raw.html → RIPV_EPH_raw.csv, RIPV_EPH_raw.txt
# Parsed RIPV_1SA_raw.html → RIPV_1SA_raw.csv, RIPV_1SA_raw.txt
# Parsed RIPV_HEB_raw.html → RIPV_HEB_raw.csv, RIPV_HEB_raw.txt
# Parsed RIPV_PHM_raw.html → RIPV_PHM_raw.csv, RIPV_PHM_raw.txt
# Parsed RIPV_AMO_raw.html → RIPV_AMO_raw.csv, RIPV_AMO_raw.txt
# Parsed RIPV_2JN_raw.html → RIPV_2JN_raw.csv, RIPV_2JN_raw.txt
# Parsed RIPV_HAG_raw.html → RIPV_HAG_raw.csv, RIPV_HAG_raw.txt
# Parsed RIPV_COL_raw.html → RIPV_COL_raw.csv, RIPV_COL_raw.txt
# Parsed RIPV_MIC_raw.html → RIPV_MIC_raw.csv, RIPV_MIC_raw.txt
# Parsed RIPV_DAN_raw.html → RIPV_DAN_raw.csv, RIPV_DAN_raw.txt
# Parsed RIPV_2KI_raw.html → RIPV_2KI_raw.csv, RIPV_2KI_raw.txt
# Parsed RIPV_MAL_raw.html → RIPV_MAL_raw.csv, RIPV_MAL_raw.txt
# Parsed RIPV_EST_raw.html → RIPV_EST_raw.csv, RIPV_EST_raw.txt
# Parsed RIPV_JON_raw.html → RIPV_JON_raw.csv, RIPV_JON_raw.txt
# Parsed RIPV_1CH_raw.html → RIPV_1CH_raw.csv, RIPV_1CH_raw.txt
# Parsed RIPV_LEV_raw.html → RIPV_LEV_raw.csv, RIPV_LEV_raw.txt
# Parsed RIPV_ZEC_raw.html → RIPV_ZEC_raw.csv, RIPV_ZEC_raw.txt
# Parsed RIPV_NAM_raw.html → RIPV_NAM_raw.csv, RIPV_NAM_raw.txt
# Parsed RIPV_REV_raw.html → RIPV_REV_raw.csv, RIPV_REV_raw.txt
# Parsed RIPV_1KI_raw.html → RIPV_1KI_raw.csv, RIPV_1KI_raw.txt
# Parsed RIPV_JER_raw.html → RIPV_JER_raw.csv, RIPV_JER_raw.txt
# Parsed RIPV_2CH_raw.html → RIPV_2CH_raw.csv, RIPV_2CH_raw.txt
# Parsed RIPV_PSA_raw.html → RIPV_PSA_raw.csv, RIPV_PSA_raw.txt
# Parsed RIPV_HAB_raw.html → RIPV_HAB_raw.csv, RIPV_HAB_raw.txt
# Parsed RIPV_OBA_raw.html → RIPV_OBA_raw.csv, RIPV_OBA_raw.txt
# Parsed RIPV_EXO_raw.html → RIPV_EXO_raw.csv, RIPV_EXO_raw.txt
# Parsed RIPV_EZR_raw.html → RIPV_EZR_raw.csv, RIPV_EZR_raw.txt
# Parsed RIPV_1JN_raw.html → RIPV_1JN_raw.csv, RIPV_1JN_raw.txt
# Parsed RIPV_PHP_raw.html → RIPV_PHP_raw.csv, RIPV_PHP_raw.txt
# Parsed RIPV_TIT_raw.html → RIPV_TIT_raw.csv, RIPV_TIT_raw.txt
# Parsed RIPV_HOS_raw.html → RIPV_HOS_raw.csv, RIPV_HOS_raw.txt
# Parsed RIPV_2PE_raw.html → RIPV_2PE_raw.csv, RIPV_2PE_raw.txt
# Parsed RIPV_NUM_raw.html → RIPV_NUM_raw.csv, RIPV_NUM_raw.txt
# Parsed RIPV_JOL_raw.html → RIPV_JOL_raw.csv, RIPV_JOL_raw.txt
# Parsed RIPV_ZEP_raw.html → RIPV_ZEP_raw.csv, RIPV_ZEP_raw.txt
# Parsed RIPV_LAM_raw.html → RIPV_LAM_raw.csv, RIPV_LAM_raw.txt
# Parsed RIPV_RUT_raw.html → RIPV_RUT_raw.csv, RIPV_RUT_raw.txt
# Parsed RIPV_2SA_raw.html → RIPV_2SA_raw.csv, RIPV_2SA_raw.txt
# Parsed RIPV_LUK_raw.html → RIPV_LUK_raw.csv, RIPV_LUK_raw.txt
# Parsed RIPV_3JN_raw.html → RIPV_3JN_raw.csv, RIPV_3JN_raw.txt
# Parsed RIPV_JDG_raw.html → RIPV_JDG_raw.csv, RIPV_JDG_raw.txt
# Parsed RIPV_SNG_raw.html → RIPV_SNG_raw.csv, RIPV_SNG_raw.txt
# Parsed RIPV_ISA_raw.html → RIPV_ISA_raw.csv, RIPV_ISA_raw.txt
# Parsed RIPV_2CO_raw.html → RIPV_2CO_raw.csv, RIPV_2CO_raw.txt
# Parsed RIPV_JOS_raw.html → RIPV_JOS_raw.csv, RIPV_JOS_raw.txt
# Parsed RIPV_NEH_raw.html → RIPV_NEH_raw.csv, RIPV_NEH_raw.txt
# Parsed RIPV_EZK_raw.html → RIPV_EZK_raw.csv, RIPV_EZK_raw.txt
# Parsed RIPV_1TH_raw.html → RIPV_1TH_raw.csv, RIPV_1TH_raw.txt
# Parsed RIPV_JUD_raw.html → RIPV_JUD_raw.csv, RIPV_JUD_raw.txt
# Parsed RIPV_1TI_raw.html → RIPV_1TI_raw.csv, RIPV_1TI_raw.txt
# Parsed kmk_COL_raw.html → kmk_COL_raw.csv, kmk_COL_raw.txt
# Parsed kmk_2JN_raw.html → kmk_2JN_raw.csv, kmk_2JN_raw.txt
# Parsed kmk_JAS_raw.html → kmk_JAS_raw.csv, kmk_JAS_raw.txt
# Parsed kmk_MRK_raw.html → kmk_MRK_raw.csv, kmk_MRK_raw.txt
# Parsed kmk_1PE_raw.html → kmk_1PE_raw.csv, kmk_1PE_raw.txt
# Parsed kmk_HEB_raw.html → kmk_HEB_raw.csv, kmk_HEB_raw.txt
# Parsed kmk_PHM_raw.html → kmk_PHM_raw.csv, kmk_PHM_raw.txt
# Parsed kmk_EPH_raw.html → kmk_EPH_raw.csv, kmk_EPH_raw.txt
# Parsed kmk_MAT_raw.html → kmk_MAT_raw.csv, kmk_MAT_raw.txt
# Parsed kmk_ACT_raw.html → kmk_ACT_raw.csv, kmk_ACT_raw.txt
# Parsed kmk_GAL_raw.html → kmk_GAL_raw.csv, kmk_GAL_raw.txt
# Parsed kmk_ROM_raw.html → kmk_ROM_raw.csv, kmk_ROM_raw.txt
# Parsed kmk_1CO_raw.html → kmk_1CO_raw.csv, kmk_1CO_raw.txt
# Parsed kmk_JHN_raw.html → kmk_JHN_raw.csv, kmk_JHN_raw.txt
# Parsed kmk_2TH_raw.html → kmk_2TH_raw.csv, kmk_2TH_raw.txt
# Parsed kmk_2TI_raw.html → kmk_2TI_raw.csv, kmk_2TI_raw.txt
# Parsed kmk_3JN_raw.html → kmk_3JN_raw.csv, kmk_3JN_raw.txt
# Parsed kmk_LUK_raw.html → kmk_LUK_raw.csv, kmk_LUK_raw.txt
# Parsed kmk_1TH_raw.html → kmk_1TH_raw.csv, kmk_1TH_raw.txt
# Parsed kmk_1TI_raw.html → kmk_1TI_raw.csv, kmk_1TI_raw.txt
# Parsed kmk_JUD_raw.html → kmk_JUD_raw.csv, kmk_JUD_raw.txt
# Parsed kmk_2CO_raw.html → kmk_2CO_raw.csv, kmk_2CO_raw.txt
# Parsed kmk_2PE_raw.html → kmk_2PE_raw.csv, kmk_2PE_raw.txt
# Parsed kmk_1JN_raw.html → kmk_1JN_raw.csv, kmk_1JN_raw.txt
# Parsed kmk_TIT_raw.html → kmk_TIT_raw.csv, kmk_TIT_raw.txt
# Parsed kmk_PHP_raw.html → kmk_PHP_raw.csv, kmk_PHP_raw.txt
# Parsed kmk_REV_raw.html → kmk_REV_raw.csv, kmk_REV_raw.txt
# Parsed PmPV_BEL_raw.html → PmPV_BEL_raw.csv, PmPV_BEL_raw.txt
# Parsed PmPV_2CH_raw.html → PmPV_2CH_raw.csv, PmPV_2CH_raw.txt
# Parsed PmPV_PSA_raw.html → PmPV_PSA_raw.csv, PmPV_PSA_raw.txt
# Parsed PmPV_HAB_raw.html → PmPV_HAB_raw.csv, PmPV_HAB_raw.txt
# Parsed PmPV_S3Y_raw.html → PmPV_S3Y_raw.csv, PmPV_S3Y_raw.txt
# Parsed PmPV_OBA_raw.html → PmPV_OBA_raw.csv, PmPV_OBA_raw.txt
# Parsed PmPV_LEV_raw.html → PmPV_LEV_raw.csv, PmPV_LEV_raw.txt
# Parsed PmPV_ZEC_raw.html → PmPV_ZEC_raw.csv, PmPV_ZEC_raw.txt
# Parsed PmPV_NAM_raw.html → PmPV_NAM_raw.csv, PmPV_NAM_raw.txt
# Parsed PmPV_JER_raw.html → PmPV_JER_raw.csv, PmPV_JER_raw.txt
# Parsed PmPV_REV_raw.html → PmPV_REV_raw.csv, PmPV_REV_raw.txt
# Parsed PmPV_1KI_raw.html → PmPV_1KI_raw.csv, PmPV_1KI_raw.txt
# Parsed PmPV_TIT_raw.html → PmPV_TIT_raw.csv, PmPV_TIT_raw.txt
# Parsed PmPV_PHP_raw.html → PmPV_PHP_raw.csv, PmPV_PHP_raw.txt
# Parsed PmPV_HOS_raw.html → PmPV_HOS_raw.csv, PmPV_HOS_raw.txt
# Parsed PmPV_EXO_raw.html → PmPV_EXO_raw.csv, PmPV_EXO_raw.txt
# Parsed PmPV_EZR_raw.html → PmPV_EZR_raw.csv, PmPV_EZR_raw.txt
# Parsed PmPV_1JN_raw.html → PmPV_1JN_raw.csv, PmPV_1JN_raw.txt
# Parsed PmPV_JDT_raw.html → PmPV_JDT_raw.csv, PmPV_JDT_raw.txt
# Parsed PmPV_SIR_raw.html → PmPV_SIR_raw.csv, PmPV_SIR_raw.txt
# Parsed PmPV_RUT_raw.html → PmPV_RUT_raw.csv, PmPV_RUT_raw.txt
# Parsed PmPV_2SA_raw.html → PmPV_2SA_raw.csv, PmPV_2SA_raw.txt
# Parsed PmPV_2PE_raw.html → PmPV_2PE_raw.csv, PmPV_2PE_raw.txt
# Parsed PmPV_LAM_raw.html → PmPV_LAM_raw.csv, PmPV_LAM_raw.txt
# Parsed PmPV_JOL_raw.html → PmPV_JOL_raw.csv, PmPV_JOL_raw.txt
# Parsed PmPV_ZEP_raw.html → PmPV_ZEP_raw.csv, PmPV_ZEP_raw.txt
# Parsed PmPV_NUM_raw.html → PmPV_NUM_raw.csv, PmPV_NUM_raw.txt
# Parsed PmPV_NEH_raw.html → PmPV_NEH_raw.csv, PmPV_NEH_raw.txt
# Parsed PmPV_2CO_raw.html → PmPV_2CO_raw.csv, PmPV_2CO_raw.txt
# Parsed PmPV_JOS_raw.html → PmPV_JOS_raw.csv, PmPV_JOS_raw.txt
# Parsed PmPV_1TH_raw.html → PmPV_1TH_raw.csv, PmPV_1TH_raw.txt
# Parsed PmPV_JUD_raw.html → PmPV_JUD_raw.csv, PmPV_JUD_raw.txt
# Parsed PmPV_1TI_raw.html → PmPV_1TI_raw.csv, PmPV_1TI_raw.txt
# Parsed PmPV_EZK_raw.html → PmPV_EZK_raw.csv, PmPV_EZK_raw.txt
# Parsed PmPV_JDG_raw.html → PmPV_JDG_raw.csv, PmPV_JDG_raw.txt
# Parsed PmPV_3JN_raw.html → PmPV_3JN_raw.csv, PmPV_3JN_raw.txt
# Parsed PmPV_LUK_raw.html → PmPV_LUK_raw.csv, PmPV_LUK_raw.txt
# Parsed PmPV_ISA_raw.html → PmPV_ISA_raw.csv, PmPV_ISA_raw.txt
# Parsed PmPV_2MA_raw.html → PmPV_2MA_raw.csv, PmPV_2MA_raw.txt
# Parsed PmPV_SNG_raw.html → PmPV_SNG_raw.csv, PmPV_SNG_raw.txt
# Parsed PmPV_DEU_raw.html → PmPV_DEU_raw.csv, PmPV_DEU_raw.txt
# Parsed PmPV_JHN_raw.html → PmPV_JHN_raw.csv, PmPV_JHN_raw.txt
# Parsed PmPV_GEN_raw.html → PmPV_GEN_raw.csv, PmPV_GEN_raw.txt
# Parsed PmPV_2TH_raw.html → PmPV_2TH_raw.csv, PmPV_2TH_raw.txt
# Parsed PmPV_2TI_raw.html → PmPV_2TI_raw.csv, PmPV_2TI_raw.txt
# Parsed PmPV_SUS_raw.html → PmPV_SUS_raw.csv, PmPV_SUS_raw.txt
# Parsed PmPV_ROM_raw.html → PmPV_ROM_raw.csv, PmPV_ROM_raw.txt
# Parsed PmPV_1CO_raw.html → PmPV_1CO_raw.csv, PmPV_1CO_raw.txt
# Parsed PmPV_PRO_raw.html → PmPV_PRO_raw.csv, PmPV_PRO_raw.txt
# Parsed PmPV_1MA_raw.html → PmPV_1MA_raw.csv, PmPV_1MA_raw.txt
# Parsed PmPV_ECC_raw.html → PmPV_ECC_raw.csv, PmPV_ECC_raw.txt
# Parsed PmPV_TOB_raw.html → PmPV_TOB_raw.csv, PmPV_TOB_raw.txt
# Parsed PmPV_GAL_raw.html → PmPV_GAL_raw.csv, PmPV_GAL_raw.txt
# Parsed PmPV_JOB_raw.html → PmPV_JOB_raw.csv, PmPV_JOB_raw.txt
# Parsed PmPV_BAR_raw.html → PmPV_BAR_raw.csv, PmPV_BAR_raw.txt
# Parsed PmPV_ACT_raw.html → PmPV_ACT_raw.csv, PmPV_ACT_raw.txt
# Parsed PmPV_1SA_raw.html → PmPV_1SA_raw.csv, PmPV_1SA_raw.txt
# Parsed PmPV_EPH_raw.html → PmPV_EPH_raw.csv, PmPV_EPH_raw.txt
# Parsed PmPV_MAT_raw.html → PmPV_MAT_raw.csv, PmPV_MAT_raw.txt
# Parsed PmPV_AMO_raw.html → PmPV_AMO_raw.csv, PmPV_AMO_raw.txt
# Parsed PmPV_HEB_raw.html → PmPV_HEB_raw.csv, PmPV_HEB_raw.txt
# Parsed PmPV_WIS_raw.html → PmPV_WIS_raw.csv, PmPV_WIS_raw.txt
# Parsed PmPV_PHM_raw.html → PmPV_PHM_raw.csv, PmPV_PHM_raw.txt
# Parsed PmPV_JAS_raw.html → PmPV_JAS_raw.csv, PmPV_JAS_raw.txt
# Parsed PmPV_1PE_raw.html → PmPV_1PE_raw.csv, PmPV_1PE_raw.txt
# Parsed PmPV_MRK_raw.html → PmPV_MRK_raw.csv, PmPV_MRK_raw.txt
# Parsed PmPV_LJE_raw.html → PmPV_LJE_raw.csv, PmPV_LJE_raw.txt
# Parsed PmPV_DAN_raw.html → PmPV_DAN_raw.csv, PmPV_DAN_raw.txt
# Parsed PmPV_MIC_raw.html → PmPV_MIC_raw.csv, PmPV_MIC_raw.txt
# Parsed PmPV_2JN_raw.html → PmPV_2JN_raw.csv, PmPV_2JN_raw.txt
# Parsed PmPV_COL_raw.html → PmPV_COL_raw.csv, PmPV_COL_raw.txt
# Parsed PmPV_HAG_raw.html → PmPV_HAG_raw.csv, PmPV_HAG_raw.txt
# Parsed PmPV_EST_raw.html → PmPV_EST_raw.csv, PmPV_EST_raw.txt
# Parsed PmPV_1CH_raw.html → PmPV_1CH_raw.csv, PmPV_1CH_raw.txt
# Parsed PmPV_JON_raw.html → PmPV_JON_raw.csv, PmPV_JON_raw.txt
# Parsed PmPV_2KI_raw.html → PmPV_2KI_raw.csv, PmPV_2KI_raw.txt
# Parsed PmPV_MAL_raw.html → PmPV_MAL_raw.csv, PmPV_MAL_raw.txt
# Parsed ISDNT_GAL_raw.html → ISDNT_GAL_raw.csv, ISDNT_GAL_raw.txt
# Parsed ISDNT_ACT_raw.html → ISDNT_ACT_raw.csv, ISDNT_ACT_raw.txt
# Parsed ISDNT_JHN_raw.html → ISDNT_JHN_raw.csv, ISDNT_JHN_raw.txt
# Parsed ISDNT_GEN_raw.html → ISDNT_GEN_raw.csv, ISDNT_GEN_raw.txt
# Parsed ISDNT_2TH_raw.html → ISDNT_2TH_raw.csv, ISDNT_2TH_raw.txt
# Parsed ISDNT_2TI_raw.html → ISDNT_2TI_raw.csv, ISDNT_2TI_raw.txt
# Parsed ISDNT_ROM_raw.html → ISDNT_ROM_raw.csv, ISDNT_ROM_raw.txt
# Parsed ISDNT_1CO_raw.html → ISDNT_1CO_raw.csv, ISDNT_1CO_raw.txt
# Parsed ISDNT_JAS_raw.html → ISDNT_JAS_raw.csv, ISDNT_JAS_raw.txt
# Parsed ISDNT_MRK_raw.html → ISDNT_MRK_raw.csv, ISDNT_MRK_raw.txt
# Parsed ISDNT_1PE_raw.html → ISDNT_1PE_raw.csv, ISDNT_1PE_raw.txt
# Parsed ISDNT_MAT_raw.html → ISDNT_MAT_raw.csv, ISDNT_MAT_raw.txt
# Parsed ISDNT_EPH_raw.html → ISDNT_EPH_raw.csv, ISDNT_EPH_raw.txt
# Parsed ISDNT_HEB_raw.html → ISDNT_HEB_raw.csv, ISDNT_HEB_raw.txt
# Parsed ISDNT_PHM_raw.html → ISDNT_PHM_raw.csv, ISDNT_PHM_raw.txt
# Parsed ISDNT_2JN_raw.html → ISDNT_2JN_raw.csv, ISDNT_2JN_raw.txt
# Parsed ISDNT_COL_raw.html → ISDNT_COL_raw.csv, ISDNT_COL_raw.txt
# Parsed ISDNT_REV_raw.html → ISDNT_REV_raw.csv, ISDNT_REV_raw.txt
# Parsed ISDNT_EXO_raw.html → ISDNT_EXO_raw.csv, ISDNT_EXO_raw.txt
# Parsed ISDNT_1JN_raw.html → ISDNT_1JN_raw.csv, ISDNT_1JN_raw.txt
# Parsed ISDNT_TIT_raw.html → ISDNT_TIT_raw.csv, ISDNT_TIT_raw.txt
# Parsed ISDNT_PHP_raw.html → ISDNT_PHP_raw.csv, ISDNT_PHP_raw.txt
# Parsed ISDNT_2PE_raw.html → ISDNT_2PE_raw.csv, ISDNT_2PE_raw.txt
# Parsed ISDNT_3JN_raw.html → ISDNT_3JN_raw.csv, ISDNT_3JN_raw.txt
# Parsed ISDNT_LUK_raw.html → ISDNT_LUK_raw.csv, ISDNT_LUK_raw.txt
# Parsed ISDNT_2CO_raw.html → ISDNT_2CO_raw.csv, ISDNT_2CO_raw.txt
# Parsed ISDNT_1TH_raw.html → ISDNT_1TH_raw.csv, ISDNT_1TH_raw.txt
# Parsed ISDNT_JUD_raw.html → ISDNT_JUD_raw.csv, ISDNT_JUD_raw.txt
# Parsed ISDNT_1TI_raw.html → ISDNT_1TI_raw.csv, ISDNT_1TI_raw.txt
# Parsed XNN_MIC_raw.html → XNN_MIC_raw.csv, XNN_MIC_raw.txt
# Parsed XNN_DAN_raw.html → XNN_DAN_raw.csv, XNN_DAN_raw.txt
# Parsed XNN_COL_raw.html → XNN_COL_raw.csv, XNN_COL_raw.txt
# Parsed XNN_2JN_raw.html → XNN_2JN_raw.csv, XNN_2JN_raw.txt
# Parsed XNN_JON_raw.html → XNN_JON_raw.csv, XNN_JON_raw.txt
# Parsed XNN_MAL_raw.html → XNN_MAL_raw.csv, XNN_MAL_raw.txt
# Parsed XNN_2KI_raw.html → XNN_2KI_raw.csv, XNN_2KI_raw.txt
# Parsed XNN_PRO_raw.html → XNN_PRO_raw.csv, XNN_PRO_raw.txt
# Parsed XNN_1CO_raw.html → XNN_1CO_raw.csv, XNN_1CO_raw.txt
# Parsed XNN_ROM_raw.html → XNN_ROM_raw.csv, XNN_ROM_raw.txt
# Parsed XNN_GEN_raw.html → XNN_GEN_raw.csv, XNN_GEN_raw.txt
# Parsed XNN_2TH_raw.html → XNN_2TH_raw.csv, XNN_2TH_raw.txt
# Parsed XNN_2TI_raw.html → XNN_2TI_raw.csv, XNN_2TI_raw.txt
# Parsed XNN_JHN_raw.html → XNN_JHN_raw.csv, XNN_JHN_raw.txt
# Parsed XNN_DEU_raw.html → XNN_DEU_raw.csv, XNN_DEU_raw.txt
# Parsed XNN_ACT_raw.html → XNN_ACT_raw.csv, XNN_ACT_raw.txt
# Parsed XNN_JOB_raw.html → XNN_JOB_raw.csv, XNN_JOB_raw.txt
# Parsed XNN_BAR_raw.html → XNN_BAR_raw.csv, XNN_BAR_raw.txt
# Parsed XNN_GAL_raw.html → XNN_GAL_raw.csv, XNN_GAL_raw.txt
# Parsed XNN_ECC_raw.html → XNN_ECC_raw.csv, XNN_ECC_raw.txt
# Parsed XNN_PHM_raw.html → XNN_PHM_raw.csv, XNN_PHM_raw.txt
# Parsed XNN_HEB_raw.html → XNN_HEB_raw.csv, XNN_HEB_raw.txt
# Parsed XNN_WIS_raw.html → XNN_WIS_raw.csv, XNN_WIS_raw.txt
# Parsed XNN_AMO_raw.html → XNN_AMO_raw.csv, XNN_AMO_raw.txt
# Parsed XNN_EPH_raw.html → XNN_EPH_raw.csv, XNN_EPH_raw.txt
# Parsed XNN_MAT_raw.html → XNN_MAT_raw.csv, XNN_MAT_raw.txt
# Parsed XNN_1SA_raw.html → XNN_1SA_raw.csv, XNN_1SA_raw.txt
# Parsed XNN_MRK_raw.html → XNN_MRK_raw.csv, XNN_MRK_raw.txt
# Parsed XNN_1PE_raw.html → XNN_1PE_raw.csv, XNN_1PE_raw.txt
# Parsed XNN_JAS_raw.html → XNN_JAS_raw.csv, XNN_JAS_raw.txt
# Parsed XNN_2SA_raw.html → XNN_2SA_raw.csv, XNN_2SA_raw.txt
# Parsed XNN_RUT_raw.html → XNN_RUT_raw.csv, XNN_RUT_raw.txt
# Parsed XNN_ZEP_raw.html → XNN_ZEP_raw.csv, XNN_ZEP_raw.txt
# Parsed XNN_JOL_raw.html → XNN_JOL_raw.csv, XNN_JOL_raw.txt
# Parsed XNN_NUM_raw.html → XNN_NUM_raw.csv, XNN_NUM_raw.txt
# Parsed XNN_2PE_raw.html → XNN_2PE_raw.csv, XNN_2PE_raw.txt
# Parsed XNN_1TH_raw.html → XNN_1TH_raw.csv, XNN_1TH_raw.txt
# Parsed XNN_JUD_raw.html → XNN_JUD_raw.csv, XNN_JUD_raw.txt
# Parsed XNN_1TI_raw.html → XNN_1TI_raw.csv, XNN_1TI_raw.txt
# Parsed XNN_EZK_raw.html → XNN_EZK_raw.csv, XNN_EZK_raw.txt
# Parsed XNN_2CO_raw.html → XNN_2CO_raw.csv, XNN_2CO_raw.txt
# Parsed XNN_JOS_raw.html → XNN_JOS_raw.csv, XNN_JOS_raw.txt
# Parsed XNN_NEH_raw.html → XNN_NEH_raw.csv, XNN_NEH_raw.txt
# Parsed XNN_ISA_raw.html → XNN_ISA_raw.csv, XNN_ISA_raw.txt
# Parsed XNN_LUK_raw.html → XNN_LUK_raw.csv, XNN_LUK_raw.txt
# Parsed XNN_JDG_raw.html → XNN_JDG_raw.csv, XNN_JDG_raw.txt
# Parsed XNN_3JN_raw.html → XNN_3JN_raw.csv, XNN_3JN_raw.txt
# Parsed XNN_HAB_raw.html → XNN_HAB_raw.csv, XNN_HAB_raw.txt
# Parsed XNN_PSA_raw.html → XNN_PSA_raw.csv, XNN_PSA_raw.txt
# Parsed XNN_2CH_raw.html → XNN_2CH_raw.csv, XNN_2CH_raw.txt
# Parsed XNN_1KI_raw.html → XNN_1KI_raw.csv, XNN_1KI_raw.txt
# Parsed XNN_REV_raw.html → XNN_REV_raw.csv, XNN_REV_raw.txt
# Parsed XNN_JER_raw.html → XNN_JER_raw.csv, XNN_JER_raw.txt
# Parsed XNN_ZEC_raw.html → XNN_ZEC_raw.csv, XNN_ZEC_raw.txt
# Parsed XNN_LEV_raw.html → XNN_LEV_raw.csv, XNN_LEV_raw.txt
# Parsed XNN_HOS_raw.html → XNN_HOS_raw.csv, XNN_HOS_raw.txt
# Parsed XNN_PHP_raw.html → XNN_PHP_raw.csv, XNN_PHP_raw.txt
# Parsed XNN_TIT_raw.html → XNN_TIT_raw.csv, XNN_TIT_raw.txt
# Parsed XNN_JDT_raw.html → XNN_JDT_raw.csv, XNN_JDT_raw.txt
# Parsed XNN_SIR_raw.html → XNN_SIR_raw.csv, XNN_SIR_raw.txt
# Parsed XNN_1JN_raw.html → XNN_1JN_raw.csv, XNN_1JN_raw.txt
# Parsed XNN_EXO_raw.html → XNN_EXO_raw.csv, XNN_EXO_raw.txt
# Parsed XSB_TIT_raw.html → XSB_TIT_raw.csv, XSB_TIT_raw.txt
# Parsed XSB_PHP_raw.html → XSB_PHP_raw.csv, XSB_PHP_raw.txt
# Parsed XSB_1JN_raw.html → XSB_1JN_raw.csv, XSB_1JN_raw.txt
# Parsed XSB_REV_raw.html → XSB_REV_raw.csv, XSB_REV_raw.txt
# Parsed XSB_2CO_raw.html → XSB_2CO_raw.csv, XSB_2CO_raw.txt
# Parsed XSB_JUD_raw.html → XSB_JUD_raw.csv, XSB_JUD_raw.txt
# Parsed XSB_1TI_raw.html → XSB_1TI_raw.csv, XSB_1TI_raw.txt
# Parsed XSB_1TH_raw.html → XSB_1TH_raw.csv, XSB_1TH_raw.txt
# Parsed XSB_3JN_raw.html → XSB_3JN_raw.csv, XSB_3JN_raw.txt
# Parsed XSB_LUK_raw.html → XSB_LUK_raw.csv, XSB_LUK_raw.txt
# Parsed XSB_2PE_raw.html → XSB_2PE_raw.csv, XSB_2PE_raw.txt
# Parsed XSB_EPH_raw.html → XSB_EPH_raw.csv, XSB_EPH_raw.txt
# Parsed XSB_MAT_raw.html → XSB_MAT_raw.csv, XSB_MAT_raw.txt
# Parsed XSB_PHM_raw.html → XSB_PHM_raw.csv, XSB_PHM_raw.txt
# Parsed XSB_HEB_raw.html → XSB_HEB_raw.csv, XSB_HEB_raw.txt
# Parsed XSB_JAS_raw.html → XSB_JAS_raw.csv, XSB_JAS_raw.txt
# Parsed XSB_1PE_raw.html → XSB_1PE_raw.csv, XSB_1PE_raw.txt
# Parsed XSB_MRK_raw.html → XSB_MRK_raw.csv, XSB_MRK_raw.txt
# Parsed XSB_JHN_raw.html → XSB_JHN_raw.csv, XSB_JHN_raw.txt
# Parsed XSB_2TI_raw.html → XSB_2TI_raw.csv, XSB_2TI_raw.txt
# Parsed XSB_2TH_raw.html → XSB_2TH_raw.csv, XSB_2TH_raw.txt
# Parsed XSB_1CO_raw.html → XSB_1CO_raw.csv, XSB_1CO_raw.txt
# Parsed XSB_ROM_raw.html → XSB_ROM_raw.csv, XSB_ROM_raw.txt
# Parsed XSB_GAL_raw.html → XSB_GAL_raw.csv, XSB_GAL_raw.txt
# Parsed XSB_ACT_raw.html → XSB_ACT_raw.csv, XSB_ACT_raw.txt
# Parsed XSB_2JN_raw.html → XSB_2JN_raw.csv, XSB_2JN_raw.txt
# Parsed XSB_COL_raw.html → XSB_COL_raw.csv, XSB_COL_raw.txt
# Parsed YAKV_3JN_raw.html → YAKV_3JN_raw.csv, YAKV_3JN_raw.txt
# Parsed YAKV_LUK_raw.html → YAKV_LUK_raw.csv, YAKV_LUK_raw.txt
# Parsed YAKV_1TI_raw.html → YAKV_1TI_raw.csv, YAKV_1TI_raw.txt
# Parsed YAKV_JUD_raw.html → YAKV_JUD_raw.csv, YAKV_JUD_raw.txt
# Parsed YAKV_1TH_raw.html → YAKV_1TH_raw.csv, YAKV_1TH_raw.txt
# Parsed YAKV_2CO_raw.html → YAKV_2CO_raw.csv, YAKV_2CO_raw.txt
# Parsed YAKV_2PE_raw.html → YAKV_2PE_raw.csv, YAKV_2PE_raw.txt
# Parsed YAKV_RUT_raw.html → YAKV_RUT_raw.csv, YAKV_RUT_raw.txt
# Parsed YAKV_1JN_raw.html → YAKV_1JN_raw.csv, YAKV_1JN_raw.txt
# Parsed YAKV_TIT_raw.html → YAKV_TIT_raw.csv, YAKV_TIT_raw.txt
# Parsed YAKV_PHP_raw.html → YAKV_PHP_raw.csv, YAKV_PHP_raw.txt
# Parsed YAKV_REV_raw.html → YAKV_REV_raw.csv, YAKV_REV_raw.txt
# Parsed YAKV_JON_raw.html → YAKV_JON_raw.csv, YAKV_JON_raw.txt
# Parsed YAKV_COL_raw.html → YAKV_COL_raw.csv, YAKV_COL_raw.txt
# Parsed YAKV_2JN_raw.html → YAKV_2JN_raw.csv, YAKV_2JN_raw.txt
# Parsed YAKV_JAS_raw.html → YAKV_JAS_raw.csv, YAKV_JAS_raw.txt
# Parsed YAKV_MRK_raw.html → YAKV_MRK_raw.csv, YAKV_MRK_raw.txt
# Parsed YAKV_1PE_raw.html → YAKV_1PE_raw.csv, YAKV_1PE_raw.txt
# Parsed YAKV_PHM_raw.html → YAKV_PHM_raw.csv, YAKV_PHM_raw.txt
# Parsed YAKV_HEB_raw.html → YAKV_HEB_raw.csv, YAKV_HEB_raw.txt
# Parsed YAKV_EPH_raw.html → YAKV_EPH_raw.csv, YAKV_EPH_raw.txt
# Parsed YAKV_MAT_raw.html → YAKV_MAT_raw.csv, YAKV_MAT_raw.txt
# Parsed YAKV_ACT_raw.html → YAKV_ACT_raw.csv, YAKV_ACT_raw.txt
# Parsed YAKV_GAL_raw.html → YAKV_GAL_raw.csv, YAKV_GAL_raw.txt
# Parsed YAKV_1CO_raw.html → YAKV_1CO_raw.csv, YAKV_1CO_raw.txt
# Parsed YAKV_ROM_raw.html → YAKV_ROM_raw.csv, YAKV_ROM_raw.txt
# Parsed YAKV_JHN_raw.html → YAKV_JHN_raw.csv, YAKV_JHN_raw.txt
# Parsed YAKV_2TI_raw.html → YAKV_2TI_raw.csv, YAKV_2TI_raw.txt
# Parsed YAKV_2TH_raw.html → YAKV_2TH_raw.csv, YAKV_2TH_raw.txt
# Parsed YAKV_GEN_raw.html → YAKV_GEN_raw.csv, YAKV_GEN_raw.txt
#
# Summary
# Processed (all folders): 791
# Empty filesets         : 0
# Errors                 : 0

# %% [markdown]
# ## By sentence

# %% [markdown]
# ### Step 1: Remove Duplicate Verse Entries
#
# **Input Sources**
#    - Each language’s processed `.csv` files are located under the `parsed/` directory.
#    - The script reads these CSVs recursively, ensuring that subfolder structure is preserved.
#
# **Target Outputs**
#    - Cleaned `.txt` files are written into the corresponding `sentence/` directory for each language.
#    - The folder hierarchy is mirrored so that each input CSV has a matching output TXT.
#
# **Robustness Features**
#    - CSVs are read with multiple encoding fallbacks (`utf-8`, `utf-8-sig`, `latin-1`).
#    - Bad lines are skipped to prevent failures on malformed files.
#    - Files without usable text columns are skipped gracefully with log messages.
#
# **Logging and Summary**
#    - For each file, the script prints the number of unique lines written.
#    - At the end of processing, a summary reports:
#      - total CSVs processed
#      - total TXT files written
#      - skipped files (due to missing `text` column or read errors)

# %%
# CHANGE: List all source folders that contain .txt files

LANG_DIRS = [
    "yna/sentence/Cebuano",
    "yna/sentence/Spanish",
    "yna/sentence/Chavacano",
    "yna/sentence/Tausug",
    "cj/sentence/Ivatan",
    "cj/sentence/Pangasinense",
    "cj/sentence/Tagalog",
    "cj/sentence/Yami",
    "trish/sentence/Bikolano",
    "trish/sentence/Ilokano",
    "trish/sentence/Kalinga",
    "trish/sentence/Kapampangan",
    "enz/sentence/Isnag",
    "enz/sentence/Kankanaey",
    "enz/sentence/Sambal",
    "enz/sentence/Yakan",
]

EXACT_TEXT_COL_NAME_ONLY = True # if True, only columns named exactly "text" (case-insensitive) are used.

# %%
# helper functions
def read_csv_any_encoding(path: str) -> pd.DataFrame:
    """
    Robust CSV reader trying common encodings and skipping bad lines.
    """
    for enc in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            return pd.read_csv(path, dtype=str, encoding=enc, on_bad_lines="skip")
        except Exception:
            continue
    raise RuntimeError(f"Failed to read CSV: {path}")

def replace_segment(path: str, old_seg: str, new_seg: str) -> str:
    """
    Replace a single path segment (e.g., 'sentence' -> 'parsed').
    If not found, create a sibling: parent/NEW/leaf
    """
    parts = path.split(os.sep)
    for i, p in enumerate(parts):
        if p == old_seg:
            parts[i] = new_seg
            return os.sep.join(parts)
    parent, leaf = os.path.split(path)
    return os.path.join(os.path.dirname(parent), new_seg, leaf)

def derive_input_root_from_lang_dir(lang_dir: str) -> str:
    """
    Given an output root like '.../sentence/Tagalog', return '.../parsed/Tagalog'.
    """
    parts = lang_dir.split(os.sep)
    if "sentence" in parts:
        return replace_segment(lang_dir, "sentence", "parsed")
    parent, leaf = os.path.split(lang_dir)
    return os.path.join(os.path.dirname(parent), "parsed", leaf)

def process_pair(input_root: str, output_root: str,
                 exact_text_only: bool = True):
    """
    Process all CSVs under input_root and write TXT under output_root, mirroring structure.
    """
    pattern = os.path.join(input_root, "**", "*.csv")
    csv_paths = glob.glob(pattern, recursive=True)

    print(f"Found {len(csv_paths)} CSV file(s).")

    processed = 0
    written   = 0
    skipped_no_text_col = 0
    skipped_read_error  = 0

    for in_path in csv_paths:
        processed += 1

        try:
            df = read_csv_any_encoding(in_path)
        except Exception as e:
            print(f"Warning Read error; skipping: {in_path} | {e}")
            skipped_read_error += 1
            continue

        cols = list(df.columns)
        if exact_text_only:
            text_cols = [c for c in cols if c.strip().lower() == "text"]
        else:
            text_cols = [c for c in cols if "text" in c.strip().lower()]

        if not text_cols:
            print(f"Info No matching 'text' column in: {in_path}; skipping.")
            skipped_no_text_col += 1
            continue

        series_list = []
        for col in text_cols:
            s = df[col].dropna().astype(str).map(str.strip)
            s = s[s != ""]
            if not s.empty:
                series_list.append(s)

        if not series_list:
            print(f"Info No non-empty text in: {in_path}; skipping write.")
            continue

        combined = pd.concat(series_list, ignore_index=True)
        #uniq = combined.drop_duplicates(keep="first")

        rel_path = os.path.relpath(in_path, input_root)  
        base_no_ext, _ = os.path.splitext(rel_path)
        out_path = os.path.join(output_root, base_no_ext + ".txt")

        out_dir = os.path.dirname(out_path)
        if out_dir and not os.path.exists(out_dir):
            os.makedirs(out_dir, exist_ok=True)

        with open(out_path, "w", encoding="utf-8", newline="\n") as f:
         for line in combined:
            f.write(line + "\n")

        written += 1
        print(f"Wrote {len(combined)} unique line(s) → {out_path}")

    print("Summary")
    print(f"Processed              : {processed}")
    print(f"Wrote TXT files        : {written}")
    print(f"Skipped (no 'text' col): {skipped_no_text_col}")
    print(f"Skipped (read errors)  : {skipped_read_error}")

# %%
# main
grand_csv = 0
grand_proc = 0
grand_written = 0
grand_skip_text = 0
grand_skip_read = 0

for lang_dir in LANG_DIRS:
    in_root  = derive_input_root_from_lang_dir(lang_dir) 
    out_root = lang_dir                                  

    if not os.path.isdir(in_root):
        print(f"\n[Skip] Input root not found: {os.path.abspath(in_root)}")
        continue

    os.makedirs(out_root, exist_ok=True)

   
    pattern = os.path.join(in_root, "**", "*.csv")
    found = len(glob.glob(pattern, recursive=True))
    grand_csv += found

  
    process_pair(in_root, out_root, exact_text_only=EXACT_TEXT_COL_NAME_ONLY)
# Out:
# Found 66 CSV file(s).
# Wrote 113 unique line(s) → yna/sentence/Cebuano/ABCEB_1TI_raw.txt
# Wrote 1068 unique line(s) → yna/sentence/Cebuano/ABCEB_MAT_raw.txt
# Wrote 406 unique line(s) → yna/sentence/Cebuano/ABCEB_NEH_raw.txt
# Wrote 357 unique line(s) → yna/sentence/Cebuano/ABCEB_DAN_raw.txt
# Wrote 1288 unique line(s) → yna/sentence/Cebuano/ABCEB_NUM_raw.txt
# Wrote 673 unique line(s) → yna/sentence/Cebuano/ABCEB_MRK_raw.txt
# Wrote 618 unique line(s) → yna/sentence/Cebuano/ABCEB_JDG_raw.txt
# Wrote 48 unique line(s) → yna/sentence/Cebuano/ABCEB_JON_raw.txt
# Wrote 1364 unique line(s) → yna/sentence/Cebuano/ABCEB_JER_raw.txt
# Wrote 1533 unique line(s) → yna/sentence/Cebuano/ABCEB_GEN_raw.txt
# Wrote 155 unique line(s) → yna/sentence/Cebuano/ABCEB_EPH_raw.txt
# Wrote 222 unique line(s) → yna/sentence/Cebuano/ABCEB_ECC_raw.txt
# Wrote 47 unique line(s) → yna/sentence/Cebuano/ABCEB_NAM_raw.txt
# Wrote 1213 unique line(s) → yna/sentence/Cebuano/ABCEB_EXO_raw.txt
# Wrote 15 unique line(s) → yna/sentence/Cebuano/ABCEB_3JN_raw.txt
# Wrote 1149 unique line(s) → yna/sentence/Cebuano/ABCEB_LUK_raw.txt
# Wrote 658 unique line(s) → yna/sentence/Cebuano/ABCEB_JOS_raw.txt
# Wrote 437 unique line(s) → yna/sentence/Cebuano/ABCEB_1CO_raw.txt
# Wrote 89 unique line(s) → yna/sentence/Cebuano/ABCEB_1TH_raw.txt
# Wrote 211 unique line(s) → yna/sentence/Cebuano/ABCEB_ZEC_raw.txt
# Wrote 915 unique line(s) → yna/sentence/Cebuano/ABCEB_PRO_raw.txt
# Wrote 21 unique line(s) → yna/sentence/Cebuano/ABCEB_OBA_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Cebuano/ABCEB_1PE_raw.txt
# Wrote 816 unique line(s) → yna/sentence/Cebuano/ABCEB_1KI_raw.txt
# Wrote 810 unique line(s) → yna/sentence/Cebuano/ABCEB_1SA_raw.txt
# Wrote 38 unique line(s) → yna/sentence/Cebuano/ABCEB_HAG_raw.txt
# Wrote 959 unique line(s) → yna/sentence/Cebuano/ABCEB_DEU_raw.txt
# Wrote 117 unique line(s) → yna/sentence/Cebuano/ABCEB_SNG_raw.txt
# Wrote 85 unique line(s) → yna/sentence/Cebuano/ABCEB_RUT_raw.txt
# Wrote 1273 unique line(s) → yna/sentence/Cebuano/ABCEB_EZK_raw.txt
# Wrote 432 unique line(s) → yna/sentence/Cebuano/ABCEB_ROM_raw.txt
# Wrote 303 unique line(s) → yna/sentence/Cebuano/ABCEB_HEB_raw.txt
# Wrote 822 unique line(s) → yna/sentence/Cebuano/ABCEB_2CH_raw.txt
# Wrote 13 unique line(s) → yna/sentence/Cebuano/ABCEB_2JN_raw.txt
# Wrote 878 unique line(s) → yna/sentence/Cebuano/ABCEB_JHN_raw.txt
# Wrote 73 unique line(s) → yna/sentence/Cebuano/ABCEB_JOL_raw.txt
# Wrote 695 unique line(s) → yna/sentence/Cebuano/ABCEB_2SA_raw.txt
# Wrote 104 unique line(s) → yna/sentence/Cebuano/ABCEB_PHP_raw.txt
# Wrote 53 unique line(s) → yna/sentence/Cebuano/ABCEB_ZEP_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Cebuano/ABCEB_1JN_raw.txt
# Wrote 149 unique line(s) → yna/sentence/Cebuano/ABCEB_GAL_raw.txt
# Wrote 942 unique line(s) → yna/sentence/Cebuano/ABCEB_1CH_raw.txt
# Wrote 146 unique line(s) → yna/sentence/Cebuano/ABCEB_AMO_raw.txt
# Wrote 154 unique line(s) → yna/sentence/Cebuano/ABCEB_LAM_raw.txt
# Wrote 56 unique line(s) → yna/sentence/Cebuano/ABCEB_HAB_raw.txt
# Wrote 2461 unique line(s) → yna/sentence/Cebuano/ABCEB_PSA_raw.txt
# Wrote 280 unique line(s) → yna/sentence/Cebuano/ABCEB_EZR_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Cebuano/ABCEB_PHM_raw.txt
# Wrote 197 unique line(s) → yna/sentence/Cebuano/ABCEB_HOS_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Cebuano/ABCEB_JUD_raw.txt
# Wrote 167 unique line(s) → yna/sentence/Cebuano/ABCEB_EST_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Cebuano/ABCEB_MIC_raw.txt
# Wrote 405 unique line(s) → yna/sentence/Cebuano/ABCEB_REV_raw.txt
# Wrote 95 unique line(s) → yna/sentence/Cebuano/ABCEB_COL_raw.txt
# Wrote 83 unique line(s) → yna/sentence/Cebuano/ABCEB_2TI_raw.txt
# Wrote 55 unique line(s) → yna/sentence/Cebuano/ABCEB_MAL_raw.txt
# Wrote 1003 unique line(s) → yna/sentence/Cebuano/ABCEB_ACT_raw.txt
# Wrote 1292 unique line(s) → yna/sentence/Cebuano/ABCEB_ISA_raw.txt
# Wrote 719 unique line(s) → yna/sentence/Cebuano/ABCEB_2KI_raw.txt
# Wrote 859 unique line(s) → yna/sentence/Cebuano/ABCEB_LEV_raw.txt
# Wrote 108 unique line(s) → yna/sentence/Cebuano/ABCEB_JAS_raw.txt
# Wrote 61 unique line(s) → yna/sentence/Cebuano/ABCEB_2PE_raw.txt
# Wrote 257 unique line(s) → yna/sentence/Cebuano/ABCEB_2CO_raw.txt
# Wrote 47 unique line(s) → yna/sentence/Cebuano/ABCEB_2TH_raw.txt
# Wrote 46 unique line(s) → yna/sentence/Cebuano/ABCEB_TIT_raw.txt
# Wrote 1070 unique line(s) → yna/sentence/Cebuano/ABCEB_JOB_raw.txt
# Summary
# Processed              : 66
# Wrote TXT files        : 66
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 66 CSV file(s).
# Wrote 83 unique line(s) → yna/sentence/Spanish/RVR95_2TI_raw.txt
# Wrote 404 unique line(s) → yna/sentence/Spanish/RVR95_REV_raw.txt
# Wrote 95 unique line(s) → yna/sentence/Spanish/RVR95_COL_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Spanish/RVR95_MIC_raw.txt
# Wrote 55 unique line(s) → yna/sentence/Spanish/RVR95_MAL_raw.txt
# Wrote 1292 unique line(s) → yna/sentence/Spanish/RVR95_ISA_raw.txt
# Wrote 1007 unique line(s) → yna/sentence/Spanish/RVR95_ACT_raw.txt
# Wrote 46 unique line(s) → yna/sentence/Spanish/RVR95_TIT_raw.txt
# Wrote 1070 unique line(s) → yna/sentence/Spanish/RVR95_JOB_raw.txt
# Wrote 47 unique line(s) → yna/sentence/Spanish/RVR95_2TH_raw.txt
# Wrote 257 unique line(s) → yna/sentence/Spanish/RVR95_2CO_raw.txt
# Wrote 61 unique line(s) → yna/sentence/Spanish/RVR95_2PE_raw.txt
# Wrote 108 unique line(s) → yna/sentence/Spanish/RVR95_JAS_raw.txt
# Wrote 859 unique line(s) → yna/sentence/Spanish/RVR95_LEV_raw.txt
# Wrote 719 unique line(s) → yna/sentence/Spanish/RVR95_2KI_raw.txt
# Wrote 695 unique line(s) → yna/sentence/Spanish/RVR95_2SA_raw.txt
# Wrote 53 unique line(s) → yna/sentence/Spanish/RVR95_ZEP_raw.txt
# Wrote 104 unique line(s) → yna/sentence/Spanish/RVR95_PHP_raw.txt
# Wrote 146 unique line(s) → yna/sentence/Spanish/RVR95_AMO_raw.txt
# Wrote 154 unique line(s) → yna/sentence/Spanish/RVR95_LAM_raw.txt
# Wrote 942 unique line(s) → yna/sentence/Spanish/RVR95_1CH_raw.txt
# Wrote 149 unique line(s) → yna/sentence/Spanish/RVR95_GAL_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Spanish/RVR95_1JN_raw.txt
# Wrote 167 unique line(s) → yna/sentence/Spanish/RVR95_EST_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Spanish/RVR95_JUD_raw.txt
# Wrote 197 unique line(s) → yna/sentence/Spanish/RVR95_HOS_raw.txt
# Wrote 280 unique line(s) → yna/sentence/Spanish/RVR95_EZR_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Spanish/RVR95_PHM_raw.txt
# Wrote 56 unique line(s) → yna/sentence/Spanish/RVR95_HAB_raw.txt
# Wrote 2462 unique line(s) → yna/sentence/Spanish/RVR95_PSA_raw.txt
# Wrote 38 unique line(s) → yna/sentence/Spanish/RVR95_HAG_raw.txt
# Wrote 810 unique line(s) → yna/sentence/Spanish/RVR95_1SA_raw.txt
# Wrote 433 unique line(s) → yna/sentence/Spanish/RVR95_ROM_raw.txt
# Wrote 85 unique line(s) → yna/sentence/Spanish/RVR95_RUT_raw.txt
# Wrote 1273 unique line(s) → yna/sentence/Spanish/RVR95_EZK_raw.txt
# Wrote 117 unique line(s) → yna/sentence/Spanish/RVR95_SNG_raw.txt
# Wrote 959 unique line(s) → yna/sentence/Spanish/RVR95_DEU_raw.txt
# Wrote 13 unique line(s) → yna/sentence/Spanish/RVR95_2JN_raw.txt
# Wrote 822 unique line(s) → yna/sentence/Spanish/RVR95_2CH_raw.txt
# Wrote 303 unique line(s) → yna/sentence/Spanish/RVR95_HEB_raw.txt
# Wrote 73 unique line(s) → yna/sentence/Spanish/RVR95_JOL_raw.txt
# Wrote 879 unique line(s) → yna/sentence/Spanish/RVR95_JHN_raw.txt
# Wrote 1288 unique line(s) → yna/sentence/Spanish/RVR95_NUM_raw.txt
# Wrote 678 unique line(s) → yna/sentence/Spanish/RVR95_MRK_raw.txt
# Wrote 357 unique line(s) → yna/sentence/Spanish/RVR95_DAN_raw.txt
# Wrote 406 unique line(s) → yna/sentence/Spanish/RVR95_NEH_raw.txt
# Wrote 1071 unique line(s) → yna/sentence/Spanish/RVR95_MAT_raw.txt
# Wrote 113 unique line(s) → yna/sentence/Spanish/RVR95_1TI_raw.txt
# Wrote 155 unique line(s) → yna/sentence/Spanish/RVR95_EPH_raw.txt
# Wrote 1364 unique line(s) → yna/sentence/Spanish/RVR95_JER_raw.txt
# Wrote 1533 unique line(s) → yna/sentence/Spanish/RVR95_GEN_raw.txt
# Wrote 48 unique line(s) → yna/sentence/Spanish/RVR95_JON_raw.txt
# Wrote 618 unique line(s) → yna/sentence/Spanish/RVR95_JDG_raw.txt
# Wrote 1151 unique line(s) → yna/sentence/Spanish/RVR95_LUK_raw.txt
# Wrote 15 unique line(s) → yna/sentence/Spanish/RVR95_3JN_raw.txt
# Wrote 1213 unique line(s) → yna/sentence/Spanish/RVR95_EXO_raw.txt
# Wrote 47 unique line(s) → yna/sentence/Spanish/RVR95_NAM_raw.txt
# Wrote 222 unique line(s) → yna/sentence/Spanish/RVR95_ECC_raw.txt
# Wrote 816 unique line(s) → yna/sentence/Spanish/RVR95_1KI_raw.txt
# Wrote 21 unique line(s) → yna/sentence/Spanish/RVR95_OBA_raw.txt
# Wrote 915 unique line(s) → yna/sentence/Spanish/RVR95_PRO_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Spanish/RVR95_1PE_raw.txt
# Wrote 211 unique line(s) → yna/sentence/Spanish/RVR95_ZEC_raw.txt
# Wrote 89 unique line(s) → yna/sentence/Spanish/RVR95_1TH_raw.txt
# Wrote 437 unique line(s) → yna/sentence/Spanish/RVR95_1CO_raw.txt
# Wrote 658 unique line(s) → yna/sentence/Spanish/RVR95_JOS_raw.txt
# Summary
# Processed              : 66
# Wrote TXT files        : 66
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 27 CSV file(s).
# Wrote 15 unique line(s) → yna/sentence/Chavacano/CBKNT_3JN_raw.txt
# Wrote 1149 unique line(s) → yna/sentence/Chavacano/CBKNT_LUK_raw.txt
# Wrote 435 unique line(s) → yna/sentence/Chavacano/CBKNT_1CO_raw.txt
# Wrote 89 unique line(s) → yna/sentence/Chavacano/CBKNT_1TH_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Chavacano/CBKNT_1PE_raw.txt
# Wrote 113 unique line(s) → yna/sentence/Chavacano/CBKNT_1TI_raw.txt
# Wrote 1071 unique line(s) → yna/sentence/Chavacano/CBKNT_MAT_raw.txt
# Wrote 676 unique line(s) → yna/sentence/Chavacano/CBKNT_MRK_raw.txt
# Wrote 155 unique line(s) → yna/sentence/Chavacano/CBKNT_EPH_raw.txt
# Wrote 303 unique line(s) → yna/sentence/Chavacano/CBKNT_HEB_raw.txt
# Wrote 13 unique line(s) → yna/sentence/Chavacano/CBKNT_2JN_raw.txt
# Wrote 877 unique line(s) → yna/sentence/Chavacano/CBKNT_JHN_raw.txt
# Wrote 431 unique line(s) → yna/sentence/Chavacano/CBKNT_ROM_raw.txt
# Wrote 104 unique line(s) → yna/sentence/Chavacano/CBKNT_1JN_raw.txt
# Wrote 149 unique line(s) → yna/sentence/Chavacano/CBKNT_GAL_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Chavacano/CBKNT_PHM_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Chavacano/CBKNT_JUD_raw.txt
# Wrote 104 unique line(s) → yna/sentence/Chavacano/CBKNT_PHP_raw.txt
# Wrote 1005 unique line(s) → yna/sentence/Chavacano/CBKNT_ACT_raw.txt
# Wrote 106 unique line(s) → yna/sentence/Chavacano/CBKNT_JAS_raw.txt
# Wrote 61 unique line(s) → yna/sentence/Chavacano/CBKNT_2PE_raw.txt
# Wrote 46 unique line(s) → yna/sentence/Chavacano/CBKNT_TIT_raw.txt
# Wrote 257 unique line(s) → yna/sentence/Chavacano/CBKNT_2CO_raw.txt
# Wrote 47 unique line(s) → yna/sentence/Chavacano/CBKNT_2TH_raw.txt
# Wrote 95 unique line(s) → yna/sentence/Chavacano/CBKNT_COL_raw.txt
# Wrote 405 unique line(s) → yna/sentence/Chavacano/CBKNT_REV_raw.txt
# Wrote 83 unique line(s) → yna/sentence/Chavacano/CBKNT_2TI_raw.txt
# Summary
# Processed              : 27
# Wrote TXT files        : 27
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 27 CSV file(s).
# Wrote 870 unique line(s) → yna/sentence/Tausug/TSG_JHN_raw.txt
# Wrote 13 unique line(s) → yna/sentence/Tausug/TSG_2JN_raw.txt
# Wrote 301 unique line(s) → yna/sentence/Tausug/TSG_HEB_raw.txt
# Wrote 432 unique line(s) → yna/sentence/Tausug/TSG_ROM_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Tausug/TSG_1PE_raw.txt
# Wrote 88 unique line(s) → yna/sentence/Tausug/TSG_1TH_raw.txt
# Wrote 434 unique line(s) → yna/sentence/Tausug/TSG_1CO_raw.txt
# Wrote 1146 unique line(s) → yna/sentence/Tausug/TSG_LUK_raw.txt
# Wrote 15 unique line(s) → yna/sentence/Tausug/TSG_3JN_raw.txt
# Wrote 155 unique line(s) → yna/sentence/Tausug/TSG_EPH_raw.txt
# Wrote 673 unique line(s) → yna/sentence/Tausug/TSG_MRK_raw.txt
# Wrote 1057 unique line(s) → yna/sentence/Tausug/TSG_MAT_raw.txt
# Wrote 113 unique line(s) → yna/sentence/Tausug/TSG_1TI_raw.txt
# Wrote 46 unique line(s) → yna/sentence/Tausug/TSG_TIT_raw.txt
# Wrote 46 unique line(s) → yna/sentence/Tausug/TSG_2TH_raw.txt
# Wrote 256 unique line(s) → yna/sentence/Tausug/TSG_2CO_raw.txt
# Wrote 59 unique line(s) → yna/sentence/Tausug/TSG_2PE_raw.txt
# Wrote 108 unique line(s) → yna/sentence/Tausug/TSG_JAS_raw.txt
# Wrote 1001 unique line(s) → yna/sentence/Tausug/TSG_ACT_raw.txt
# Wrote 83 unique line(s) → yna/sentence/Tausug/TSG_2TI_raw.txt
# Wrote 402 unique line(s) → yna/sentence/Tausug/TSG_REV_raw.txt
# Wrote 95 unique line(s) → yna/sentence/Tausug/TSG_COL_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Tausug/TSG_JUD_raw.txt
# Wrote 25 unique line(s) → yna/sentence/Tausug/TSG_PHM_raw.txt
# Wrote 148 unique line(s) → yna/sentence/Tausug/TSG_GAL_raw.txt
# Wrote 105 unique line(s) → yna/sentence/Tausug/TSG_1JN_raw.txt
# Wrote 104 unique line(s) → yna/sentence/Tausug/TSG_PHP_raw.txt
# Summary
# Processed              : 27
# Wrote TXT files        : 27
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 29 CSV file(s).
# Wrote 113 unique line(s) → cj/sentence/Ivatan/VTSP_1TI_raw.txt
# Wrote 1071 unique line(s) → cj/sentence/Ivatan/VTSP_MAT_raw.txt
# Wrote 678 unique line(s) → cj/sentence/Ivatan/VTSP_MRK_raw.txt
# Wrote 151 unique line(s) → cj/sentence/Ivatan/VTSP_EPH_raw.txt
# Wrote 15 unique line(s) → cj/sentence/Ivatan/VTSP_3JN_raw.txt
# Wrote 1150 unique line(s) → cj/sentence/Ivatan/VTSP_LUK_raw.txt
# Wrote 436 unique line(s) → cj/sentence/Ivatan/VTSP_1CO_raw.txt
# Wrote 89 unique line(s) → cj/sentence/Ivatan/VTSP_1TH_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Ivatan/VTSP_1PE_raw.txt
# Wrote 908 unique line(s) → cj/sentence/Ivatan/VTSP_PRO_raw.txt
# Wrote 431 unique line(s) → cj/sentence/Ivatan/VTSP_ROM_raw.txt
# Wrote 303 unique line(s) → cj/sentence/Ivatan/VTSP_HEB_raw.txt
# Wrote 13 unique line(s) → cj/sentence/Ivatan/VTSP_2JN_raw.txt
# Wrote 879 unique line(s) → cj/sentence/Ivatan/VTSP_JHN_raw.txt
# Wrote 104 unique line(s) → cj/sentence/Ivatan/VTSP_PHP_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Ivatan/VTSP_1JN_raw.txt
# Wrote 149 unique line(s) → cj/sentence/Ivatan/VTSP_GAL_raw.txt
# Wrote 691 unique line(s) → cj/sentence/Ivatan/VTSP_PSA_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Ivatan/VTSP_PHM_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Ivatan/VTSP_JUD_raw.txt
# Wrote 91 unique line(s) → cj/sentence/Ivatan/VTSP_COL_raw.txt
# Wrote 405 unique line(s) → cj/sentence/Ivatan/VTSP_REV_raw.txt
# Wrote 83 unique line(s) → cj/sentence/Ivatan/VTSP_2TI_raw.txt
# Wrote 999 unique line(s) → cj/sentence/Ivatan/VTSP_ACT_raw.txt
# Wrote 108 unique line(s) → cj/sentence/Ivatan/VTSP_JAS_raw.txt
# Wrote 61 unique line(s) → cj/sentence/Ivatan/VTSP_2PE_raw.txt
# Wrote 257 unique line(s) → cj/sentence/Ivatan/VTSP_2CO_raw.txt
# Wrote 47 unique line(s) → cj/sentence/Ivatan/VTSP_2TH_raw.txt
# Wrote 46 unique line(s) → cj/sentence/Ivatan/VTSP_TIT_raw.txt
# Summary
# Processed              : 29
# Wrote TXT files        : 29
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 77 CSV file(s).
# Wrote 15 unique line(s) → cj/sentence/Pangasinense/PNPV_3JN_raw.txt
# Wrote 1147 unique line(s) → cj/sentence/Pangasinense/PNPV_LUK_raw.txt
# Wrote 221 unique line(s) → cj/sentence/Pangasinense/PNPV_ECC_raw.txt
# Wrote 47 unique line(s) → cj/sentence/Pangasinense/PNPV_NAM_raw.txt
# Wrote 1200 unique line(s) → cj/sentence/Pangasinense/PNPV_EXO_raw.txt
# Wrote 21 unique line(s) → cj/sentence/Pangasinense/PNPV_OBA_raw.txt
# Wrote 911 unique line(s) → cj/sentence/Pangasinense/PNPV_PRO_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Pangasinense/PNPV_1PE_raw.txt
# Wrote 801 unique line(s) → cj/sentence/Pangasinense/PNPV_1KI_raw.txt
# Wrote 1337 unique line(s) → cj/sentence/Pangasinense/PNPV_SIR_raw.txt
# Wrote 644 unique line(s) → cj/sentence/Pangasinense/PNPV_JOS_raw.txt
# Wrote 136 unique line(s) → cj/sentence/Pangasinense/PNPV_BAR_raw.txt
# Wrote 436 unique line(s) → cj/sentence/Pangasinense/PNPV_1CO_raw.txt
# Wrote 208 unique line(s) → cj/sentence/Pangasinense/PNPV_ZEC_raw.txt
# Wrote 89 unique line(s) → cj/sentence/Pangasinense/PNPV_1TH_raw.txt
# Wrote 312 unique line(s) → cj/sentence/Pangasinense/PNPV_NEH_raw.txt
# Wrote 356 unique line(s) → cj/sentence/Pangasinense/PNPV_DAN_raw.txt
# Wrote 1039 unique line(s) → cj/sentence/Pangasinense/PNPV_NUM_raw.txt
# Wrote 671 unique line(s) → cj/sentence/Pangasinense/PNPV_MRK_raw.txt
# Wrote 113 unique line(s) → cj/sentence/Pangasinense/PNPV_1TI_raw.txt
# Wrote 1066 unique line(s) → cj/sentence/Pangasinense/PNPV_MAT_raw.txt
# Wrote 155 unique line(s) → cj/sentence/Pangasinense/PNPV_EPH_raw.txt
# Wrote 606 unique line(s) → cj/sentence/Pangasinense/PNPV_JDG_raw.txt
# Wrote 48 unique line(s) → cj/sentence/Pangasinense/PNPV_JON_raw.txt
# Wrote 1503 unique line(s) → cj/sentence/Pangasinense/PNPV_GEN_raw.txt
# Wrote 1336 unique line(s) → cj/sentence/Pangasinense/PNPV_JER_raw.txt
# Wrote 13 unique line(s) → cj/sentence/Pangasinense/PNPV_2JN_raw.txt
# Wrote 303 unique line(s) → cj/sentence/Pangasinense/PNPV_HEB_raw.txt
# Wrote 802 unique line(s) → cj/sentence/Pangasinense/PNPV_2CH_raw.txt
# Wrote 914 unique line(s) → cj/sentence/Pangasinense/PNPV_1MA_raw.txt
# Wrote 877 unique line(s) → cj/sentence/Pangasinense/PNPV_JHN_raw.txt
# Wrote 72 unique line(s) → cj/sentence/Pangasinense/PNPV_JOL_raw.txt
# Wrote 38 unique line(s) → cj/sentence/Pangasinense/PNPV_HAG_raw.txt
# Wrote 803 unique line(s) → cj/sentence/Pangasinense/PNPV_1SA_raw.txt
# Wrote 117 unique line(s) → cj/sentence/Pangasinense/PNPV_SNG_raw.txt
# Wrote 81 unique line(s) → cj/sentence/Pangasinense/PNPV_RUT_raw.txt
# Wrote 1242 unique line(s) → cj/sentence/Pangasinense/PNPV_EZK_raw.txt
# Wrote 432 unique line(s) → cj/sentence/Pangasinense/PNPV_ROM_raw.txt
# Wrote 946 unique line(s) → cj/sentence/Pangasinense/PNPV_DEU_raw.txt
# Wrote 818 unique line(s) → cj/sentence/Pangasinense/PNPV_1CH_raw.txt
# Wrote 146 unique line(s) → cj/sentence/Pangasinense/PNPV_AMO_raw.txt
# Wrote 154 unique line(s) → cj/sentence/Pangasinense/PNPV_LAM_raw.txt
# Wrote 426 unique line(s) → cj/sentence/Pangasinense/PNPV_WIS_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Pangasinense/PNPV_1JN_raw.txt
# Wrote 149 unique line(s) → cj/sentence/Pangasinense/PNPV_GAL_raw.txt
# Wrote 195 unique line(s) → cj/sentence/Pangasinense/PNPV_HOS_raw.txt
# Wrote 332 unique line(s) → cj/sentence/Pangasinense/PNPV_JDT_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Pangasinense/PNPV_JUD_raw.txt
# Wrote 163 unique line(s) → cj/sentence/Pangasinense/PNPV_EST_raw.txt
# Wrote 2456 unique line(s) → cj/sentence/Pangasinense/PNPV_PSA_raw.txt
# Wrote 56 unique line(s) → cj/sentence/Pangasinense/PNPV_HAB_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Pangasinense/PNPV_PHM_raw.txt
# Wrote 549 unique line(s) → cj/sentence/Pangasinense/PNPV_2MA_raw.txt
# Wrote 203 unique line(s) → cj/sentence/Pangasinense/PNPV_EZR_raw.txt
# Wrote 674 unique line(s) → cj/sentence/Pangasinense/PNPV_2SA_raw.txt
# Wrote 67 unique line(s) → cj/sentence/Pangasinense/PNPV_S3Y_raw.txt
# Wrote 61 unique line(s) → cj/sentence/Pangasinense/PNPV_SUS_raw.txt
# Wrote 73 unique line(s) → cj/sentence/Pangasinense/PNPV_LJE_raw.txt
# Wrote 53 unique line(s) → cj/sentence/Pangasinense/PNPV_ZEP_raw.txt
# Wrote 104 unique line(s) → cj/sentence/Pangasinense/PNPV_PHP_raw.txt
# Wrote 40 unique line(s) → cj/sentence/Pangasinense/PNPV_BEL_raw.txt
# Wrote 1286 unique line(s) → cj/sentence/Pangasinense/PNPV_ISA_raw.txt
# Wrote 1002 unique line(s) → cj/sentence/Pangasinense/PNPV_ACT_raw.txt
# Wrote 255 unique line(s) → cj/sentence/Pangasinense/PNPV_2CO_raw.txt
# Wrote 47 unique line(s) → cj/sentence/Pangasinense/PNPV_2TH_raw.txt
# Wrote 46 unique line(s) → cj/sentence/Pangasinense/PNPV_TIT_raw.txt
# Wrote 1058 unique line(s) → cj/sentence/Pangasinense/PNPV_JOB_raw.txt
# Wrote 717 unique line(s) → cj/sentence/Pangasinense/PNPV_2KI_raw.txt
# Wrote 108 unique line(s) → cj/sentence/Pangasinense/PNPV_JAS_raw.txt
# Wrote 820 unique line(s) → cj/sentence/Pangasinense/PNPV_LEV_raw.txt
# Wrote 61 unique line(s) → cj/sentence/Pangasinense/PNPV_2PE_raw.txt
# Wrote 83 unique line(s) → cj/sentence/Pangasinense/PNPV_2TI_raw.txt
# Wrote 236 unique line(s) → cj/sentence/Pangasinense/PNPV_TOB_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Pangasinense/PNPV_MIC_raw.txt
# Wrote 404 unique line(s) → cj/sentence/Pangasinense/PNPV_REV_raw.txt
# Wrote 95 unique line(s) → cj/sentence/Pangasinense/PNPV_COL_raw.txt
# Wrote 55 unique line(s) → cj/sentence/Pangasinense/PNPV_MAL_raw.txt
# Summary
# Processed              : 77
# Wrote TXT files        : 77
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 77 CSV file(s).
# Wrote 104 unique line(s) → cj/sentence/Tagalog/MBB05_PHP_raw.txt
# Wrote 41 unique line(s) → cj/sentence/Tagalog/MBB05_BEL_raw.txt
# Wrote 53 unique line(s) → cj/sentence/Tagalog/MBB05_ZEP_raw.txt
# Wrote 73 unique line(s) → cj/sentence/Tagalog/MBB05_LJE_raw.txt
# Wrote 62 unique line(s) → cj/sentence/Tagalog/MBB05_SUS_raw.txt
# Wrote 68 unique line(s) → cj/sentence/Tagalog/MBB05_S3Y_raw.txt
# Wrote 695 unique line(s) → cj/sentence/Tagalog/MBB05_2SA_raw.txt
# Wrote 555 unique line(s) → cj/sentence/Tagalog/MBB05_2MA_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Tagalog/MBB05_PHM_raw.txt
# Wrote 210 unique line(s) → cj/sentence/Tagalog/MBB05_EZR_raw.txt
# Wrote 2458 unique line(s) → cj/sentence/Tagalog/MBB05_PSA_raw.txt
# Wrote 56 unique line(s) → cj/sentence/Tagalog/MBB05_HAB_raw.txt
# Wrote 167 unique line(s) → cj/sentence/Tagalog/MBB05_EST_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Tagalog/MBB05_JUD_raw.txt
# Wrote 338 unique line(s) → cj/sentence/Tagalog/MBB05_JDT_raw.txt
# Wrote 197 unique line(s) → cj/sentence/Tagalog/MBB05_HOS_raw.txt
# Wrote 149 unique line(s) → cj/sentence/Tagalog/MBB05_GAL_raw.txt
# Wrote 104 unique line(s) → cj/sentence/Tagalog/MBB05_1JN_raw.txt
# Wrote 435 unique line(s) → cj/sentence/Tagalog/MBB05_WIS_raw.txt
# Wrote 153 unique line(s) → cj/sentence/Tagalog/MBB05_LAM_raw.txt
# Wrote 146 unique line(s) → cj/sentence/Tagalog/MBB05_AMO_raw.txt
# Wrote 867 unique line(s) → cj/sentence/Tagalog/MBB05_1CH_raw.txt
# Wrote 55 unique line(s) → cj/sentence/Tagalog/MBB05_MAL_raw.txt
# Wrote 95 unique line(s) → cj/sentence/Tagalog/MBB05_COL_raw.txt
# Wrote 402 unique line(s) → cj/sentence/Tagalog/MBB05_REV_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Tagalog/MBB05_MIC_raw.txt
# Wrote 241 unique line(s) → cj/sentence/Tagalog/MBB05_TOB_raw.txt
# Wrote 83 unique line(s) → cj/sentence/Tagalog/MBB05_2TI_raw.txt
# Wrote 61 unique line(s) → cj/sentence/Tagalog/MBB05_2PE_raw.txt
# Wrote 857 unique line(s) → cj/sentence/Tagalog/MBB05_LEV_raw.txt
# Wrote 108 unique line(s) → cj/sentence/Tagalog/MBB05_JAS_raw.txt
# Wrote 719 unique line(s) → cj/sentence/Tagalog/MBB05_2KI_raw.txt
# Wrote 1063 unique line(s) → cj/sentence/Tagalog/MBB05_JOB_raw.txt
# Wrote 46 unique line(s) → cj/sentence/Tagalog/MBB05_TIT_raw.txt
# Wrote 47 unique line(s) → cj/sentence/Tagalog/MBB05_2TH_raw.txt
# Wrote 256 unique line(s) → cj/sentence/Tagalog/MBB05_2CO_raw.txt
# Wrote 998 unique line(s) → cj/sentence/Tagalog/MBB05_ACT_raw.txt
# Wrote 1292 unique line(s) → cj/sentence/Tagalog/MBB05_ISA_raw.txt
# Wrote 1527 unique line(s) → cj/sentence/Tagalog/MBB05_GEN_raw.txt
# Wrote 1359 unique line(s) → cj/sentence/Tagalog/MBB05_JER_raw.txt
# Wrote 48 unique line(s) → cj/sentence/Tagalog/MBB05_JON_raw.txt
# Wrote 611 unique line(s) → cj/sentence/Tagalog/MBB05_JDG_raw.txt
# Wrote 155 unique line(s) → cj/sentence/Tagalog/MBB05_EPH_raw.txt
# Wrote 1052 unique line(s) → cj/sentence/Tagalog/MBB05_MAT_raw.txt
# Wrote 113 unique line(s) → cj/sentence/Tagalog/MBB05_1TI_raw.txt
# Wrote 671 unique line(s) → cj/sentence/Tagalog/MBB05_MRK_raw.txt
# Wrote 1087 unique line(s) → cj/sentence/Tagalog/MBB05_NUM_raw.txt
# Wrote 357 unique line(s) → cj/sentence/Tagalog/MBB05_DAN_raw.txt
# Wrote 318 unique line(s) → cj/sentence/Tagalog/MBB05_NEH_raw.txt
# Wrote 89 unique line(s) → cj/sentence/Tagalog/MBB05_1TH_raw.txt
# Wrote 210 unique line(s) → cj/sentence/Tagalog/MBB05_ZEC_raw.txt
# Wrote 436 unique line(s) → cj/sentence/Tagalog/MBB05_1CO_raw.txt
# Wrote 656 unique line(s) → cj/sentence/Tagalog/MBB05_JOS_raw.txt
# Wrote 138 unique line(s) → cj/sentence/Tagalog/MBB05_BAR_raw.txt
# Wrote 1360 unique line(s) → cj/sentence/Tagalog/MBB05_SIR_raw.txt
# Wrote 810 unique line(s) → cj/sentence/Tagalog/MBB05_1KI_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Tagalog/MBB05_1PE_raw.txt
# Wrote 914 unique line(s) → cj/sentence/Tagalog/MBB05_PRO_raw.txt
# Wrote 21 unique line(s) → cj/sentence/Tagalog/MBB05_OBA_raw.txt
# Wrote 1208 unique line(s) → cj/sentence/Tagalog/MBB05_EXO_raw.txt
# Wrote 47 unique line(s) → cj/sentence/Tagalog/MBB05_NAM_raw.txt
# Wrote 222 unique line(s) → cj/sentence/Tagalog/MBB05_ECC_raw.txt
# Wrote 1135 unique line(s) → cj/sentence/Tagalog/MBB05_LUK_raw.txt
# Wrote 15 unique line(s) → cj/sentence/Tagalog/MBB05_3JN_raw.txt
# Wrote 951 unique line(s) → cj/sentence/Tagalog/MBB05_DEU_raw.txt
# Wrote 430 unique line(s) → cj/sentence/Tagalog/MBB05_ROM_raw.txt
# Wrote 1264 unique line(s) → cj/sentence/Tagalog/MBB05_EZK_raw.txt
# Wrote 77 unique line(s) → cj/sentence/Tagalog/MBB05_RUT_raw.txt
# Wrote 117 unique line(s) → cj/sentence/Tagalog/MBB05_SNG_raw.txt
# Wrote 810 unique line(s) → cj/sentence/Tagalog/MBB05_1SA_raw.txt
# Wrote 38 unique line(s) → cj/sentence/Tagalog/MBB05_HAG_raw.txt
# Wrote 72 unique line(s) → cj/sentence/Tagalog/MBB05_JOL_raw.txt
# Wrote 876 unique line(s) → cj/sentence/Tagalog/MBB05_JHN_raw.txt
# Wrote 921 unique line(s) → cj/sentence/Tagalog/MBB05_1MA_raw.txt
# Wrote 817 unique line(s) → cj/sentence/Tagalog/MBB05_2CH_raw.txt
# Wrote 302 unique line(s) → cj/sentence/Tagalog/MBB05_HEB_raw.txt
# Wrote 13 unique line(s) → cj/sentence/Tagalog/MBB05_2JN_raw.txt
# Summary
# Processed              : 77
# Wrote TXT files        : 77
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 27 CSV file(s).
# Wrote 104 unique line(s) → cj/sentence/Yami/SNT_PHP_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Yami/SNT_JUD_raw.txt
# Wrote 25 unique line(s) → cj/sentence/Yami/SNT_PHM_raw.txt
# Wrote 148 unique line(s) → cj/sentence/Yami/SNT_GAL_raw.txt
# Wrote 105 unique line(s) → cj/sentence/Yami/SNT_1JN_raw.txt
# Wrote 83 unique line(s) → cj/sentence/Yami/SNT_2TI_raw.txt
# Wrote 404 unique line(s) → cj/sentence/Yami/SNT_REV_raw.txt
# Wrote 95 unique line(s) → cj/sentence/Yami/SNT_COL_raw.txt
# Wrote 46 unique line(s) → cj/sentence/Yami/SNT_2TH_raw.txt
# Wrote 256 unique line(s) → cj/sentence/Yami/SNT_2CO_raw.txt
# Wrote 46 unique line(s) → cj/sentence/Yami/SNT_TIT_raw.txt
# Wrote 61 unique line(s) → cj/sentence/Yami/SNT_2PE_raw.txt
# Wrote 107 unique line(s) → cj/sentence/Yami/SNT_JAS_raw.txt
# Wrote 997 unique line(s) → cj/sentence/Yami/SNT_ACT_raw.txt
# Wrote 152 unique line(s) → cj/sentence/Yami/SNT_EPH_raw.txt
# Wrote 676 unique line(s) → cj/sentence/Yami/SNT_MRK_raw.txt
# Wrote 1069 unique line(s) → cj/sentence/Yami/SNT_MAT_raw.txt
# Wrote 113 unique line(s) → cj/sentence/Yami/SNT_1TI_raw.txt
# Wrote 104 unique line(s) → cj/sentence/Yami/SNT_1PE_raw.txt
# Wrote 89 unique line(s) → cj/sentence/Yami/SNT_1TH_raw.txt
# Wrote 433 unique line(s) → cj/sentence/Yami/SNT_1CO_raw.txt
# Wrote 1147 unique line(s) → cj/sentence/Yami/SNT_LUK_raw.txt
# Wrote 15 unique line(s) → cj/sentence/Yami/SNT_3JN_raw.txt
# Wrote 425 unique line(s) → cj/sentence/Yami/SNT_ROM_raw.txt
# Wrote 878 unique line(s) → cj/sentence/Yami/SNT_JHN_raw.txt
# Wrote 13 unique line(s) → cj/sentence/Yami/SNT_2JN_raw.txt
# Wrote 301 unique line(s) → cj/sentence/Yami/SNT_HEB_raw.txt
# Summary
# Processed              : 27
# Wrote TXT files        : 27
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 77 CSV file(s).
# Wrote 334 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JDT_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JUD_raw.txt
# Wrote 195 unique line(s) → trish/sentence/Bikolano/MBBBIK92_HOS_raw.txt
# Wrote 163 unique line(s) → trish/sentence/Bikolano/MBBBIK92_EST_raw.txt
# Wrote 2459 unique line(s) → trish/sentence/Bikolano/MBBBIK92_PSA_raw.txt
# Wrote 56 unique line(s) → trish/sentence/Bikolano/MBBBIK92_HAB_raw.txt
# Wrote 214 unique line(s) → trish/sentence/Bikolano/MBBBIK92_EZR_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Bikolano/MBBBIK92_PHM_raw.txt
# Wrote 549 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2MA_raw.txt
# Wrote 146 unique line(s) → trish/sentence/Bikolano/MBBBIK92_AMO_raw.txt
# Wrote 154 unique line(s) → trish/sentence/Bikolano/MBBBIK92_LAM_raw.txt
# Wrote 816 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1CH_raw.txt
# Wrote 429 unique line(s) → trish/sentence/Bikolano/MBBBIK92_WIS_raw.txt
# Wrote 149 unique line(s) → trish/sentence/Bikolano/MBBBIK92_GAL_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1JN_raw.txt
# Wrote 73 unique line(s) → trish/sentence/Bikolano/MBBBIK92_LJE_raw.txt
# Wrote 53 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ZEP_raw.txt
# Wrote 104 unique line(s) → trish/sentence/Bikolano/MBBBIK92_PHP_raw.txt
# Wrote 40 unique line(s) → trish/sentence/Bikolano/MBBBIK92_BEL_raw.txt
# Wrote 672 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2SA_raw.txt
# Wrote 67 unique line(s) → trish/sentence/Bikolano/MBBBIK92_S3Y_raw.txt
# Wrote 61 unique line(s) → trish/sentence/Bikolano/MBBBIK92_SUS_raw.txt
# Wrote 46 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2TH_raw.txt
# Wrote 255 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2CO_raw.txt
# Wrote 46 unique line(s) → trish/sentence/Bikolano/MBBBIK92_TIT_raw.txt
# Wrote 1062 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JOB_raw.txt
# Wrote 718 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2KI_raw.txt
# Wrote 61 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2PE_raw.txt
# Wrote 108 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JAS_raw.txt
# Wrote 833 unique line(s) → trish/sentence/Bikolano/MBBBIK92_LEV_raw.txt
# Wrote 1288 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ISA_raw.txt
# Wrote 1004 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ACT_raw.txt
# Wrote 55 unique line(s) → trish/sentence/Bikolano/MBBBIK92_MAL_raw.txt
# Wrote 83 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2TI_raw.txt
# Wrote 240 unique line(s) → trish/sentence/Bikolano/MBBBIK92_TOB_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Bikolano/MBBBIK92_MIC_raw.txt
# Wrote 401 unique line(s) → trish/sentence/Bikolano/MBBBIK92_REV_raw.txt
# Wrote 94 unique line(s) → trish/sentence/Bikolano/MBBBIK92_COL_raw.txt
# Wrote 21 unique line(s) → trish/sentence/Bikolano/MBBBIK92_OBA_raw.txt
# Wrote 911 unique line(s) → trish/sentence/Bikolano/MBBBIK92_PRO_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1PE_raw.txt
# Wrote 1340 unique line(s) → trish/sentence/Bikolano/MBBBIK92_SIR_raw.txt
# Wrote 804 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1KI_raw.txt
# Wrote 137 unique line(s) → trish/sentence/Bikolano/MBBBIK92_BAR_raw.txt
# Wrote 645 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JOS_raw.txt
# Wrote 208 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ZEC_raw.txt
# Wrote 89 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1TH_raw.txt
# Wrote 436 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1CO_raw.txt
# Wrote 1149 unique line(s) → trish/sentence/Bikolano/MBBBIK92_LUK_raw.txt
# Wrote 15 unique line(s) → trish/sentence/Bikolano/MBBBIK92_3JN_raw.txt
# Wrote 47 unique line(s) → trish/sentence/Bikolano/MBBBIK92_NAM_raw.txt
# Wrote 222 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ECC_raw.txt
# Wrote 1200 unique line(s) → trish/sentence/Bikolano/MBBBIK92_EXO_raw.txt
# Wrote 155 unique line(s) → trish/sentence/Bikolano/MBBBIK92_EPH_raw.txt
# Wrote 48 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JON_raw.txt
# Wrote 607 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JDG_raw.txt
# Wrote 1509 unique line(s) → trish/sentence/Bikolano/MBBBIK92_GEN_raw.txt
# Wrote 1336 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JER_raw.txt
# Wrote 356 unique line(s) → trish/sentence/Bikolano/MBBBIK92_DAN_raw.txt
# Wrote 312 unique line(s) → trish/sentence/Bikolano/MBBBIK92_NEH_raw.txt
# Wrote 1044 unique line(s) → trish/sentence/Bikolano/MBBBIK92_NUM_raw.txt
# Wrote 677 unique line(s) → trish/sentence/Bikolano/MBBBIK92_MRK_raw.txt
# Wrote 1070 unique line(s) → trish/sentence/Bikolano/MBBBIK92_MAT_raw.txt
# Wrote 112 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1TI_raw.txt
# Wrote 914 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1MA_raw.txt
# Wrote 877 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JHN_raw.txt
# Wrote 72 unique line(s) → trish/sentence/Bikolano/MBBBIK92_JOL_raw.txt
# Wrote 13 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2JN_raw.txt
# Wrote 303 unique line(s) → trish/sentence/Bikolano/MBBBIK92_HEB_raw.txt
# Wrote 808 unique line(s) → trish/sentence/Bikolano/MBBBIK92_2CH_raw.txt
# Wrote 117 unique line(s) → trish/sentence/Bikolano/MBBBIK92_SNG_raw.txt
# Wrote 431 unique line(s) → trish/sentence/Bikolano/MBBBIK92_ROM_raw.txt
# Wrote 79 unique line(s) → trish/sentence/Bikolano/MBBBIK92_RUT_raw.txt
# Wrote 1254 unique line(s) → trish/sentence/Bikolano/MBBBIK92_EZK_raw.txt
# Wrote 958 unique line(s) → trish/sentence/Bikolano/MBBBIK92_DEU_raw.txt
# Wrote 38 unique line(s) → trish/sentence/Bikolano/MBBBIK92_HAG_raw.txt
# Wrote 805 unique line(s) → trish/sentence/Bikolano/MBBBIK92_1SA_raw.txt
# Summary
# Processed              : 77
# Wrote TXT files        : 77
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 66 CSV file(s).
# Wrote 801 unique line(s) → trish/sentence/Ilokano/RIPV_2CH_raw.txt
# Wrote 300 unique line(s) → trish/sentence/Ilokano/RIPV_HEB_raw.txt
# Wrote 13 unique line(s) → trish/sentence/Ilokano/RIPV_2JN_raw.txt
# Wrote 72 unique line(s) → trish/sentence/Ilokano/RIPV_JOL_raw.txt
# Wrote 876 unique line(s) → trish/sentence/Ilokano/RIPV_JHN_raw.txt
# Wrote 801 unique line(s) → trish/sentence/Ilokano/RIPV_1SA_raw.txt
# Wrote 38 unique line(s) → trish/sentence/Ilokano/RIPV_HAG_raw.txt
# Wrote 947 unique line(s) → trish/sentence/Ilokano/RIPV_DEU_raw.txt
# Wrote 431 unique line(s) → trish/sentence/Ilokano/RIPV_ROM_raw.txt
# Wrote 1241 unique line(s) → trish/sentence/Ilokano/RIPV_EZK_raw.txt
# Wrote 81 unique line(s) → trish/sentence/Ilokano/RIPV_RUT_raw.txt
# Wrote 117 unique line(s) → trish/sentence/Ilokano/RIPV_SNG_raw.txt
# Wrote 1197 unique line(s) → trish/sentence/Ilokano/RIPV_EXO_raw.txt
# Wrote 47 unique line(s) → trish/sentence/Ilokano/RIPV_NAM_raw.txt
# Wrote 221 unique line(s) → trish/sentence/Ilokano/RIPV_ECC_raw.txt
# Wrote 1141 unique line(s) → trish/sentence/Ilokano/RIPV_LUK_raw.txt
# Wrote 15 unique line(s) → trish/sentence/Ilokano/RIPV_3JN_raw.txt
# Wrote 208 unique line(s) → trish/sentence/Ilokano/RIPV_ZEC_raw.txt
# Wrote 89 unique line(s) → trish/sentence/Ilokano/RIPV_1TH_raw.txt
# Wrote 433 unique line(s) → trish/sentence/Ilokano/RIPV_1CO_raw.txt
# Wrote 644 unique line(s) → trish/sentence/Ilokano/RIPV_JOS_raw.txt
# Wrote 800 unique line(s) → trish/sentence/Ilokano/RIPV_1KI_raw.txt
# Wrote 103 unique line(s) → trish/sentence/Ilokano/RIPV_1PE_raw.txt
# Wrote 21 unique line(s) → trish/sentence/Ilokano/RIPV_OBA_raw.txt
# Wrote 910 unique line(s) → trish/sentence/Ilokano/RIPV_PRO_raw.txt
# Wrote 1052 unique line(s) → trish/sentence/Ilokano/RIPV_MAT_raw.txt
# Wrote 110 unique line(s) → trish/sentence/Ilokano/RIPV_1TI_raw.txt
# Wrote 671 unique line(s) → trish/sentence/Ilokano/RIPV_MRK_raw.txt
# Wrote 1051 unique line(s) → trish/sentence/Ilokano/RIPV_NUM_raw.txt
# Wrote 356 unique line(s) → trish/sentence/Ilokano/RIPV_DAN_raw.txt
# Wrote 314 unique line(s) → trish/sentence/Ilokano/RIPV_NEH_raw.txt
# Wrote 1333 unique line(s) → trish/sentence/Ilokano/RIPV_JER_raw.txt
# Wrote 1502 unique line(s) → trish/sentence/Ilokano/RIPV_GEN_raw.txt
# Wrote 48 unique line(s) → trish/sentence/Ilokano/RIPV_JON_raw.txt
# Wrote 606 unique line(s) → trish/sentence/Ilokano/RIPV_JDG_raw.txt
# Wrote 152 unique line(s) → trish/sentence/Ilokano/RIPV_EPH_raw.txt
# Wrote 1000 unique line(s) → trish/sentence/Ilokano/RIPV_ACT_raw.txt
# Wrote 1285 unique line(s) → trish/sentence/Ilokano/RIPV_ISA_raw.txt
# Wrote 60 unique line(s) → trish/sentence/Ilokano/RIPV_2PE_raw.txt
# Wrote 107 unique line(s) → trish/sentence/Ilokano/RIPV_JAS_raw.txt
# Wrote 818 unique line(s) → trish/sentence/Ilokano/RIPV_LEV_raw.txt
# Wrote 717 unique line(s) → trish/sentence/Ilokano/RIPV_2KI_raw.txt
# Wrote 1033 unique line(s) → trish/sentence/Ilokano/RIPV_JOB_raw.txt
# Wrote 43 unique line(s) → trish/sentence/Ilokano/RIPV_TIT_raw.txt
# Wrote 46 unique line(s) → trish/sentence/Ilokano/RIPV_2TH_raw.txt
# Wrote 253 unique line(s) → trish/sentence/Ilokano/RIPV_2CO_raw.txt
# Wrote 94 unique line(s) → trish/sentence/Ilokano/RIPV_COL_raw.txt
# Wrote 403 unique line(s) → trish/sentence/Ilokano/RIPV_REV_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Ilokano/RIPV_MIC_raw.txt
# Wrote 82 unique line(s) → trish/sentence/Ilokano/RIPV_2TI_raw.txt
# Wrote 55 unique line(s) → trish/sentence/Ilokano/RIPV_MAL_raw.txt
# Wrote 145 unique line(s) → trish/sentence/Ilokano/RIPV_GAL_raw.txt
# Wrote 103 unique line(s) → trish/sentence/Ilokano/RIPV_1JN_raw.txt
# Wrote 154 unique line(s) → trish/sentence/Ilokano/RIPV_LAM_raw.txt
# Wrote 146 unique line(s) → trish/sentence/Ilokano/RIPV_AMO_raw.txt
# Wrote 799 unique line(s) → trish/sentence/Ilokano/RIPV_1CH_raw.txt
# Wrote 23 unique line(s) → trish/sentence/Ilokano/RIPV_PHM_raw.txt
# Wrote 204 unique line(s) → trish/sentence/Ilokano/RIPV_EZR_raw.txt
# Wrote 56 unique line(s) → trish/sentence/Ilokano/RIPV_HAB_raw.txt
# Wrote 2454 unique line(s) → trish/sentence/Ilokano/RIPV_PSA_raw.txt
# Wrote 164 unique line(s) → trish/sentence/Ilokano/RIPV_EST_raw.txt
# Wrote 23 unique line(s) → trish/sentence/Ilokano/RIPV_JUD_raw.txt
# Wrote 193 unique line(s) → trish/sentence/Ilokano/RIPV_HOS_raw.txt
# Wrote 674 unique line(s) → trish/sentence/Ilokano/RIPV_2SA_raw.txt
# Wrote 100 unique line(s) → trish/sentence/Ilokano/RIPV_PHP_raw.txt
# Wrote 53 unique line(s) → trish/sentence/Ilokano/RIPV_ZEP_raw.txt
# Summary
# Processed              : 66
# Wrote TXT files        : 66
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 27 CSV file(s).
# Wrote 112 unique line(s) → trish/sentence/Kalinga/kmk_1TI_raw.txt
# Wrote 1070 unique line(s) → trish/sentence/Kalinga/kmk_MAT_raw.txt
# Wrote 674 unique line(s) → trish/sentence/Kalinga/kmk_MRK_raw.txt
# Wrote 153 unique line(s) → trish/sentence/Kalinga/kmk_EPH_raw.txt
# Wrote 15 unique line(s) → trish/sentence/Kalinga/kmk_3JN_raw.txt
# Wrote 1147 unique line(s) → trish/sentence/Kalinga/kmk_LUK_raw.txt
# Wrote 435 unique line(s) → trish/sentence/Kalinga/kmk_1CO_raw.txt
# Wrote 89 unique line(s) → trish/sentence/Kalinga/kmk_1TH_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Kalinga/kmk_1PE_raw.txt
# Wrote 430 unique line(s) → trish/sentence/Kalinga/kmk_ROM_raw.txt
# Wrote 299 unique line(s) → trish/sentence/Kalinga/kmk_HEB_raw.txt
# Wrote 11 unique line(s) → trish/sentence/Kalinga/kmk_2JN_raw.txt
# Wrote 877 unique line(s) → trish/sentence/Kalinga/kmk_JHN_raw.txt
# Wrote 104 unique line(s) → trish/sentence/Kalinga/kmk_PHP_raw.txt
# Wrote 104 unique line(s) → trish/sentence/Kalinga/kmk_1JN_raw.txt
# Wrote 148 unique line(s) → trish/sentence/Kalinga/kmk_GAL_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Kalinga/kmk_PHM_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Kalinga/kmk_JUD_raw.txt
# Wrote 94 unique line(s) → trish/sentence/Kalinga/kmk_COL_raw.txt
# Wrote 402 unique line(s) → trish/sentence/Kalinga/kmk_REV_raw.txt
# Wrote 82 unique line(s) → trish/sentence/Kalinga/kmk_2TI_raw.txt
# Wrote 1005 unique line(s) → trish/sentence/Kalinga/kmk_ACT_raw.txt
# Wrote 106 unique line(s) → trish/sentence/Kalinga/kmk_JAS_raw.txt
# Wrote 59 unique line(s) → trish/sentence/Kalinga/kmk_2PE_raw.txt
# Wrote 43 unique line(s) → trish/sentence/Kalinga/kmk_TIT_raw.txt
# Wrote 255 unique line(s) → trish/sentence/Kalinga/kmk_2CO_raw.txt
# Wrote 46 unique line(s) → trish/sentence/Kalinga/kmk_2TH_raw.txt
# Summary
# Processed              : 27
# Wrote TXT files        : 27
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 77 CSV file(s).
# Wrote 155 unique line(s) → trish/sentence/Kapampangan/PmPV_EPH_raw.txt
# Wrote 48 unique line(s) → trish/sentence/Kapampangan/PmPV_JON_raw.txt
# Wrote 610 unique line(s) → trish/sentence/Kapampangan/PmPV_JDG_raw.txt
# Wrote 1525 unique line(s) → trish/sentence/Kapampangan/PmPV_GEN_raw.txt
# Wrote 1361 unique line(s) → trish/sentence/Kapampangan/PmPV_JER_raw.txt
# Wrote 356 unique line(s) → trish/sentence/Kapampangan/PmPV_DAN_raw.txt
# Wrote 355 unique line(s) → trish/sentence/Kapampangan/PmPV_NEH_raw.txt
# Wrote 674 unique line(s) → trish/sentence/Kapampangan/PmPV_MRK_raw.txt
# Wrote 1283 unique line(s) → trish/sentence/Kapampangan/PmPV_NUM_raw.txt
# Wrote 1071 unique line(s) → trish/sentence/Kapampangan/PmPV_MAT_raw.txt
# Wrote 113 unique line(s) → trish/sentence/Kapampangan/PmPV_1TI_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Kapampangan/PmPV_1PE_raw.txt
# Wrote 914 unique line(s) → trish/sentence/Kapampangan/PmPV_PRO_raw.txt
# Wrote 21 unique line(s) → trish/sentence/Kapampangan/PmPV_OBA_raw.txt
# Wrote 1367 unique line(s) → trish/sentence/Kapampangan/PmPV_SIR_raw.txt
# Wrote 815 unique line(s) → trish/sentence/Kapampangan/PmPV_1KI_raw.txt
# Wrote 139 unique line(s) → trish/sentence/Kapampangan/PmPV_BAR_raw.txt
# Wrote 647 unique line(s) → trish/sentence/Kapampangan/PmPV_JOS_raw.txt
# Wrote 89 unique line(s) → trish/sentence/Kapampangan/PmPV_1TH_raw.txt
# Wrote 208 unique line(s) → trish/sentence/Kapampangan/PmPV_ZEC_raw.txt
# Wrote 436 unique line(s) → trish/sentence/Kapampangan/PmPV_1CO_raw.txt
# Wrote 1150 unique line(s) → trish/sentence/Kapampangan/PmPV_LUK_raw.txt
# Wrote 15 unique line(s) → trish/sentence/Kapampangan/PmPV_3JN_raw.txt
# Wrote 47 unique line(s) → trish/sentence/Kapampangan/PmPV_NAM_raw.txt
# Wrote 222 unique line(s) → trish/sentence/Kapampangan/PmPV_ECC_raw.txt
# Wrote 1205 unique line(s) → trish/sentence/Kapampangan/PmPV_EXO_raw.txt
# Wrote 117 unique line(s) → trish/sentence/Kapampangan/PmPV_SNG_raw.txt
# Wrote 432 unique line(s) → trish/sentence/Kapampangan/PmPV_ROM_raw.txt
# Wrote 1267 unique line(s) → trish/sentence/Kapampangan/PmPV_EZK_raw.txt
# Wrote 81 unique line(s) → trish/sentence/Kapampangan/PmPV_RUT_raw.txt
# Wrote 954 unique line(s) → trish/sentence/Kapampangan/PmPV_DEU_raw.txt
# Wrote 38 unique line(s) → trish/sentence/Kapampangan/PmPV_HAG_raw.txt
# Wrote 808 unique line(s) → trish/sentence/Kapampangan/PmPV_1SA_raw.txt
# Wrote 924 unique line(s) → trish/sentence/Kapampangan/PmPV_1MA_raw.txt
# Wrote 879 unique line(s) → trish/sentence/Kapampangan/PmPV_JHN_raw.txt
# Wrote 72 unique line(s) → trish/sentence/Kapampangan/PmPV_JOL_raw.txt
# Wrote 13 unique line(s) → trish/sentence/Kapampangan/PmPV_2JN_raw.txt
# Wrote 303 unique line(s) → trish/sentence/Kapampangan/PmPV_HEB_raw.txt
# Wrote 822 unique line(s) → trish/sentence/Kapampangan/PmPV_2CH_raw.txt
# Wrote 73 unique line(s) → trish/sentence/Kapampangan/PmPV_LJE_raw.txt
# Wrote 53 unique line(s) → trish/sentence/Kapampangan/PmPV_ZEP_raw.txt
# Wrote 104 unique line(s) → trish/sentence/Kapampangan/PmPV_PHP_raw.txt
# Wrote 42 unique line(s) → trish/sentence/Kapampangan/PmPV_BEL_raw.txt
# Wrote 694 unique line(s) → trish/sentence/Kapampangan/PmPV_2SA_raw.txt
# Wrote 68 unique line(s) → trish/sentence/Kapampangan/PmPV_S3Y_raw.txt
# Wrote 62 unique line(s) → trish/sentence/Kapampangan/PmPV_SUS_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Kapampangan/PmPV_JUD_raw.txt
# Wrote 339 unique line(s) → trish/sentence/Kapampangan/PmPV_JDT_raw.txt
# Wrote 197 unique line(s) → trish/sentence/Kapampangan/PmPV_HOS_raw.txt
# Wrote 166 unique line(s) → trish/sentence/Kapampangan/PmPV_EST_raw.txt
# Wrote 2458 unique line(s) → trish/sentence/Kapampangan/PmPV_PSA_raw.txt
# Wrote 56 unique line(s) → trish/sentence/Kapampangan/PmPV_HAB_raw.txt
# Wrote 280 unique line(s) → trish/sentence/Kapampangan/PmPV_EZR_raw.txt
# Wrote 555 unique line(s) → trish/sentence/Kapampangan/PmPV_2MA_raw.txt
# Wrote 25 unique line(s) → trish/sentence/Kapampangan/PmPV_PHM_raw.txt
# Wrote 154 unique line(s) → trish/sentence/Kapampangan/PmPV_LAM_raw.txt
# Wrote 146 unique line(s) → trish/sentence/Kapampangan/PmPV_AMO_raw.txt
# Wrote 942 unique line(s) → trish/sentence/Kapampangan/PmPV_1CH_raw.txt
# Wrote 435 unique line(s) → trish/sentence/Kapampangan/PmPV_WIS_raw.txt
# Wrote 149 unique line(s) → trish/sentence/Kapampangan/PmPV_GAL_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Kapampangan/PmPV_1JN_raw.txt
# Wrote 55 unique line(s) → trish/sentence/Kapampangan/PmPV_MAL_raw.txt
# Wrote 83 unique line(s) → trish/sentence/Kapampangan/PmPV_2TI_raw.txt
# Wrote 242 unique line(s) → trish/sentence/Kapampangan/PmPV_TOB_raw.txt
# Wrote 105 unique line(s) → trish/sentence/Kapampangan/PmPV_MIC_raw.txt
# Wrote 95 unique line(s) → trish/sentence/Kapampangan/PmPV_COL_raw.txt
# Wrote 405 unique line(s) → trish/sentence/Kapampangan/PmPV_REV_raw.txt
# Wrote 47 unique line(s) → trish/sentence/Kapampangan/PmPV_2TH_raw.txt
# Wrote 256 unique line(s) → trish/sentence/Kapampangan/PmPV_2CO_raw.txt
# Wrote 1068 unique line(s) → trish/sentence/Kapampangan/PmPV_JOB_raw.txt
# Wrote 46 unique line(s) → trish/sentence/Kapampangan/PmPV_TIT_raw.txt
# Wrote 719 unique line(s) → trish/sentence/Kapampangan/PmPV_2KI_raw.txt
# Wrote 61 unique line(s) → trish/sentence/Kapampangan/PmPV_2PE_raw.txt
# Wrote 859 unique line(s) → trish/sentence/Kapampangan/PmPV_LEV_raw.txt
# Wrote 108 unique line(s) → trish/sentence/Kapampangan/PmPV_JAS_raw.txt
# Wrote 1287 unique line(s) → trish/sentence/Kapampangan/PmPV_ISA_raw.txt
# Wrote 1003 unique line(s) → trish/sentence/Kapampangan/PmPV_ACT_raw.txt
# Summary
# Processed              : 77
# Wrote TXT files        : 77
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 29 CSV file(s).
# Wrote 95 unique line(s) → enz/sentence/Isnag/ISDNT_COL_raw.txt
# Wrote 400 unique line(s) → enz/sentence/Isnag/ISDNT_REV_raw.txt
# Wrote 83 unique line(s) → enz/sentence/Isnag/ISDNT_2TI_raw.txt
# Wrote 990 unique line(s) → enz/sentence/Isnag/ISDNT_ACT_raw.txt
# Wrote 60 unique line(s) → enz/sentence/Isnag/ISDNT_2PE_raw.txt
# Wrote 106 unique line(s) → enz/sentence/Isnag/ISDNT_JAS_raw.txt
# Wrote 47 unique line(s) → enz/sentence/Isnag/ISDNT_2TH_raw.txt
# Wrote 257 unique line(s) → enz/sentence/Isnag/ISDNT_2CO_raw.txt
# Wrote 46 unique line(s) → enz/sentence/Isnag/ISDNT_TIT_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Isnag/ISDNT_PHP_raw.txt
# Wrote 149 unique line(s) → enz/sentence/Isnag/ISDNT_GAL_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Isnag/ISDNT_1JN_raw.txt
# Wrote 24 unique line(s) → enz/sentence/Isnag/ISDNT_PHM_raw.txt
# Wrote 24 unique line(s) → enz/sentence/Isnag/ISDNT_JUD_raw.txt
# Wrote 431 unique line(s) → enz/sentence/Isnag/ISDNT_ROM_raw.txt
# Wrote 302 unique line(s) → enz/sentence/Isnag/ISDNT_HEB_raw.txt
# Wrote 13 unique line(s) → enz/sentence/Isnag/ISDNT_2JN_raw.txt
# Wrote 864 unique line(s) → enz/sentence/Isnag/ISDNT_JHN_raw.txt
# Wrote 1071 unique line(s) → enz/sentence/Isnag/ISDNT_MAT_raw.txt
# Wrote 113 unique line(s) → enz/sentence/Isnag/ISDNT_1TI_raw.txt
# Wrote 675 unique line(s) → enz/sentence/Isnag/ISDNT_MRK_raw.txt
# Wrote 1516 unique line(s) → enz/sentence/Isnag/ISDNT_GEN_raw.txt
# Wrote 155 unique line(s) → enz/sentence/Isnag/ISDNT_EPH_raw.txt
# Wrote 1206 unique line(s) → enz/sentence/Isnag/ISDNT_EXO_raw.txt
# Wrote 1141 unique line(s) → enz/sentence/Isnag/ISDNT_LUK_raw.txt
# Wrote 15 unique line(s) → enz/sentence/Isnag/ISDNT_3JN_raw.txt
# Wrote 89 unique line(s) → enz/sentence/Isnag/ISDNT_1TH_raw.txt
# Wrote 434 unique line(s) → enz/sentence/Isnag/ISDNT_1CO_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Isnag/ISDNT_1PE_raw.txt
# Summary
# Processed              : 29
# Wrote TXT files        : 29
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 62 CSV file(s).
# Wrote 25 unique line(s) → enz/sentence/Kankanaey/XNN_JOS_raw.txt
# Wrote 9 unique line(s) → enz/sentence/Kankanaey/XNN_BAR_raw.txt
# Wrote 425 unique line(s) → enz/sentence/Kankanaey/XNN_1CO_raw.txt
# Wrote 21 unique line(s) → enz/sentence/Kankanaey/XNN_ZEC_raw.txt
# Wrote 87 unique line(s) → enz/sentence/Kankanaey/XNN_1TH_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Kankanaey/XNN_1PE_raw.txt
# Wrote 13 unique line(s) → enz/sentence/Kankanaey/XNN_PRO_raw.txt
# Wrote 45 unique line(s) → enz/sentence/Kankanaey/XNN_1KI_raw.txt
# Wrote 82 unique line(s) → enz/sentence/Kankanaey/XNN_SIR_raw.txt
# Wrote 6 unique line(s) → enz/sentence/Kankanaey/XNN_ECC_raw.txt
# Wrote 546 unique line(s) → enz/sentence/Kankanaey/XNN_EXO_raw.txt
# Wrote 15 unique line(s) → enz/sentence/Kankanaey/XNN_3JN_raw.txt
# Wrote 1124 unique line(s) → enz/sentence/Kankanaey/XNN_LUK_raw.txt
# Wrote 14 unique line(s) → enz/sentence/Kankanaey/XNN_JDG_raw.txt
# Wrote 48 unique line(s) → enz/sentence/Kankanaey/XNN_JON_raw.txt
# Wrote 581 unique line(s) → enz/sentence/Kankanaey/XNN_GEN_raw.txt
# Wrote 120 unique line(s) → enz/sentence/Kankanaey/XNN_JER_raw.txt
# Wrote 150 unique line(s) → enz/sentence/Kankanaey/XNN_EPH_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Kankanaey/XNN_1TI_raw.txt
# Wrote 1069 unique line(s) → enz/sentence/Kankanaey/XNN_MAT_raw.txt
# Wrote 27 unique line(s) → enz/sentence/Kankanaey/XNN_NEH_raw.txt
# Wrote 20 unique line(s) → enz/sentence/Kankanaey/XNN_DAN_raw.txt
# Wrote 671 unique line(s) → enz/sentence/Kankanaey/XNN_MRK_raw.txt
# Wrote 108 unique line(s) → enz/sentence/Kankanaey/XNN_NUM_raw.txt
# Wrote 868 unique line(s) → enz/sentence/Kankanaey/XNN_JHN_raw.txt
# Wrote 20 unique line(s) → enz/sentence/Kankanaey/XNN_JOL_raw.txt
# Wrote 290 unique line(s) → enz/sentence/Kankanaey/XNN_HEB_raw.txt
# Wrote 12 unique line(s) → enz/sentence/Kankanaey/XNN_2CH_raw.txt
# Wrote 13 unique line(s) → enz/sentence/Kankanaey/XNN_2JN_raw.txt
# Wrote 270 unique line(s) → enz/sentence/Kankanaey/XNN_DEU_raw.txt
# Wrote 112 unique line(s) → enz/sentence/Kankanaey/XNN_EZK_raw.txt
# Wrote 19 unique line(s) → enz/sentence/Kankanaey/XNN_RUT_raw.txt
# Wrote 419 unique line(s) → enz/sentence/Kankanaey/XNN_ROM_raw.txt
# Wrote 40 unique line(s) → enz/sentence/Kankanaey/XNN_1SA_raw.txt
# Wrote 2460 unique line(s) → enz/sentence/Kankanaey/XNN_PSA_raw.txt
# Wrote 26 unique line(s) → enz/sentence/Kankanaey/XNN_HAB_raw.txt
# Wrote 24 unique line(s) → enz/sentence/Kankanaey/XNN_PHM_raw.txt
# Wrote 16 unique line(s) → enz/sentence/Kankanaey/XNN_HOS_raw.txt
# Wrote 24 unique line(s) → enz/sentence/Kankanaey/XNN_JUD_raw.txt
# Wrote 5 unique line(s) → enz/sentence/Kankanaey/XNN_JDT_raw.txt
# Wrote 102 unique line(s) → enz/sentence/Kankanaey/XNN_1JN_raw.txt
# Wrote 141 unique line(s) → enz/sentence/Kankanaey/XNN_GAL_raw.txt
# Wrote 33 unique line(s) → enz/sentence/Kankanaey/XNN_AMO_raw.txt
# Wrote 46 unique line(s) → enz/sentence/Kankanaey/XNN_WIS_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Kankanaey/XNN_PHP_raw.txt
# Wrote 16 unique line(s) → enz/sentence/Kankanaey/XNN_ZEP_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Kankanaey/XNN_2SA_raw.txt
# Wrote 75 unique line(s) → enz/sentence/Kankanaey/XNN_2KI_raw.txt
# Wrote 103 unique line(s) → enz/sentence/Kankanaey/XNN_JAS_raw.txt
# Wrote 12 unique line(s) → enz/sentence/Kankanaey/XNN_LEV_raw.txt
# Wrote 56 unique line(s) → enz/sentence/Kankanaey/XNN_2PE_raw.txt
# Wrote 251 unique line(s) → enz/sentence/Kankanaey/XNN_2CO_raw.txt
# Wrote 44 unique line(s) → enz/sentence/Kankanaey/XNN_2TH_raw.txt
# Wrote 39 unique line(s) → enz/sentence/Kankanaey/XNN_JOB_raw.txt
# Wrote 42 unique line(s) → enz/sentence/Kankanaey/XNN_TIT_raw.txt
# Wrote 985 unique line(s) → enz/sentence/Kankanaey/XNN_ACT_raw.txt
# Wrote 341 unique line(s) → enz/sentence/Kankanaey/XNN_ISA_raw.txt
# Wrote 14 unique line(s) → enz/sentence/Kankanaey/XNN_MAL_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Kankanaey/XNN_MIC_raw.txt
# Wrote 95 unique line(s) → enz/sentence/Kankanaey/XNN_COL_raw.txt
# Wrote 389 unique line(s) → enz/sentence/Kankanaey/XNN_REV_raw.txt
# Wrote 80 unique line(s) → enz/sentence/Kankanaey/XNN_2TI_raw.txt
# Summary
# Processed              : 62
# Wrote TXT files        : 62
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 27 CSV file(s).
# Wrote 1005 unique line(s) → enz/sentence/Sambal/XSB_ACT_raw.txt
# Wrote 108 unique line(s) → enz/sentence/Sambal/XSB_JAS_raw.txt
# Wrote 61 unique line(s) → enz/sentence/Sambal/XSB_2PE_raw.txt
# Wrote 46 unique line(s) → enz/sentence/Sambal/XSB_TIT_raw.txt
# Wrote 257 unique line(s) → enz/sentence/Sambal/XSB_2CO_raw.txt
# Wrote 47 unique line(s) → enz/sentence/Sambal/XSB_2TH_raw.txt
# Wrote 404 unique line(s) → enz/sentence/Sambal/XSB_REV_raw.txt
# Wrote 95 unique line(s) → enz/sentence/Sambal/XSB_COL_raw.txt
# Wrote 83 unique line(s) → enz/sentence/Sambal/XSB_2TI_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Sambal/XSB_1JN_raw.txt
# Wrote 149 unique line(s) → enz/sentence/Sambal/XSB_GAL_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Sambal/XSB_PHM_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Sambal/XSB_JUD_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Sambal/XSB_PHP_raw.txt
# Wrote 303 unique line(s) → enz/sentence/Sambal/XSB_HEB_raw.txt
# Wrote 13 unique line(s) → enz/sentence/Sambal/XSB_2JN_raw.txt
# Wrote 879 unique line(s) → enz/sentence/Sambal/XSB_JHN_raw.txt
# Wrote 433 unique line(s) → enz/sentence/Sambal/XSB_ROM_raw.txt
# Wrote 15 unique line(s) → enz/sentence/Sambal/XSB_3JN_raw.txt
# Wrote 1151 unique line(s) → enz/sentence/Sambal/XSB_LUK_raw.txt
# Wrote 437 unique line(s) → enz/sentence/Sambal/XSB_1CO_raw.txt
# Wrote 89 unique line(s) → enz/sentence/Sambal/XSB_1TH_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Sambal/XSB_1PE_raw.txt
# Wrote 113 unique line(s) → enz/sentence/Sambal/XSB_1TI_raw.txt
# Wrote 1071 unique line(s) → enz/sentence/Sambal/XSB_MAT_raw.txt
# Wrote 678 unique line(s) → enz/sentence/Sambal/XSB_MRK_raw.txt
# Wrote 155 unique line(s) → enz/sentence/Sambal/XSB_EPH_raw.txt
# Summary
# Processed              : 27
# Wrote TXT files        : 27
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0
# Found 30 CSV file(s).
# Wrote 430 unique line(s) → enz/sentence/Yakan/YAKV_ROM_raw.txt
# Wrote 85 unique line(s) → enz/sentence/Yakan/YAKV_RUT_raw.txt
# Wrote 868 unique line(s) → enz/sentence/Yakan/YAKV_JHN_raw.txt
# Wrote 13 unique line(s) → enz/sentence/Yakan/YAKV_2JN_raw.txt
# Wrote 300 unique line(s) → enz/sentence/Yakan/YAKV_HEB_raw.txt
# Wrote 154 unique line(s) → enz/sentence/Yakan/YAKV_EPH_raw.txt
# Wrote 48 unique line(s) → enz/sentence/Yakan/YAKV_JON_raw.txt
# Wrote 448 unique line(s) → enz/sentence/Yakan/YAKV_GEN_raw.txt
# Wrote 674 unique line(s) → enz/sentence/Yakan/YAKV_MRK_raw.txt
# Wrote 1056 unique line(s) → enz/sentence/Yakan/YAKV_MAT_raw.txt
# Wrote 113 unique line(s) → enz/sentence/Yakan/YAKV_1TI_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Yakan/YAKV_1PE_raw.txt
# Wrote 89 unique line(s) → enz/sentence/Yakan/YAKV_1TH_raw.txt
# Wrote 434 unique line(s) → enz/sentence/Yakan/YAKV_1CO_raw.txt
# Wrote 1148 unique line(s) → enz/sentence/Yakan/YAKV_LUK_raw.txt
# Wrote 15 unique line(s) → enz/sentence/Yakan/YAKV_3JN_raw.txt
# Wrote 83 unique line(s) → enz/sentence/Yakan/YAKV_2TI_raw.txt
# Wrote 403 unique line(s) → enz/sentence/Yakan/YAKV_REV_raw.txt
# Wrote 95 unique line(s) → enz/sentence/Yakan/YAKV_COL_raw.txt
# Wrote 46 unique line(s) → enz/sentence/Yakan/YAKV_2TH_raw.txt
# Wrote 256 unique line(s) → enz/sentence/Yakan/YAKV_2CO_raw.txt
# Wrote 46 unique line(s) → enz/sentence/Yakan/YAKV_TIT_raw.txt
# Wrote 61 unique line(s) → enz/sentence/Yakan/YAKV_2PE_raw.txt
# Wrote 108 unique line(s) → enz/sentence/Yakan/YAKV_JAS_raw.txt
# Wrote 1003 unique line(s) → enz/sentence/Yakan/YAKV_ACT_raw.txt
# Wrote 104 unique line(s) → enz/sentence/Yakan/YAKV_PHP_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Yakan/YAKV_JUD_raw.txt
# Wrote 25 unique line(s) → enz/sentence/Yakan/YAKV_PHM_raw.txt
# Wrote 149 unique line(s) → enz/sentence/Yakan/YAKV_GAL_raw.txt
# Wrote 105 unique line(s) → enz/sentence/Yakan/YAKV_1JN_raw.txt
# Summary
# Processed              : 30
# Wrote TXT files        : 30
# Skipped (no 'text' col): 0
# Skipped (read errors)  : 0

# %% [markdown]
# ### Step 2: Clean - From Verses to Sentences
# After removing duplicates in the previous step, we now split each verse into individual sentences, ensuring that every sentence is clean, normalized, and stored on its own line.  This step transforms the dataset from verse-level text into a clean, deduplicated, and sentence-aligned corpus, stored in both `.txt` and `.csv` formats. This sentence-level structure is now suitable for tasks like tokenization, alignment, and natural language processing.
#
# **Input and Output**
# - Deduplicated `.txt` files from the `sentence/` directories of each language.
# - Sentence-level `.txt` and `.csv` files stored under the `by_sentence/` directory, preserving the folder hierarchy.
#
# **Cleaning Operations** <br>
# Before splitting into sentences, each verse undergoes a series of cleanup steps:
# - **Header removal:** Lines such as `ORIGINAL TEXT` are stripped using `HEADER_RE`.
# - **Verse markers:** References like `1CO.1.11` at the start of lines are removed with `VERSE_RE`.
# - **Unwanted characters:** Quotation marks, brackets, and other symbols (e.g., `“”‘’()[]«»`) are deleted.
# - **Whitespace normalization:** Newlines are flattened into spaces, and multiple spaces are collapsed.
#
# **Sentence Splitting** <br>
# After cleaning, text is segmented into sentences using punctuation rules:
# - The regex `SENTENCE_SPLIT_RE` detects sentence boundaries after `.`, `!`, or `?`.
# - Each detected sentence is trimmed and filtered to drop empties.
# - Final output has one sentence per line.
#
# **Conversion to CSV**
# - Every sentence `.txt` file is converted to a `.csv` with a single column named `sentence`.
# - This ensures consistency across languages and allows for easier downstream analysis.
#
# **Logging and Summary**
# - For each language, the script prints how many `.txt` files were processed and where outputs were saved.
# - Every text-to-CSV conversion is logged with the source and destination file paths.
# - At the end, a summary reports the total number of files processed across all languages.

# %%
# CHANGE: List all source folders that contain .txt files

LANG_DIRS = [
    "yna/sentence/Cebuano",
    "yna/sentence/Spanish",
    "yna/sentence/Chavacano",
    "yna/sentence/Tausug",
    "cj/sentence/Ivatan",
    "cj/sentence/Pangasinense",
    "cj/sentence/Tagalog",
    "cj/sentence/Yami",
    "trish/sentence/Bikolano",
    "trish/sentence/Ilokano",
    "trish/sentence/Kalinga",
    "trish/sentence/Kapampangan",
    "enz/sentence/Isnag",
    "enz/sentence/Kankanaey",
    "enz/sentence/Sambal",
    "enz/sentence/Yakan",

]

OUT_BASE = os.path.normpath(os.path.join("by_sentence"))

# %%
# REGEXES
HEADER_RE = re.compile(r'(?im)^\s*ORIGINAL\s+TEXT\s*\n?')
# verse markers like "1CO.1.11" at the start of lines
VERSE_RE  = re.compile(r'(?m)^\s*(?:[1-3]?[A-Z]{2,}\.\d+\.\d+)\s*')

# characters to delete entirely
STRIP_CHARS_RE = re.compile(r'[“”‘’()\[\]«»]')

# split sentences on ., !, ? (end the sentence right after the mark)
SENTENCE_SPLIT_RE = re.compile(r'(?<=[.!?])\s+')

# %%
# helper functions

def clean_and_split(text: str) -> str:
    """Remove headers/markers & unwanted chars, normalize spaces, then split into sentences.
       Returns a single string with one sentence per line."""
    # remove header + verse markers
    text = HEADER_RE.sub("", text)
    text = VERSE_RE.sub("", text)

    # delete specific characters
    text = STRIP_CHARS_RE.sub("", text)

    # flatten newlines -> spaces; collapse spaces
    text = re.sub(r'[ \t]*\n[ \t]*', ' ', text)
    text = re.sub(r'\s{2,}', ' ', text).strip()

    if not text:
        return ""

    # split into sentences
    sentences = SENTENCE_SPLIT_RE.split(text)

    # trim each, drop empties, and join one per line
    sentences = [s.strip() for s in sentences if s.strip()]
    return "\n".join(sentences)

# %%
# main

total_processed = 0

for lang_dir in LANG_DIRS:
    in_root  = lang_dir                        
    out_root = os.path.join(OUT_BASE, lang_dir)  
    os.makedirs(out_root, exist_ok=True)

    pattern = os.path.join(in_root, "**", "*.txt")
    in_files = sorted(glob.glob(pattern, recursive=True))
    print(f"\n[{lang_dir}] Found {len(in_files)} .txt files under {os.path.abspath(in_root)}")
    if not in_files:
        continue

    processed = 0
    for in_path in in_files:
        rel_path = os.path.relpath(in_path, in_root)
        out_path = os.path.join(out_root, rel_path)
        os.makedirs(os.path.dirname(out_path), exist_ok=True)

        with open(in_path, "r", encoding="utf-8", errors="ignore") as f:
            raw = f.read()

        cleaned = clean_and_split(raw)

        with open(out_path, "w", encoding="utf-8") as f:
            f.write(cleaned)

        processed += 1
        total_processed += 1

    print(f"[{lang_dir}] Processed {processed} files. Output → {os.path.abspath(out_root)}")

print(f"\nAll done. Total processed: {total_processed} files.")
# Out:
# [yna/sentence/Cebuano] Found 66 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/yna/sentence/Cebuano
# [yna/sentence/Cebuano] Processed 66 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/yna/sentence/Cebuano
#
# [yna/sentence/Spanish] Found 66 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/yna/sentence/Spanish
# [yna/sentence/Spanish] Processed 66 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/yna/sentence/Spanish
#
# [yna/sentence/Chavacano] Found 27 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/yna/sentence/Chavacano
# [yna/sentence/Chavacano] Processed 27 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/yna/sentence/Chavacano
#
# [yna/sentence/Tausug] Found 27 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/yna/sentence/Tausug
# [yna/sentence/Tausug] Processed 27 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/yna/sentence/Tausug
#
# [cj/sentence/Ivatan] Found 29 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/cj/sentence/Ivatan
# [cj/sentence/Ivatan] Processed 29 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/cj/sentence/Ivatan
#
# [cj/sentence/Pangasinense] Found 77 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/cj/sentence/Pangasinense
# [cj/sentence/Pangasinense] Processed 77 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/cj/sentence/Pangasinense
#
# [cj/sentence/Tagalog] Found 77 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/cj/sentence/Tagalog
# [cj/sentence/Tagalog] Processed 77 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/cj/sentence/Tagalog
#
# [cj/sentence/Yami] Found 27 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/cj/sentence/Yami
# [cj/sentence/Yami] Processed 27 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/cj/sentence/Yami
#
# [trish/sentence/Bikolano] Found 77 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/trish/sentence/Bikolano
# [trish/sentence/Bikolano] Processed 77 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/trish/sentence/Bikolano
#
# [trish/sentence/Ilokano] Found 66 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/trish/sentence/Ilokano
# [trish/sentence/Ilokano] Processed 66 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/trish/sentence/Ilokano
#
# [trish/sentence/Kalinga] Found 27 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/trish/sentence/Kalinga
# [trish/sentence/Kalinga] Processed 27 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/trish/sentence/Kalinga
#
# [trish/sentence/Kapampangan] Found 77 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/trish/sentence/Kapampangan
# [trish/sentence/Kapampangan] Processed 77 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/trish/sentence/Kapampangan
#
# [enz/sentence/Isnag] Found 29 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/enz/sentence/Isnag
# [enz/sentence/Isnag] Processed 29 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/enz/sentence/Isnag
#
# [enz/sentence/Kankanaey] Found 62 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/enz/sentence/Kankanaey
# [enz/sentence/Kankanaey] Processed 62 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/enz/sentence/Kankanaey
#
# [enz/sentence/Sambal] Found 27 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/enz/sentence/Sambal
# [enz/sentence/Sambal] Processed 27 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/enz/sentence/Sambal
#
# [enz/sentence/Yakan] Found 30 .txt files under /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/enz/sentence/Yakan
# [enz/sentence/Yakan] Processed 30 files. Output → /Users/armina/Documents/GitHub/bible-dot-com-scraper/parser/by_sentence/enz/sentence/Yakan
#
# All done. Total processed: 791 files.

# %%
BASE_DIR = "by_sentence"   
OVERWRITE = True           # False: skip if CSV already exists
SKIP_BLANKS = False        # True: drop completely empty lines
TRIM_WHITESPACE = False    # True: strip leading/trailing spaces per line

#helpers
def read_txt_lines_any_encoding(path: str) -> List[str]:
    """
    Read a text file robustly with a few common encodings, returning lines without newline chars.
    """
    for enc in ("utf-8", "utf-8-sig", "latin-1"):
        try:
            with open(path, "r", encoding=enc) as f:
                return f.read().splitlines()
        except UnicodeDecodeError:
            continue
    with open(path, "r", encoding="utf-8", errors="replace") as f:
        return f.read().splitlines()

def convert_txt_to_csv(txt_path: str, csv_path: str) -> int:
    """
    Convert a single .txt to .csv with header 'sentence'.
    Returns the number of data rows written (excluding header).
    """
    lines = read_txt_lines_any_encoding(txt_path)

    if TRIM_WHITESPACE:
        lines = [ln.strip() for ln in lines]
    if SKIP_BLANKS:
        lines = [ln for ln in lines if ln != ""]

    os.makedirs(os.path.dirname(csv_path), exist_ok=True)
    with open(csv_path, "w", newline="", encoding="utf-8") as f:
        writer = csv.writer(f)
        writer.writerow(["sentence"])
        for ln in lines:
            writer.writerow([ln])
    return len(lines)

# main
total_txt = 0
total_csv = 0
total_rows = 0

if not os.path.isdir(BASE_DIR):
    raise FileNotFoundError(f"Base directory not found: {BASE_DIR}")

for root, _, files in os.walk(BASE_DIR):
    for name in files:
        if not name.lower().endswith(".txt"):
            continue
        total_txt += 1
        txt_path = os.path.join(root, name)
        csv_path = os.path.join(root, os.path.splitext(name)[0] + ".csv")

        if (not OVERWRITE) and os.path.exists(csv_path):
            print(f"SKIP (exists): {csv_path}")
            continue

        rows = convert_txt_to_csv(txt_path, csv_path)
        total_rows += rows
        total_csv += 1
        print(f"WROTE {rows:5d} rows → {csv_path}")

print("\nDone.")
print(f"TXT files found:   {total_txt}")
print(f"CSV files written: {total_csv}")
print(f"Total rows:        {total_rows}")
# Out:
# WROTE   217 rows → by_sentence/enz/sentence/Kankanaey/XNN_1JN_raw.csv
# WROTE   304 rows → by_sentence/enz/sentence/Kankanaey/XNN_GAL_raw.csv
# WROTE    55 rows → by_sentence/enz/sentence/Kankanaey/XNN_AMO_raw.csv
# WROTE    77 rows → by_sentence/enz/sentence/Kankanaey/XNN_WIS_raw.csv
# WROTE    53 rows → by_sentence/enz/sentence/Kankanaey/XNN_HAB_raw.csv
# WROTE  3124 rows → by_sentence/enz/sentence/Kankanaey/XNN_PSA_raw.csv
# WROTE    38 rows → by_sentence/enz/sentence/Kankanaey/XNN_PHM_raw.csv
# WROTE    29 rows → by_sentence/enz/sentence/Kankanaey/XNN_HOS_raw.csv
# WROTE     9 rows → by_sentence/enz/sentence/Kankanaey/XNN_JDT_raw.csv
# WROTE    71 rows → by_sentence/enz/sentence/Kankanaey/XNN_JUD_raw.csv
# WROTE    36 rows → by_sentence/enz/sentence/Kankanaey/XNN_2SA_raw.csv
# WROTE   150 rows → by_sentence/enz/sentence/Kankanaey/XNN_PHP_raw.csv
# WROTE    31 rows → by_sentence/enz/sentence/Kankanaey/XNN_ZEP_raw.csv
# WROTE  1687 rows → by_sentence/enz/sentence/Kankanaey/XNN_ACT_raw.csv
# WROTE   600 rows → by_sentence/enz/sentence/Kankanaey/XNN_ISA_raw.csv
# WROTE   128 rows → by_sentence/enz/sentence/Kankanaey/XNN_2KI_raw.csv
# WROTE   175 rows → by_sentence/enz/sentence/Kankanaey/XNN_JAS_raw.csv
# WROTE    19 rows → by_sentence/enz/sentence/Kankanaey/XNN_LEV_raw.csv
# WROTE   137 rows → by_sentence/enz/sentence/Kankanaey/XNN_2PE_raw.csv
# WROTE   546 rows → by_sentence/enz/sentence/Kankanaey/XNN_2CO_raw.csv
# WROTE    83 rows → by_sentence/enz/sentence/Kankanaey/XNN_2TH_raw.csv
# WROTE   103 rows → by_sentence/enz/sentence/Kankanaey/XNN_TIT_raw.csv
# WROTE    48 rows → by_sentence/enz/sentence/Kankanaey/XNN_JOB_raw.csv
# WROTE    50 rows → by_sentence/enz/sentence/Kankanaey/XNN_MIC_raw.csv
# WROTE   779 rows → by_sentence/enz/sentence/Kankanaey/XNN_REV_raw.csv
# WROTE   148 rows → by_sentence/enz/sentence/Kankanaey/XNN_COL_raw.csv
# WROTE   179 rows → by_sentence/enz/sentence/Kankanaey/XNN_2TI_raw.csv
# WROTE    23 rows → by_sentence/enz/sentence/Kankanaey/XNN_MAL_raw.csv
# WROTE     7 rows → by_sentence/enz/sentence/Kankanaey/XNN_ECC_raw.csv
# WROTE   798 rows → by_sentence/enz/sentence/Kankanaey/XNN_EXO_raw.csv
# WROTE    33 rows → by_sentence/enz/sentence/Kankanaey/XNN_3JN_raw.csv
# WROTE  1511 rows → by_sentence/enz/sentence/Kankanaey/XNN_LUK_raw.csv
# WROTE    31 rows → by_sentence/enz/sentence/Kankanaey/XNN_JOS_raw.csv
# WROTE    10 rows → by_sentence/enz/sentence/Kankanaey/XNN_BAR_raw.csv
# WROTE   880 rows → by_sentence/enz/sentence/Kankanaey/XNN_1CO_raw.csv
# WROTE    30 rows → by_sentence/enz/sentence/Kankanaey/XNN_ZEC_raw.csv
# WROTE   156 rows → by_sentence/enz/sentence/Kankanaey/XNN_1TH_raw.csv
# WROTE    12 rows → by_sentence/enz/sentence/Kankanaey/XNN_PRO_raw.csv
# WROTE   236 rows → by_sentence/enz/sentence/Kankanaey/XNN_1PE_raw.csv
# WROTE    64 rows → by_sentence/enz/sentence/Kankanaey/XNN_1KI_raw.csv
# WROTE   114 rows → by_sentence/enz/sentence/Kankanaey/XNN_SIR_raw.csv
# WROTE   256 rows → by_sentence/enz/sentence/Kankanaey/XNN_1TI_raw.csv
# WROTE  1566 rows → by_sentence/enz/sentence/Kankanaey/XNN_MAT_raw.csv
# WROTE    44 rows → by_sentence/enz/sentence/Kankanaey/XNN_NEH_raw.csv
# WROTE    33 rows → by_sentence/enz/sentence/Kankanaey/XNN_DAN_raw.csv
# WROTE   156 rows → by_sentence/enz/sentence/Kankanaey/XNN_NUM_raw.csv
# WROTE   977 rows → by_sentence/enz/sentence/Kankanaey/XNN_MRK_raw.csv
# WROTE    24 rows → by_sentence/enz/sentence/Kankanaey/XNN_JDG_raw.csv
# WROTE    71 rows → by_sentence/enz/sentence/Kankanaey/XNN_JON_raw.csv
# WROTE   185 rows → by_sentence/enz/sentence/Kankanaey/XNN_JER_raw.csv
# WROTE   785 rows → by_sentence/enz/sentence/Kankanaey/XNN_GEN_raw.csv
# WROTE   211 rows → by_sentence/enz/sentence/Kankanaey/XNN_EPH_raw.csv
# WROTE   613 rows → by_sentence/enz/sentence/Kankanaey/XNN_HEB_raw.csv
# WROTE    21 rows → by_sentence/enz/sentence/Kankanaey/XNN_2CH_raw.csv
# WROTE    28 rows → by_sentence/enz/sentence/Kankanaey/XNN_2JN_raw.csv
# WROTE  1151 rows → by_sentence/enz/sentence/Kankanaey/XNN_JHN_raw.csv
# WROTE    37 rows → by_sentence/enz/sentence/Kankanaey/XNN_JOL_raw.csv
# WROTE    72 rows → by_sentence/enz/sentence/Kankanaey/XNN_1SA_raw.csv
# WROTE   395 rows → by_sentence/enz/sentence/Kankanaey/XNN_DEU_raw.csv
# WROTE    34 rows → by_sentence/enz/sentence/Kankanaey/XNN_RUT_raw.csv
# WROTE   178 rows → by_sentence/enz/sentence/Kankanaey/XNN_EZK_raw.csv
# WROTE   861 rows → by_sentence/enz/sentence/Kankanaey/XNN_ROM_raw.csv
# WROTE   770 rows → by_sentence/enz/sentence/Isnag/ISDNT_ROM_raw.csv
# WROTE  1529 rows → by_sentence/enz/sentence/Isnag/ISDNT_JHN_raw.csv
# WROTE   514 rows → by_sentence/enz/sentence/Isnag/ISDNT_HEB_raw.csv
# WROTE    22 rows → by_sentence/enz/sentence/Isnag/ISDNT_2JN_raw.csv
# WROTE  3237 rows → by_sentence/enz/sentence/Isnag/ISDNT_GEN_raw.csv
# WROTE   237 rows → by_sentence/enz/sentence/Isnag/ISDNT_EPH_raw.csv
# WROTE  2039 rows → by_sentence/enz/sentence/Isnag/ISDNT_MAT_raw.csv
# WROTE   219 rows → by_sentence/enz/sentence/Isnag/ISDNT_1TI_raw.csv
# WROTE  1201 rows → by_sentence/enz/sentence/Isnag/ISDNT_MRK_raw.csv
# WROTE   145 rows → by_sentence/enz/sentence/Isnag/ISDNT_1TH_raw.csv
# WROTE   777 rows → by_sentence/enz/sentence/Isnag/ISDNT_1CO_raw.csv
# WROTE   223 rows → by_sentence/enz/sentence/Isnag/ISDNT_1PE_raw.csv
# WROTE  2249 rows → by_sentence/enz/sentence/Isnag/ISDNT_EXO_raw.csv
# WROTE  2114 rows → by_sentence/enz/sentence/Isnag/ISDNT_LUK_raw.csv
# WROTE    29 rows → by_sentence/enz/sentence/Isnag/ISDNT_3JN_raw.csv
# WROTE   823 rows → by_sentence/enz/sentence/Isnag/ISDNT_REV_raw.csv
# WROTE   170 rows → by_sentence/enz/sentence/Isnag/ISDNT_COL_raw.csv
# WROTE   169 rows → by_sentence/enz/sentence/Isnag/ISDNT_2TI_raw.csv
# WROTE   130 rows → by_sentence/enz/sentence/Isnag/ISDNT_2PE_raw.csv
# WROTE   193 rows → by_sentence/enz/sentence/Isnag/ISDNT_JAS_raw.csv
# WROTE    80 rows → by_sentence/enz/sentence/Isnag/ISDNT_2TH_raw.csv
# WROTE   508 rows → by_sentence/enz/sentence/Isnag/ISDNT_2CO_raw.csv
# WROTE   102 rows → by_sentence/enz/sentence/Isnag/ISDNT_TIT_raw.csv
# WROTE  1647 rows → by_sentence/enz/sentence/Isnag/ISDNT_ACT_raw.csv
# WROTE   180 rows → by_sentence/enz/sentence/Isnag/ISDNT_PHP_raw.csv
# WROTE    30 rows → by_sentence/enz/sentence/Isnag/ISDNT_PHM_raw.csv
# WROTE    68 rows → by_sentence/enz/sentence/Isnag/ISDNT_JUD_raw.csv
# WROTE   294 rows → by_sentence/enz/sentence/Isnag/ISDNT_GAL_raw.csv
# WROTE   185 rows → by_sentence/enz/sentence/Isnag/ISDNT_1JN_raw.csv
# WROTE   184 rows → by_sentence/enz/sentence/Yakan/YAKV_2TI_raw.csv
# WROTE   191 rows → by_sentence/enz/sentence/Yakan/YAKV_COL_raw.csv
# WROTE   990 rows → by_sentence/enz/sentence/Yakan/YAKV_REV_raw.csv
# WROTE  1999 rows → by_sentence/enz/sentence/Yakan/YAKV_ACT_raw.csv
# WROTE    74 rows → by_sentence/enz/sentence/Yakan/YAKV_2TH_raw.csv
# WROTE   560 rows → by_sentence/enz/sentence/Yakan/YAKV_2CO_raw.csv
# WROTE    99 rows → by_sentence/enz/sentence/Yakan/YAKV_TIT_raw.csv
# WROTE   131 rows → by_sentence/enz/sentence/Yakan/YAKV_2PE_raw.csv
# WROTE   245 rows → by_sentence/enz/sentence/Yakan/YAKV_JAS_raw.csv
# WROTE   189 rows → by_sentence/enz/sentence/Yakan/YAKV_PHP_raw.csv
# WROTE   312 rows → by_sentence/enz/sentence/Yakan/YAKV_GAL_raw.csv
# WROTE   194 rows → by_sentence/enz/sentence/Yakan/YAKV_1JN_raw.csv
# WROTE    71 rows → by_sentence/enz/sentence/Yakan/YAKV_JUD_raw.csv
# WROTE    37 rows → by_sentence/enz/sentence/Yakan/YAKV_PHM_raw.csv
# WROTE   950 rows → by_sentence/enz/sentence/Yakan/YAKV_ROM_raw.csv
# WROTE   181 rows → by_sentence/enz/sentence/Yakan/YAKV_RUT_raw.csv
# WROTE    25 rows → by_sentence/enz/sentence/Yakan/YAKV_2JN_raw.csv
# WROTE   580 rows → by_sentence/enz/sentence/Yakan/YAKV_HEB_raw.csv
# WROTE  1637 rows → by_sentence/enz/sentence/Yakan/YAKV_JHN_raw.csv
# WROTE  1334 rows → by_sentence/enz/sentence/Yakan/YAKV_MRK_raw.csv
# WROTE  1797 rows → by_sentence/enz/sentence/Yakan/YAKV_MAT_raw.csv
# WROTE   235 rows → by_sentence/enz/sentence/Yakan/YAKV_1TI_raw.csv
# WROTE   269 rows → by_sentence/enz/sentence/Yakan/YAKV_EPH_raw.csv
# WROTE    97 rows → by_sentence/enz/sentence/Yakan/YAKV_JON_raw.csv
# WROTE   849 rows → by_sentence/enz/sentence/Yakan/YAKV_GEN_raw.csv
# WROTE  1986 rows → by_sentence/enz/sentence/Yakan/YAKV_LUK_raw.csv
# WROTE    29 rows → by_sentence/enz/sentence/Yakan/YAKV_3JN_raw.csv
# WROTE   237 rows → by_sentence/enz/sentence/Yakan/YAKV_1PE_raw.csv
# WROTE   158 rows → by_sentence/enz/sentence/Yakan/YAKV_1TH_raw.csv
# WROTE   848 rows → by_sentence/enz/sentence/Yakan/YAKV_1CO_raw.csv
# WROTE  1340 rows → by_sentence/enz/sentence/Sambal/XSB_JHN_raw.csv
# WROTE   424 rows → by_sentence/enz/sentence/Sambal/XSB_HEB_raw.csv
# WROTE    21 rows → by_sentence/enz/sentence/Sambal/XSB_2JN_raw.csv
# WROTE   689 rows → by_sentence/enz/sentence/Sambal/XSB_ROM_raw.csv
# WROTE   653 rows → by_sentence/enz/sentence/Sambal/XSB_1CO_raw.csv
# WROTE   115 rows → by_sentence/enz/sentence/Sambal/XSB_1TH_raw.csv
# WROTE   169 rows → by_sentence/enz/sentence/Sambal/XSB_1PE_raw.csv
# WROTE    19 rows → by_sentence/enz/sentence/Sambal/XSB_3JN_raw.csv
# WROTE  1763 rows → by_sentence/enz/sentence/Sambal/XSB_LUK_raw.csv
# WROTE   207 rows → by_sentence/enz/sentence/Sambal/XSB_EPH_raw.csv
# WROTE   152 rows → by_sentence/enz/sentence/Sambal/XSB_1TI_raw.csv
# WROTE  1712 rows → by_sentence/enz/sentence/Sambal/XSB_MAT_raw.csv
# WROTE  1075 rows → by_sentence/enz/sentence/Sambal/XSB_MRK_raw.csv
# WROTE   163 rows → by_sentence/enz/sentence/Sambal/XSB_JAS_raw.csv
# WROTE   101 rows → by_sentence/enz/sentence/Sambal/XSB_2PE_raw.csv
# WROTE    68 rows → by_sentence/enz/sentence/Sambal/XSB_TIT_raw.csv
# WROTE   411 rows → by_sentence/enz/sentence/Sambal/XSB_2CO_raw.csv
# WROTE    64 rows → by_sentence/enz/sentence/Sambal/XSB_2TH_raw.csv
# WROTE  1570 rows → by_sentence/enz/sentence/Sambal/XSB_ACT_raw.csv
# WROTE   134 rows → by_sentence/enz/sentence/Sambal/XSB_COL_raw.csv
# WROTE   716 rows → by_sentence/enz/sentence/Sambal/XSB_REV_raw.csv
# WROTE   121 rows → by_sentence/enz/sentence/Sambal/XSB_2TI_raw.csv
# WROTE    29 rows → by_sentence/enz/sentence/Sambal/XSB_PHM_raw.csv
# WROTE    51 rows → by_sentence/enz/sentence/Sambal/XSB_JUD_raw.csv
# WROTE   157 rows → by_sentence/enz/sentence/Sambal/XSB_1JN_raw.csv
# WROTE   224 rows → by_sentence/enz/sentence/Sambal/XSB_GAL_raw.csv
# WROTE   143 rows → by_sentence/enz/sentence/Sambal/XSB_PHP_raw.csv
# WROTE    30 rows → by_sentence/yna/sentence/Chavacano/CBKNT_PHM_raw.csv
# WROTE    57 rows → by_sentence/yna/sentence/Chavacano/CBKNT_JUD_raw.csv
# WROTE   154 rows → by_sentence/yna/sentence/Chavacano/CBKNT_1JN_raw.csv
# WROTE   264 rows → by_sentence/yna/sentence/Chavacano/CBKNT_GAL_raw.csv
# WROTE   164 rows → by_sentence/yna/sentence/Chavacano/CBKNT_PHP_raw.csv
# WROTE   185 rows → by_sentence/yna/sentence/Chavacano/CBKNT_JAS_raw.csv
# WROTE   116 rows → by_sentence/yna/sentence/Chavacano/CBKNT_2PE_raw.csv
# WROTE    78 rows → by_sentence/yna/sentence/Chavacano/CBKNT_TIT_raw.csv
# WROTE   505 rows → by_sentence/yna/sentence/Chavacano/CBKNT_2CO_raw.csv
# WROTE    65 rows → by_sentence/yna/sentence/Chavacano/CBKNT_2TH_raw.csv
# WROTE  1355 rows → by_sentence/yna/sentence/Chavacano/CBKNT_ACT_raw.csv
# WROTE   631 rows → by_sentence/yna/sentence/Chavacano/CBKNT_REV_raw.csv
# WROTE   166 rows → by_sentence/yna/sentence/Chavacano/CBKNT_COL_raw.csv
# WROTE   128 rows → by_sentence/yna/sentence/Chavacano/CBKNT_2TI_raw.csv
# WROTE   749 rows → by_sentence/yna/sentence/Chavacano/CBKNT_1CO_raw.csv
# WROTE   121 rows → by_sentence/yna/sentence/Chavacano/CBKNT_1TH_raw.csv
# WROTE   187 rows → by_sentence/yna/sentence/Chavacano/CBKNT_1PE_raw.csv
# WROTE    24 rows → by_sentence/yna/sentence/Chavacano/CBKNT_3JN_raw.csv
# WROTE  1593 rows → by_sentence/yna/sentence/Chavacano/CBKNT_LUK_raw.csv
# WROTE   240 rows → by_sentence/yna/sentence/Chavacano/CBKNT_EPH_raw.csv
# WROTE   174 rows → by_sentence/yna/sentence/Chavacano/CBKNT_1TI_raw.csv
# WROTE  1501 rows → by_sentence/yna/sentence/Chavacano/CBKNT_MAT_raw.csv
# WROTE   944 rows → by_sentence/yna/sentence/Chavacano/CBKNT_MRK_raw.csv
# WROTE  1314 rows → by_sentence/yna/sentence/Chavacano/CBKNT_JHN_raw.csv
# WROTE   488 rows → by_sentence/yna/sentence/Chavacano/CBKNT_HEB_raw.csv
# WROTE    18 rows → by_sentence/yna/sentence/Chavacano/CBKNT_2JN_raw.csv
# WROTE   638 rows → by_sentence/yna/sentence/Chavacano/CBKNT_ROM_raw.csv
# WROTE   414 rows → by_sentence/yna/sentence/Spanish/RVR95_ROM_raw.csv
# WROTE  1490 rows → by_sentence/yna/sentence/Spanish/RVR95_EZK_raw.csv
# WROTE   119 rows → by_sentence/yna/sentence/Spanish/RVR95_RUT_raw.csv
# WROTE   162 rows → by_sentence/yna/sentence/Spanish/RVR95_SNG_raw.csv
# WROTE   914 rows → by_sentence/yna/sentence/Spanish/RVR95_DEU_raw.csv
# WROTE    37 rows → by_sentence/yna/sentence/Spanish/RVR95_HAG_raw.csv
# WROTE  1144 rows → by_sentence/yna/sentence/Spanish/RVR95_1SA_raw.csv
# WROTE    86 rows → by_sentence/yna/sentence/Spanish/RVR95_JOL_raw.csv
# WROTE  1007 rows → by_sentence/yna/sentence/Spanish/RVR95_JHN_raw.csv
# WROTE    14 rows → by_sentence/yna/sentence/Spanish/RVR95_2JN_raw.csv
# WROTE   892 rows → by_sentence/yna/sentence/Spanish/RVR95_2CH_raw.csv
# WROTE   243 rows → by_sentence/yna/sentence/Spanish/RVR95_HEB_raw.csv
# WROTE    87 rows → by_sentence/yna/sentence/Spanish/RVR95_EPH_raw.csv
# WROTE  1770 rows → by_sentence/yna/sentence/Spanish/RVR95_GEN_raw.csv
# WROTE  1684 rows → by_sentence/yna/sentence/Spanish/RVR95_JER_raw.csv
# WROTE    61 rows → by_sentence/yna/sentence/Spanish/RVR95_JON_raw.csv
# WROTE   822 rows → by_sentence/yna/sentence/Spanish/RVR95_JDG_raw.csv
# WROTE   748 rows → by_sentence/yna/sentence/Spanish/RVR95_MRK_raw.csv
# WROTE  1271 rows → by_sentence/yna/sentence/Spanish/RVR95_NUM_raw.csv
# WROTE   407 rows → by_sentence/yna/sentence/Spanish/RVR95_DAN_raw.csv
# WROTE   423 rows → by_sentence/yna/sentence/Spanish/RVR95_NEH_raw.csv
# WROTE  1093 rows → by_sentence/yna/sentence/Spanish/RVR95_MAT_raw.csv
# WROTE    84 rows → by_sentence/yna/sentence/Spanish/RVR95_1TI_raw.csv
# WROTE   980 rows → by_sentence/yna/sentence/Spanish/RVR95_1KI_raw.csv
# WROTE    87 rows → by_sentence/yna/sentence/Spanish/RVR95_1PE_raw.csv
# WROTE    29 rows → by_sentence/yna/sentence/Spanish/RVR95_OBA_raw.csv
# WROTE   815 rows → by_sentence/yna/sentence/Spanish/RVR95_PRO_raw.csv
# WROTE   269 rows → by_sentence/yna/sentence/Spanish/RVR95_ZEC_raw.csv
# WROTE    78 rows → by_sentence/yna/sentence/Spanish/RVR95_1TH_raw.csv
# WROTE   446 rows → by_sentence/yna/sentence/Spanish/RVR95_1CO_raw.csv
# WROTE   637 rows → by_sentence/yna/sentence/Spanish/RVR95_JOS_raw.csv
# WROTE  1144 rows → by_sentence/yna/sentence/Spanish/RVR95_LUK_raw.csv
# WROTE    15 rows → by_sentence/yna/sentence/Spanish/RVR95_3JN_raw.csv
# WROTE  1339 rows → by_sentence/yna/sentence/Spanish/RVR95_EXO_raw.csv
# WROTE    73 rows → by_sentence/yna/sentence/Spanish/RVR95_NAM_raw.csv
# WROTE   254 rows → by_sentence/yna/sentence/Spanish/RVR95_ECC_raw.csv
# WROTE    91 rows → by_sentence/yna/sentence/Spanish/RVR95_MAL_raw.csv
# WROTE    73 rows → by_sentence/yna/sentence/Spanish/RVR95_2TI_raw.csv
# WROTE    83 rows → by_sentence/yna/sentence/Spanish/RVR95_COL_raw.csv
# WROTE   493 rows → by_sentence/yna/sentence/Spanish/RVR95_REV_raw.csv
# WROTE   141 rows → by_sentence/yna/sentence/Spanish/RVR95_MIC_raw.csv
# WROTE  1070 rows → by_sentence/yna/sentence/Spanish/RVR95_JOB_raw.csv
# WROTE    42 rows → by_sentence/yna/sentence/Spanish/RVR95_TIT_raw.csv
# WROTE    39 rows → by_sentence/yna/sentence/Spanish/RVR95_2TH_raw.csv
# WROTE   224 rows → by_sentence/yna/sentence/Spanish/RVR95_2CO_raw.csv
# WROTE    52 rows → by_sentence/yna/sentence/Spanish/RVR95_2PE_raw.csv
# WROTE   121 rows → by_sentence/yna/sentence/Spanish/RVR95_JAS_raw.csv
# WROTE   895 rows → by_sentence/yna/sentence/Spanish/RVR95_LEV_raw.csv
# WROTE  1125 rows → by_sentence/yna/sentence/Spanish/RVR95_2KI_raw.csv
# WROTE  1635 rows → by_sentence/yna/sentence/Spanish/RVR95_ISA_raw.csv
# WROTE   949 rows → by_sentence/yna/sentence/Spanish/RVR95_ACT_raw.csv
# WROTE    65 rows → by_sentence/yna/sentence/Spanish/RVR95_ZEP_raw.csv
# WROTE    79 rows → by_sentence/yna/sentence/Spanish/RVR95_PHP_raw.csv
# WROTE   945 rows → by_sentence/yna/sentence/Spanish/RVR95_2SA_raw.csv
# WROTE   189 rows → by_sentence/yna/sentence/Spanish/RVR95_EST_raw.csv
# WROTE    20 rows → by_sentence/yna/sentence/Spanish/RVR95_JUD_raw.csv
# WROTE   263 rows → by_sentence/yna/sentence/Spanish/RVR95_HOS_raw.csv
# WROTE   254 rows → by_sentence/yna/sentence/Spanish/RVR95_EZR_raw.csv
# WROTE    18 rows → by_sentence/yna/sentence/Spanish/RVR95_PHM_raw.csv
# WROTE  2495 rows → by_sentence/yna/sentence/Spanish/RVR95_PSA_raw.csv
# WROTE    79 rows → by_sentence/yna/sentence/Spanish/RVR95_HAB_raw.csv
# WROTE   177 rows → by_sentence/yna/sentence/Spanish/RVR95_LAM_raw.csv
# WROTE   163 rows → by_sentence/yna/sentence/Spanish/RVR95_AMO_raw.csv
# WROTE   850 rows → by_sentence/yna/sentence/Spanish/RVR95_1CH_raw.csv
# WROTE   129 rows → by_sentence/yna/sentence/Spanish/RVR95_GAL_raw.csv
# WROTE   123 rows → by_sentence/yna/sentence/Spanish/RVR95_1JN_raw.csv
# WROTE  1964 rows → by_sentence/yna/sentence/Tausug/TSG_ACT_raw.csv
# WROTE    97 rows → by_sentence/yna/sentence/Tausug/TSG_TIT_raw.csv
# WROTE    86 rows → by_sentence/yna/sentence/Tausug/TSG_2TH_raw.csv
# WROTE   575 rows → by_sentence/yna/sentence/Tausug/TSG_2CO_raw.csv
# WROTE   140 rows → by_sentence/yna/sentence/Tausug/TSG_2PE_raw.csv
# WROTE   244 rows → by_sentence/yna/sentence/Tausug/TSG_JAS_raw.csv
# WROTE   176 rows → by_sentence/yna/sentence/Tausug/TSG_2TI_raw.csv
# WROTE   206 rows → by_sentence/yna/sentence/Tausug/TSG_COL_raw.csv
# WROTE  1059 rows → by_sentence/yna/sentence/Tausug/TSG_REV_raw.csv
# WROTE   312 rows → by_sentence/yna/sentence/Tausug/TSG_GAL_raw.csv
# WROTE   187 rows → by_sentence/yna/sentence/Tausug/TSG_1JN_raw.csv
# WROTE    71 rows → by_sentence/yna/sentence/Tausug/TSG_JUD_raw.csv
# WROTE    50 rows → by_sentence/yna/sentence/Tausug/TSG_PHM_raw.csv
# WROTE   198 rows → by_sentence/yna/sentence/Tausug/TSG_PHP_raw.csv
# WROTE    23 rows → by_sentence/yna/sentence/Tausug/TSG_2JN_raw.csv
# WROTE   624 rows → by_sentence/yna/sentence/Tausug/TSG_HEB_raw.csv
# WROTE  1646 rows → by_sentence/yna/sentence/Tausug/TSG_JHN_raw.csv
# WROTE   981 rows → by_sentence/yna/sentence/Tausug/TSG_ROM_raw.csv
# WROTE  2209 rows → by_sentence/yna/sentence/Tausug/TSG_LUK_raw.csv
# WROTE    30 rows → by_sentence/yna/sentence/Tausug/TSG_3JN_raw.csv
# WROTE   235 rows → by_sentence/yna/sentence/Tausug/TSG_1PE_raw.csv
# WROTE   162 rows → by_sentence/yna/sentence/Tausug/TSG_1TH_raw.csv
# WROTE   901 rows → by_sentence/yna/sentence/Tausug/TSG_1CO_raw.csv
# WROTE  1306 rows → by_sentence/yna/sentence/Tausug/TSG_MRK_raw.csv
# WROTE  2050 rows → by_sentence/yna/sentence/Tausug/TSG_MAT_raw.csv
# WROTE   237 rows → by_sentence/yna/sentence/Tausug/TSG_1TI_raw.csv
# WROTE   286 rows → by_sentence/yna/sentence/Tausug/TSG_EPH_raw.csv
# WROTE    95 rows → by_sentence/yna/sentence/Cebuano/ABCEB_PHP_raw.csv
# WROTE    65 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ZEP_raw.csv
# WROTE   950 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2SA_raw.csv
# WROTE  2475 rows → by_sentence/yna/sentence/Cebuano/ABCEB_PSA_raw.csv
# WROTE    82 rows → by_sentence/yna/sentence/Cebuano/ABCEB_HAB_raw.csv
# WROTE   268 rows → by_sentence/yna/sentence/Cebuano/ABCEB_EZR_raw.csv
# WROTE    21 rows → by_sentence/yna/sentence/Cebuano/ABCEB_PHM_raw.csv
# WROTE   266 rows → by_sentence/yna/sentence/Cebuano/ABCEB_HOS_raw.csv
# WROTE    22 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JUD_raw.csv
# WROTE   201 rows → by_sentence/yna/sentence/Cebuano/ABCEB_EST_raw.csv
# WROTE   123 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1JN_raw.csv
# WROTE   161 rows → by_sentence/yna/sentence/Cebuano/ABCEB_GAL_raw.csv
# WROTE   884 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1CH_raw.csv
# WROTE   154 rows → by_sentence/yna/sentence/Cebuano/ABCEB_LAM_raw.csv
# WROTE   151 rows → by_sentence/yna/sentence/Cebuano/ABCEB_AMO_raw.csv
# WROTE    99 rows → by_sentence/yna/sentence/Cebuano/ABCEB_MAL_raw.csv
# WROTE   121 rows → by_sentence/yna/sentence/Cebuano/ABCEB_MIC_raw.csv
# WROTE    82 rows → by_sentence/yna/sentence/Cebuano/ABCEB_COL_raw.csv
# WROTE   448 rows → by_sentence/yna/sentence/Cebuano/ABCEB_REV_raw.csv
# WROTE    78 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2TI_raw.csv
# WROTE  1012 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2KI_raw.csv
# WROTE   938 rows → by_sentence/yna/sentence/Cebuano/ABCEB_LEV_raw.csv
# WROTE   138 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JAS_raw.csv
# WROTE    57 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2PE_raw.csv
# WROTE   285 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2CO_raw.csv
# WROTE    41 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2TH_raw.csv
# WROTE  1021 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JOB_raw.csv
# WROTE    37 rows → by_sentence/yna/sentence/Cebuano/ABCEB_TIT_raw.csv
# WROTE  1089 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ACT_raw.csv
# WROTE  1461 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ISA_raw.csv
# WROTE   877 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JDG_raw.csv
# WROTE    64 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JON_raw.csv
# WROTE  1986 rows → by_sentence/yna/sentence/Cebuano/ABCEB_GEN_raw.csv
# WROTE  1648 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JER_raw.csv
# WROTE   107 rows → by_sentence/yna/sentence/Cebuano/ABCEB_EPH_raw.csv
# WROTE    91 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1TI_raw.csv
# WROTE  1204 rows → by_sentence/yna/sentence/Cebuano/ABCEB_MAT_raw.csv
# WROTE   427 rows → by_sentence/yna/sentence/Cebuano/ABCEB_NEH_raw.csv
# WROTE   431 rows → by_sentence/yna/sentence/Cebuano/ABCEB_DAN_raw.csv
# WROTE   798 rows → by_sentence/yna/sentence/Cebuano/ABCEB_MRK_raw.csv
# WROTE  1190 rows → by_sentence/yna/sentence/Cebuano/ABCEB_NUM_raw.csv
# WROTE   707 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JOS_raw.csv
# WROTE   522 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1CO_raw.csv
# WROTE    74 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1TH_raw.csv
# WROTE   264 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ZEC_raw.csv
# WROTE   103 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1PE_raw.csv
# WROTE   811 rows → by_sentence/yna/sentence/Cebuano/ABCEB_PRO_raw.csv
# WROTE    25 rows → by_sentence/yna/sentence/Cebuano/ABCEB_OBA_raw.csv
# WROTE   963 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1KI_raw.csv
# WROTE   246 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ECC_raw.csv
# WROTE    73 rows → by_sentence/yna/sentence/Cebuano/ABCEB_NAM_raw.csv
# WROTE  1445 rows → by_sentence/yna/sentence/Cebuano/ABCEB_EXO_raw.csv
# WROTE    21 rows → by_sentence/yna/sentence/Cebuano/ABCEB_3JN_raw.csv
# WROTE  1260 rows → by_sentence/yna/sentence/Cebuano/ABCEB_LUK_raw.csv
# WROTE  1009 rows → by_sentence/yna/sentence/Cebuano/ABCEB_DEU_raw.csv
# WROTE   157 rows → by_sentence/yna/sentence/Cebuano/ABCEB_SNG_raw.csv
# WROTE  1522 rows → by_sentence/yna/sentence/Cebuano/ABCEB_EZK_raw.csv
# WROTE   138 rows → by_sentence/yna/sentence/Cebuano/ABCEB_RUT_raw.csv
# WROTE   479 rows → by_sentence/yna/sentence/Cebuano/ABCEB_ROM_raw.csv
# WROTE  1188 rows → by_sentence/yna/sentence/Cebuano/ABCEB_1SA_raw.csv
# WROTE    44 rows → by_sentence/yna/sentence/Cebuano/ABCEB_HAG_raw.csv
# WROTE  1141 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JHN_raw.csv
# WROTE    98 rows → by_sentence/yna/sentence/Cebuano/ABCEB_JOL_raw.csv
# WROTE   287 rows → by_sentence/yna/sentence/Cebuano/ABCEB_HEB_raw.csv
# WROTE   953 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2CH_raw.csv
# WROTE    13 rows → by_sentence/yna/sentence/Cebuano/ABCEB_2JN_raw.csv
# WROTE  1292 rows → by_sentence/cj/sentence/Yami/SNT_MRK_raw.csv
# WROTE  2027 rows → by_sentence/cj/sentence/Yami/SNT_MAT_raw.csv
# WROTE   247 rows → by_sentence/cj/sentence/Yami/SNT_1TI_raw.csv
# WROTE   289 rows → by_sentence/cj/sentence/Yami/SNT_EPH_raw.csv
# WROTE  2157 rows → by_sentence/cj/sentence/Yami/SNT_LUK_raw.csv
# WROTE    31 rows → by_sentence/cj/sentence/Yami/SNT_3JN_raw.csv
# WROTE   259 rows → by_sentence/cj/sentence/Yami/SNT_1PE_raw.csv
# WROTE   173 rows → by_sentence/cj/sentence/Yami/SNT_1TH_raw.csv
# WROTE   944 rows → by_sentence/cj/sentence/Yami/SNT_1CO_raw.csv
# WROTE   999 rows → by_sentence/cj/sentence/Yami/SNT_ROM_raw.csv
# WROTE    27 rows → by_sentence/cj/sentence/Yami/SNT_2JN_raw.csv
# WROTE   660 rows → by_sentence/cj/sentence/Yami/SNT_HEB_raw.csv
# WROTE  1849 rows → by_sentence/cj/sentence/Yami/SNT_JHN_raw.csv
# WROTE   215 rows → by_sentence/cj/sentence/Yami/SNT_PHP_raw.csv
# WROTE   307 rows → by_sentence/cj/sentence/Yami/SNT_GAL_raw.csv
# WROTE   236 rows → by_sentence/cj/sentence/Yami/SNT_1JN_raw.csv
# WROTE    57 rows → by_sentence/cj/sentence/Yami/SNT_JUD_raw.csv
# WROTE    49 rows → by_sentence/cj/sentence/Yami/SNT_PHM_raw.csv
# WROTE   178 rows → by_sentence/cj/sentence/Yami/SNT_2TI_raw.csv
# WROTE   198 rows → by_sentence/cj/sentence/Yami/SNT_COL_raw.csv
# WROTE   936 rows → by_sentence/cj/sentence/Yami/SNT_REV_raw.csv
# WROTE  1960 rows → by_sentence/cj/sentence/Yami/SNT_ACT_raw.csv
# WROTE    87 rows → by_sentence/cj/sentence/Yami/SNT_2TH_raw.csv
# WROTE   612 rows → by_sentence/cj/sentence/Yami/SNT_2CO_raw.csv
# WROTE   120 rows → by_sentence/cj/sentence/Yami/SNT_TIT_raw.csv
# WROTE   133 rows → by_sentence/cj/sentence/Yami/SNT_2PE_raw.csv
# WROTE   227 rows → by_sentence/cj/sentence/Yami/SNT_JAS_raw.csv
# WROTE    93 rows → by_sentence/cj/sentence/Ivatan/VTSP_PHP_raw.csv
# WROTE   844 rows → by_sentence/cj/sentence/Ivatan/VTSP_PSA_raw.csv
# WROTE    23 rows → by_sentence/cj/sentence/Ivatan/VTSP_PHM_raw.csv
# WROTE    34 rows → by_sentence/cj/sentence/Ivatan/VTSP_JUD_raw.csv
# WROTE   112 rows → by_sentence/cj/sentence/Ivatan/VTSP_1JN_raw.csv
# WROTE   181 rows → by_sentence/cj/sentence/Ivatan/VTSP_GAL_raw.csv
# WROTE   667 rows → by_sentence/cj/sentence/Ivatan/VTSP_REV_raw.csv
# WROTE    93 rows → by_sentence/cj/sentence/Ivatan/VTSP_COL_raw.csv
# WROTE    95 rows → by_sentence/cj/sentence/Ivatan/VTSP_2TI_raw.csv
# WROTE   114 rows → by_sentence/cj/sentence/Ivatan/VTSP_JAS_raw.csv
# WROTE    68 rows → by_sentence/cj/sentence/Ivatan/VTSP_2PE_raw.csv
# WROTE   273 rows → by_sentence/cj/sentence/Ivatan/VTSP_2CO_raw.csv
# WROTE    40 rows → by_sentence/cj/sentence/Ivatan/VTSP_2TH_raw.csv
# WROTE    48 rows → by_sentence/cj/sentence/Ivatan/VTSP_TIT_raw.csv
# WROTE  1329 rows → by_sentence/cj/sentence/Ivatan/VTSP_ACT_raw.csv
# WROTE   110 rows → by_sentence/cj/sentence/Ivatan/VTSP_EPH_raw.csv
# WROTE   126 rows → by_sentence/cj/sentence/Ivatan/VTSP_1TI_raw.csv
# WROTE  1278 rows → by_sentence/cj/sentence/Ivatan/VTSP_MAT_raw.csv
# WROTE   771 rows → by_sentence/cj/sentence/Ivatan/VTSP_MRK_raw.csv
# WROTE   500 rows → by_sentence/cj/sentence/Ivatan/VTSP_1CO_raw.csv
# WROTE    63 rows → by_sentence/cj/sentence/Ivatan/VTSP_1TH_raw.csv
# WROTE  1069 rows → by_sentence/cj/sentence/Ivatan/VTSP_PRO_raw.csv
# WROTE   111 rows → by_sentence/cj/sentence/Ivatan/VTSP_1PE_raw.csv
# WROTE    19 rows → by_sentence/cj/sentence/Ivatan/VTSP_3JN_raw.csv
# WROTE  1228 rows → by_sentence/cj/sentence/Ivatan/VTSP_LUK_raw.csv
# WROTE   464 rows → by_sentence/cj/sentence/Ivatan/VTSP_ROM_raw.csv
# WROTE  1151 rows → by_sentence/cj/sentence/Ivatan/VTSP_JHN_raw.csv
# WROTE   265 rows → by_sentence/cj/sentence/Ivatan/VTSP_HEB_raw.csv
# WROTE    14 rows → by_sentence/cj/sentence/Ivatan/VTSP_2JN_raw.csv
# WROTE  1590 rows → by_sentence/cj/sentence/Tagalog/MBB05_MAT_raw.csv
# WROTE   133 rows → by_sentence/cj/sentence/Tagalog/MBB05_1TI_raw.csv
# WROTE  1388 rows → by_sentence/cj/sentence/Tagalog/MBB05_NUM_raw.csv
# WROTE  1033 rows → by_sentence/cj/sentence/Tagalog/MBB05_MRK_raw.csv
# WROTE   622 rows → by_sentence/cj/sentence/Tagalog/MBB05_DAN_raw.csv
# WROTE   558 rows → by_sentence/cj/sentence/Tagalog/MBB05_NEH_raw.csv
# WROTE  2259 rows → by_sentence/cj/sentence/Tagalog/MBB05_JER_raw.csv
# WROTE  2279 rows → by_sentence/cj/sentence/Tagalog/MBB05_GEN_raw.csv
# WROTE    83 rows → by_sentence/cj/sentence/Tagalog/MBB05_JON_raw.csv
# WROTE  1099 rows → by_sentence/cj/sentence/Tagalog/MBB05_JDG_raw.csv
# WROTE   184 rows → by_sentence/cj/sentence/Tagalog/MBB05_EPH_raw.csv
# WROTE  1677 rows → by_sentence/cj/sentence/Tagalog/MBB05_EXO_raw.csv
# WROTE    99 rows → by_sentence/cj/sentence/Tagalog/MBB05_NAM_raw.csv
# WROTE   342 rows → by_sentence/cj/sentence/Tagalog/MBB05_ECC_raw.csv
# WROTE  1662 rows → by_sentence/cj/sentence/Tagalog/MBB05_LUK_raw.csv
# WROTE    20 rows → by_sentence/cj/sentence/Tagalog/MBB05_3JN_raw.csv
# WROTE   105 rows → by_sentence/cj/sentence/Tagalog/MBB05_1TH_raw.csv
# WROTE   338 rows → by_sentence/cj/sentence/Tagalog/MBB05_ZEC_raw.csv
# WROTE   606 rows → by_sentence/cj/sentence/Tagalog/MBB05_1CO_raw.csv
# WROTE   932 rows → by_sentence/cj/sentence/Tagalog/MBB05_JOS_raw.csv
# WROTE   193 rows → by_sentence/cj/sentence/Tagalog/MBB05_BAR_raw.csv
# WROTE  1618 rows → by_sentence/cj/sentence/Tagalog/MBB05_SIR_raw.csv
# WROTE  1361 rows → by_sentence/cj/sentence/Tagalog/MBB05_1KI_raw.csv
# WROTE   923 rows → by_sentence/cj/sentence/Tagalog/MBB05_PRO_raw.csv
# WROTE    43 rows → by_sentence/cj/sentence/Tagalog/MBB05_OBA_raw.csv
# WROTE   154 rows → by_sentence/cj/sentence/Tagalog/MBB05_1PE_raw.csv
# WROTE  1516 rows → by_sentence/cj/sentence/Tagalog/MBB05_1SA_raw.csv
# WROTE    60 rows → by_sentence/cj/sentence/Tagalog/MBB05_HAG_raw.csv
# WROTE  1266 rows → by_sentence/cj/sentence/Tagalog/MBB05_DEU_raw.csv
# WROTE   628 rows → by_sentence/cj/sentence/Tagalog/MBB05_ROM_raw.csv
# WROTE   179 rows → by_sentence/cj/sentence/Tagalog/MBB05_RUT_raw.csv
# WROTE  2144 rows → by_sentence/cj/sentence/Tagalog/MBB05_EZK_raw.csv
# WROTE   156 rows → by_sentence/cj/sentence/Tagalog/MBB05_SNG_raw.csv
# WROTE  1419 rows → by_sentence/cj/sentence/Tagalog/MBB05_2CH_raw.csv
# WROTE   418 rows → by_sentence/cj/sentence/Tagalog/MBB05_HEB_raw.csv
# WROTE    18 rows → by_sentence/cj/sentence/Tagalog/MBB05_2JN_raw.csv
# WROTE   130 rows → by_sentence/cj/sentence/Tagalog/MBB05_JOL_raw.csv
# WROTE  1324 rows → by_sentence/cj/sentence/Tagalog/MBB05_JHN_raw.csv
# WROTE  1322 rows → by_sentence/cj/sentence/Tagalog/MBB05_1MA_raw.csv
# WROTE    97 rows → by_sentence/cj/sentence/Tagalog/MBB05_SUS_raw.csv
# WROTE    80 rows → by_sentence/cj/sentence/Tagalog/MBB05_S3Y_raw.csv
# WROTE  1253 rows → by_sentence/cj/sentence/Tagalog/MBB05_2SA_raw.csv
# WROTE    79 rows → by_sentence/cj/sentence/Tagalog/MBB05_BEL_raw.csv
# WROTE   138 rows → by_sentence/cj/sentence/Tagalog/MBB05_PHP_raw.csv
# WROTE    90 rows → by_sentence/cj/sentence/Tagalog/MBB05_ZEP_raw.csv
# WROTE   118 rows → by_sentence/cj/sentence/Tagalog/MBB05_LJE_raw.csv
# WROTE   208 rows → by_sentence/cj/sentence/Tagalog/MBB05_GAL_raw.csv
# WROTE   156 rows → by_sentence/cj/sentence/Tagalog/MBB05_1JN_raw.csv
# WROTE   632 rows → by_sentence/cj/sentence/Tagalog/MBB05_WIS_raw.csv
# WROTE   256 rows → by_sentence/cj/sentence/Tagalog/MBB05_AMO_raw.csv
# WROTE   202 rows → by_sentence/cj/sentence/Tagalog/MBB05_LAM_raw.csv
# WROTE  1133 rows → by_sentence/cj/sentence/Tagalog/MBB05_1CH_raw.csv
# WROTE   927 rows → by_sentence/cj/sentence/Tagalog/MBB05_2MA_raw.csv
# WROTE    25 rows → by_sentence/cj/sentence/Tagalog/MBB05_PHM_raw.csv
# WROTE   301 rows → by_sentence/cj/sentence/Tagalog/MBB05_EZR_raw.csv
# WROTE   110 rows → by_sentence/cj/sentence/Tagalog/MBB05_HAB_raw.csv
# WROTE  2641 rows → by_sentence/cj/sentence/Tagalog/MBB05_PSA_raw.csv
# WROTE   284 rows → by_sentence/cj/sentence/Tagalog/MBB05_EST_raw.csv
# WROTE   612 rows → by_sentence/cj/sentence/Tagalog/MBB05_JDT_raw.csv
# WROTE    39 rows → by_sentence/cj/sentence/Tagalog/MBB05_JUD_raw.csv
# WROTE   353 rows → by_sentence/cj/sentence/Tagalog/MBB05_HOS_raw.csv
# WROTE   684 rows → by_sentence/cj/sentence/Tagalog/MBB05_REV_raw.csv
# WROTE   123 rows → by_sentence/cj/sentence/Tagalog/MBB05_COL_raw.csv
# WROTE   214 rows → by_sentence/cj/sentence/Tagalog/MBB05_MIC_raw.csv
# WROTE   677 rows → by_sentence/cj/sentence/Tagalog/MBB05_TOB_raw.csv
# WROTE   107 rows → by_sentence/cj/sentence/Tagalog/MBB05_2TI_raw.csv
# WROTE   107 rows → by_sentence/cj/sentence/Tagalog/MBB05_MAL_raw.csv
# WROTE  1465 rows → by_sentence/cj/sentence/Tagalog/MBB05_ACT_raw.csv
# WROTE  2026 rows → by_sentence/cj/sentence/Tagalog/MBB05_ISA_raw.csv
# WROTE    92 rows → by_sentence/cj/sentence/Tagalog/MBB05_2PE_raw.csv
# WROTE  1072 rows → by_sentence/cj/sentence/Tagalog/MBB05_LEV_raw.csv
# WROTE   154 rows → by_sentence/cj/sentence/Tagalog/MBB05_JAS_raw.csv
# WROTE  1297 rows → by_sentence/cj/sentence/Tagalog/MBB05_2KI_raw.csv
# WROTE    59 rows → by_sentence/cj/sentence/Tagalog/MBB05_TIT_raw.csv
# WROTE  1148 rows → by_sentence/cj/sentence/Tagalog/MBB05_JOB_raw.csv
# WROTE    62 rows → by_sentence/cj/sentence/Tagalog/MBB05_2TH_raw.csv
# WROTE   385 rows → by_sentence/cj/sentence/Tagalog/MBB05_2CO_raw.csv
# WROTE   369 rows → by_sentence/cj/sentence/Pangasinense/PNPV_HOS_raw.csv
# WROTE    39 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JUD_raw.csv
# WROTE   560 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JDT_raw.csv
# WROTE   293 rows → by_sentence/cj/sentence/Pangasinense/PNPV_EST_raw.csv
# WROTE   102 rows → by_sentence/cj/sentence/Pangasinense/PNPV_HAB_raw.csv
# WROTE  2809 rows → by_sentence/cj/sentence/Pangasinense/PNPV_PSA_raw.csv
# WROTE    27 rows → by_sentence/cj/sentence/Pangasinense/PNPV_PHM_raw.csv
# WROTE   788 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2MA_raw.csv
# WROTE   305 rows → by_sentence/cj/sentence/Pangasinense/PNPV_EZR_raw.csv
# WROTE  1080 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1CH_raw.csv
# WROTE   224 rows → by_sentence/cj/sentence/Pangasinense/PNPV_LAM_raw.csv
# WROTE   277 rows → by_sentence/cj/sentence/Pangasinense/PNPV_AMO_raw.csv
# WROTE   631 rows → by_sentence/cj/sentence/Pangasinense/PNPV_WIS_raw.csv
# WROTE   161 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1JN_raw.csv
# WROTE   207 rows → by_sentence/cj/sentence/Pangasinense/PNPV_GAL_raw.csv
# WROTE   100 rows → by_sentence/cj/sentence/Pangasinense/PNPV_LJE_raw.csv
# WROTE   101 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ZEP_raw.csv
# WROTE    73 rows → by_sentence/cj/sentence/Pangasinense/PNPV_BEL_raw.csv
# WROTE   141 rows → by_sentence/cj/sentence/Pangasinense/PNPV_PHP_raw.csv
# WROTE  1141 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2SA_raw.csv
# WROTE    76 rows → by_sentence/cj/sentence/Pangasinense/PNPV_S3Y_raw.csv
# WROTE    88 rows → by_sentence/cj/sentence/Pangasinense/PNPV_SUS_raw.csv
# WROTE   386 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2CO_raw.csv
# WROTE    63 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2TH_raw.csv
# WROTE  1167 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JOB_raw.csv
# WROTE    62 rows → by_sentence/cj/sentence/Pangasinense/PNPV_TIT_raw.csv
# WROTE  1117 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2KI_raw.csv
# WROTE   164 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JAS_raw.csv
# WROTE  1002 rows → by_sentence/cj/sentence/Pangasinense/PNPV_LEV_raw.csv
# WROTE    92 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2PE_raw.csv
# WROTE  2299 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ISA_raw.csv
# WROTE  1517 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ACT_raw.csv
# WROTE   117 rows → by_sentence/cj/sentence/Pangasinense/PNPV_MAL_raw.csv
# WROTE   112 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2TI_raw.csv
# WROTE   642 rows → by_sentence/cj/sentence/Pangasinense/PNPV_TOB_raw.csv
# WROTE   204 rows → by_sentence/cj/sentence/Pangasinense/PNPV_MIC_raw.csv
# WROTE   134 rows → by_sentence/cj/sentence/Pangasinense/PNPV_COL_raw.csv
# WROTE   718 rows → by_sentence/cj/sentence/Pangasinense/PNPV_REV_raw.csv
# WROTE   159 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1PE_raw.csv
# WROTE    41 rows → by_sentence/cj/sentence/Pangasinense/PNPV_OBA_raw.csv
# WROTE  1063 rows → by_sentence/cj/sentence/Pangasinense/PNPV_PRO_raw.csv
# WROTE  1163 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1KI_raw.csv
# WROTE  1723 rows → by_sentence/cj/sentence/Pangasinense/PNPV_SIR_raw.csv
# WROTE   867 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JOS_raw.csv
# WROTE   178 rows → by_sentence/cj/sentence/Pangasinense/PNPV_BAR_raw.csv
# WROTE   624 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1CO_raw.csv
# WROTE   347 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ZEC_raw.csv
# WROTE   117 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1TH_raw.csv
# WROTE    23 rows → by_sentence/cj/sentence/Pangasinense/PNPV_3JN_raw.csv
# WROTE  1755 rows → by_sentence/cj/sentence/Pangasinense/PNPV_LUK_raw.csv
# WROTE   347 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ECC_raw.csv
# WROTE   100 rows → by_sentence/cj/sentence/Pangasinense/PNPV_NAM_raw.csv
# WROTE  1515 rows → by_sentence/cj/sentence/Pangasinense/PNPV_EXO_raw.csv
# WROTE   175 rows → by_sentence/cj/sentence/Pangasinense/PNPV_EPH_raw.csv
# WROTE  1083 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JDG_raw.csv
# WROTE    78 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JON_raw.csv
# WROTE  2354 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JER_raw.csv
# WROTE  2150 rows → by_sentence/cj/sentence/Pangasinense/PNPV_GEN_raw.csv
# WROTE   522 rows → by_sentence/cj/sentence/Pangasinense/PNPV_NEH_raw.csv
# WROTE   598 rows → by_sentence/cj/sentence/Pangasinense/PNPV_DAN_raw.csv
# WROTE  1082 rows → by_sentence/cj/sentence/Pangasinense/PNPV_MRK_raw.csv
# WROTE  1257 rows → by_sentence/cj/sentence/Pangasinense/PNPV_NUM_raw.csv
# WROTE   145 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1TI_raw.csv
# WROTE  1662 rows → by_sentence/cj/sentence/Pangasinense/PNPV_MAT_raw.csv
# WROTE  1187 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1MA_raw.csv
# WROTE  1365 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JHN_raw.csv
# WROTE   125 rows → by_sentence/cj/sentence/Pangasinense/PNPV_JOL_raw.csv
# WROTE    19 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2JN_raw.csv
# WROTE   437 rows → by_sentence/cj/sentence/Pangasinense/PNPV_HEB_raw.csv
# WROTE  1254 rows → by_sentence/cj/sentence/Pangasinense/PNPV_2CH_raw.csv
# WROTE   189 rows → by_sentence/cj/sentence/Pangasinense/PNPV_SNG_raw.csv
# WROTE  2136 rows → by_sentence/cj/sentence/Pangasinense/PNPV_EZK_raw.csv
# WROTE   174 rows → by_sentence/cj/sentence/Pangasinense/PNPV_RUT_raw.csv
# WROTE   611 rows → by_sentence/cj/sentence/Pangasinense/PNPV_ROM_raw.csv
# WROTE  1249 rows → by_sentence/cj/sentence/Pangasinense/PNPV_DEU_raw.csv
# WROTE    54 rows → by_sentence/cj/sentence/Pangasinense/PNPV_HAG_raw.csv
# WROTE  1420 rows → by_sentence/cj/sentence/Pangasinense/PNPV_1SA_raw.csv
# WROTE  1235 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2SA_raw.csv
# WROTE    83 rows → by_sentence/trish/sentence/Kapampangan/PmPV_S3Y_raw.csv
# WROTE   101 rows → by_sentence/trish/sentence/Kapampangan/PmPV_SUS_raw.csv
# WROTE   115 rows → by_sentence/trish/sentence/Kapampangan/PmPV_LJE_raw.csv
# WROTE   104 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ZEP_raw.csv
# WROTE    80 rows → by_sentence/trish/sentence/Kapampangan/PmPV_BEL_raw.csv
# WROTE   142 rows → by_sentence/trish/sentence/Kapampangan/PmPV_PHP_raw.csv
# WROTE   287 rows → by_sentence/trish/sentence/Kapampangan/PmPV_AMO_raw.csv
# WROTE   231 rows → by_sentence/trish/sentence/Kapampangan/PmPV_LAM_raw.csv
# WROTE  1262 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1CH_raw.csv
# WROTE   648 rows → by_sentence/trish/sentence/Kapampangan/PmPV_WIS_raw.csv
# WROTE   226 rows → by_sentence/trish/sentence/Kapampangan/PmPV_GAL_raw.csv
# WROTE   159 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1JN_raw.csv
# WROTE   621 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JDT_raw.csv
# WROTE    41 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JUD_raw.csv
# WROTE   397 rows → by_sentence/trish/sentence/Kapampangan/PmPV_HOS_raw.csv
# WROTE   276 rows → by_sentence/trish/sentence/Kapampangan/PmPV_EST_raw.csv
# WROTE   104 rows → by_sentence/trish/sentence/Kapampangan/PmPV_HAB_raw.csv
# WROTE  2740 rows → by_sentence/trish/sentence/Kapampangan/PmPV_PSA_raw.csv
# WROTE   288 rows → by_sentence/trish/sentence/Kapampangan/PmPV_EZR_raw.csv
# WROTE   775 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2MA_raw.csv
# WROTE    29 rows → by_sentence/trish/sentence/Kapampangan/PmPV_PHM_raw.csv
# WROTE   118 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2TI_raw.csv
# WROTE   633 rows → by_sentence/trish/sentence/Kapampangan/PmPV_TOB_raw.csv
# WROTE   215 rows → by_sentence/trish/sentence/Kapampangan/PmPV_MIC_raw.csv
# WROTE   734 rows → by_sentence/trish/sentence/Kapampangan/PmPV_REV_raw.csv
# WROTE   137 rows → by_sentence/trish/sentence/Kapampangan/PmPV_COL_raw.csv
# WROTE   118 rows → by_sentence/trish/sentence/Kapampangan/PmPV_MAL_raw.csv
# WROTE  2378 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ISA_raw.csv
# WROTE  1487 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ACT_raw.csv
# WROTE    63 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2TH_raw.csv
# WROTE   387 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2CO_raw.csv
# WROTE    66 rows → by_sentence/trish/sentence/Kapampangan/PmPV_TIT_raw.csv
# WROTE  1181 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JOB_raw.csv
# WROTE  1319 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2KI_raw.csv
# WROTE    94 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2PE_raw.csv
# WROTE  1124 rows → by_sentence/trish/sentence/Kapampangan/PmPV_LEV_raw.csv
# WROTE   167 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JAS_raw.csv
# WROTE   638 rows → by_sentence/trish/sentence/Kapampangan/PmPV_DAN_raw.csv
# WROTE   559 rows → by_sentence/trish/sentence/Kapampangan/PmPV_NEH_raw.csv
# WROTE  1590 rows → by_sentence/trish/sentence/Kapampangan/PmPV_NUM_raw.csv
# WROTE  1065 rows → by_sentence/trish/sentence/Kapampangan/PmPV_MRK_raw.csv
# WROTE  1591 rows → by_sentence/trish/sentence/Kapampangan/PmPV_MAT_raw.csv
# WROTE   143 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1TI_raw.csv
# WROTE   179 rows → by_sentence/trish/sentence/Kapampangan/PmPV_EPH_raw.csv
# WROTE    86 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JON_raw.csv
# WROTE  1086 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JDG_raw.csv
# WROTE  2386 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JER_raw.csv
# WROTE  2444 rows → by_sentence/trish/sentence/Kapampangan/PmPV_GEN_raw.csv
# WROTE  1673 rows → by_sentence/trish/sentence/Kapampangan/PmPV_LUK_raw.csv
# WROTE    23 rows → by_sentence/trish/sentence/Kapampangan/PmPV_3JN_raw.csv
# WROTE   101 rows → by_sentence/trish/sentence/Kapampangan/PmPV_NAM_raw.csv
# WROTE   320 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ECC_raw.csv
# WROTE  1638 rows → by_sentence/trish/sentence/Kapampangan/PmPV_EXO_raw.csv
# WROTE   959 rows → by_sentence/trish/sentence/Kapampangan/PmPV_PRO_raw.csv
# WROTE    41 rows → by_sentence/trish/sentence/Kapampangan/PmPV_OBA_raw.csv
# WROTE   156 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1PE_raw.csv
# WROTE  1781 rows → by_sentence/trish/sentence/Kapampangan/PmPV_SIR_raw.csv
# WROTE  1263 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1KI_raw.csv
# WROTE   201 rows → by_sentence/trish/sentence/Kapampangan/PmPV_BAR_raw.csv
# WROTE   908 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JOS_raw.csv
# WROTE   119 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1TH_raw.csv
# WROTE   357 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ZEC_raw.csv
# WROTE   609 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1CO_raw.csv
# WROTE    60 rows → by_sentence/trish/sentence/Kapampangan/PmPV_HAG_raw.csv
# WROTE  1473 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1SA_raw.csv
# WROTE   190 rows → by_sentence/trish/sentence/Kapampangan/PmPV_SNG_raw.csv
# WROTE   616 rows → by_sentence/trish/sentence/Kapampangan/PmPV_ROM_raw.csv
# WROTE   165 rows → by_sentence/trish/sentence/Kapampangan/PmPV_RUT_raw.csv
# WROTE  2227 rows → by_sentence/trish/sentence/Kapampangan/PmPV_EZK_raw.csv
# WROTE  1259 rows → by_sentence/trish/sentence/Kapampangan/PmPV_DEU_raw.csv
# WROTE    19 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2JN_raw.csv
# WROTE   442 rows → by_sentence/trish/sentence/Kapampangan/PmPV_HEB_raw.csv
# WROTE  1307 rows → by_sentence/trish/sentence/Kapampangan/PmPV_2CH_raw.csv
# WROTE  1208 rows → by_sentence/trish/sentence/Kapampangan/PmPV_1MA_raw.csv
# WROTE  1323 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JHN_raw.csv
# WROTE   122 rows → by_sentence/trish/sentence/Kapampangan/PmPV_JOL_raw.csv
# WROTE  1581 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_LUK_raw.csv
# WROTE    21 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_3JN_raw.csv
# WROTE   103 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_NAM_raw.csv
# WROTE   318 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ECC_raw.csv
# WROTE  1530 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_EXO_raw.csv
# WROTE   139 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1PE_raw.csv
# WROTE    41 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_OBA_raw.csv
# WROTE   982 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_PRO_raw.csv
# WROTE  1690 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_SIR_raw.csv
# WROTE  1180 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1KI_raw.csv
# WROTE   192 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_BAR_raw.csv
# WROTE   875 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JOS_raw.csv
# WROTE   346 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ZEC_raw.csv
# WROTE   108 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1TH_raw.csv
# WROTE   608 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1CO_raw.csv
# WROTE   588 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_DAN_raw.csv
# WROTE   479 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_NEH_raw.csv
# WROTE   964 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_MRK_raw.csv
# WROTE  1246 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_NUM_raw.csv
# WROTE  1480 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_MAT_raw.csv
# WROTE   130 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1TI_raw.csv
# WROTE   170 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_EPH_raw.csv
# WROTE    75 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JON_raw.csv
# WROTE  1018 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JDG_raw.csv
# WROTE  2332 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JER_raw.csv
# WROTE  2037 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_GEN_raw.csv
# WROTE    15 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2JN_raw.csv
# WROTE   405 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_HEB_raw.csv
# WROTE  1200 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2CH_raw.csv
# WROTE  1168 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1MA_raw.csv
# WROTE  1285 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JHN_raw.csv
# WROTE   124 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JOL_raw.csv
# WROTE    54 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_HAG_raw.csv
# WROTE  1366 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1SA_raw.csv
# WROTE   187 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_SNG_raw.csv
# WROTE   606 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ROM_raw.csv
# WROTE  2047 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_EZK_raw.csv
# WROTE   154 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_RUT_raw.csv
# WROTE  1198 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_DEU_raw.csv
# WROTE   205 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_LAM_raw.csv
# WROTE   264 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_AMO_raw.csv
# WROTE   984 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1CH_raw.csv
# WROTE   601 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_WIS_raw.csv
# WROTE   208 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_GAL_raw.csv
# WROTE   143 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_1JN_raw.csv
# WROTE    34 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JUD_raw.csv
# WROTE   579 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JDT_raw.csv
# WROTE   363 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_HOS_raw.csv
# WROTE   278 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_EST_raw.csv
# WROTE    97 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_HAB_raw.csv
# WROTE  2785 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_PSA_raw.csv
# WROTE   241 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_EZR_raw.csv
# WROTE    25 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_PHM_raw.csv
# WROTE   818 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2MA_raw.csv
# WROTE  1084 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2SA_raw.csv
# WROTE    80 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_S3Y_raw.csv
# WROTE    96 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_SUS_raw.csv
# WROTE   111 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_LJE_raw.csv
# WROTE   100 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ZEP_raw.csv
# WROTE    78 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_BEL_raw.csv
# WROTE   118 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_PHP_raw.csv
# WROTE  2208 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ISA_raw.csv
# WROTE  1426 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_ACT_raw.csv
# WROTE    56 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2TH_raw.csv
# WROTE   365 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2CO_raw.csv
# WROTE  1140 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JOB_raw.csv
# WROTE    56 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_TIT_raw.csv
# WROTE  1190 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2KI_raw.csv
# WROTE    81 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2PE_raw.csv
# WROTE   159 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_JAS_raw.csv
# WROTE  1015 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_LEV_raw.csv
# WROTE    94 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_2TI_raw.csv
# WROTE   519 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_TOB_raw.csv
# WROTE   206 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_MIC_raw.csv
# WROTE   124 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_COL_raw.csv
# WROTE   650 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_REV_raw.csv
# WROTE   116 rows → by_sentence/trish/sentence/Bikolano/MBBBIK92_MAL_raw.csv
# WROTE   141 rows → by_sentence/trish/sentence/Kalinga/kmk_PHP_raw.csv
# WROTE    29 rows → by_sentence/trish/sentence/Kalinga/kmk_PHM_raw.csv
# WROTE    57 rows → by_sentence/trish/sentence/Kalinga/kmk_JUD_raw.csv
# WROTE   175 rows → by_sentence/trish/sentence/Kalinga/kmk_1JN_raw.csv
# WROTE   245 rows → by_sentence/trish/sentence/Kalinga/kmk_GAL_raw.csv
# WROTE   758 rows → by_sentence/trish/sentence/Kalinga/kmk_REV_raw.csv
# WROTE   146 rows → by_sentence/trish/sentence/Kalinga/kmk_COL_raw.csv
# WROTE   132 rows → by_sentence/trish/sentence/Kalinga/kmk_2TI_raw.csv
# WROTE   181 rows → by_sentence/trish/sentence/Kalinga/kmk_JAS_raw.csv
# WROTE   108 rows → by_sentence/trish/sentence/Kalinga/kmk_2PE_raw.csv
# WROTE    74 rows → by_sentence/trish/sentence/Kalinga/kmk_TIT_raw.csv
# WROTE   441 rows → by_sentence/trish/sentence/Kalinga/kmk_2CO_raw.csv
# WROTE    61 rows → by_sentence/trish/sentence/Kalinga/kmk_2TH_raw.csv
# WROTE  1441 rows → by_sentence/trish/sentence/Kalinga/kmk_ACT_raw.csv
# WROTE   214 rows → by_sentence/trish/sentence/Kalinga/kmk_EPH_raw.csv
# WROTE   175 rows → by_sentence/trish/sentence/Kalinga/kmk_1TI_raw.csv
# WROTE  1514 rows → by_sentence/trish/sentence/Kalinga/kmk_MAT_raw.csv
# WROTE   978 rows → by_sentence/trish/sentence/Kalinga/kmk_MRK_raw.csv
# WROTE   721 rows → by_sentence/trish/sentence/Kalinga/kmk_1CO_raw.csv
# WROTE   135 rows → by_sentence/trish/sentence/Kalinga/kmk_1TH_raw.csv
# WROTE   184 rows → by_sentence/trish/sentence/Kalinga/kmk_1PE_raw.csv
# WROTE    27 rows → by_sentence/trish/sentence/Kalinga/kmk_3JN_raw.csv
# WROTE  1675 rows → by_sentence/trish/sentence/Kalinga/kmk_LUK_raw.csv
# WROTE   707 rows → by_sentence/trish/sentence/Kalinga/kmk_ROM_raw.csv
# WROTE  1242 rows → by_sentence/trish/sentence/Kalinga/kmk_JHN_raw.csv
# WROTE   472 rows → by_sentence/trish/sentence/Kalinga/kmk_HEB_raw.csv
# WROTE    17 rows → by_sentence/trish/sentence/Kalinga/kmk_2JN_raw.csv
# WROTE   103 rows → by_sentence/trish/sentence/Ilokano/RIPV_2PE_raw.csv
# WROTE   198 rows → by_sentence/trish/sentence/Ilokano/RIPV_JAS_raw.csv
# WROTE  1065 rows → by_sentence/trish/sentence/Ilokano/RIPV_LEV_raw.csv
# WROTE  1327 rows → by_sentence/trish/sentence/Ilokano/RIPV_2KI_raw.csv
# WROTE    70 rows → by_sentence/trish/sentence/Ilokano/RIPV_TIT_raw.csv
# WROTE  1265 rows → by_sentence/trish/sentence/Ilokano/RIPV_JOB_raw.csv
# WROTE    71 rows → by_sentence/trish/sentence/Ilokano/RIPV_2TH_raw.csv
# WROTE   457 rows → by_sentence/trish/sentence/Ilokano/RIPV_2CO_raw.csv
# WROTE  1687 rows → by_sentence/trish/sentence/Ilokano/RIPV_ACT_raw.csv
# WROTE  2541 rows → by_sentence/trish/sentence/Ilokano/RIPV_ISA_raw.csv
# WROTE   125 rows → by_sentence/trish/sentence/Ilokano/RIPV_MAL_raw.csv
# WROTE   777 rows → by_sentence/trish/sentence/Ilokano/RIPV_REV_raw.csv
# WROTE   156 rows → by_sentence/trish/sentence/Ilokano/RIPV_COL_raw.csv
# WROTE   248 rows → by_sentence/trish/sentence/Ilokano/RIPV_MIC_raw.csv
# WROTE   132 rows → by_sentence/trish/sentence/Ilokano/RIPV_2TI_raw.csv
# WROTE    35 rows → by_sentence/trish/sentence/Ilokano/RIPV_PHM_raw.csv
# WROTE   323 rows → by_sentence/trish/sentence/Ilokano/RIPV_EZR_raw.csv
# WROTE  2969 rows → by_sentence/trish/sentence/Ilokano/RIPV_PSA_raw.csv
# WROTE   112 rows → by_sentence/trish/sentence/Ilokano/RIPV_HAB_raw.csv
# WROTE   323 rows → by_sentence/trish/sentence/Ilokano/RIPV_EST_raw.csv
# WROTE    53 rows → by_sentence/trish/sentence/Ilokano/RIPV_JUD_raw.csv
# WROTE   422 rows → by_sentence/trish/sentence/Ilokano/RIPV_HOS_raw.csv
# WROTE   238 rows → by_sentence/trish/sentence/Ilokano/RIPV_GAL_raw.csv
# WROTE   167 rows → by_sentence/trish/sentence/Ilokano/RIPV_1JN_raw.csv
# WROTE   306 rows → by_sentence/trish/sentence/Ilokano/RIPV_AMO_raw.csv
# WROTE   274 rows → by_sentence/trish/sentence/Ilokano/RIPV_LAM_raw.csv
# WROTE  1156 rows → by_sentence/trish/sentence/Ilokano/RIPV_1CH_raw.csv
# WROTE   157 rows → by_sentence/trish/sentence/Ilokano/RIPV_PHP_raw.csv
# WROTE   120 rows → by_sentence/trish/sentence/Ilokano/RIPV_ZEP_raw.csv
# WROTE  1331 rows → by_sentence/trish/sentence/Ilokano/RIPV_2SA_raw.csv
# WROTE   138 rows → by_sentence/trish/sentence/Ilokano/RIPV_JOL_raw.csv
# WROTE  1505 rows → by_sentence/trish/sentence/Ilokano/RIPV_JHN_raw.csv
# WROTE  1358 rows → by_sentence/trish/sentence/Ilokano/RIPV_2CH_raw.csv
# WROTE   481 rows → by_sentence/trish/sentence/Ilokano/RIPV_HEB_raw.csv
# WROTE    20 rows → by_sentence/trish/sentence/Ilokano/RIPV_2JN_raw.csv
# WROTE  1401 rows → by_sentence/trish/sentence/Ilokano/RIPV_DEU_raw.csv
# WROTE   749 rows → by_sentence/trish/sentence/Ilokano/RIPV_ROM_raw.csv
# WROTE   179 rows → by_sentence/trish/sentence/Ilokano/RIPV_RUT_raw.csv
# WROTE  2340 rows → by_sentence/trish/sentence/Ilokano/RIPV_EZK_raw.csv
# WROTE   193 rows → by_sentence/trish/sentence/Ilokano/RIPV_SNG_raw.csv
# WROTE  1680 rows → by_sentence/trish/sentence/Ilokano/RIPV_1SA_raw.csv
# WROTE    63 rows → by_sentence/trish/sentence/Ilokano/RIPV_HAG_raw.csv
# WROTE   397 rows → by_sentence/trish/sentence/Ilokano/RIPV_ZEC_raw.csv
# WROTE   144 rows → by_sentence/trish/sentence/Ilokano/RIPV_1TH_raw.csv
# WROTE   710 rows → by_sentence/trish/sentence/Ilokano/RIPV_1CO_raw.csv
# WROTE   930 rows → by_sentence/trish/sentence/Ilokano/RIPV_JOS_raw.csv
# WROTE  1369 rows → by_sentence/trish/sentence/Ilokano/RIPV_1KI_raw.csv
# WROTE    44 rows → by_sentence/trish/sentence/Ilokano/RIPV_OBA_raw.csv
# WROTE  1134 rows → by_sentence/trish/sentence/Ilokano/RIPV_PRO_raw.csv
# WROTE   192 rows → by_sentence/trish/sentence/Ilokano/RIPV_1PE_raw.csv
# WROTE  1750 rows → by_sentence/trish/sentence/Ilokano/RIPV_EXO_raw.csv
# WROTE   103 rows → by_sentence/trish/sentence/Ilokano/RIPV_NAM_raw.csv
# WROTE   387 rows → by_sentence/trish/sentence/Ilokano/RIPV_ECC_raw.csv
# WROTE  1882 rows → by_sentence/trish/sentence/Ilokano/RIPV_LUK_raw.csv
# WROTE    29 rows → by_sentence/trish/sentence/Ilokano/RIPV_3JN_raw.csv
# WROTE  2561 rows → by_sentence/trish/sentence/Ilokano/RIPV_GEN_raw.csv
# WROTE  2747 rows → by_sentence/trish/sentence/Ilokano/RIPV_JER_raw.csv
# WROTE    95 rows → by_sentence/trish/sentence/Ilokano/RIPV_JON_raw.csv
# WROTE  1172 rows → by_sentence/trish/sentence/Ilokano/RIPV_JDG_raw.csv
# WROTE   222 rows → by_sentence/trish/sentence/Ilokano/RIPV_EPH_raw.csv
# WROTE  1670 rows → by_sentence/trish/sentence/Ilokano/RIPV_MAT_raw.csv
# WROTE   161 rows → by_sentence/trish/sentence/Ilokano/RIPV_1TI_raw.csv
# WROTE  1350 rows → by_sentence/trish/sentence/Ilokano/RIPV_NUM_raw.csv
# WROTE  1197 rows → by_sentence/trish/sentence/Ilokano/RIPV_MRK_raw.csv
# WROTE   714 rows → by_sentence/trish/sentence/Ilokano/RIPV_DAN_raw.csv
# WROTE   568 rows → by_sentence/trish/sentence/Ilokano/RIPV_NEH_raw.csv
#
# Done.
# TXT files found:   791
# CSV files written: 791
# Total rows:        458896
